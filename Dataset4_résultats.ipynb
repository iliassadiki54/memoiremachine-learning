# %% [markdown]
# # A : cross validation

# %% [markdown]
# # A1 : edit distance

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d




DOMAIN_FOLDER =r"\\student.fucam.ac.be\users$\isadiki\Downloads\Domain4base\DOMAIN4_CSVcorrigé"

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
print(f"Dossier source : {DOMAIN_FOLDER}")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:

                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2:
                    continue


                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])


                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)


                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration

                df = pd.concat([df, file_df], ignore_index=True)

            except FileNotFoundError:
                continue
            except Exception:
                continue

print(f"Nombre total d'observations chargées : {len(df)}")


for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)



def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f"{axis}_std"] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation des données...")
df = df.groupby(["subject", "gesture", "iter"], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    groups = df_input.groupby(["gesture", "subject", "iter"])

    for (gesture, subject, iteration), group in groups:
        n = len(group)
        if n < 2: continue

        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)

        res_dict = {
            "gesture": [gesture]*target_len,
            "subject": [subject]*target_len,
            "iter": [iteration]*target_len
        }

        for col in ["x_std", "y_std", "z_std"]:
            res_dict[col] = interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame(res_dict))

    return pd.concat(resampled_data, ignore_index=True)

print("Resampling à 100 points...")
df100 = resample_gesture(df)



def edit_distance(s1, s2):
    n, m = len(s1), len(s2)
    M = [[0]*(m+1) for _ in range(n+1)]
    for i in range(n+1): M[i][0] = i
    for j in range(m+1): M[0][j] = j
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            M[i][j] = min(M[i-1][j] + 1, M[i][j-1] + 1, M[i-1][j-1] + cost)
    return M[n][m]

def gesture_to_sequence(df_sym):
    seq_dict = defaultdict(list)
    for (gesture, subject, iteration), group in df_sym.groupby(["gesture", "subject", "iter"]):
        seq = "".join(group["symbol"].tolist())
        seq_dict[gesture].append(seq)
    return seq_dict

def cluster_and_convert(df_train, df_test, k_clusters=50):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = df_train[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def assign_symbols(df_local):
        pts = df_local[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        df_copy = df_local.copy()
        df_copy["symbol"] = symbols
        return df_copy

    return gesture_to_sequence(assign_symbols(df_train)), gesture_to_sequence(assign_symbols(df_test))

def knn_edit_predict(seq, train_dict, k=7):
    distances = []
    for gesture, sequences in train_dict.items():
        for s in sequences:
            d = edit_distance(seq, s)
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]


def dict_creation_userout(df_in, subj_out):
    return df_in[df_in["subject"] != subj_out], df_in[df_in["subject"] == subj_out]

def testmodel(df_target, loop_range=10, k_knn=7, k_clusters=50):
    total_true, total_pred = [], []

    for i in range(1, loop_range + 1):
        print(f"Test sur sujet sorti : {i}")
        train_df, test_df = dict_creation_userout(df_target, i)

        if test_df.empty: continue

        train_seq, test_seq = cluster_and_convert(train_df, test_df, k_clusters)

        y_true, y_pred = [], []
        for gesture, sequences in test_seq.items():
            for seq in sequences:
                pred = knn_edit_predict(seq, train_seq, k=k_knn)
                y_true.append(gesture)
                y_pred.append(pred)

        total_true.extend(y_true)
        total_pred.extend(y_pred)
        print(f"Précision split : {accuracy_score(y_true, y_pred):.2%}")


    print(f"\n=== EXACTITUDE GLOBALE : {accuracy_score(total_true, total_pred):.2%} ===")
    cm = confusion_matrix(total_true, total_pred)
    disp = ConfusionMatrixDisplay(cm)
    disp.plot(cmap="Blues")
    plt.title("Matrice de Confusion")
    plt.show()


testmodel(df100)
# Out:
# --- Début du Chargement ---
# Dossier source : \\student.fucam.ac.be\users$\isadiki\Downloads\Domain4base\DOMAIN4_CSVcorrigé
# C:\Users\Isadiki\AppData\Local\Temp\ipykernel_7712\2306698995.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Nombre total d'observations chargées : 139615
# Standardisation des données...
# C:\Users\Isadiki\AppData\Local\Temp\ipykernel_7712\2306698995.py:73: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(["subject", "gesture", "iter"], group_keys=False).apply(standardize_gesture)
# Resampling à 100 points...
# Test sur sujet sorti : 1
# Précision split : 94.00%
# Test sur sujet sorti : 2
# Précision split : 87.00%
# Test sur sujet sorti : 3
# Précision split : 85.00%
# Test sur sujet sorti : 4
# Précision split : 87.00%
# Test sur sujet sorti : 5
# Précision split : 78.00%
# Test sur sujet sorti : 6
# Précision split : 87.00%
# Test sur sujet sorti : 7
# Précision split : 99.00%
# Test sur sujet sorti : 8
# Précision split : 94.00%
# Test sur sujet sorti : 9
# Précision split : 100.00%
# Test sur sujet sorti : 10
# Précision split : 86.00%
#
# === EXACTITUDE GLOBALE : 89.70% ===

# %% [markdown]
# # A2 : LCSQ

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d




DOMAIN_FOLDER =r"\\student.fucam.ac.be\users$\isadiki\Downloads\Domain4base\DOMAIN4_CSVcorrigé"

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
print(f"Dossier source : {DOMAIN_FOLDER}")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:

                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2:
                    continue


                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])


                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                # Ajout des meta-données
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration

                df = pd.concat([df, file_df], ignore_index=True)

            except FileNotFoundError:
                continue
            except Exception:
                continue


for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Nombre total d'observations chargées : {len(df)}")



def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:

        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation en cours...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'),
            'y_std': interp('y_std'),
            'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling en cours...")
df100 = resample_gesture(df)



def cluster_and_symbolize(train_df, test_df, k_clusters=20):

    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = train_df[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)

        symbols = [chr(ord('A') + (c % 26)) for c in clusters]

        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append("".join(group['symbol'].tolist()))
        return seq_dict

    return to_seq_dict(train_df), to_seq_dict(test_df)


def lcs_length(s1, s2):
    n, m = len(s1), len(s2)
    dp = [[0]*(m+1) for _ in range(n+1)]
    for i in range(1, n+1):
        for j in range(1, m+1):
            if s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1] + 1
            else:
                dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    return dp[n][m]

def lcs_distance(s1, s2):

    return len(s1) + len(s2) - 2 * lcs_length(s1, s2)

def knn_lcs_predict(seq, train_dict, k=3):
    distances = []
    for gesture, sequences in train_dict.items():
        for s in sequences:
            d = lcs_distance(seq, s)
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def testmodel(df_input, loop_range=10, k_knn=3, k_clusters=20):
    total_true, total_pred = [], []

    for i in range(1, loop_range + 1):

        train_df = df_input[df_input["subject"] != i]
        test_df = df_input[df_input["subject"] == i]

        if test_df.empty:
            continue

        print(f"\n--- TEST SUJET SORTI : {i} ---")


        train_dict, test_dict = cluster_and_symbolize(train_df, test_df, k_clusters)

        y_true, y_pred = [], []
        for gesture, sequences in test_dict.items():
            for seq in sequences:
                pred = knn_lcs_predict(seq, train_dict, k=k_knn)
                y_true.append(gesture)
                y_pred.append(pred)

        acc = accuracy_score(y_true, y_pred)
        print(f"Précision sujet {i} : {acc:.2%}")
        total_true.extend(y_true)
        total_pred.extend(y_pred)

    final_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE KNN-LCSS : {final_acc:.2%} ===")


    cm = confusion_matrix(total_true, total_pred)
    disp = ConfusionMatrixDisplay(cm)
    disp.plot(cmap="Blues")
    plt.title("Matrice de confusion – KNN + LCSS (Clustering In-Loop)")
    plt.show()


testmodel(df100)
# Out:
# --- Début du Chargement ---
# Dossier source : \\student.fucam.ac.be\users$\isadiki\Downloads\Domain4base\DOMAIN4_CSVcorrigé
# C:\Users\Isadiki\AppData\Local\Temp\ipykernel_6248\3286419123.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Nombre total d'observations chargées : 139615
# Standardisation en cours...
# C:\Users\Isadiki\AppData\Local\Temp\ipykernel_6248\3286419123.py:74: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling en cours...
#
# --- TEST SUJET SORTI : 1 ---
# Précision sujet 1 : 82.00%
#
# --- TEST SUJET SORTI : 2 ---
# Précision sujet 2 : 77.00%
#
# --- TEST SUJET SORTI : 3 ---
# Précision sujet 3 : 74.00%
#
# --- TEST SUJET SORTI : 4 ---
# Précision sujet 4 : 86.00%
#
# --- TEST SUJET SORTI : 5 ---
# Précision sujet 5 : 77.00%
#
# --- TEST SUJET SORTI : 6 ---
# Précision sujet 6 : 80.00%
#
# --- TEST SUJET SORTI : 7 ---
# Précision sujet 7 : 95.00%
#
# --- TEST SUJET SORTI : 8 ---
# Précision sujet 8 : 86.00%
#
# --- TEST SUJET SORTI : 9 ---
# Précision sujet 9 : 100.00%
#
# --- TEST SUJET SORTI : 10 ---
# Précision sujet 10 : 75.00%
#
# === EXACTITUDE GLOBALE KNN-LCSS : 83.20% ===

# %% [markdown]
# # A3 : transformer

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf




DOMAIN_FOLDER =r"\\student.fucam.ac.be\users$\isadiki\Downloads\Domain4base\DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")
print(f"Dossier source : {DOMAIN_FOLDER}")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:

                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2: continue


                data = file[0].str.strip('"').str.split(',', expand=True)

                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])


                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)


                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration

                df_list.append(file_df)

            except FileNotFoundError:
                continue
            except Exception:
                continue


if not df_list:
    raise ValueError("Aucun fichier n'a pu être chargé. Vérifiez le chemin et le format des fichiers.")

df = pd.concat(df_list, ignore_index=True)


for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Nombre total d'observations chargées : {len(df)}")



grouped = df.groupby(['gesture', 'iter'])
sequence_lengths = grouped.size().reset_index(name='length')
mean_lengths = sequence_lengths.groupby('gesture')['length'].mean().reset_index()
mean_lengths.columns = ['Chiffre', 'Frames moyennes']

plt.figure(figsize=(8, 5))
plt.bar(mean_lengths["Chiffre"], mean_lengths["Frames moyennes"])
plt.title("Nombre moyen de coordonnées par chiffre")
plt.xlabel("Chiffre")
plt.ylabel("Nombre moyen de coordonnées")
plt.xticks(mean_lengths["Chiffre"])
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

durations = df.groupby(['gesture', 'iter'])['t'].agg(lambda x: x.max() - x.min()).reset_index(name='duration')
mean_durations = durations.groupby('gesture')['duration'].mean()
for gesture, mean_dur in mean_durations.items():
    print(f"Chiffre {gesture} : {mean_dur:.2f} s")



def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        if std == 0 or np.isnan(std):
            df_copy[f'{axis}_std'] = 0.0
        else:
            df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)




def resample_gesture(df_in, target_len=100):
    resampled_data = []

    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue

        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'),
            'y_std': interp('y_std'),
            'z_std': interp('z_std')
        }))

    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)




def create_user_independent_split(df_in, subj_out):
    train_df = df_in[df_in['subject'] != subj_out]
    test_df = df_in[df_in['subject'] == subj_out]

    def df_to_array(df_target):
        X, y = [], []
        for (gesture, subject, iteration), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(gesture)
        return np.array(X), np.array(y)

    X_train, y_train = df_to_array(train_df)
    X_test, y_test = df_to_array(test_df)
    return X_train, y_train, X_test, y_test




class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]




def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)

    ffn = models.Sequential([
        layers.Dense(dff, activation="relu"),
        layers.Dense(d_model),
    ])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    out2 = layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)
    return out2

def create_transformer_model(input_shape, num_classes, seq_len=100):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2

    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(seq_len, d_model)(x)

    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)

    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model




def test_transformer_user_independent(df_data, loop_range=10, epochs=50, batch_size=32, verbose_fit=1):
    total_true, total_pred = [], []

    for subj_out in range(1, loop_range + 1):
        if df_data[df_data['subject'] == subj_out].empty: continue

        print(f"\n--- Test subject OUT : {subj_out} ---")
        X_train, y_train, X_test, y_test = create_user_independent_split(df_data, subj_out)

        n_classes = len(np.unique(df_data['gesture']))
        input_shape = (X_train.shape[1], X_train.shape[2])

        model = create_transformer_model(input_shape=input_shape, num_classes=n_classes)
        model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=verbose_fit)

        y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
        acc = accuracy_score(y_test, y_pred)
        print(f"Exactitude subject {subj_out} : {acc:.2%}")

        total_true.extend(y_test)
        total_pred.extend(y_pred)

    final_acc = accuracy_score(total_true, total_pred)
    print(f"\nExactitude globale Transformer : {final_acc:.2%}")

    cm = confusion_matrix(total_true, total_pred)
    disp = ConfusionMatrixDisplay(cm)
    disp.plot(cmap="Blues")
    plt.title("Matrice de confusion – Transformer")
    plt.show()

test_transformer_user_independent(df100, loop_range=10, epochs=50, batch_size=32, verbose_fit=1)
# Out:
# --- 1. Début du Chargement du Domaine 4 ---
# Dossier source : \\student.fucam.ac.be\users$\isadiki\Downloads\Domain4base\DOMAIN4_CSVcorrigé
# Nombre total d'observations chargées : 139615
# Chiffre 0 : 5617.80 s
# Chiffre 1 : 4471.30 s
# Chiffre 2 : 6968.80 s
# Chiffre 3 : 9840.80 s
# Chiffre 4 : 4995.50 s
# Chiffre 5 : 6658.20 s
# Chiffre 6 : 7136.30 s
# Chiffre 7 : 5698.10 s
# Chiffre 8 : 6041.50 s
# Chiffre 9 : 6774.80 s
# C:\Users\Isadiki\AppData\Local\Temp\ipykernel_6284\1615355736.py:108: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# --- Test subject OUT : 1 ---
# WARNING:tensorflow:From \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 13s 217ms/step - accuracy: 0.1011 - loss: 2.4170
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 220ms/step - accuracy: 0.4133 - loss: 1.5941
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 219ms/step - accuracy: 0.7656 - loss: 0.6322
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.8756 - loss: 0.3411
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 227ms/step - accuracy: 0.9189 - loss: 0.2694
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - accuracy: 0.9600 - loss: 0.1469
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 227ms/step - accuracy: 0.9533 - loss: 0.1583
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.9767 - loss: 0.0853
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.9822 - loss: 0.0821
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.9767 - loss: 0.0627
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.9789 - loss: 0.0766
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 226ms/step - accuracy: 0.9822 - loss: 0.0564
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - accuracy: 0.9756 - loss: 0.0923
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9756 - loss: 0.0713
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 225ms/step - accuracy: 0.9778 - loss: 0.0848
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 227ms/step - accuracy: 0.9733 - loss: 0.0977
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9622 - loss: 0.1554
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.9511 - loss: 0.1616
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 225ms/step - accuracy: 0.9844 - loss: 0.0804
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 226ms/step - accuracy: 0.9889 - loss: 0.0499
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 225ms/step - accuracy: 0.9878 - loss: 0.0439
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9811 - loss: 0.0787
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 225ms/step - accuracy: 0.9600 - loss: 0.1301
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.9856 - loss: 0.0510
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - accuracy: 0.9956 - loss: 0.0231
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 227ms/step - accuracy: 0.9944 - loss: 0.0190
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 227ms/step - accuracy: 0.9900 - loss: 0.0392
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 219ms/step - accuracy: 0.9867 - loss: 0.0516
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9922 - loss: 0.0278
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9900 - loss: 0.0294
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9978 - loss: 0.0146
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 226ms/step - accuracy: 0.9989 - loss: 0.0099
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.9989 - loss: 0.0091
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9989 - loss: 0.0089
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9989 - loss: 0.0067
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9989 - loss: 0.0069
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9989 - loss: 0.0075
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9989 - loss: 0.0076
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 224ms/step - accuracy: 0.9989 - loss: 0.0065
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9989 - loss: 0.0070
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 227ms/step - accuracy: 0.9989 - loss: 0.0081
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - accuracy: 0.9989 - loss: 0.0050
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9989 - loss: 0.0062
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9989 - loss: 0.0057
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9967 - loss: 0.0086
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 227ms/step - accuracy: 0.9856 - loss: 0.0393
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9689 - loss: 0.1255
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9433 - loss: 0.2277
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 227ms/step - accuracy: 0.9500 - loss: 0.1589
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9722 - loss: 0.1227
# Exactitude subject 1 : 97.00%
#
# --- Test subject OUT : 2 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 231ms/step - accuracy: 0.1022 - loss: 2.4155
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.2000 - loss: 2.1591
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.7478 - loss: 0.7492
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.8911 - loss: 0.3543
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9256 - loss: 0.2407
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.8767 - loss: 0.4022
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9289 - loss: 0.2164
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9644 - loss: 0.1203
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 230ms/step - accuracy: 0.9578 - loss: 0.1315
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9611 - loss: 0.1252
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9678 - loss: 0.1150
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9744 - loss: 0.0900
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9778 - loss: 0.0871
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9900 - loss: 0.0411
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9856 - loss: 0.0590
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9822 - loss: 0.0724
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9922 - loss: 0.0350
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9911 - loss: 0.0450
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9822 - loss: 0.0528
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9844 - loss: 0.0516
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9100 - loss: 0.3268
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9544 - loss: 0.1706
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9667 - loss: 0.1159
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9844 - loss: 0.0636
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9889 - loss: 0.0328
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9878 - loss: 0.0497
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9833 - loss: 0.0581
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9844 - loss: 0.0468
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9867 - loss: 0.0539
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9800 - loss: 0.0535
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9844 - loss: 0.0451
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9856 - loss: 0.0429
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9933 - loss: 0.0237
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9967 - loss: 0.0156
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9967 - loss: 0.0139
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9911 - loss: 0.0206
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9856 - loss: 0.0604
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 232ms/step - accuracy: 0.9856 - loss: 0.0544
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9900 - loss: 0.0361
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9878 - loss: 0.0492
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9900 - loss: 0.0372
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - accuracy: 0.9944 - loss: 0.0157
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9922 - loss: 0.0281
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9922 - loss: 0.0464
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9911 - loss: 0.0334
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 227ms/step - accuracy: 0.9856 - loss: 0.0667
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 229ms/step - accuracy: 0.9800 - loss: 0.0600
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9311 - loss: 0.2547
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9422 - loss: 0.1810
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - accuracy: 0.9633 - loss: 0.1646
# Exactitude subject 2 : 71.00%
#
# --- Test subject OUT : 3 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 228ms/step - accuracy: 0.1056 - loss: 2.4351
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.3356 - loss: 1.8498
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.7522 - loss: 0.7097
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - accuracy: 0.8222 - loss: 0.4380
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - accuracy: 0.8933 - loss: 0.2687
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.8633 - loss: 0.4159
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9211 - loss: 0.2221
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9400 - loss: 0.1886
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9400 - loss: 0.1612
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9578 - loss: 0.1266
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 227ms/step - accuracy: 0.9222 - loss: 0.2114
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9689 - loss: 0.0971
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9867 - loss: 0.0614
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9867 - loss: 0.0484
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9956 - loss: 0.0223
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9811 - loss: 0.0538
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9778 - loss: 0.0618
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9756 - loss: 0.1023
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9867 - loss: 0.0447
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 229ms/step - accuracy: 0.9733 - loss: 0.0837
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 231ms/step - accuracy: 0.9511 - loss: 0.1520
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9767 - loss: 0.0789
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9889 - loss: 0.0374
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9911 - loss: 0.0267
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9833 - loss: 0.0490
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9989 - loss: 0.0133
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9967 - loss: 0.0130
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9933 - loss: 0.0222
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9967 - loss: 0.0116
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9978 - loss: 0.0079
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9989 - loss: 0.0037
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 1.0000 - loss: 9.1710e-04
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 1.0000 - loss: 9.2726e-04
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 1.0000 - loss: 6.3784e-04
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 1.0000 - loss: 8.2048e-04
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 1.0000 - loss: 5.2689e-04
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 1.0000 - loss: 4.3024e-04
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 1.0000 - loss: 4.9409e-04
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 1.0000 - loss: 3.6140e-04
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 1.0000 - loss: 4.6158e-04
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 2.8564e-04
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 1.0000 - loss: 3.3614e-04
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 1.0000 - loss: 3.7253e-04
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 1.0000 - loss: 2.7902e-04
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 1.0000 - loss: 3.4792e-04
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 1.0000 - loss: 2.3932e-04
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 227ms/step - accuracy: 1.0000 - loss: 2.9634e-04
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - accuracy: 1.0000 - loss: 2.5317e-04
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 1.0000 - loss: 2.7210e-04
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002679FE4AAC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002679FE4AAC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exactitude subject 3 : 94.00%
#
# --- Test subject OUT : 4 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 240ms/step - accuracy: 0.1156 - loss: 2.4321
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.2522 - loss: 2.0696
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.6622 - loss: 0.8952
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.8189 - loss: 0.4738
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.8800 - loss: 0.3091
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9278 - loss: 0.2075
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9078 - loss: 0.2555
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9367 - loss: 0.1774
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9367 - loss: 0.2133
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 0.9611 - loss: 0.1162
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9656 - loss: 0.0938
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9778 - loss: 0.0642
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9756 - loss: 0.0767
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9878 - loss: 0.0452
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 0.9800 - loss: 0.0731
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9844 - loss: 0.0579
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9578 - loss: 0.1457
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9400 - loss: 0.2078
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9689 - loss: 0.1128
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9733 - loss: 0.0994
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9611 - loss: 0.1263
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9822 - loss: 0.0425
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9833 - loss: 0.0540
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9833 - loss: 0.0711
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9911 - loss: 0.0265
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9956 - loss: 0.0174
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9900 - loss: 0.0385
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9978 - loss: 0.0101
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9978 - loss: 0.0094
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9933 - loss: 0.0299
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9978 - loss: 0.0120
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9989 - loss: 0.0087
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.9989 - loss: 0.0068
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.9989 - loss: 0.0056
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9989 - loss: 0.0057
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9989 - loss: 0.0061
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9989 - loss: 0.0069
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9989 - loss: 0.0070
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9989 - loss: 0.0061
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9989 - loss: 0.0064
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9989 - loss: 0.0076
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9989 - loss: 0.0032
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9989 - loss: 0.0020
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9989 - loss: 0.0024
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9856 - loss: 0.0486
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9778 - loss: 0.0817
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9600 - loss: 0.1265
# Exactitude subject 4 : 87.00%
#
# --- Test subject OUT : 5 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - accuracy: 0.1033 - loss: 2.4524
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.4144 - loss: 1.5948
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.7389 - loss: 0.6141
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.8500 - loss: 0.3936
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.7778 - loss: 0.6300
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.8844 - loss: 0.2958
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9467 - loss: 0.1610
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9644 - loss: 0.1118
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9400 - loss: 0.1400
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9333 - loss: 0.1927
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9656 - loss: 0.1221
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9644 - loss: 0.1124
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 229ms/step - accuracy: 0.9689 - loss: 0.0862
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9800 - loss: 0.0895
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9744 - loss: 0.0780
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9767 - loss: 0.0756
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9800 - loss: 0.0582
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9822 - loss: 0.0514
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9911 - loss: 0.0371
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9844 - loss: 0.0470
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9867 - loss: 0.0514
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9556 - loss: 0.1492
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9822 - loss: 0.0586
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 227ms/step - accuracy: 0.9878 - loss: 0.0422
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9922 - loss: 0.0297
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.9867 - loss: 0.0388
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9856 - loss: 0.0720
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.9922 - loss: 0.0334
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9811 - loss: 0.0673
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9833 - loss: 0.0522
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9878 - loss: 0.0385
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9989 - loss: 0.0147
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9978 - loss: 0.0108
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9967 - loss: 0.0079
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 1.0000 - loss: 9.6745e-04
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 1.0000 - loss: 6.4471e-04
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 1.0000 - loss: 7.7516e-04
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 1.0000 - loss: 5.0825e-04
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 1.0000 - loss: 5.7129e-04
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 1.0000 - loss: 5.8929e-04
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 1.0000 - loss: 5.6148e-04
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 1.0000 - loss: 4.3203e-04
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 1.0000 - loss: 3.6024e-04
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 1.0000 - loss: 4.0523e-04
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 1.0000 - loss: 3.4380e-04
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 1.0000 - loss: 3.5628e-04
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 1.0000 - loss: 3.7098e-04
# Exactitude subject 5 : 91.00%
#
# --- Test subject OUT : 6 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 232ms/step - accuracy: 0.1067 - loss: 2.4505
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.3478 - loss: 1.7977
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.7289 - loss: 0.7480
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.8389 - loss: 0.4571
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.8833 - loss: 0.3565
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9178 - loss: 0.2473
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9567 - loss: 0.1468
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9811 - loss: 0.0766
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9722 - loss: 0.0948
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9656 - loss: 0.1044
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9733 - loss: 0.0891
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9800 - loss: 0.0561
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9856 - loss: 0.0530
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9756 - loss: 0.0744
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9533 - loss: 0.1830
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9733 - loss: 0.1220
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9856 - loss: 0.0463
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9944 - loss: 0.0345
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9900 - loss: 0.0346
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9956 - loss: 0.0296
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9989 - loss: 0.0103
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9989 - loss: 0.0095
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9989 - loss: 0.0068
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9989 - loss: 0.0084
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9889 - loss: 0.0288
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9900 - loss: 0.0275
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9556 - loss: 0.1357
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9289 - loss: 0.2470
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9722 - loss: 0.1044
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9856 - loss: 0.0538
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9822 - loss: 0.0566
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9856 - loss: 0.0514
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9922 - loss: 0.0256
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9756 - loss: 0.1029
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9556 - loss: 0.1521
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9789 - loss: 0.0821
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9889 - loss: 0.0396
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9900 - loss: 0.0339
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9889 - loss: 0.0481
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9956 - loss: 0.0247
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9433 - loss: 0.1993
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9744 - loss: 0.0933
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9833 - loss: 0.0639
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9367 - loss: 0.2367
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9700 - loss: 0.1089
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9889 - loss: 0.0511
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9989 - loss: 0.0131
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9989 - loss: 0.0078
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9989 - loss: 0.0071
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9989 - loss: 0.0043
# Exactitude subject 6 : 81.00%
#
# --- Test subject OUT : 7 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 11s 243ms/step - accuracy: 0.0922 - loss: 2.4720
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.1056 - loss: 2.3360
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.2378 - loss: 2.0627
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.7044 - loss: 0.7931
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.8000 - loss: 0.5125
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9089 - loss: 0.2988
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9167 - loss: 0.2368
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9444 - loss: 0.1949
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9678 - loss: 0.1070
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9678 - loss: 0.0883
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9189 - loss: 0.2656
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.9667 - loss: 0.1248
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9767 - loss: 0.0795
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9889 - loss: 0.0549
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9878 - loss: 0.0413
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9656 - loss: 0.1449
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9778 - loss: 0.0811
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9889 - loss: 0.0532
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9889 - loss: 0.0380
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9889 - loss: 0.0423
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.9822 - loss: 0.0552
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9878 - loss: 0.0418
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9822 - loss: 0.0678
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9400 - loss: 0.2108
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9756 - loss: 0.0884
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9856 - loss: 0.0445
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9900 - loss: 0.0460
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9689 - loss: 0.0823
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9900 - loss: 0.0449
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9744 - loss: 0.0700
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9867 - loss: 0.0575
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9644 - loss: 0.1177
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9522 - loss: 0.1597
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9911 - loss: 0.0413
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9500 - loss: 0.2186
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9578 - loss: 0.1485
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9867 - loss: 0.0452
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9978 - loss: 0.0142
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9922 - loss: 0.0233
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9900 - loss: 0.0396
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9922 - loss: 0.0292
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9978 - loss: 0.0123
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9978 - loss: 0.0098
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9989 - loss: 0.0094
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9978 - loss: 0.0118
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9978 - loss: 0.0087
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9978 - loss: 0.0078
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9978 - loss: 0.0075
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9967 - loss: 0.0092
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9978 - loss: 0.0061
# Exactitude subject 7 : 95.00%
#
# --- Test subject OUT : 8 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 233ms/step - accuracy: 0.1278 - loss: 2.4042
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.3933 - loss: 1.6797
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.7967 - loss: 0.5641
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.8967 - loss: 0.2990
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9000 - loss: 0.2705
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9667 - loss: 0.1186
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9633 - loss: 0.1084
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9511 - loss: 0.1519
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.8578 - loss: 0.4317
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.8978 - loss: 0.2184
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9078 - loss: 0.1790
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9333 - loss: 0.1933
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9578 - loss: 0.1706
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9678 - loss: 0.1292
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9811 - loss: 0.0749
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9844 - loss: 0.0487
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9900 - loss: 0.0414
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9667 - loss: 0.0984
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9789 - loss: 0.0739
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9867 - loss: 0.0516
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9689 - loss: 0.0918
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9622 - loss: 0.1165
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9800 - loss: 0.0722
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9844 - loss: 0.0477
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9944 - loss: 0.0347
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9911 - loss: 0.0532
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9944 - loss: 0.0227
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9944 - loss: 0.0255
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9956 - loss: 0.0182
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9889 - loss: 0.0427
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9944 - loss: 0.0199
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9889 - loss: 0.0323
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9978 - loss: 0.0167
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9833 - loss: 0.0594
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9300 - loss: 0.2248
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9622 - loss: 0.1120
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9922 - loss: 0.0381
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9911 - loss: 0.0248
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9978 - loss: 0.0178
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9478 - loss: 0.2247
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9667 - loss: 0.1132
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9756 - loss: 0.0773
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9878 - loss: 0.0490
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9856 - loss: 0.0613
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9878 - loss: 0.0407
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9944 - loss: 0.0234
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9978 - loss: 0.0137
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9978 - loss: 0.0126
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9967 - loss: 0.0153
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9944 - loss: 0.0169
# Exactitude subject 8 : 94.00%
#
# --- Test subject OUT : 9 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 236ms/step - accuracy: 0.1078 - loss: 2.4264
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.3778 - loss: 1.7221
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.7844 - loss: 0.5906
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.8733 - loss: 0.3789
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9167 - loss: 0.2428
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9111 - loss: 0.2790
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9467 - loss: 0.1585
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9622 - loss: 0.1337
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9533 - loss: 0.1598
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9567 - loss: 0.1496
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9689 - loss: 0.0827
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9844 - loss: 0.0467
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9922 - loss: 0.0366
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9900 - loss: 0.0403
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9911 - loss: 0.0267
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9844 - loss: 0.0468
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9989 - loss: 0.0138
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9933 - loss: 0.0342
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9856 - loss: 0.0478
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 0.9889 - loss: 0.0470
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9900 - loss: 0.0290
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9544 - loss: 0.1645
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9611 - loss: 0.1106
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.9644 - loss: 0.1264
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9667 - loss: 0.1031
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9800 - loss: 0.0648
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9800 - loss: 0.0616
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9667 - loss: 0.1372
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9189 - loss: 0.2773
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9744 - loss: 0.0862
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9911 - loss: 0.0323
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9956 - loss: 0.0239
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9922 - loss: 0.0236
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9933 - loss: 0.0292
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9800 - loss: 0.0868
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9911 - loss: 0.0295
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9944 - loss: 0.0240
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9911 - loss: 0.0265
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9844 - loss: 0.0550
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9667 - loss: 0.1162
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9811 - loss: 0.0607
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9911 - loss: 0.0279
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9867 - loss: 0.0405
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9889 - loss: 0.0368
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9622 - loss: 0.1597
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9767 - loss: 0.0947
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9500 - loss: 0.1743
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9844 - loss: 0.0709
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9856 - loss: 0.0504
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9911 - loss: 0.0298
# Exactitude subject 9 : 100.00%
#
# --- Test subject OUT : 10 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 239ms/step - accuracy: 0.1056 - loss: 2.4195
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.3267 - loss: 1.7908
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.7433 - loss: 0.7374
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.8189 - loss: 0.4714
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 0.8767 - loss: 0.3574
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 0.9156 - loss: 0.2225
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.9400 - loss: 0.1953
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.9289 - loss: 0.2128
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9422 - loss: 0.1896
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9333 - loss: 0.1795
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9344 - loss: 0.1659
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9611 - loss: 0.1183
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9678 - loss: 0.1009
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9222 - loss: 0.2644
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9422 - loss: 0.1836
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9400 - loss: 0.2149
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9633 - loss: 0.1450
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9622 - loss: 0.1280
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9600 - loss: 0.1163
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9400 - loss: 0.1470
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9811 - loss: 0.0713
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9756 - loss: 0.0752
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 236ms/step - accuracy: 0.9867 - loss: 0.0660
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9878 - loss: 0.0469
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9500 - loss: 0.1528
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9789 - loss: 0.0824
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 0.9822 - loss: 0.0620
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9700 - loss: 0.0818
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9444 - loss: 0.2191
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9633 - loss: 0.1285
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.8878 - loss: 0.3879
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9411 - loss: 0.1612
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9833 - loss: 0.0640
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9889 - loss: 0.0409
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 232ms/step - accuracy: 0.9911 - loss: 0.0316
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9856 - loss: 0.0546
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9944 - loss: 0.0256
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9911 - loss: 0.0302
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9889 - loss: 0.0416
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9856 - loss: 0.0461
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.9422 - loss: 0.1302
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9756 - loss: 0.0848
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9611 - loss: 0.0927
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9689 - loss: 0.1034
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9733 - loss: 0.1147
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9767 - loss: 0.0702
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9856 - loss: 0.0512
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9744 - loss: 0.0859
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9778 - loss: 0.0866
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9889 - loss: 0.0444
# Exactitude subject 10 : 81.00%
#
# Exactitude globale Transformer : 89.10%

# %% [markdown]
# # A4 : lstm

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers




DOMAIN_FOLDER = r"\\student.fucam.ac.be\users$\isadiki\Downloads\Domain4base\DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")
print(f"Dossier source : {DOMAIN_FOLDER}")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:

                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2: continue


                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])


                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)


                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration

                df_list.append(file_df)

            except (FileNotFoundError, Exception):
                continue


if not df_list:
    raise ValueError("Aucun fichier n'a été chargé. Vérifiez le chemin : " + DOMAIN_FOLDER)

df = pd.concat(df_list, ignore_index=True)


for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f" Nombre total d'observations chargées : {len(df)}")



print("\n--- 2. Analyse Exploratoire ---")
grouped = df.groupby(['gesture', 'iter'])
sequence_lengths = grouped.size().reset_index(name='length')
mean_lengths = sequence_lengths.groupby('gesture')['length'].mean().reset_index()
mean_lengths.columns = ['Chiffre', 'Frames moyennes']

plt.figure(figsize=(8, 5))
plt.bar(mean_lengths["Chiffre"], mean_lengths["Frames moyennes"])
plt.title("Nombre moyen de coordonnées par chiffre")
plt.xlabel("Chiffre")
plt.ylabel("Nombre moyen de coordonnées")
plt.xticks(mean_lengths["Chiffre"])
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

durations = df.groupby(['gesture', 'iter'])['t'].agg(lambda x: x.max() - x.min()).reset_index(name='duration')
mean_durations = durations.groupby('gesture')['duration'].mean()
for gesture, mean_dur in mean_durations.items():
    print(f"Chiffre {gesture} : {mean_dur:.2f} s")



def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        if std == 0 or np.isnan(std):
            df_copy[f'{axis}_std'] = 0.0
        else:
            df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std
    return df_copy

print("\nStandardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'),
            'y_std': interp('y_std'),
            'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling à longueur 100...")
df100 = resample_gesture(df)



def create_user_independent_split(df_in, subj_out):
    train_df = df_in[df_in['subject'] != subj_out]
    test_df = df_in[df_in['subject'] == subj_out]

    def df_to_array(df_target):
        X, y = [], []
        for (gesture, subject, iteration), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(gesture)
        return np.array(X), np.array(y)

    X_train, y_train = df_to_array(train_df)
    X_test, y_test = df_to_array(test_df)
    return X_train, y_train, X_test, y_test



def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, dropout=0.2, input_shape=input_shape),
        layers.LSTM(256, dropout=0.3),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model



def test_lstm_user_independent(df_data, loop_range=10, epochs=50, batch_size=32):
    total_true, total_pred = [], []
    subjects = sorted(df_data['subject'].unique())

    for subj_out in subjects:
        print(f"\n--- Test subject OUT : {subj_out} ---")
        X_train, y_train, X_test, y_test = create_user_independent_split(df_data, subj_out)


        all_labels = np.unique(df_data['gesture'])
        num_classes = int(max(all_labels) + 1)

        model = create_lstm_model(input_shape=(X_train.shape[1], X_train.shape[2]), num_classes=num_classes)


        model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)


        y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
        acc = accuracy_score(y_test, y_pred)
        print(f"Exactitude subject {subj_out} : {acc:.2%}")

        total_true.extend(y_test)
        total_pred.extend(y_pred)

    final_acc = accuracy_score(total_true, total_pred)
    print(f"\nExactitude globale LSTM : {final_acc:.2%}")


    cm = confusion_matrix(total_true, total_pred)
    disp = ConfusionMatrixDisplay(cm)
    disp.plot(cmap="Blues")
    plt.title("Matrice de confusion – LSTM")
    plt.show()


test_lstm_user_independent(df100)
# Out:
# --- 1. Début du Chargement du Domaine 4 ---
# Dossier source : \\student.fucam.ac.be\users$\isadiki\Downloads\Domain4base\DOMAIN4_CSVcorrigé
# ✅ Nombre total d'observations chargées : 139615
#
# --- 2. Analyse Exploratoire ---
# Chiffre 0 : 5617.80 s
# Chiffre 1 : 4471.30 s
# Chiffre 2 : 6968.80 s
# Chiffre 3 : 9840.80 s
# Chiffre 4 : 4995.50 s
# Chiffre 5 : 6658.20 s
# Chiffre 6 : 7136.30 s
# Chiffre 7 : 5698.10 s
# Chiffre 8 : 6041.50 s
# Chiffre 9 : 6774.80 s
#
# Standardisation...
# C:\Users\Isadiki\AppData\Local\Temp\ipykernel_10152\347728140.py:105: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling à longueur 100...
#
# --- Test subject OUT : 1 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 1 : 93.00%
#
# --- Test subject OUT : 2 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 2 : 89.00%
#
# --- Test subject OUT : 3 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000015A9A25B380> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000015A9A25B380> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exactitude subject 3 : 87.00%
#
# --- Test subject OUT : 4 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 4 : 98.00%
#
# --- Test subject OUT : 5 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 5 : 85.00%
#
# --- Test subject OUT : 6 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 6 : 84.00%
#
# --- Test subject OUT : 7 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 7 : 92.00%
#
# --- Test subject OUT : 8 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 8 : 81.00%
#
# --- Test subject OUT : 9 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 9 : 100.00%
#
# --- Test subject OUT : 10 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 10 : 78.00%
#
# Exactitude globale LSTM : 88.70%

# %% [markdown]
# # A5 : DTW

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import interp1d
import seaborn as sns



DOMAIN_FOLDER =  r"\\student.fucam.ac.be\users$\isadiki\Downloads\Domain4base\DOMAIN4_CSVcorrigé"

df_list = []

print("--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:

                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2:
                    continue


                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])


                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)


                file_df['gesture'] = int(number)
                file_df['subject'] = int(subject)
                file_df['iter'] = int(iteration)

                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(" Aucun fichier chargé. Vérifiez le chemin : " + DOMAIN_FOLDER)

df = pd.concat(df_list, ignore_index=True)
for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f" Données chargées : {len(df)} lignes.")



subdf = df.loc[(df['gesture'] == 0) & (df['subject'] == 10) & (df['iter'] == 1)]

if not subdf.empty:
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(subdf['x'], subdf['y'], subdf['z'], c='red', s=20)
    ax.set_title("Visualisation 3D du geste (Sujet 10, Geste 0, Iter 1)")
    ax.set_xlabel('X'); ax.set_ylabel('Y'); ax.set_zlabel('Z')
    plt.show()




durations = df.groupby(['gesture', 'iter'])['t'].agg(lambda x: x.max() - x.min()).reset_index(name='duration')
mean_durations = durations.groupby('gesture')['duration'].mean()
print("\n--- Durée moyenne des gestes (s) ---")
print(mean_durations)


mean_coords_user = df.groupby(['subject', 'gesture'])[['x', 'y', 'z']].mean().reset_index()
mean_coords_global = df.groupby('gesture')[['x', 'y', 'z']].mean().reset_index().rename(
    columns={'x':'x_global', 'y':'y_global', 'z':'z_global'})

merged = pd.merge(mean_coords_user, mean_coords_global, on='gesture')
merged['dist_to_global'] = np.sqrt((merged['x']-merged['x_global'])**2 +
                                   (merged['y']-merged['y_global'])**2 +
                                   (merged['z']-merged['z_global'])**2)

pivot = merged.pivot(index='subject', columns='gesture', values='dist_to_global')
plt.figure(figsize=(10, 6))
sns.heatmap(pivot, annot=True, fmt=".3f", cmap='Blues')
plt.title("Écart entre la moyenne de l'utilisateur et la moyenne globale")
plt.show()



def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def eucl_dist(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def dtw_dist(seq1, seq2):
    n, m = len(seq1), len(seq2)
    dtw = np.full((n+1, m+1), np.inf)
    dtw[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = eucl_dist(seq1[i-1], seq2[j-1])
            dtw[i, j] = cost + min(dtw[i-1, j], dtw[i, j-1], dtw[i-1, j-1])
    return dtw[n, m]

def knn_dtw_predict(reference_seq, train_dict, k=3):
    distances = []
    for gesture, sequences in train_dict.items():
        for seq in sequences:
            dist = dtw_dist(reference_seq, seq)
            distances.append((gesture, dist))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def dict_creation_userout(df, subj_out):
    test_df = df[df["subject"] == subj_out]
    train_df = df[df["subject"] != subj_out]

    dict_train = defaultdict(list)
    dict_test = defaultdict(list)

    for (g, s, it), group in train_df.groupby(["gesture", "subject", "iter"]):
        dict_train[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())
    for (g, s, it), group in test_df.groupby(["gesture", "subject", "iter"]):
        dict_test[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())
    return dict_train, dict_test

def testmodel(DictCreationFunc, df, loop_range=10, k=3):
    total_true, total_pred = [], []
    for i in range(1, loop_range + 1):
        print(f"\n--- Test Split OUT : {i} ---")
        coord_train, coord_test = DictCreationFunc(df, i)
        y_true, y_pred = [], []
        for gesture, sequences in coord_test.items():
            for seq in sequences:
                pred = knn_dtw_predict(seq, coord_train, k=k)
                y_true.append(gesture)
                y_pred.append(pred)

        acc = accuracy_score(y_true, y_pred)
        total_true.extend(y_true); total_pred.extend(y_pred)
        print(f"Précision split {i} : {acc:.2%}")

    print(f"\nPrécision GLOBALE : {accuracy_score(total_true, total_pred):.2%}")
    cm = confusion_matrix(total_true, total_pred)
    ConfusionMatrixDisplay(cm).plot(cmap="Blues")
    plt.title("Matrice de Confusion Finale")
    plt.show()

testmodel(dict_creation_userout, df100, loop_range=10, k=3)
# Out:
# --- Début du Chargement ---
# ✅ Données chargées : 139615 lignes.
# --- Durée moyenne des gestes (s) ---
# gesture
# 0    5617.8
# 1    4471.3
# 2    6968.8
# 3    9840.8
# 4    4995.5
# 5    6658.2
# 6    7136.3
# 7    5698.1
# 8    6041.5
# 9    6774.8
# Name: duration, dtype: float64
# Standardisation...
# C:\Users\Isadiki\AppData\Local\Temp\ipykernel_4996\1890533262.py:112: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling...
#
# --- Test Split OUT : 1 ---
# Précision split 1 : 88.00%
#
# --- Test Split OUT : 2 ---
# Précision split 2 : 90.00%
#
# --- Test Split OUT : 3 ---
# Précision split 3 : 87.00%
#
# --- Test Split OUT : 4 ---
# Précision split 4 : 95.00%
#
# --- Test Split OUT : 5 ---
# Précision split 5 : 85.00%
#
# --- Test Split OUT : 6 ---
# Précision split 6 : 88.00%
#
# --- Test Split OUT : 7 ---
# Précision split 7 : 98.00%
#
# --- Test Split OUT : 8 ---
# Précision split 8 : 86.00%
#
# --- Test Split OUT : 9 ---
# Précision split 9 : 100.00%
#
# --- Test Split OUT : 10 ---
# Précision split 10 : 74.00%
#
# ✅ Précision GLOBALE : 89.10%

# %% [markdown]
# # B : Tests approfondis

# %% [markdown]
# # B1 : LCSQ

# %% [markdown]
# ## lcss cluster 40 knn 3 traine 4 tes 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d



DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")


for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:
                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2:
                    continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration

                df = pd.concat([df, file_df], ignore_index=True)

            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)





def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation en cours...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'),
            'y_std': interp('y_std'),
            'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling en cours...")
df100 = resample_gesture(df)


def cluster_and_symbolize(train_df, test_df, k_clusters=40):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = train_df[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]

        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(train_df), to_seq_dict(test_df)

def lcs_length(s1, s2):
    n, m = len(s1), len(s2)
    dp = [[0]*(m+1) for _ in range(n+1)]
    for i in range(1, n+1):
        for j in range(1, m+1):
            if s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1] + 1
            else:
                dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    return dp[n][m]

def lcs_distance(s1, s2):
    return len(s1) + len(s2) - 2 * lcs_length(s1, s2)

def knn_lcs_predict(seq, train_dict, k=3):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = lcs_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]


def run_experiment_fixed(df_input, k_knn=3, k_clusters=40):
    all_subjects = sorted(df_input['subject'].unique().tolist())

    subject_removed = 3
    print(f"\n>>> CONFIGURATION : Le sujet {subject_removed} est exclu de l'expérience.")

    remaining = [s for s in all_subjects if s != subject_removed]

    train_subjects = remaining[:4]
    test_subjects = remaining[4:]

    print(f"Sujets d'entraînement (Train) : {train_subjects}")
    print(f"Sujets de prédiction (Test)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    train_dict, test_dict = cluster_and_symbolize(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions LCSS (cela peut prendre un moment)...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_lcs_predict(item['seq'], train_dict, k=k_knn)

            total_true.append(gesture)
            total_pred.append(pred)

            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS DÉTAILLÉS PAR SUJET TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE (Sujets {test_subjects}) : {global_acc:.2%} ===")



if not df100.empty:
    run_experiment_fixed(df100)
else:
    print("Erreur : Aucune donnée n'a été chargée.")
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_19389/1502044339.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Standardisation en cours...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_19389/1502044339.py:70: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling en cours...
#
# >>> CONFIGURATION : Le sujet 3 est exclu de l'expérience.
# Sujets d'entraînement (Train) : [1, 2, 4, 5]
# Sujets de prédiction (Test)  : [6, 7, 8, 9, 10]
#
# Calcul des prédictions LCSS (cela peut prendre un moment)...
#
# --- RÉSULTATS DÉTAILLÉS PAR SUJET TEST ---
# Précision Sujet 6 : 67.78%
# Précision Sujet 7 : 85.56%
# Précision Sujet 8 : 83.33%
# Précision Sujet 9 : 90.00%
# Précision Sujet 10 : 80.00%
#
# === EXACTITUDE GLOBALE (Sujets [6, 7, 8, 9, 10]) : 81.33% ===

# %% [markdown]
# ## lcss cluster 40 knn 3 traine 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d



DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)





def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)


def cluster_and_symbolize(train_df, test_df, k_clusters=40):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = train_df[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols
        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(train_df), to_seq_dict(test_df)

def lcs_length(s1, s2):
    n, m = len(s1), len(s2)
    dp = [[0]*(m+1) for _ in range(n+1)]
    for i in range(1, n+1):
        for j in range(1, m+1):
            if s1[i-1] == s2[j-1]: dp[i][j] = dp[i-1][j-1] + 1
            else: dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    return dp[n][m]

def lcs_distance(s1, s2):
    return len(s1) + len(s2) - 2 * lcs_length(s1, s2)

def knn_lcs_predict(seq, train_dict, k=3):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = lcs_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def run_custom_experiment(df_input, k_knn=3, k_clusters=40):
    train_subjects = [6, 7, 8, 9, 10]
    test_subjects = [1, 2, 4, 5]

    print(f"\n>>> CONFIGURATION DEMANDÉE (Sujet 3 exclu) <<<")
    print(f"Sujets d'entraînement (5) : {train_subjects}")
    print(f"Sujets de prédiction (4)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Un des sets est vide. Vérifie le chargement des données.")
        return

    train_dict, test_dict = cluster_and_symbolize(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions LCSS...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_lcs_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)
            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS PAR SUJET DE TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE SUR {len(test_subjects)} SUJETS : {global_acc:.2%} ===")



if not df100.empty:
    run_custom_experiment(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_19389/1209672135.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_19389/1209672135.py:58: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION DEMANDÉE (Sujet 3 exclu) <<<
# Sujets d'entraînement (5) : [6, 7, 8, 9, 10]
# Sujets de prédiction (4)  : [1, 2, 4, 5]
#
# Calcul des prédictions LCSS...
#
# --- RÉSULTATS PAR SUJET DE TEST ---
# Précision Sujet 1 : 76.67%
# Précision Sujet 2 : 75.56%
# Précision Sujet 4 : 77.78%
# Précision Sujet 5 : 70.00%
#
# === EXACTITUDE GLOBALE SUR 4 SUJETS : 75.00% ===

# %% [markdown]
# # lcss cluster 20 knn3 traine 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
print(f"Dossier source : {DOMAIN_FOLDER}")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:
                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2:
                    continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration

                df = pd.concat([df, file_df], ignore_index=True)

            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Nombre total d'observations chargées : {len(df)}")



def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation en cours...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'),
            'y_std': interp('y_std'),
            'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling en cours...")
df100 = resample_gesture(df)



def cluster_and_symbolize(train_df, test_df, k_clusters=20):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = train_df[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]

        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(train_df), to_seq_dict(test_df)

def lcs_length(s1, s2):
    n, m = len(s1), len(s2)
    dp = [[0]*(m+1) for _ in range(n+1)]
    for i in range(1, n+1):
        for j in range(1, m+1):
            if s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1] + 1
            else:
                dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    return dp[n][m]

def lcs_distance(s1, s2):
    return len(s1) + len(s2) - 2 * lcs_length(s1, s2)

def knn_lcs_predict(seq, train_dict, k=3):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = lcs_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]


def run_experiment_fixed(df_input, k_knn=3, k_clusters=20):
    all_subjects = sorted(df_input['subject'].unique().tolist())

    subject_removed = 3
    print(f"\n>>> CONFIGURATION : Le sujet {subject_removed} est exclu de l'expérience.")

    remaining = [s for s in all_subjects if s != subject_removed]

    train_subjects = remaining[:4]
    test_subjects = remaining[4:]

    print(f"Sujets d'entraînement (Train) : {train_subjects}")
    print(f"Sujets de prédiction (Test)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    train_dict, test_dict = cluster_and_symbolize(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions LCSS (cela peut prendre un moment)...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_lcs_predict(item['seq'], train_dict, k=k_knn)

            total_true.append(gesture)
            total_pred.append(pred)

            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS DÉTAILLÉS PAR SUJET TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE (Sujets {test_subjects}) : {global_acc:.2%} ===")



if not df100.empty:
    run_experiment_fixed(df100)
else:
    print("Erreur : Aucune donnée n'a été chargée.")
# Out:
# --- Début du Chargement ---
# Dossier source : /Users/iliassadiki/Downloads/DOMAIN4_CSV
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/3833248958.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Nombre total d'observations chargées : 126156
# Standardisation en cours...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/3833248958.py:70: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling en cours...
#
# >>> CONFIGURATION : Le sujet 3 est exclu de l'expérience.
# Sujets d'entraînement (Train) : [1, 2, 4, 5]
# Sujets de prédiction (Test)  : [6, 7, 8, 9, 10]
#
# Calcul des prédictions LCSS (cela peut prendre un moment)...
#
# --- RÉSULTATS DÉTAILLÉS PAR SUJET TEST ---
# Précision Sujet 6 : 77.78%
# Précision Sujet 7 : 93.33%
# Précision Sujet 8 : 82.22%
# Précision Sujet 9 : 90.00%
# Précision Sujet 10 : 70.00%
#
# === EXACTITUDE GLOBALE (Sujets [6, 7, 8, 9, 10]) : 82.67% ===

# %% [markdown]
# # lcss cluster 20 knn 3 traine 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d



DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")



def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def cluster_and_symbolize(train_df, test_df, k_clusters=20):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = train_df[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols
        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(train_df), to_seq_dict(test_df)

def lcs_length(s1, s2):
    n, m = len(s1), len(s2)
    dp = [[0]*(m+1) for _ in range(n+1)]
    for i in range(1, n+1):
        for j in range(1, m+1):
            if s1[i-1] == s2[j-1]: dp[i][j] = dp[i-1][j-1] + 1
            else: dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    return dp[n][m]

def lcs_distance(s1, s2):
    return len(s1) + len(s2) - 2 * lcs_length(s1, s2)

def knn_lcs_predict(seq, train_dict, k=3):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = lcs_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]


def run_custom_experiment(df_input, k_knn=3, k_clusters=20):
    train_subjects = [6, 7, 8, 9, 10]
    test_subjects = [1, 2, 4, 5]

    print(f"\n>>> CONFIGURATION DEMANDÉE (Sujet 3 exclu) <<<")
    print(f"Sujets d'entraînement (5) : {train_subjects}")
    print(f"Sujets de prédiction (4)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Un des sets est vide. Vérifie le chargement des données.")
        return

    train_dict, test_dict = cluster_and_symbolize(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions LCSS...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_lcs_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)
            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS PAR SUJET DE TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE SUR {len(test_subjects)} SUJETS : {global_acc:.2%} ===")


if not df100.empty:
    run_custom_experiment(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/2868535272.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/2868535272.py:58: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION DEMANDÉE (Sujet 3 exclu) <<<
# Sujets d'entraînement (5) : [6, 7, 8, 9, 10]
# Sujets de prédiction (4)  : [1, 2, 4, 5]
#
# Calcul des prédictions LCSS...
#
# --- RÉSULTATS PAR SUJET DE TEST ---
# Précision Sujet 1 : 78.89%
# Précision Sujet 2 : 81.11%
# Précision Sujet 4 : 76.67%
# Précision Sujet 5 : 80.00%
#
# === EXACTITUDE GLOBALE SUR 4 SUJETS : 79.17% ===

# %% [markdown]
# # lcs cluster 20 knn3 test sujet 3

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")



def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)


def cluster_and_symbolize(train_df, test_df, k_clusters=20):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = train_df[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols
        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(train_df), to_seq_dict(test_df)

def lcs_length(s1, s2):
    n, m = len(s1), len(s2)
    dp = [[0]*(m+1) for _ in range(n+1)]
    for i in range(1, n+1):
        for j in range(1, m+1):
            if s1[i-1] == s2[j-1]: dp[i][j] = dp[i-1][j-1] + 1
            else: dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    return dp[n][m]

def lcs_distance(s1, s2):
    return len(s1) + len(s2) - 2 * lcs_length(s1, s2)

def knn_lcs_predict(seq, train_dict, k=3):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = lcs_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def run_leave_subject_3_out(df_input, k_knn=3, k_clusters=20):
    train_subjects = [1, 2, 4, 5, 6, 7, 8, 9, 10]
    test_subjects = [3]

    print(f"\n>>> CONFIGURATION : TEST SUR SUJET 3 UNIQUEMENT <<<")
    print(f"Sujets d'entraînement (9) : {train_subjects}")
    print(f"Sujet de test (1)         : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Données manquantes pour le sujet 3 ou les autres.")
        return

    train_dict, test_dict = cluster_and_symbolize(train_df, test_df, k_clusters)

    total_true, total_pred = [], []

    print("Calcul des prédictions LCSS pour le sujet 3...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_lcs_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)

    final_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== PRÉCISION FINALE SUR LE SUJET 3 : {final_acc:.2%} ===")



if not df100.empty:
    run_leave_subject_3_out(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/3869766258.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/3869766258.py:58: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION : TEST SUR SUJET 3 UNIQUEMENT <<<
# Sujets d'entraînement (9) : [1, 2, 4, 5, 6, 7, 8, 9, 10]
# Sujet de test (1)         : [3]
#
# Calcul des prédictions LCSS pour le sujet 3...
#
# === PRÉCISION FINALE SUR LE SUJET 3 : 74.44% ===

# %% [markdown]
# # lcss clusyter 50 knn 3 traine 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
print(f"Dossier source : {DOMAIN_FOLDER}")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:
                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2:
                    continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                # Conversion numérique
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration

                df = pd.concat([df, file_df], ignore_index=True)

            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Nombre total d'observations chargées : {len(df)}")


def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation en cours...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'),
            'y_std': interp('y_std'),
            'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling en cours...")
df100 = resample_gesture(df)


def cluster_and_symbolize(train_df, test_df, k_clusters=50):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = train_df[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]

        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(train_df), to_seq_dict(test_df)

def lcs_length(s1, s2):
    n, m = len(s1), len(s2)
    dp = [[0]*(m+1) for _ in range(n+1)]
    for i in range(1, n+1):
        for j in range(1, m+1):
            if s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1] + 1
            else:
                dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    return dp[n][m]

def lcs_distance(s1, s2):
    return len(s1) + len(s2) - 2 * lcs_length(s1, s2)

def knn_lcs_predict(seq, train_dict, k=3):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = lcs_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]


def run_experiment_fixed(df_input, k_knn=3, k_clusters=50):
    all_subjects = sorted(df_input['subject'].unique().tolist())

    subject_removed = 3
    print(f"\n>>> CONFIGURATION : Le sujet {subject_removed} est exclu de l'expérience.")

    remaining = [s for s in all_subjects if s != subject_removed]

    train_subjects = remaining[:4]
    test_subjects = remaining[4:]

    print(f"Sujets d'entraînement (Train) : {train_subjects}")
    print(f"Sujets de prédiction (Test)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    train_dict, test_dict = cluster_and_symbolize(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions LCSS (cela peut prendre un moment)...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_lcs_predict(item['seq'], train_dict, k=k_knn)

            total_true.append(gesture)
            total_pred.append(pred)

            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS DÉTAILLÉS PAR SUJET TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    # Moyenne globale
    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE (Sujets {test_subjects}) : {global_acc:.2%} ===")


if not df100.empty:
    run_experiment_fixed(df100)
else:
    print("Erreur : Aucune donnée n'a été chargée.")
# Out:
# --- Début du Chargement ---
# Dossier source : /Users/iliassadiki/Downloads/DOMAIN4_CSV
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/3605467395.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Nombre total d'observations chargées : 126156
# Standardisation en cours...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/3605467395.py:70: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling en cours...
#
# >>> CONFIGURATION : Le sujet 3 est exclu de l'expérience.
# Sujets d'entraînement (Train) : [1, 2, 4, 5]
# Sujets de prédiction (Test)  : [6, 7, 8, 9, 10]
#
# Calcul des prédictions LCSS (cela peut prendre un moment)...
#
# --- RÉSULTATS DÉTAILLÉS PAR SUJET TEST ---
# Précision Sujet 6 : 68.89%
# Précision Sujet 7 : 88.89%
# Précision Sujet 8 : 80.00%
# Précision Sujet 9 : 91.11%
# Précision Sujet 10 : 71.11%
#
# === EXACTITUDE GLOBALE (Sujets [6, 7, 8, 9, 10]) : 80.00% ===

# %% [markdown]
# # lcss cluster 50 knn 3 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")


def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def cluster_and_symbolize(train_df, test_df, k_clusters=50):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = train_df[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols
        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(train_df), to_seq_dict(test_df)

def lcs_length(s1, s2):
    n, m = len(s1), len(s2)
    dp = [[0]*(m+1) for _ in range(n+1)]
    for i in range(1, n+1):
        for j in range(1, m+1):
            if s1[i-1] == s2[j-1]: dp[i][j] = dp[i-1][j-1] + 1
            else: dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    return dp[n][m]

def lcs_distance(s1, s2):
    return len(s1) + len(s2) - 2 * lcs_length(s1, s2)

def knn_lcs_predict(seq, train_dict, k=3):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = lcs_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def run_custom_experiment(df_input, k_knn=3, k_clusters=50):
    train_subjects = [6, 7, 8, 9, 10]
    test_subjects = [1, 2, 4, 5]

    print(f"\n>>> CONFIGURATION DEMANDÉE (Sujet 3 exclu) <<<")
    print(f"Sujets d'entraînement (5) : {train_subjects}")
    print(f"Sujets de prédiction (4)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Un des sets est vide. Vérifie le chargement des données.")
        return

    train_dict, test_dict = cluster_and_symbolize(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions LCSS...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_lcs_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)
            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS PAR SUJET DE TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE SUR {len(test_subjects)} SUJETS : {global_acc:.2%} ===")


if not df100.empty:
    run_custom_experiment(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/4056542318.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/4056542318.py:58: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION DEMANDÉE (Sujet 3 exclu) <<<
# Sujets d'entraînement (5) : [6, 7, 8, 9, 10]
# Sujets de prédiction (4)  : [1, 2, 4, 5]
#
# Calcul des prédictions LCSS...
#
# --- RÉSULTATS PAR SUJET DE TEST ---
# Précision Sujet 1 : 81.11%
# Précision Sujet 2 : 77.78%
# Précision Sujet 4 : 72.22%
# Précision Sujet 5 : 73.33%
#
# === EXACTITUDE GLOBALE SUR 4 SUJETS : 76.11% ===

# %% [markdown]
# # lcs cluster 20 knn 5 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d



DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
print(f"Dossier source : {DOMAIN_FOLDER}")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:
                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2:
                    continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration

                df = pd.concat([df, file_df], ignore_index=True)

            except (FileNotFoundError, Exception):
                continue

# Conversion finale des types
for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Nombre total d'observations chargées : {len(df)}")



def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation en cours...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'),
            'y_std': interp('y_std'),
            'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling en cours...")
df100 = resample_gesture(df)


def cluster_and_symbolize(train_df, test_df, k_clusters=20):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = train_df[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]

        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(train_df), to_seq_dict(test_df)

def lcs_length(s1, s2):
    n, m = len(s1), len(s2)
    dp = [[0]*(m+1) for _ in range(n+1)]
    for i in range(1, n+1):
        for j in range(1, m+1):
            if s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1] + 1
            else:
                dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    return dp[n][m]

def lcs_distance(s1, s2):
    return len(s1) + len(s2) - 2 * lcs_length(s1, s2)

def knn_lcs_predict(seq, train_dict, k=5):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = lcs_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]


def run_experiment_fixed(df_input, k_knn=5, k_clusters=20):
    all_subjects = sorted(df_input['subject'].unique().tolist())

    # Exclusion manuelle du sujet 3
    subject_removed = 3
    print(f"\n>>> CONFIGURATION : Le sujet {subject_removed} est exclu de l'expérience.")

    remaining = [s for s in all_subjects if s != subject_removed]

    train_subjects = remaining[:4]
    test_subjects = remaining[4:]

    print(f"Sujets d'entraînement (Train) : {train_subjects}")
    print(f"Sujets de prédiction (Test)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    train_dict, test_dict = cluster_and_symbolize(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions LCSS (cela peut prendre un moment)...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_lcs_predict(item['seq'], train_dict, k=k_knn)

            total_true.append(gesture)
            total_pred.append(pred)

            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS DÉTAILLÉS PAR SUJET TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE (Sujets {test_subjects}) : {global_acc:.2%} ===")



if not df100.empty:
    run_experiment_fixed(df100)
else:
    print("Erreur : Aucune donnée n'a été chargée.")
# Out:
# --- Début du Chargement ---
# Dossier source : /Users/iliassadiki/Downloads/DOMAIN4_CSV
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/1820515476.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Nombre total d'observations chargées : 126156
# Standardisation en cours...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/1820515476.py:70: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling en cours...
#
# >>> CONFIGURATION : Le sujet 3 est exclu de l'expérience.
# Sujets d'entraînement (Train) : [1, 2, 4, 5]
# Sujets de prédiction (Test)  : [6, 7, 8, 9, 10]
#
# Calcul des prédictions LCSS (cela peut prendre un moment)...
#
# --- RÉSULTATS DÉTAILLÉS PAR SUJET TEST ---
# Précision Sujet 6 : 78.89%
# Précision Sujet 7 : 92.22%
# Précision Sujet 8 : 81.11%
# Précision Sujet 9 : 88.89%
# Précision Sujet 10 : 70.00%
#
# === EXACTITUDE GLOBALE (Sujets [6, 7, 8, 9, 10]) : 82.22% ===

# %% [markdown]
# # lcs cluster 20 knnn 5 traine 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d



DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")



def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)

def cluster_and_symbolize(train_df, test_df, k_clusters=20):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = train_df[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols
        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(train_df), to_seq_dict(test_df)

def lcs_length(s1, s2):
    n, m = len(s1), len(s2)
    dp = [[0]*(m+1) for _ in range(n+1)]
    for i in range(1, n+1):
        for j in range(1, m+1):
            if s1[i-1] == s2[j-1]: dp[i][j] = dp[i-1][j-1] + 1
            else: dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    return dp[n][m]

def lcs_distance(s1, s2):
    return len(s1) + len(s2) - 2 * lcs_length(s1, s2)

def knn_lcs_predict(seq, train_dict, k=5):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = lcs_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]


def run_custom_experiment(df_input, k_knn=5, k_clusters=20):
    train_subjects = [6, 7, 8, 9, 10]
    test_subjects = [1, 2, 4, 5]

    print(f"\n>>> CONFIGURATION DEMANDÉE (Sujet 3 exclu) <<<")
    print(f"Sujets d'entraînement (5) : {train_subjects}")
    print(f"Sujets de prédiction (4)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Un des sets est vide. Vérifie le chargement des données.")
        return

    train_dict, test_dict = cluster_and_symbolize(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions LCSS...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_lcs_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)
            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS PAR SUJET DE TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE SUR {len(test_subjects)} SUJETS : {global_acc:.2%} ===")



if not df100.empty:
    run_custom_experiment(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/1473148943.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/1473148943.py:58: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION DEMANDÉE (Sujet 3 exclu) <<<
# Sujets d'entraînement (5) : [6, 7, 8, 9, 10]
# Sujets de prédiction (4)  : [1, 2, 4, 5]
#
# Calcul des prédictions LCSS...
#
# --- RÉSULTATS PAR SUJET DE TEST ---
# Précision Sujet 1 : 76.67%
# Précision Sujet 2 : 81.11%
# Précision Sujet 4 : 76.67%
# Précision Sujet 5 : 76.67%
#
# === EXACTITUDE GLOBALE SUR 4 SUJETS : 77.78% ===

# %% [markdown]
# # lcs cluster 20 knn 7 traine 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
print(f"Dossier source : {DOMAIN_FOLDER}")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:
                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2:
                    continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration

                df = pd.concat([df, file_df], ignore_index=True)

            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Nombre total d'observations chargées : {len(df)}")



def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation en cours...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'),
            'y_std': interp('y_std'),
            'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling en cours...")
df100 = resample_gesture(df)



def cluster_and_symbolize(train_df, test_df, k_clusters=20):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = train_df[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]

        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(train_df), to_seq_dict(test_df)

def lcs_length(s1, s2):
    n, m = len(s1), len(s2)
    dp = [[0]*(m+1) for _ in range(n+1)]
    for i in range(1, n+1):
        for j in range(1, m+1):
            if s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1] + 1
            else:
                dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    return dp[n][m]

def lcs_distance(s1, s2):
    return len(s1) + len(s2) - 2 * lcs_length(s1, s2)

def knn_lcs_predict(seq, train_dict, k=7):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = lcs_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def run_experiment_fixed(df_input, k_knn=7, k_clusters=20):
    all_subjects = sorted(df_input['subject'].unique().tolist())

    subject_removed = 3
    print(f"\n>>> CONFIGURATION : Le sujet {subject_removed} est exclu de l'expérience.")

    remaining = [s for s in all_subjects if s != subject_removed]

    train_subjects = remaining[:4]
    test_subjects = remaining[4:]

    print(f"Sujets d'entraînement (Train) : {train_subjects}")
    print(f"Sujets de prédiction (Test)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    train_dict, test_dict = cluster_and_symbolize(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions LCSS (cela peut prendre un moment)...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_lcs_predict(item['seq'], train_dict, k=k_knn)

            total_true.append(gesture)
            total_pred.append(pred)

            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS DÉTAILLÉS PAR SUJET TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE (Sujets {test_subjects}) : {global_acc:.2%} ===")


if not df100.empty:
    run_experiment_fixed(df100)
else:
    print("Erreur : Aucune donnée n'a été chargée.")
# Out:
# --- Début du Chargement ---
# Dossier source : /Users/iliassadiki/Downloads/DOMAIN4_CSV
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/846898797.py:47: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Nombre total d'observations chargées : 126156
# Standardisation en cours...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/846898797.py:70: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling en cours...
#
# >>> CONFIGURATION : Le sujet 3 est exclu de l'expérience.
# Sujets d'entraînement (Train) : [1, 2, 4, 5]
# Sujets de prédiction (Test)  : [6, 7, 8, 9, 10]
#
# Calcul des prédictions LCSS (cela peut prendre un moment)...
#
# --- RÉSULTATS DÉTAILLÉS PAR SUJET TEST ---
# Précision Sujet 6 : 80.00%
# Précision Sujet 7 : 92.22%
# Précision Sujet 8 : 76.67%
# Précision Sujet 9 : 91.11%
# Précision Sujet 10 : 70.00%
#
# === EXACTITUDE GLOBALE (Sujets [6, 7, 8, 9, 10]) : 82.00% ===

# %% [markdown]
# # lcs cluster 20 knn 7 traine 5 tesgt 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")


def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def cluster_and_symbolize(train_df, test_df, k_clusters=20):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = train_df[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols
        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(train_df), to_seq_dict(test_df)

def lcs_length(s1, s2):
    n, m = len(s1), len(s2)
    dp = [[0]*(m+1) for _ in range(n+1)]
    for i in range(1, n+1):
        for j in range(1, m+1):
            if s1[i-1] == s2[j-1]: dp[i][j] = dp[i-1][j-1] + 1
            else: dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    return dp[n][m]

def lcs_distance(s1, s2):
    return len(s1) + len(s2) - 2 * lcs_length(s1, s2)

def knn_lcs_predict(seq, train_dict, k=7):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = lcs_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def run_custom_experiment(df_input, k_knn=7, k_clusters=20):
    train_subjects = [6, 7, 8, 9, 10]
    test_subjects = [1, 2, 4, 5]

    print(f"\n>>> CONFIGURATION DEMANDÉE (Sujet 3 exclu) <<<")
    print(f"Sujets d'entraînement (5) : {train_subjects}")
    print(f"Sujets de prédiction (4)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Un des sets est vide. Vérifie le chargement des données.")
        return

    train_dict, test_dict = cluster_and_symbolize(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions LCSS...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_lcs_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)
            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS PAR SUJET DE TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE SUR {len(test_subjects)} SUJETS : {global_acc:.2%} ===")


if not df100.empty:
    run_custom_experiment(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/1169725343.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_14530/1169725343.py:58: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION DEMANDÉE (Sujet 3 exclu) <<<
# Sujets d'entraînement (5) : [6, 7, 8, 9, 10]
# Sujets de prédiction (4)  : [1, 2, 4, 5]
#
# Calcul des prédictions LCSS...
#
# --- RÉSULTATS PAR SUJET DE TEST ---
# Précision Sujet 1 : 77.78%
# Précision Sujet 2 : 76.67%
# Précision Sujet 4 : 75.56%
# Précision Sujet 5 : 76.67%
#
# === EXACTITUDE GLOBALE SUR 4 SUJETS : 76.67% ===

# %% [markdown]
# # pas de nouvelle combinaison

# %% [markdown]
# # B2 : edit distance

# %% [markdown]
# # edit cluster 40 knn 3 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d



DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")



def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def edit_distance(s1, s2):
    n, m = len(s1), len(s2)
    M = [[0]*(m+1) for _ in range(n+1)]
    for i in range(n+1): M[i][0] = i
    for j in range(m+1): M[0][j] = j
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            M[i][j] = min(M[i-1][j] + 1, M[i][j-1] + 1, M[i-1][j-1] + cost)
    return M[n][m]

def cluster_and_convert(df_train, df_test, k_clusters=40):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = df_train[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(df_train), to_seq_dict(df_test)

def knn_edit_predict(seq, train_dict, k=3):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = edit_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def run_custom_experiment(df_input, k_knn=3, k_clusters=40):
    train_subjects =    [1, 2, 4, 5]
    test_subjects = [6, 7, 8, 9, 10]

    print(f"\n>>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<")
    print(f"Sujets d'entraînement (5) : {train_subjects}")
    print(f"Sujets de prédiction (4)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Un des sets est vide. Vérifie le chargement des données.")
        return

    train_dict, test_dict = cluster_and_convert(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions Edit Distance...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_edit_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)
            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS PAR SUJET DE TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE : {global_acc:.2%} ===")



if not df100.empty:
    run_custom_experiment(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_19389/3932694250.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_19389/3932694250.py:62: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<
# Sujets d'entraînement (5) : [1, 2, 4, 5]
# Sujets de prédiction (4)  : [6, 7, 8, 9, 10]
#
# Calcul des prédictions Edit Distance...
#
# --- RÉSULTATS PAR SUJET DE TEST ---
# Précision Sujet 6 : 64.44%
# Précision Sujet 7 : 88.89%
# Précision Sujet 8 : 85.56%
# Précision Sujet 9 : 93.33%
# Précision Sujet 10 : 76.67%
#
# === EXACTITUDE GLOBALE : 81.78% ===

# %% [markdown]
# # edit cluster 40 knn 3 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d



DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)




def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def edit_distance(s1, s2):
    n, m = len(s1), len(s2)
    M = [[0]*(m+1) for _ in range(n+1)]
    for i in range(n+1): M[i][0] = i
    for j in range(m+1): M[0][j] = j
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            M[i][j] = min(M[i-1][j] + 1, M[i][j-1] + 1, M[i-1][j-1] + cost)
    return M[n][m]

def cluster_and_convert(df_train, df_test, k_clusters=40):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = df_train[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(df_train), to_seq_dict(df_test)

def knn_edit_predict(seq, train_dict, k=3):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = edit_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]


def run_custom_experiment(df_input, k_knn=3, k_clusters=40):
    train_subjects =  [6, 7, 8, 9, 10]
    test_subjects =  [1, 2, 4, 5]

    print(f"\n>>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<")
    print(f"Sujets d'entraînement (5) : {train_subjects}")
    print(f"Sujets de prédiction (4)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Un des sets est vide. Vérifie le chargement des données.")
        return

    train_dict, test_dict = cluster_and_convert(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions Edit Distance...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_edit_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)
            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS PAR SUJET DE TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE : {global_acc:.2%} ===")



if not df100.empty:
    run_custom_experiment(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_19389/2322882190.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_19389/2322882190.py:62: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<
# Sujets d'entraînement (5) : [6, 7, 8, 9, 10]
# Sujets de prédiction (4)  : [1, 2, 4, 5]
#
# Calcul des prédictions Edit Distance...
#
# --- RÉSULTATS PAR SUJET DE TEST ---
# Précision Sujet 1 : 86.67%
# Précision Sujet 2 : 88.89%
# Précision Sujet 4 : 83.33%
# Précision Sujet 5 : 76.67%
#
# === EXACTITUDE GLOBALE : 83.89% ===

# %% [markdown]
# # edit cluster 20 knn 3 test 5 train 4 )

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d



DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")


def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def edit_distance(s1, s2):
    n, m = len(s1), len(s2)
    M = [[0]*(m+1) for _ in range(n+1)]
    for i in range(n+1): M[i][0] = i
    for j in range(m+1): M[0][j] = j
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            M[i][j] = min(M[i-1][j] + 1, M[i][j-1] + 1, M[i-1][j-1] + cost)
    return M[n][m]

def cluster_and_convert(df_train, df_test, k_clusters=20):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = df_train[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(df_train), to_seq_dict(df_test)

def knn_edit_predict(seq, train_dict, k=3):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = edit_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]


def run_custom_experiment(df_input, k_knn=3, k_clusters=20):
    train_subjects =    [1, 2, 4, 5]
    test_subjects = [6, 7, 8, 9, 10]

    print(f"\n>>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<")
    print(f"Sujets d'entraînement (5) : {train_subjects}")
    print(f"Sujets de prédiction (4)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Un des sets est vide. Vérifie le chargement des données.")
        return

    train_dict, test_dict = cluster_and_convert(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions Edit Distance...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_edit_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)
            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS PAR SUJET DE TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE : {global_acc:.2%} ===")



if not df100.empty:
    run_custom_experiment(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/3373129982.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/3373129982.py:62: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<
# Sujets d'entraînement (5) : [1, 2, 4, 5]
# Sujets de prédiction (4)  : [6, 7, 8, 9, 10]
#
# Calcul des prédictions Edit Distance...
#
# --- RÉSULTATS PAR SUJET DE TEST ---
# Précision Sujet 6 : 71.11%
# Précision Sujet 7 : 96.67%
# Précision Sujet 8 : 81.11%
# Précision Sujet 9 : 97.78%
# Précision Sujet 10 : 72.22%
#
# === EXACTITUDE GLOBALE : 83.78% ===

# %% [markdown]
# # edit c luster 20 knn 3 train 5 tezst 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d



DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")


def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def edit_distance(s1, s2):
    n, m = len(s1), len(s2)
    M = [[0]*(m+1) for _ in range(n+1)]
    for i in range(n+1): M[i][0] = i
    for j in range(m+1): M[0][j] = j
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            M[i][j] = min(M[i-1][j] + 1, M[i][j-1] + 1, M[i-1][j-1] + cost)
    return M[n][m]

def cluster_and_convert(df_train, df_test, k_clusters=20):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = df_train[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(df_train), to_seq_dict(df_test)

def knn_edit_predict(seq, train_dict, k=3):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = edit_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def run_custom_experiment(df_input, k_knn=3, k_clusters=20):
    train_subjects =  [6, 7, 8, 9, 10]
    test_subjects =  [1, 2, 4, 5]

    print(f"\n>>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<")
    print(f"Sujets d'entraînement (5) : {train_subjects}")
    print(f"Sujets de prédiction (4)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Un des sets est vide. Vérifie le chargement des données.")
        return

    train_dict, test_dict = cluster_and_convert(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions Edit Distance...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_edit_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)
            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS PAR SUJET DE TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE : {global_acc:.2%} ===")



if not df100.empty:
    run_custom_experiment(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/229263192.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/229263192.py:62: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<
# Sujets d'entraînement (5) : [6, 7, 8, 9, 10]
# Sujets de prédiction (4)  : [1, 2, 4, 5]
#
# Calcul des prédictions Edit Distance...
#
# --- RÉSULTATS PAR SUJET DE TEST ---
# Précision Sujet 1 : 84.44%
# Précision Sujet 2 : 85.56%
# Précision Sujet 4 : 86.67%
# Précision Sujet 5 : 80.00%
#
# === EXACTITUDE GLOBALE : 84.17% ===

# %% [markdown]
# # edit cluster 50 knn3 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d



DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")



def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def edit_distance(s1, s2):
    n, m = len(s1), len(s2)
    M = [[0]*(m+1) for _ in range(n+1)]
    for i in range(n+1): M[i][0] = i
    for j in range(m+1): M[0][j] = j
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            M[i][j] = min(M[i-1][j] + 1, M[i][j-1] + 1, M[i-1][j-1] + cost)
    return M[n][m]

def cluster_and_convert(df_train, df_test, k_clusters=50):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = df_train[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(df_train), to_seq_dict(df_test)

def knn_edit_predict(seq, train_dict, k=3):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = edit_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]


def run_custom_experiment(df_input, k_knn=3, k_clusters=50):
    train_subjects =    [1, 2, 4, 5]
    test_subjects = [6, 7, 8, 9, 10]

    print(f"\n>>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<")
    print(f"Sujets d'entraînement (5) : {train_subjects}")
    print(f"Sujets de prédiction (4)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Un des sets est vide. Vérifie le chargement des données.")
        return

    train_dict, test_dict = cluster_and_convert(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions Edit Distance...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_edit_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)
            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS PAR SUJET DE TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE : {global_acc:.2%} ===")



if not df100.empty:
    run_custom_experiment(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/2590775762.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/2590775762.py:62: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<
# Sujets d'entraînement (5) : [1, 2, 4, 5]
# Sujets de prédiction (4)  : [6, 7, 8, 9, 10]
#
# Calcul des prédictions Edit Distance...
#
# --- RÉSULTATS PAR SUJET DE TEST ---
# Précision Sujet 6 : 76.67%
# Précision Sujet 7 : 95.56%
# Précision Sujet 8 : 78.89%
# Précision Sujet 9 : 95.56%
# Précision Sujet 10 : 72.22%
#
# === EXACTITUDE GLOBALE : 83.78% ===

# %% [markdown]
# # edit cluster 50 knn 3 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d



DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")



def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def edit_distance(s1, s2):
    n, m = len(s1), len(s2)
    M = [[0]*(m+1) for _ in range(n+1)]
    for i in range(n+1): M[i][0] = i
    for j in range(m+1): M[0][j] = j
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            M[i][j] = min(M[i-1][j] + 1, M[i][j-1] + 1, M[i-1][j-1] + cost)
    return M[n][m]

def cluster_and_convert(df_train, df_test, k_clusters=50):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = df_train[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(df_train), to_seq_dict(df_test)

def knn_edit_predict(seq, train_dict, k=3):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = edit_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def run_custom_experiment(df_input, k_knn=3, k_clusters=50):
    train_subjects =  [6, 7, 8, 9, 10]
    test_subjects =  [1, 2, 4, 5]

    print(f"\n>>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<")
    print(f"Sujets d'entraînement (5) : {train_subjects}")
    print(f"Sujets de prédiction (4)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Un des sets est vide. Vérifie le chargement des données.")
        return

    train_dict, test_dict = cluster_and_convert(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions Edit Distance...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_edit_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)
            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS PAR SUJET DE TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE : {global_acc:.2%} ===")



if not df100.empty:
    run_custom_experiment(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/1689217240.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/1689217240.py:62: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<
# Sujets d'entraînement (5) : [6, 7, 8, 9, 10]
# Sujets de prédiction (4)  : [1, 2, 4, 5]
#
# Calcul des prédictions Edit Distance...
#
# --- RÉSULTATS PAR SUJET DE TEST ---
# Précision Sujet 1 : 88.89%
# Précision Sujet 2 : 83.33%
# Précision Sujet 4 : 86.67%
# Précision Sujet 5 : 78.89%
#
# === EXACTITUDE GLOBALE : 84.44% ===

# %% [markdown]
# # edit distznce knn 3 cluster 50 test sur le sujet 3

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d



DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print("--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f"Subject{subject}-{number}-{iteration}.csv")
            try:
                raw_file = pd.read_csv(filename, skiprows=5, header=None)
                if raw_file.empty or raw_file.shape[0] < 2:
                    continue

                data = raw_file[0].str.strip('"').str.split(',', expand=True)

                # On ne garde que les 4 premières colonnes (x, y, z, t)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                # Ajout des métadonnées
                file_df["gesture"] = number
                file_df["subject"] = subject
                file_df["iter"] = iteration

                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")

def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        s = res[axis].std()
        res[f"{axis}_std"] = (res[axis] - res[axis].mean()) / s if s != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(["subject", "gesture", "iter"], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(["gesture", "subject", "iter"]):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            "gesture": [gesture]*target_len,
            "subject": [subject]*target_len,
            "iter": [iteration]*target_len,
            "x_std": interp("x_std"),
            "y_std": interp("y_std"),
            "z_std": interp("z_std")
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def gesture_to_sequence(df_local):
    seq_dict = defaultdict(list)
    for (gesture, subject, iteration), group in df_local.groupby(["gesture", "subject", "iter"]):
        seq = "".join(group["symbol"].tolist())
        seq_dict[gesture].append(seq)
    return seq_dict

def cluster_and_convert(df_train, df_test, k_clusters=50):
    train_points = df_train[['x_std', 'y_std', 'z_std']].values
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    kmeans.fit(train_points)

    def assign_symbols(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        df_res = df_target.copy()
        df_res["symbol"] = symbols
        return df_res

    train_sym = assign_symbols(df_train)
    test_sym = assign_symbols(df_test)

    return gesture_to_sequence(train_sym), gesture_to_sequence(test_sym)

def edit_distance(s1, s2):
    n, m = len(s1), len(s2)
    M = [[0]*(m+1) for _ in range(n+1)]
    for i in range(n+1): M[i][0] = i
    for j in range(m+1): M[0][j] = j
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            M[i][j] = min(M[i-1][j] + 1, M[i][j-1] + 1, M[i-1][j-1] + cost)
    return M[n][m]

def knn_edit_predict(seq, train_dict, k=3):
    distances = []
    for gesture, sequences in train_dict.items():
        for s in sequences:
            d = edit_distance(seq, s)
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]


def run_leave_subject_3_out(df_input, k_knn=3, k_clusters=50):
    train_subjects = [1, 2, 4, 5, 6, 7, 8, 9, 10]
    test_subjects = [3]

    print(f"\n--- CONFIGURATION : LEAVE-SUBJECT-3-OUT ---")
    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Données manquantes pour le test.")
        return

    train_dict, test_dict = cluster_and_convert(train_df, test_df, k_clusters)
    total_true, total_pred = [], []

    print("Calcul des prédictions pour le sujet 3...")
    for gesture, sequences in test_dict.items():
        for seq in sequences:
            pred = knn_edit_predict(seq, train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)

    final_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE SUR LE SUJET 3 : {final_acc:.2%} ===")

if not df100.empty:
    run_leave_subject_3_out(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/575744726.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/575744726.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(["subject", "gesture", "iter"], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# --- CONFIGURATION : LEAVE-SUBJECT-3-OUT ---
# Calcul des prédictions pour le sujet 3...
#
# === EXACTITUDE SUR LE SUJET 3 : 78.89% ===

# %% [markdown]
# #edit dist knn 5 cluster 50 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")



def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def edit_distance(s1, s2):
    n, m = len(s1), len(s2)
    M = [[0]*(m+1) for _ in range(n+1)]
    for i in range(n+1): M[i][0] = i
    for j in range(m+1): M[0][j] = j
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            M[i][j] = min(M[i-1][j] + 1, M[i][j-1] + 1, M[i-1][j-1] + cost)
    return M[n][m]

def cluster_and_convert(df_train, df_test, k_clusters=50):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = df_train[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(df_train), to_seq_dict(df_test)

def knn_edit_predict(seq, train_dict, k=5):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = edit_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def run_custom_experiment(df_input, k_knn=5, k_clusters=50):
    train_subjects =    [1, 2, 4, 5]
    test_subjects = [6, 7, 8, 9, 10]

    print(f"\n>>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<")
    print(f"Sujets d'entraînement (5) : {train_subjects}")
    print(f"Sujets de prédiction (4)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Un des sets est vide. Vérifie le chargement des données.")
        return

    train_dict, test_dict = cluster_and_convert(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions Edit Distance...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_edit_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)
            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS PAR SUJET DE TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE : {global_acc:.2%} ===")



# LANCEMENT
if not df100.empty:
    run_custom_experiment(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/4105012169.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/4105012169.py:62: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<
# Sujets d'entraînement (5) : [1, 2, 4, 5]
# Sujets de prédiction (4)  : [6, 7, 8, 9, 10]
#
# Calcul des prédictions Edit Distance...
#
# --- RÉSULTATS PAR SUJET DE TEST ---
# Précision Sujet 6 : 71.11%
# Précision Sujet 7 : 94.44%
# Précision Sujet 8 : 83.33%
# Précision Sujet 9 : 96.67%
# Précision Sujet 10 : 70.00%
#
# === EXACTITUDE GLOBALE : 83.11% ===

# %% [markdown]
# # eedit cluster 50 knn 5 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d



DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")


def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def edit_distance(s1, s2):
    n, m = len(s1), len(s2)
    M = [[0]*(m+1) for _ in range(n+1)]
    for i in range(n+1): M[i][0] = i
    for j in range(m+1): M[0][j] = j
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            M[i][j] = min(M[i-1][j] + 1, M[i][j-1] + 1, M[i-1][j-1] + cost)
    return M[n][m]

def cluster_and_convert(df_train, df_test, k_clusters=50):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = df_train[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(df_train), to_seq_dict(df_test)

def knn_edit_predict(seq, train_dict, k=5):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = edit_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def run_custom_experiment(df_input, k_knn=5, k_clusters=50):
    train_subjects =  [6, 7, 8, 9, 10]
    test_subjects =  [1, 2, 4, 5]

    print(f"\n>>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<")
    print(f"Sujets d'entraînement (5) : {train_subjects}")
    print(f"Sujets de prédiction (4)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Un des sets est vide. Vérifie le chargement des données.")
        return

    train_dict, test_dict = cluster_and_convert(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions Edit Distance...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_edit_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)
            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS PAR SUJET DE TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE : {global_acc:.2%} ===")



if not df100.empty:
    run_custom_experiment(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/1097578583.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/1097578583.py:62: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<
# Sujets d'entraînement (5) : [6, 7, 8, 9, 10]
# Sujets de prédiction (4)  : [1, 2, 4, 5]
#
# Calcul des prédictions Edit Distance...
#
# --- RÉSULTATS PAR SUJET DE TEST ---
# Précision Sujet 1 : 90.00%
# Précision Sujet 2 : 82.22%
# Précision Sujet 4 : 87.78%
# Précision Sujet 5 : 77.78%
#
# === EXACTITUDE GLOBALE : 84.44% ===

# %% [markdown]
# # edit cluster 50 knn 7 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d



DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")



def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def edit_distance(s1, s2):
    n, m = len(s1), len(s2)
    M = [[0]*(m+1) for _ in range(n+1)]
    for i in range(n+1): M[i][0] = i
    for j in range(m+1): M[0][j] = j
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            M[i][j] = min(M[i-1][j] + 1, M[i][j-1] + 1, M[i-1][j-1] + cost)
    return M[n][m]

def cluster_and_convert(df_train, df_test, k_clusters=50):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = df_train[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(df_train), to_seq_dict(df_test)

def knn_edit_predict(seq, train_dict, k=7):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = edit_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]


def run_custom_experiment(df_input, k_knn=7, k_clusters=50):
    train_subjects =    [1, 2, 4, 5]
    test_subjects = [6, 7, 8, 9, 10]

    print(f"\n>>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<")
    print(f"Sujets d'entraînement (5) : {train_subjects}")
    print(f"Sujets de prédiction (4)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Un des sets est vide. Vérifie le chargement des données.")
        return

    train_dict, test_dict = cluster_and_convert(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions Edit Distance...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_edit_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)
            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS PAR SUJET DE TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE : {global_acc:.2%} ===")



if not df100.empty:
    run_custom_experiment(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/3630555954.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/3630555954.py:62: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<
# Sujets d'entraînement (5) : [1, 2, 4, 5]
# Sujets de prédiction (4)  : [6, 7, 8, 9, 10]
#
# Calcul des prédictions Edit Distance...
#
# --- RÉSULTATS PAR SUJET DE TEST ---
# Précision Sujet 6 : 73.33%
# Précision Sujet 7 : 91.11%
# Précision Sujet 8 : 88.89%
# Précision Sujet 9 : 96.67%
# Précision Sujet 10 : 73.33%
#
# === EXACTITUDE GLOBALE : 84.67% ===

# %% [markdown]
# # edit cluster 50 knn 7 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")


def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def edit_distance(s1, s2):
    n, m = len(s1), len(s2)
    M = [[0]*(m+1) for _ in range(n+1)]
    for i in range(n+1): M[i][0] = i
    for j in range(m+1): M[0][j] = j
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            M[i][j] = min(M[i-1][j] + 1, M[i][j-1] + 1, M[i-1][j-1] + cost)
    return M[n][m]

def cluster_and_convert(df_train, df_test, k_clusters=50):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = df_train[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append({'subj': subj, 'seq': "".join(group['symbol'].tolist())})
        return seq_dict

    return to_seq_dict(df_train), to_seq_dict(df_test)

def knn_edit_predict(seq, train_dict, k=7):
    distances = []
    for gesture, data_list in train_dict.items():
        for item in data_list:
            d = edit_distance(seq, item['seq'])
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def run_custom_experiment(df_input, k_knn=7, k_clusters=50):
    train_subjects =  [6, 7, 8, 9, 10]
    test_subjects =  [1, 2, 4, 5]

    print(f"\n>>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<")
    print(f"Sujets d'entraînement (5) : {train_subjects}")
    print(f"Sujets de prédiction (4)  : {test_subjects}\n")

    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Un des sets est vide. Vérifie le chargement des données.")
        return

    train_dict, test_dict = cluster_and_convert(train_df, test_df, k_clusters)

    total_true, total_pred = [], []
    subject_scores = defaultdict(lambda: {"true": [], "pred": []})

    print("Calcul des prédictions Edit Distance...")
    for gesture, data_list in test_dict.items():
        for item in data_list:
            pred = knn_edit_predict(item['seq'], train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)
            subject_scores[item['subj']]["true"].append(gesture)
            subject_scores[item['subj']]["pred"].append(pred)

    print("\n--- RÉSULTATS PAR SUJET DE TEST ---")
    for s in test_subjects:
        if s in subject_scores:
            acc = accuracy_score(subject_scores[s]["true"], subject_scores[s]["pred"])
            print(f"Précision Sujet {s} : {acc:.2%}")

    global_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE : {global_acc:.2%} ===")




if not df100.empty:
    run_custom_experiment(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/2598453105.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/2598453105.py:62: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# >>> CONFIGURATION EDIT DISTANCE (Sujet 3 exclu) <<<
# Sujets d'entraînement (5) : [6, 7, 8, 9, 10]
# Sujets de prédiction (4)  : [1, 2, 4, 5]
#
# Calcul des prédictions Edit Distance...
#
# --- RÉSULTATS PAR SUJET DE TEST ---
# Précision Sujet 1 : 88.89%
# Précision Sujet 2 : 83.33%
# Précision Sujet 4 : 86.67%
# Précision Sujet 5 : 75.56%
#
# === EXACTITUDE GLOBALE : 83.61% ===

# %% [markdown]
# # edit cluster 50 knn 7 test sur sujet 3

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d



DOMAIN_FOLDER = os.path.expanduser("~/Downloads/DOMAIN4_CSVcorrigé")

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print("--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f"Subject{subject}-{number}-{iteration}.csv")
            try:
                raw_file = pd.read_csv(filename, skiprows=5, header=None)
                if raw_file.empty or raw_file.shape[0] < 2:
                    continue

                data = raw_file[0].str.strip('"').str.split(',', expand=True)

                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df["gesture"] = number
                file_df["subject"] = subject
                file_df["iter"] = iteration

                df = pd.concat([df, file_df], ignore_index=True)
            except (FileNotFoundError, Exception):
                continue

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Observations chargées : {len(df)}")

def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        s = res[axis].std()
        res[f"{axis}_std"] = (res[axis] - res[axis].mean()) / s if s != 0 else 0
    return res

print("Standardisation...")
df = df.groupby(["subject", "gesture", "iter"], group_keys=False).apply(standardize_gesture).reset_index(drop=True)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(["gesture", "subject", "iter"]):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            "gesture": [gesture]*target_len,
            "subject": [subject]*target_len,
            "iter": [iteration]*target_len,
            "x_std": interp("x_std"),
            "y_std": interp("y_std"),
            "z_std": interp("z_std")
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def gesture_to_sequence(df_local):
    seq_dict = defaultdict(list)
    for (gesture, subject, iteration), group in df_local.groupby(["gesture", "subject", "iter"]):
        seq = "".join(group["symbol"].tolist())
        seq_dict[gesture].append(seq)
    return seq_dict

def cluster_and_convert(df_train, df_test, k_clusters=50):
    train_points = df_train[['x_std', 'y_std', 'z_std']].values
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    kmeans.fit(train_points)

    def assign_symbols(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        df_res = df_target.copy()
        df_res["symbol"] = symbols
        return df_res

    train_sym = assign_symbols(df_train)
    test_sym = assign_symbols(df_test)

    return gesture_to_sequence(train_sym), gesture_to_sequence(test_sym)

def edit_distance(s1, s2):
    n, m = len(s1), len(s2)
    M = [[0]*(m+1) for _ in range(n+1)]
    for i in range(n+1): M[i][0] = i
    for j in range(m+1): M[0][j] = j
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            M[i][j] = min(M[i-1][j] + 1, M[i][j-1] + 1, M[i-1][j-1] + cost)
    return M[n][m]

def knn_edit_predict(seq, train_dict, k=7):
    distances = []
    for gesture, sequences in train_dict.items():
        for s in sequences:
            d = edit_distance(seq, s)
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def run_leave_subject_3_out(df_input, k_knn=7, k_clusters=50):
    train_subjects = [1, 2, 4, 5, 6, 7, 8, 9, 10]
    test_subjects = [3]

    print(f"\n--- CONFIGURATION : LEAVE-SUBJECT-3-OUT ---")
    train_df = df_input[df_input["subject"].isin(train_subjects)]
    test_df = df_input[df_input["subject"].isin(test_subjects)]

    if train_df.empty or test_df.empty:
        print("Erreur : Données manquantes pour le test.")
        return

    train_dict, test_dict = cluster_and_convert(train_df, test_df, k_clusters)
    total_true, total_pred = [], []

    print("Calcul des prédictions pour le sujet 3...")
    for gesture, sequences in test_dict.items():
        for seq in sequences:
            pred = knn_edit_predict(seq, train_dict, k=k_knn)
            total_true.append(gesture)
            total_pred.append(pred)

    final_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE SUR LE SUJET 3 : {final_acc:.2%} ===")

if not df100.empty:
    run_leave_subject_3_out(df100)
# Out:
# --- Début du Chargement ---
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/104785346.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Observations chargées : 126156
# Standardisation...
# /var/folders/56/kr59nzt503z0bg38p1nh0wtw0000gn/T/ipykernel_1760/104785346.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(["subject", "gesture", "iter"], group_keys=False).apply(standardize_gesture).reset_index(drop=True)
# Resampling...
#
# --- CONFIGURATION : LEAVE-SUBJECT-3-OUT ---
# Calcul des prédictions pour le sujet 3...
#
# === EXACTITUDE SUR LE SUJET 3 : 82.22% ===

# %% [markdown]
# # pas de nouvelle combinaison découvert

# %% [markdown]
# # B3 : LSTM

# %% [markdown]
# # lstm 64 64 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")

DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(64, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(64),
        layers.Dense(64, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# Décompression terminée !
# --- 1. Début du Chargement du Domaine 4 ---
# /tmp/ipykernel_2763/359121453.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 266ms/step - accuracy: 0.3179 - loss: 2.1886 - val_accuracy: 0.0000e+00 - val_loss: 2.6007
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - accuracy: 0.3765 - loss: 1.7934 - val_accuracy: 0.0000e+00 - val_loss: 3.5046
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.4568 - loss: 1.3782 - val_accuracy: 0.0000e+00 - val_loss: 4.0054
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - accuracy: 0.6080 - loss: 1.0766 - val_accuracy: 0.0000e+00 - val_loss: 4.1949
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - accuracy: 0.6975 - loss: 0.8612 - val_accuracy: 0.0000e+00 - val_loss: 3.9298
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.7932 - loss: 0.7127 - val_accuracy: 0.0000e+00 - val_loss: 4.5008
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.8179 - loss: 0.5797 - val_accuracy: 0.0000e+00 - val_loss: 4.3700
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - accuracy: 0.7840 - loss: 0.5335 - val_accuracy: 0.0000e+00 - val_loss: 3.6609
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - accuracy: 0.8549 - loss: 0.4437 - val_accuracy: 0.0000e+00 - val_loss: 3.4813
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.8611 - loss: 0.3810 - val_accuracy: 0.0000e+00 - val_loss: 3.8261
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.8920 - loss: 0.3112 - val_accuracy: 0.0000e+00 - val_loss: 3.3471
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 289ms/step - accuracy: 0.8951 - loss: 0.3068 - val_accuracy: 0.0000e+00 - val_loss: 3.7358
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 195ms/step - accuracy: 0.9136 - loss: 0.2511 - val_accuracy: 0.0000e+00 - val_loss: 2.7161
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.9198 - loss: 0.2287 - val_accuracy: 0.0556 - val_loss: 3.0932
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 0.9475 - loss: 0.1721 - val_accuracy: 0.1111 - val_loss: 3.0373
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 221ms/step - accuracy: 0.9475 - loss: 0.1627 - val_accuracy: 0.1389 - val_loss: 3.1546
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - accuracy: 0.9383 - loss: 0.1996 - val_accuracy: 0.1944 - val_loss: 3.0318
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9321 - loss: 0.2343 - val_accuracy: 0.2222 - val_loss: 3.2004
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.9198 - loss: 0.2384 - val_accuracy: 0.1667 - val_loss: 3.2032
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 224ms/step - accuracy: 0.9352 - loss: 0.1837 - val_accuracy: 0.3333 - val_loss: 2.8817
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 221ms/step - accuracy: 0.9352 - loss: 0.1827 - val_accuracy: 0.1667 - val_loss: 3.6012
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 255ms/step - accuracy: 0.9383 - loss: 0.1596 - val_accuracy: 0.2222 - val_loss: 3.6008
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.9444 - loss: 0.1833 - val_accuracy: 0.3611 - val_loss: 2.9065
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.9475 - loss: 0.1398 - val_accuracy: 0.1389 - val_loss: 3.9227
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.9444 - loss: 0.1563 - val_accuracy: 0.3889 - val_loss: 3.2082
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.9136 - loss: 0.2037 - val_accuracy: 0.2778 - val_loss: 3.5880
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.9383 - loss: 0.1651 - val_accuracy: 0.1389 - val_loss: 3.8501
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - accuracy: 0.9660 - loss: 0.1035 - val_accuracy: 0.1667 - val_loss: 4.0638
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step - accuracy: 0.9630 - loss: 0.1012 - val_accuracy: 0.1944 - val_loss: 4.3136
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.9444 - loss: 0.1304 - val_accuracy: 0.1944 - val_loss: 3.7442
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9722 - loss: 0.0999 - val_accuracy: 0.1389 - val_loss: 4.1325
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.9691 - loss: 0.0795 - val_accuracy: 0.2222 - val_loss: 3.8724
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.9753 - loss: 0.0729 - val_accuracy: 0.1944 - val_loss: 4.2377
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.9815 - loss: 0.0578 - val_accuracy: 0.1389 - val_loss: 4.6131
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.9475 - loss: 0.1423 - val_accuracy: 0.1944 - val_loss: 3.7483
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9506 - loss: 0.1254 - val_accuracy: 0.1944 - val_loss: 4.1307
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.9383 - loss: 0.1613 - val_accuracy: 0.4722 - val_loss: 2.5677
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.9691 - loss: 0.0908 - val_accuracy: 0.2222 - val_loss: 3.6432
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.9784 - loss: 0.0683 - val_accuracy: 0.1944 - val_loss: 4.1207
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - accuracy: 0.9815 - loss: 0.0570 - val_accuracy: 0.1944 - val_loss: 4.3304
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9938 - loss: 0.0431 - val_accuracy: 0.1944 - val_loss: 4.0941
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9938 - loss: 0.0456 - val_accuracy: 0.1111 - val_loss: 5.1477
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.9907 - loss: 0.0364 - val_accuracy: 0.1944 - val_loss: 3.9659
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9877 - loss: 0.0352 - val_accuracy: 0.2500 - val_loss: 3.9486
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9938 - loss: 0.0297 - val_accuracy: 0.1389 - val_loss: 5.3515
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.9815 - loss: 0.0508 - val_accuracy: 0.3611 - val_loss: 3.1985
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.9969 - loss: 0.0309 - val_accuracy: 0.3056 - val_loss: 3.8628
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9938 - loss: 0.0246 - val_accuracy: 0.2500 - val_loss: 4.5634
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9938 - loss: 0.0298 - val_accuracy: 0.1389 - val_loss: 5.1375
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.9877 - loss: 0.0476 - val_accuracy: 0.3333 - val_loss: 4.3703
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets        : [6, 7, 8, 9, 10]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 6 : 64.44%
# Précision Sujet 7 : 94.44%
# Précision Sujet 8 : 87.78%
# Précision Sujet 9 : 90.00%
# Précision Sujet 10 : 71.11%
# ------------------------------
# MOYENNE GLOBALE TEST : 81.56%
# ------------------------------

# %% [markdown]
# # lstm 64 64 32 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")

DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 3
TRAIN_SUBJECTS =   [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(64, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(64),
        layers.Dense(64, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 3 ---
# /tmp/ipykernel_2763/1035202685.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 133ms/step - accuracy: 0.3531 - loss: 2.1399 - val_accuracy: 0.0000e+00 - val_loss: 2.7277
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - accuracy: 0.4519 - loss: 1.6151 - val_accuracy: 0.0000e+00 - val_loss: 3.6619
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.6444 - loss: 1.1370 - val_accuracy: 0.0000e+00 - val_loss: 4.1637
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.7383 - loss: 0.8071 - val_accuracy: 0.0000e+00 - val_loss: 4.4472
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.8272 - loss: 0.5442 - val_accuracy: 0.0000e+00 - val_loss: 4.5129
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.8790 - loss: 0.4039 - val_accuracy: 0.0000e+00 - val_loss: 3.1772
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.9185 - loss: 0.2743 - val_accuracy: 0.0222 - val_loss: 3.4292
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.9062 - loss: 0.2655 - val_accuracy: 0.2000 - val_loss: 2.7445
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - accuracy: 0.8938 - loss: 0.2866 - val_accuracy: 0.4667 - val_loss: 1.7208
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9556 - loss: 0.1614 - val_accuracy: 0.2667 - val_loss: 2.9352
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - accuracy: 0.9654 - loss: 0.1246 - val_accuracy: 0.2222 - val_loss: 3.0311
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - accuracy: 0.9605 - loss: 0.1157 - val_accuracy: 0.4444 - val_loss: 1.7869
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9654 - loss: 0.1130 - val_accuracy: 0.7556 - val_loss: 1.0098
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.9802 - loss: 0.0632 - val_accuracy: 0.5556 - val_loss: 1.6893
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9728 - loss: 0.0833 - val_accuracy: 0.1778 - val_loss: 3.6170
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.9926 - loss: 0.0613 - val_accuracy: 0.5111 - val_loss: 2.0278
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.9827 - loss: 0.0523 - val_accuracy: 0.2889 - val_loss: 3.8792
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.9827 - loss: 0.0442 - val_accuracy: 0.3556 - val_loss: 3.1588
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9951 - loss: 0.0310 - val_accuracy: 0.3556 - val_loss: 3.1137
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.9901 - loss: 0.0377 - val_accuracy: 0.2444 - val_loss: 3.7786
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - accuracy: 0.9951 - loss: 0.0255 - val_accuracy: 0.5556 - val_loss: 2.1539
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.9975 - loss: 0.0211 - val_accuracy: 0.5556 - val_loss: 2.1282
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.5111 - val_loss: 2.2973
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.6000 - val_loss: 2.0228
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.6000 - val_loss: 2.0786
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.5333 - val_loss: 2.3931
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.5111 - val_loss: 2.5216
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.5333 - val_loss: 2.4226
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.5333 - val_loss: 2.4439
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.5333 - val_loss: 2.4470
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.5556 - val_loss: 2.4001
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.5556 - val_loss: 2.3271
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.6000 - val_loss: 2.3082
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.5778 - val_loss: 2.3600
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.5556 - val_loss: 2.4000
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.6000 - val_loss: 2.3582
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.6222 - val_loss: 2.3133
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.6000 - val_loss: 2.3338
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6000 - val_loss: 2.3583
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5778 - val_loss: 2.3989
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5556 - val_loss: 2.4263
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5333 - val_loss: 2.4299
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5778 - val_loss: 2.4261
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.5778 - val_loss: 2.4386
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.5333 - val_loss: 2.4957
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.5778 - val_loss: 2.4592
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6000 - val_loss: 2.4733
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6000 - val_loss: 2.5051
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6000 - val_loss: 2.4620
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6000 - val_loss: 2.4383
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets        : [1, 2, 4, 5]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 1 : 78.89%
# Précision Sujet 2 : 70.00%
# Précision Sujet 4 : 78.89%
# Précision Sujet 5 : 75.56%
# ------------------------------
# MOYENNE GLOBALE TEST : 75.83%
# ------------------------------

# %% [markdown]
# # lstm 128 64 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")

DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(128, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(128),
        layers.Dense(64, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 ---
# /tmp/ipykernel_2763/2247575032.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 625ms/step - accuracy: 0.3920 - loss: 1.9859 - val_accuracy: 0.0000e+00 - val_loss: 3.8118
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 554ms/step - accuracy: 0.5586 - loss: 1.3019 - val_accuracy: 0.0000e+00 - val_loss: 4.3590
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 461ms/step - accuracy: 0.7222 - loss: 0.9284 - val_accuracy: 0.0000e+00 - val_loss: 4.7107
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 228ms/step - accuracy: 0.7130 - loss: 0.7167 - val_accuracy: 0.0000e+00 - val_loss: 5.2308
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 226ms/step - accuracy: 0.7438 - loss: 0.5931 - val_accuracy: 0.0000e+00 - val_loss: 4.0070
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 348ms/step - accuracy: 0.8056 - loss: 0.4770 - val_accuracy: 0.0000e+00 - val_loss: 3.2676
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 224ms/step - accuracy: 0.8549 - loss: 0.4044 - val_accuracy: 0.0556 - val_loss: 3.1766
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 225ms/step - accuracy: 0.8210 - loss: 0.4410 - val_accuracy: 0.0556 - val_loss: 3.5932
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.8241 - loss: 0.4030 - val_accuracy: 0.0278 - val_loss: 2.9733
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 291ms/step - accuracy: 0.8148 - loss: 0.3684 - val_accuracy: 0.0278 - val_loss: 3.5006
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 274ms/step - accuracy: 0.8642 - loss: 0.3326 - val_accuracy: 0.1667 - val_loss: 2.6253
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 228ms/step - accuracy: 0.9043 - loss: 0.2587 - val_accuracy: 0.0833 - val_loss: 2.6569
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 302ms/step - accuracy: 0.9259 - loss: 0.2296 - val_accuracy: 0.2778 - val_loss: 2.5194
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9198 - loss: 0.1847 - val_accuracy: 0.3333 - val_loss: 2.5445
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 314ms/step - accuracy: 0.9537 - loss: 0.1545 - val_accuracy: 0.3333 - val_loss: 2.3971
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 224ms/step - accuracy: 0.9383 - loss: 0.2095 - val_accuracy: 0.4167 - val_loss: 2.3514
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 227ms/step - accuracy: 0.9444 - loss: 0.1814 - val_accuracy: 0.4722 - val_loss: 2.5103
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 227ms/step - accuracy: 0.9290 - loss: 0.1770 - val_accuracy: 0.3611 - val_loss: 2.2651
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 327ms/step - accuracy: 0.9537 - loss: 0.1670 - val_accuracy: 0.5000 - val_loss: 2.3584
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.9537 - loss: 0.1443 - val_accuracy: 0.5278 - val_loss: 2.6562
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 224ms/step - accuracy: 0.9074 - loss: 0.2191 - val_accuracy: 0.4722 - val_loss: 2.6298
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 226ms/step - accuracy: 0.9475 - loss: 0.1411 - val_accuracy: 0.4722 - val_loss: 2.3944
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 227ms/step - accuracy: 0.9660 - loss: 0.0920 - val_accuracy: 0.5278 - val_loss: 2.3102
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 358ms/step - accuracy: 0.9630 - loss: 0.1172 - val_accuracy: 0.5278 - val_loss: 2.1730
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - accuracy: 0.9660 - loss: 0.0925 - val_accuracy: 0.4444 - val_loss: 2.2894
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - accuracy: 0.9630 - loss: 0.1257 - val_accuracy: 0.3889 - val_loss: 2.9801
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.9383 - loss: 0.1379 - val_accuracy: 0.3333 - val_loss: 2.5335
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 343ms/step - accuracy: 0.9259 - loss: 0.1750 - val_accuracy: 0.4167 - val_loss: 2.9402
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - accuracy: 0.9753 - loss: 0.0736 - val_accuracy: 0.3611 - val_loss: 2.5658
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 228ms/step - accuracy: 0.8704 - loss: 0.4988 - val_accuracy: 0.2500 - val_loss: 3.3084
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 227ms/step - accuracy: 0.8086 - loss: 0.4389 - val_accuracy: 0.0000e+00 - val_loss: 5.3888
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 227ms/step - accuracy: 0.9074 - loss: 0.3287 - val_accuracy: 0.1944 - val_loss: 2.9725
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 341ms/step - accuracy: 0.9599 - loss: 0.1444 - val_accuracy: 0.3056 - val_loss: 2.3579
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 228ms/step - accuracy: 0.9630 - loss: 0.1271 - val_accuracy: 0.1667 - val_loss: 3.6324
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 262ms/step - accuracy: 0.9660 - loss: 0.1175 - val_accuracy: 0.1944 - val_loss: 3.1506
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 226ms/step - accuracy: 0.9722 - loss: 0.1027 - val_accuracy: 0.1944 - val_loss: 2.9318
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 352ms/step - accuracy: 0.9815 - loss: 0.0777 - val_accuracy: 0.2222 - val_loss: 2.9052
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 223ms/step - accuracy: 0.9846 - loss: 0.0540 - val_accuracy: 0.3056 - val_loss: 2.5302
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 230ms/step - accuracy: 0.9537 - loss: 0.1445 - val_accuracy: 0.4167 - val_loss: 2.3744
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step - accuracy: 0.9444 - loss: 0.1369 - val_accuracy: 0.1389 - val_loss: 3.9096
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 343ms/step - accuracy: 0.9815 - loss: 0.0791 - val_accuracy: 0.1389 - val_loss: 3.3513
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 225ms/step - accuracy: 0.9722 - loss: 0.0830 - val_accuracy: 0.1944 - val_loss: 3.2717
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 230ms/step - accuracy: 0.9815 - loss: 0.0821 - val_accuracy: 0.2778 - val_loss: 2.9825
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - accuracy: 0.9969 - loss: 0.0419 - val_accuracy: 0.2778 - val_loss: 3.3645
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 312ms/step - accuracy: 0.9969 - loss: 0.0297 - val_accuracy: 0.3611 - val_loss: 3.0507
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.9938 - loss: 0.0267 - val_accuracy: 0.3333 - val_loss: 3.0529
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 226ms/step - accuracy: 0.9969 - loss: 0.0223 - val_accuracy: 0.3889 - val_loss: 3.0287
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 224ms/step - accuracy: 0.9907 - loss: 0.0277 - val_accuracy: 0.3056 - val_loss: 3.3686
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 226ms/step - accuracy: 0.9938 - loss: 0.0227 - val_accuracy: 0.3056 - val_loss: 3.6503
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 359ms/step - accuracy: 0.9969 - loss: 0.0179 - val_accuracy: 0.3056 - val_loss: 3.9018
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets        : [6, 7, 8, 9, 10]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 6 : 66.67%
# Précision Sujet 7 : 90.00%
# Précision Sujet 8 : 88.89%
# Précision Sujet 9 : 82.22%
# Précision Sujet 10 : 68.89%
# ------------------------------
# MOYENNE GLOBALE TEST : 79.33%
# ------------------------------

# %% [markdown]
# # lstm 128 64 32 train 5 tets 4

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")

DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 3
TRAIN_SUBJECTS =   [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(128, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(128),
        layers.Dense(64, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 3 ---
# /tmp/ipykernel_2763/703450814.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 270ms/step - accuracy: 0.4099 - loss: 1.9563 - val_accuracy: 0.0000e+00 - val_loss: 3.3977
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - accuracy: 0.6494 - loss: 1.0664 - val_accuracy: 0.0000e+00 - val_loss: 3.1435
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 309ms/step - accuracy: 0.8247 - loss: 0.5729 - val_accuracy: 0.0000e+00 - val_loss: 5.5461
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.8346 - loss: 0.4172 - val_accuracy: 0.2889 - val_loss: 2.7662
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.8469 - loss: 0.3735 - val_accuracy: 0.1556 - val_loss: 2.6448
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 299ms/step - accuracy: 0.9062 - loss: 0.2561 - val_accuracy: 0.4222 - val_loss: 1.6872
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 273ms/step - accuracy: 0.9457 - loss: 0.1871 - val_accuracy: 0.4444 - val_loss: 2.0302
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9531 - loss: 0.1400 - val_accuracy: 0.4444 - val_loss: 2.6260
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9679 - loss: 0.1052 - val_accuracy: 0.5556 - val_loss: 1.7730
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 348ms/step - accuracy: 0.9556 - loss: 0.1432 - val_accuracy: 0.6000 - val_loss: 1.3077
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9580 - loss: 0.1167 - val_accuracy: 0.3556 - val_loss: 2.5413
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - accuracy: 0.9679 - loss: 0.1050 - val_accuracy: 0.5778 - val_loss: 2.0875
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 301ms/step - accuracy: 0.9605 - loss: 0.1093 - val_accuracy: 0.4889 - val_loss: 2.4376
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 233ms/step - accuracy: 0.9704 - loss: 0.0709 - val_accuracy: 0.3111 - val_loss: 3.0259
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9679 - loss: 0.0790 - val_accuracy: 0.4222 - val_loss: 1.9794
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 304ms/step - accuracy: 0.9877 - loss: 0.0389 - val_accuracy: 0.5333 - val_loss: 2.2050
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 238ms/step - accuracy: 0.9926 - loss: 0.0254 - val_accuracy: 0.0667 - val_loss: 4.5509
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.9753 - loss: 0.0552 - val_accuracy: 0.6889 - val_loss: 1.4870
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9827 - loss: 0.0759 - val_accuracy: 0.5333 - val_loss: 3.0397
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - accuracy: 0.9679 - loss: 0.1073 - val_accuracy: 0.3333 - val_loss: 2.9356
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 237ms/step - accuracy: 0.9654 - loss: 0.0912 - val_accuracy: 0.6667 - val_loss: 1.1382
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 304ms/step - accuracy: 0.9827 - loss: 0.0481 - val_accuracy: 0.5778 - val_loss: 1.8020
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9827 - loss: 0.0618 - val_accuracy: 0.5556 - val_loss: 1.5517
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - accuracy: 0.9877 - loss: 0.0385 - val_accuracy: 0.6444 - val_loss: 1.3210
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 306ms/step - accuracy: 0.9951 - loss: 0.0209 - val_accuracy: 0.6222 - val_loss: 1.8054
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 257ms/step - accuracy: 0.9852 - loss: 0.0739 - val_accuracy: 0.6889 - val_loss: 2.0648
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9877 - loss: 0.0444 - val_accuracy: 0.4444 - val_loss: 2.7183
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 232ms/step - accuracy: 0.9951 - loss: 0.0271 - val_accuracy: 0.6667 - val_loss: 1.8541
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 339ms/step - accuracy: 0.9802 - loss: 0.0357 - val_accuracy: 0.5778 - val_loss: 2.4945
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9827 - loss: 0.0493 - val_accuracy: 0.5778 - val_loss: 2.1202
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - accuracy: 0.9926 - loss: 0.0237 - val_accuracy: 0.4889 - val_loss: 2.3850
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.9951 - loss: 0.0224 - val_accuracy: 0.6444 - val_loss: 1.6380
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - accuracy: 0.9975 - loss: 0.0087 - val_accuracy: 0.4222 - val_loss: 2.9210
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - accuracy: 0.9827 - loss: 0.0649 - val_accuracy: 0.5778 - val_loss: 2.0071
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - accuracy: 0.9531 - loss: 0.1562 - val_accuracy: 0.3111 - val_loss: 3.0288
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 347ms/step - accuracy: 0.9605 - loss: 0.1462 - val_accuracy: 0.8222 - val_loss: 0.9866
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.9802 - loss: 0.0567 - val_accuracy: 0.7111 - val_loss: 0.9802
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9926 - loss: 0.0286 - val_accuracy: 0.6889 - val_loss: 1.5300
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - accuracy: 0.9951 - loss: 0.0141 - val_accuracy: 0.6444 - val_loss: 2.0980
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 347ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.6667 - val_loss: 2.1780
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 252ms/step - accuracy: 0.9975 - loss: 0.0135 - val_accuracy: 0.5111 - val_loss: 2.4126
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.9975 - loss: 0.0089 - val_accuracy: 0.6889 - val_loss: 1.5527
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 382ms/step - accuracy: 0.9951 - loss: 0.0155 - val_accuracy: 0.6667 - val_loss: 1.7564
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - accuracy: 0.9951 - loss: 0.0134 - val_accuracy: 0.5556 - val_loss: 2.5461
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.9975 - loss: 0.0062 - val_accuracy: 0.6667 - val_loss: 2.2252
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 287ms/step - accuracy: 0.9975 - loss: 0.0092 - val_accuracy: 0.4444 - val_loss: 3.1504
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 319ms/step - accuracy: 0.9901 - loss: 0.0361 - val_accuracy: 0.6889 - val_loss: 1.6398
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 0.9901 - loss: 0.0307 - val_accuracy: 0.4667 - val_loss: 1.9815
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 267ms/step - accuracy: 0.9926 - loss: 0.0268 - val_accuracy: 0.5778 - val_loss: 1.4528
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.9901 - loss: 0.0203 - val_accuracy: 0.6889 - val_loss: 1.7380
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets        : [1, 2, 4, 5]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 1 : 75.56%
# Précision Sujet 2 : 67.78%
# Précision Sujet 4 : 87.78%
# Précision Sujet 5 : 76.67%
# ------------------------------
# MOYENNE GLOBALE TEST : 76.94%
# ------------------------------

# %% [markdown]
# # lstm 256 64 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")

DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dropout(0.3),
        layers.Dense(64, activation='relu'),
         layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 ---
# /tmp/ipykernel_2763/4062840826.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 844ms/step - accuracy: 0.3488 - loss: 1.8873 - val_accuracy: 0.0000e+00 - val_loss: 4.5130
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 782ms/step - accuracy: 0.5340 - loss: 1.2275 - val_accuracy: 0.0000e+00 - val_loss: 3.5809
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 650ms/step - accuracy: 0.5679 - loss: 1.0130 - val_accuracy: 0.0000e+00 - val_loss: 3.8834
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 767ms/step - accuracy: 0.6667 - loss: 0.7999 - val_accuracy: 0.0000e+00 - val_loss: 3.2614
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 718ms/step - accuracy: 0.7284 - loss: 0.6165 - val_accuracy: 0.0000e+00 - val_loss: 3.4730
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 666ms/step - accuracy: 0.7716 - loss: 0.5387 - val_accuracy: 0.0000e+00 - val_loss: 3.3656
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 789ms/step - accuracy: 0.8056 - loss: 0.4720 - val_accuracy: 0.0000e+00 - val_loss: 3.4795
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 785ms/step - accuracy: 0.7716 - loss: 0.5786 - val_accuracy: 0.0000e+00 - val_loss: 3.8093
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 688ms/step - accuracy: 0.8241 - loss: 0.4999 - val_accuracy: 0.0000e+00 - val_loss: 3.8866
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 821ms/step - accuracy: 0.8580 - loss: 0.3677 - val_accuracy: 0.1111 - val_loss: 2.6428
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 791ms/step - accuracy: 0.8981 - loss: 0.2582 - val_accuracy: 0.0556 - val_loss: 3.1064
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 686ms/step - accuracy: 0.9475 - loss: 0.1977 - val_accuracy: 0.1667 - val_loss: 3.0967
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 681ms/step - accuracy: 0.8827 - loss: 0.3880 - val_accuracy: 0.2222 - val_loss: 3.5165
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 811ms/step - accuracy: 0.8735 - loss: 0.3197 - val_accuracy: 0.0556 - val_loss: 4.4308
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 805ms/step - accuracy: 0.8951 - loss: 0.2669 - val_accuracy: 0.2222 - val_loss: 3.2164
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 687ms/step - accuracy: 0.8796 - loss: 0.3331 - val_accuracy: 0.2222 - val_loss: 3.5227
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 676ms/step - accuracy: 0.9290 - loss: 0.2307 - val_accuracy: 0.3611 - val_loss: 2.8019
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 753ms/step - accuracy: 0.9352 - loss: 0.1802 - val_accuracy: 0.1111 - val_loss: 4.2348
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 818ms/step - accuracy: 0.9568 - loss: 0.1519 - val_accuracy: 0.3611 - val_loss: 3.2581
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 690ms/step - accuracy: 0.9506 - loss: 0.1609 - val_accuracy: 0.1944 - val_loss: 4.2865
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 763ms/step - accuracy: 0.9136 - loss: 0.1928 - val_accuracy: 0.3889 - val_loss: 3.2528
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 815ms/step - accuracy: 0.9414 - loss: 0.1825 - val_accuracy: 0.3056 - val_loss: 3.8505
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 758ms/step - accuracy: 0.9722 - loss: 0.1334 - val_accuracy: 0.3333 - val_loss: 3.4665
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 670ms/step - accuracy: 0.9722 - loss: 0.0887 - val_accuracy: 0.2778 - val_loss: 4.4283
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 802ms/step - accuracy: 0.9815 - loss: 0.0663 - val_accuracy: 0.2778 - val_loss: 3.8457
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 798ms/step - accuracy: 0.9846 - loss: 0.0701 - val_accuracy: 0.3056 - val_loss: 3.6571
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 675ms/step - accuracy: 0.9846 - loss: 0.0596 - val_accuracy: 0.0833 - val_loss: 5.2352
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 794ms/step - accuracy: 0.9753 - loss: 0.0886 - val_accuracy: 0.4722 - val_loss: 2.5030
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 820ms/step - accuracy: 0.9383 - loss: 0.1883 - val_accuracy: 0.2222 - val_loss: 4.8384
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 678ms/step - accuracy: 0.9753 - loss: 0.0984 - val_accuracy: 0.2778 - val_loss: 4.3433
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 756ms/step - accuracy: 0.9599 - loss: 0.1098 - val_accuracy: 0.3333 - val_loss: 4.3349
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 779ms/step - accuracy: 0.9506 - loss: 0.1442 - val_accuracy: 0.3889 - val_loss: 3.3410
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 658ms/step - accuracy: 0.9630 - loss: 0.0955 - val_accuracy: 0.1944 - val_loss: 4.0033
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 783ms/step - accuracy: 0.9784 - loss: 0.0891 - val_accuracy: 0.4444 - val_loss: 2.9938
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 741ms/step - accuracy: 0.9877 - loss: 0.0519 - val_accuracy: 0.3889 - val_loss: 3.8770
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 708ms/step - accuracy: 0.9907 - loss: 0.0300 - val_accuracy: 0.3611 - val_loss: 3.7626
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 779ms/step - accuracy: 0.9938 - loss: 0.0304 - val_accuracy: 0.3056 - val_loss: 4.4904
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 711ms/step - accuracy: 0.9846 - loss: 0.0618 - val_accuracy: 0.1944 - val_loss: 5.1968
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 703ms/step - accuracy: 0.9815 - loss: 0.0600 - val_accuracy: 0.5556 - val_loss: 2.1861
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 792ms/step - accuracy: 0.9784 - loss: 0.0601 - val_accuracy: 0.2222 - val_loss: 3.4129
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 725ms/step - accuracy: 0.9722 - loss: 0.1003 - val_accuracy: 0.1667 - val_loss: 4.6279
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 676ms/step - accuracy: 0.9259 - loss: 0.2384 - val_accuracy: 0.1667 - val_loss: 5.0335
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 788ms/step - accuracy: 0.8673 - loss: 0.4019 - val_accuracy: 0.2222 - val_loss: 3.9736
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 821ms/step - accuracy: 0.8519 - loss: 0.4118 - val_accuracy: 0.0833 - val_loss: 4.9484
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9012 - loss: 0.3556 - val_accuracy: 0.2778 - val_loss: 2.6863
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9414 - loss: 0.1909 - val_accuracy: 0.3333 - val_loss: 2.9267
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 16s 747ms/step - accuracy: 0.9167 - loss: 0.1683 - val_accuracy: 0.4722 - val_loss: 2.3600
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 651ms/step - accuracy: 0.9444 - loss: 0.1377 - val_accuracy: 0.3611 - val_loss: 2.9006
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 777ms/step - accuracy: 0.9660 - loss: 0.1185 - val_accuracy: 0.1944 - val_loss: 4.0301
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 773ms/step - accuracy: 0.9846 - loss: 0.0782 - val_accuracy: 0.3889 - val_loss: 2.7854
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets        : [6, 7, 8, 9, 10]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 6 : 64.44%
# Précision Sujet 7 : 91.11%
# Précision Sujet 8 : 88.89%
# Précision Sujet 9 : 91.11%
# Précision Sujet 10 : 75.56%
# ------------------------------
# MOYENNE GLOBALE TEST : 82.22%
# ------------------------------

# %% [markdown]
# # lstm 256 64 32 train 5 tets 4

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")

DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4
TRAIN_SUBJECTS = [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dropout(0.3),
        layers.Dense(64, activation='relu'),
         layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 ---
# /tmp/ipykernel_2763/1028320627.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 14s 749ms/step - accuracy: 0.4123 - loss: 1.7949 - val_accuracy: 0.0000e+00 - val_loss: 3.7911
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 704ms/step - accuracy: 0.6049 - loss: 1.0488 - val_accuracy: 0.0000e+00 - val_loss: 3.2004
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 764ms/step - accuracy: 0.7136 - loss: 0.6982 - val_accuracy: 0.2222 - val_loss: 2.3763
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 767ms/step - accuracy: 0.8198 - loss: 0.5054 - val_accuracy: 0.5111 - val_loss: 2.1598
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 709ms/step - accuracy: 0.8716 - loss: 0.3426 - val_accuracy: 0.5778 - val_loss: 2.6632
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 718ms/step - accuracy: 0.9062 - loss: 0.2505 - val_accuracy: 0.4222 - val_loss: 2.6984
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 706ms/step - accuracy: 0.8840 - loss: 0.2914 - val_accuracy: 0.6889 - val_loss: 1.3161
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 767ms/step - accuracy: 0.8346 - loss: 0.5197 - val_accuracy: 0.6000 - val_loss: 1.4194
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 754ms/step - accuracy: 0.8889 - loss: 0.3651 - val_accuracy: 0.3556 - val_loss: 3.4518
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 715ms/step - accuracy: 0.9160 - loss: 0.2403 - val_accuracy: 0.4000 - val_loss: 2.4652
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 657ms/step - accuracy: 0.9506 - loss: 0.1521 - val_accuracy: 0.4444 - val_loss: 3.2101
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 765ms/step - accuracy: 0.9679 - loss: 0.1003 - val_accuracy: 0.8667 - val_loss: 0.7731
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 762ms/step - accuracy: 0.9704 - loss: 0.0964 - val_accuracy: 0.6000 - val_loss: 1.8770
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 751ms/step - accuracy: 0.9877 - loss: 0.0556 - val_accuracy: 0.7111 - val_loss: 1.2402
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 662ms/step - accuracy: 0.9901 - loss: 0.0394 - val_accuracy: 0.6444 - val_loss: 1.8553
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 733ms/step - accuracy: 0.9901 - loss: 0.0249 - val_accuracy: 0.6000 - val_loss: 2.7746
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 766ms/step - accuracy: 0.9852 - loss: 0.0492 - val_accuracy: 0.6667 - val_loss: 2.1459
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 765ms/step - accuracy: 0.9926 - loss: 0.0296 - val_accuracy: 0.2222 - val_loss: 4.6376
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 658ms/step - accuracy: 0.9432 - loss: 0.1976 - val_accuracy: 0.5778 - val_loss: 2.1072
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 802ms/step - accuracy: 0.9679 - loss: 0.1000 - val_accuracy: 0.3778 - val_loss: 2.8879
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 759ms/step - accuracy: 0.9309 - loss: 0.2325 - val_accuracy: 0.8222 - val_loss: 0.8051
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 765ms/step - accuracy: 0.9309 - loss: 0.2268 - val_accuracy: 0.0000e+00 - val_loss: 4.7861
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 675ms/step - accuracy: 0.9383 - loss: 0.2426 - val_accuracy: 0.5556 - val_loss: 1.6443
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 735ms/step - accuracy: 0.9654 - loss: 0.1498 - val_accuracy: 0.6889 - val_loss: 1.2462
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 765ms/step - accuracy: 0.9654 - loss: 0.1102 - val_accuracy: 0.4222 - val_loss: 1.7795
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 766ms/step - accuracy: 0.9728 - loss: 0.0625 - val_accuracy: 0.5556 - val_loss: 2.2732
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 670ms/step - accuracy: 0.9827 - loss: 0.0488 - val_accuracy: 0.6222 - val_loss: 1.9306
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 741ms/step - accuracy: 0.9852 - loss: 0.0451 - val_accuracy: 0.5333 - val_loss: 1.8925
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 771ms/step - accuracy: 0.9877 - loss: 0.0359 - val_accuracy: 0.5111 - val_loss: 1.4963
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 760ms/step - accuracy: 0.9951 - loss: 0.0271 - val_accuracy: 0.5556 - val_loss: 2.0237
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 659ms/step - accuracy: 0.9975 - loss: 0.0164 - val_accuracy: 0.6444 - val_loss: 2.1590
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 772ms/step - accuracy: 0.9975 - loss: 0.0110 - val_accuracy: 0.5556 - val_loss: 2.2713
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 765ms/step - accuracy: 0.9926 - loss: 0.0209 - val_accuracy: 0.5778 - val_loss: 1.9259
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 777ms/step - accuracy: 0.9926 - loss: 0.0173 - val_accuracy: 0.6667 - val_loss: 1.4064
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 660ms/step - accuracy: 0.9975 - loss: 0.0176 - val_accuracy: 0.6667 - val_loss: 1.6258
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 760ms/step - accuracy: 0.9926 - loss: 0.0177 - val_accuracy: 0.5111 - val_loss: 2.4564
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 763ms/step - accuracy: 0.9975 - loss: 0.0064 - val_accuracy: 0.5556 - val_loss: 2.1103
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 762ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.5778 - val_loss: 2.0032
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 661ms/step - accuracy: 0.9951 - loss: 0.0108 - val_accuracy: 0.6222 - val_loss: 1.7470
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 765ms/step - accuracy: 0.9975 - loss: 0.0103 - val_accuracy: 0.5556 - val_loss: 2.2193
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 771ms/step - accuracy: 0.9901 - loss: 0.0296 - val_accuracy: 0.7556 - val_loss: 1.1059
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 775ms/step - accuracy: 0.9926 - loss: 0.0284 - val_accuracy: 0.7556 - val_loss: 1.4757
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 670ms/step - accuracy: 0.9951 - loss: 0.0089 - val_accuracy: 0.6444 - val_loss: 1.4937
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 775ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.7333 - val_loss: 1.3847
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 788ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.7333 - val_loss: 1.3465
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 839ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.7333 - val_loss: 1.3487
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 735ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.7333 - val_loss: 1.3597
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 829ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.7556 - val_loss: 1.3531
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 859ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8000 - val_loss: 1.3137
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 834ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8000 - val_loss: 1.3097
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets        : [1, 2, 4, 5]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 1 : 86.67%
# Précision Sujet 2 : 66.67%
# Précision Sujet 4 : 84.44%
# Précision Sujet 5 : 74.44%
# ------------------------------
# MOYENNE GLOBALE TEST : 78.06%
# ------------------------------

# %% [markdown]
# # lstm 256 64 32 test sur le sujet 3

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4

TRAIN_SUBJECTS = [1, 2, 4, 5, 6, 7, 8, 9, 10]

TEST_SUBJECTS = [3]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

#
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)


def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)


def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dropout(0.3),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)


print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# Décompression terminée !
# --- 1. Début du Chargement du Domaine 4 ---
# /tmp/ipykernel_7893/2152113884.py:58: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 976ms/step - accuracy: 0.4472 - loss: 1.5373 - val_accuracy: 0.0000e+00 - val_loss: 3.2667
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 821ms/step - accuracy: 0.7133 - loss: 0.8150 - val_accuracy: 0.0000e+00 - val_loss: 4.2536
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 800ms/step - accuracy: 0.7737 - loss: 0.5967 - val_accuracy: 0.0000e+00 - val_loss: 3.7621
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 17s 755ms/step - accuracy: 0.8422 - loss: 0.4464 - val_accuracy: 0.1481 - val_loss: 2.9793
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 776ms/step - accuracy: 0.8752 - loss: 0.3690 - val_accuracy: 0.0864 - val_loss: 3.3792
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 814ms/step - accuracy: 0.8957 - loss: 0.3180 - val_accuracy: 0.1358 - val_loss: 3.4017
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 772ms/step - accuracy: 0.9259 - loss: 0.2139 - val_accuracy: 0.3704 - val_loss: 2.3131
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 933ms/step - accuracy: 0.9218 - loss: 0.2226 - val_accuracy: 0.2593 - val_loss: 2.8734
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 798ms/step - accuracy: 0.9451 - loss: 0.1727 - val_accuracy: 0.4321 - val_loss: 2.3625
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 817ms/step - accuracy: 0.9465 - loss: 0.1749 - val_accuracy: 0.3333 - val_loss: 3.0085
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 794ms/step - accuracy: 0.9657 - loss: 0.1091 - val_accuracy: 0.3704 - val_loss: 2.9853
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 871ms/step - accuracy: 0.9684 - loss: 0.0985 - val_accuracy: 0.5062 - val_loss: 2.2292
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 761ms/step - accuracy: 0.9684 - loss: 0.1045 - val_accuracy: 0.5679 - val_loss: 2.1246
# Epoch 14/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 828ms/step - accuracy: 0.9520 - loss: 0.1330 - val_accuracy: 0.5432 - val_loss: 2.3756
# Epoch 15/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 784ms/step - accuracy: 0.9534 - loss: 0.1555 - val_accuracy: 0.5556 - val_loss: 2.2708
# Epoch 16/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 821ms/step - accuracy: 0.9218 - loss: 0.2425 - val_accuracy: 0.6296 - val_loss: 1.5158
# Epoch 17/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 17s 746ms/step - accuracy: 0.9671 - loss: 0.1144 - val_accuracy: 0.3827 - val_loss: 2.6182
# Epoch 18/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 17s 756ms/step - accuracy: 0.9863 - loss: 0.0709 - val_accuracy: 0.6790 - val_loss: 1.5360
# Epoch 19/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 835ms/step - accuracy: 0.9794 - loss: 0.0684 - val_accuracy: 0.5062 - val_loss: 1.8644
# Epoch 20/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 17s 764ms/step - accuracy: 0.9630 - loss: 0.1167 - val_accuracy: 0.5802 - val_loss: 1.9917
# Epoch 21/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 803ms/step - accuracy: 0.9781 - loss: 0.0932 - val_accuracy: 0.5185 - val_loss: 1.7828
# Epoch 22/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 17s 759ms/step - accuracy: 0.9684 - loss: 0.1196 - val_accuracy: 0.4321 - val_loss: 2.4175
# Epoch 23/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 17s 756ms/step - accuracy: 0.9822 - loss: 0.0564 - val_accuracy: 0.5062 - val_loss: 2.4865
# Epoch 24/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 754ms/step - accuracy: 0.9877 - loss: 0.0549 - val_accuracy: 0.6543 - val_loss: 1.5621
# Epoch 25/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 17s 757ms/step - accuracy: 0.9890 - loss: 0.0303 - val_accuracy: 0.5556 - val_loss: 2.2491
# Epoch 26/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 821ms/step - accuracy: 0.9698 - loss: 0.0832 - val_accuracy: 0.6790 - val_loss: 1.2646
# Epoch 27/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 17s 762ms/step - accuracy: 0.9602 - loss: 0.1174 - val_accuracy: 0.4444 - val_loss: 3.4920
# Epoch 28/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 815ms/step - accuracy: 0.9575 - loss: 0.1320 - val_accuracy: 0.5556 - val_loss: 2.3838
# Epoch 29/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 778ms/step - accuracy: 0.9767 - loss: 0.0612 - val_accuracy: 0.6420 - val_loss: 1.8626
# Epoch 30/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 831ms/step - accuracy: 0.9835 - loss: 0.0677 - val_accuracy: 0.5185 - val_loss: 2.5475
# Epoch 31/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 771ms/step - accuracy: 0.9904 - loss: 0.0442 - val_accuracy: 0.3580 - val_loss: 3.6186
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 778ms/step - accuracy: 0.9931 - loss: 0.0252 - val_accuracy: 0.5062 - val_loss: 2.7518
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 793ms/step - accuracy: 0.9657 - loss: 0.1159 - val_accuracy: 0.4568 - val_loss: 2.6856
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 764ms/step - accuracy: 0.9561 - loss: 0.1235 - val_accuracy: 0.7160 - val_loss: 1.5741
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 835ms/step - accuracy: 0.9657 - loss: 0.1171 - val_accuracy: 0.5926 - val_loss: 2.0384
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 759ms/step - accuracy: 0.9931 - loss: 0.0317 - val_accuracy: 0.5062 - val_loss: 2.6765
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 800ms/step - accuracy: 0.9945 - loss: 0.0204 - val_accuracy: 0.5926 - val_loss: 2.7132
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 768ms/step - accuracy: 0.9945 - loss: 0.0233 - val_accuracy: 0.7284 - val_loss: 2.1251
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 815ms/step - accuracy: 0.9602 - loss: 0.0984 - val_accuracy: 0.6543 - val_loss: 2.0204
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 808ms/step - accuracy: 0.8889 - loss: 0.3777 - val_accuracy: 0.2222 - val_loss: 3.8688
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 809ms/step - accuracy: 0.9726 - loss: 0.1059 - val_accuracy: 0.0617 - val_loss: 5.4695
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 794ms/step - accuracy: 0.9945 - loss: 0.0299 - val_accuracy: 0.3457 - val_loss: 3.5376
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 835ms/step - accuracy: 0.9767 - loss: 0.0805 - val_accuracy: 0.3827 - val_loss: 3.5214
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 779ms/step - accuracy: 0.9739 - loss: 0.0743 - val_accuracy: 0.4321 - val_loss: 3.2890
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 825ms/step - accuracy: 0.9918 - loss: 0.0326 - val_accuracy: 0.5062 - val_loss: 3.2843
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 777ms/step - accuracy: 0.9959 - loss: 0.0194 - val_accuracy: 0.5432 - val_loss: 3.1672
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 882ms/step - accuracy: 0.9973 - loss: 0.0116 - val_accuracy: 0.5062 - val_loss: 3.1526
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 782ms/step - accuracy: 0.9986 - loss: 0.0069 - val_accuracy: 0.4691 - val_loss: 3.3489
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 825ms/step - accuracy: 0.9973 - loss: 0.0158 - val_accuracy: 0.5062 - val_loss: 3.3407
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 17s 763ms/step - accuracy: 0.9945 - loss: 0.0233 - val_accuracy: 0.4815 - val_loss: 3.5903
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [1, 2, 4, 5, 6, 7, 8, 9, 10]
# Test sur sujets         : [3]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 3 : 86.67%
# ------------------------------
# MOYENNE GLOBALE TEST : 86.67%
# ------------------------------

# %% [markdown]
# # lstm 256 32 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)


def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)


def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)


def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(32, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)


print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# Décompression terminée !
# --- 1. Début du Chargement du Domaine 4 ---
# /tmp/ipykernel_8171/2200059452.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 722ms/step - accuracy: 0.3858 - loss: 1.8363 - val_accuracy: 0.0000e+00 - val_loss: 4.1246
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 959ms/step - accuracy: 0.6080 - loss: 1.0488 - val_accuracy: 0.0000e+00 - val_loss: 4.9688
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7006 - loss: 0.8156 - val_accuracy: 0.0000e+00 - val_loss: 4.2216
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.7407 - loss: 0.6394 - val_accuracy: 0.0000e+00 - val_loss: 3.2948
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7963 - loss: 0.5112 - val_accuracy: 0.0278 - val_loss: 3.8183
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 18s 988ms/step - accuracy: 0.8025 - loss: 0.4729 - val_accuracy: 0.0833 - val_loss: 4.9606
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 18s 698ms/step - accuracy: 0.7191 - loss: 0.7947 - val_accuracy: 0.0278 - val_loss: 2.8575
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 612ms/step - accuracy: 0.7191 - loss: 0.5903 - val_accuracy: 0.0000e+00 - val_loss: 3.2734
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 650ms/step - accuracy: 0.8395 - loss: 0.3943 - val_accuracy: 0.1667 - val_loss: 2.0578
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 603ms/step - accuracy: 0.8488 - loss: 0.3561 - val_accuracy: 0.1667 - val_loss: 2.6694
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 600ms/step - accuracy: 0.8488 - loss: 0.3353 - val_accuracy: 0.3056 - val_loss: 1.9523
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 597ms/step - accuracy: 0.8796 - loss: 0.2847 - val_accuracy: 0.4722 - val_loss: 2.4042
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 636ms/step - accuracy: 0.9290 - loss: 0.1941 - val_accuracy: 0.5833 - val_loss: 1.8425
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 633ms/step - accuracy: 0.9506 - loss: 0.1542 - val_accuracy: 0.5556 - val_loss: 1.8832
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 621ms/step - accuracy: 0.9167 - loss: 0.2426 - val_accuracy: 0.6389 - val_loss: 1.5258
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 665ms/step - accuracy: 0.9167 - loss: 0.2013 - val_accuracy: 0.3333 - val_loss: 3.4173
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 717ms/step - accuracy: 0.9537 - loss: 0.1527 - val_accuracy: 0.2778 - val_loss: 2.6893
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 648ms/step - accuracy: 0.9660 - loss: 0.1014 - val_accuracy: 0.4167 - val_loss: 2.1715
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 629ms/step - accuracy: 0.9599 - loss: 0.1047 - val_accuracy: 0.3889 - val_loss: 2.2796
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 617ms/step - accuracy: 0.9630 - loss: 0.0966 - val_accuracy: 0.4722 - val_loss: 1.9955
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 706ms/step - accuracy: 0.9722 - loss: 0.0788 - val_accuracy: 0.5000 - val_loss: 1.7973
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 694ms/step - accuracy: 0.9599 - loss: 0.1170 - val_accuracy: 0.5000 - val_loss: 1.7725
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 622ms/step - accuracy: 0.9753 - loss: 0.0671 - val_accuracy: 0.4444 - val_loss: 2.0319
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 591ms/step - accuracy: 0.9722 - loss: 0.0645 - val_accuracy: 0.6111 - val_loss: 1.4894
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 645ms/step - accuracy: 0.9877 - loss: 0.0340 - val_accuracy: 0.4167 - val_loss: 1.8985
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 601ms/step - accuracy: 0.9568 - loss: 0.1516 - val_accuracy: 0.6111 - val_loss: 1.7346
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 662ms/step - accuracy: 0.9198 - loss: 0.1932 - val_accuracy: 0.1111 - val_loss: 5.1273
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 646ms/step - accuracy: 0.9506 - loss: 0.1652 - val_accuracy: 0.1667 - val_loss: 4.6210
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 636ms/step - accuracy: 0.9475 - loss: 0.1675 - val_accuracy: 0.2222 - val_loss: 2.5454
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 647ms/step - accuracy: 0.9537 - loss: 0.1538 - val_accuracy: 0.0278 - val_loss: 4.4650
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 611ms/step - accuracy: 0.9321 - loss: 0.2068 - val_accuracy: 0.2500 - val_loss: 1.7852
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 601ms/step - accuracy: 0.9105 - loss: 0.2210 - val_accuracy: 0.3056 - val_loss: 2.9566
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 760ms/step - accuracy: 0.9568 - loss: 0.1121 - val_accuracy: 0.4167 - val_loss: 2.4895
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 595ms/step - accuracy: 0.9506 - loss: 0.1415 - val_accuracy: 0.3056 - val_loss: 2.5702
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 604ms/step - accuracy: 0.9691 - loss: 0.0857 - val_accuracy: 0.3889 - val_loss: 2.2817
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 605ms/step - accuracy: 0.9877 - loss: 0.0445 - val_accuracy: 0.2778 - val_loss: 2.7874
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 578ms/step - accuracy: 0.9907 - loss: 0.0348 - val_accuracy: 0.3889 - val_loss: 2.5934
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 603ms/step - accuracy: 0.9969 - loss: 0.0383 - val_accuracy: 0.3889 - val_loss: 2.3154
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 586ms/step - accuracy: 0.9846 - loss: 0.0465 - val_accuracy: 0.3056 - val_loss: 3.2301
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 633ms/step - accuracy: 0.9753 - loss: 0.0645 - val_accuracy: 0.3333 - val_loss: 3.9012
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 607ms/step - accuracy: 0.9753 - loss: 0.0848 - val_accuracy: 0.1667 - val_loss: 5.5656
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 659ms/step - accuracy: 0.9784 - loss: 0.0940 - val_accuracy: 0.4444 - val_loss: 3.5660
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 644ms/step - accuracy: 0.9784 - loss: 0.0984 - val_accuracy: 0.5000 - val_loss: 2.3564
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 676ms/step - accuracy: 0.9753 - loss: 0.0848 - val_accuracy: 0.4167 - val_loss: 3.5732
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 620ms/step - accuracy: 0.9784 - loss: 0.0561 - val_accuracy: 0.3889 - val_loss: 3.3616
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 689ms/step - accuracy: 1.0000 - loss: 0.0267 - val_accuracy: 0.3056 - val_loss: 4.5393
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 696ms/step - accuracy: 0.9938 - loss: 0.0244 - val_accuracy: 0.3333 - val_loss: 3.9148
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 648ms/step - accuracy: 0.9907 - loss: 0.0404 - val_accuracy: 0.2778 - val_loss: 4.9543
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 660ms/step - accuracy: 0.9877 - loss: 0.0313 - val_accuracy: 0.1389 - val_loss: 6.5844
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 720ms/step - accuracy: 0.9691 - loss: 0.1120 - val_accuracy: 0.2778 - val_loss: 4.2707
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets        : [6, 7, 8, 9, 10]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 6 : 67.78%
# Précision Sujet 7 : 97.78%
# Précision Sujet 8 : 96.67%
# Précision Sujet 9 : 76.67%
# Précision Sujet 10 : 81.11%
# ------------------------------
# MOYENNE GLOBALE TEST : 84.00%
# ------------------------------

# %% [markdown]
# # lstm 256 32 32 train 5 tedst 4

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 3
TRAIN_SUBJECTS =   [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)


def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)


def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(32, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)


print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 3 ---
# /tmp/ipykernel_8171/1977143710.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 745ms/step - accuracy: 0.4148 - loss: 1.6910 - val_accuracy: 0.0000e+00 - val_loss: 2.5064
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 697ms/step - accuracy: 0.6691 - loss: 0.8479 - val_accuracy: 0.0000e+00 - val_loss: 2.9451
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 703ms/step - accuracy: 0.8173 - loss: 0.4983 - val_accuracy: 0.0000e+00 - val_loss: 3.0599
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 660ms/step - accuracy: 0.8395 - loss: 0.3831 - val_accuracy: 0.1111 - val_loss: 2.8676
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 655ms/step - accuracy: 0.8617 - loss: 0.3470 - val_accuracy: 0.1778 - val_loss: 3.2733
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 685ms/step - accuracy: 0.9210 - loss: 0.2259 - val_accuracy: 0.3333 - val_loss: 2.9438
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 708ms/step - accuracy: 0.9235 - loss: 0.2322 - val_accuracy: 0.4444 - val_loss: 2.7989
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 700ms/step - accuracy: 0.9284 - loss: 0.1972 - val_accuracy: 0.3556 - val_loss: 2.5312
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 685ms/step - accuracy: 0.8914 - loss: 0.3093 - val_accuracy: 0.3778 - val_loss: 2.4935
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 663ms/step - accuracy: 0.9457 - loss: 0.1690 - val_accuracy: 0.3778 - val_loss: 2.1004
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 680ms/step - accuracy: 0.9580 - loss: 0.1379 - val_accuracy: 0.1333 - val_loss: 3.0876
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 696ms/step - accuracy: 0.9753 - loss: 0.0719 - val_accuracy: 0.6889 - val_loss: 1.4670
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 701ms/step - accuracy: 0.9852 - loss: 0.0549 - val_accuracy: 0.2222 - val_loss: 2.9136
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 703ms/step - accuracy: 0.9852 - loss: 0.0511 - val_accuracy: 0.6444 - val_loss: 1.5367
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 648ms/step - accuracy: 0.9802 - loss: 0.0461 - val_accuracy: 0.6000 - val_loss: 1.6629
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 655ms/step - accuracy: 0.9951 - loss: 0.0205 - val_accuracy: 0.6667 - val_loss: 1.3375
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 665ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.6667 - val_loss: 1.1522
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 710ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.6444 - val_loss: 1.2892
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 691ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.6444 - val_loss: 1.3541
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 699ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.6444 - val_loss: 1.3557
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 843ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.6222 - val_loss: 1.3665
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 724ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.6222 - val_loss: 1.3790
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 661ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.6222 - val_loss: 1.3875
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 734ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.6222 - val_loss: 1.4049
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 697ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6222 - val_loss: 1.4161
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 724ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6222 - val_loss: 1.4297
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 733ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6222 - val_loss: 1.4390
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 676ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6222 - val_loss: 1.4377
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 688ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.6667 - val_loss: 1.4383
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6667 - val_loss: 1.4557
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 14s 733ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6667 - val_loss: 1.4589
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 801ms/step - accuracy: 1.0000 - loss: 9.9875e-04 - val_accuracy: 0.6667 - val_loss: 1.4805
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 708ms/step - accuracy: 1.0000 - loss: 9.4430e-04 - val_accuracy: 0.6667 - val_loss: 1.4881
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 654ms/step - accuracy: 1.0000 - loss: 8.8908e-04 - val_accuracy: 0.6667 - val_loss: 1.4957
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 598ms/step - accuracy: 1.0000 - loss: 8.4325e-04 - val_accuracy: 0.6667 - val_loss: 1.4991
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 637ms/step - accuracy: 1.0000 - loss: 8.0032e-04 - val_accuracy: 0.6667 - val_loss: 1.5081
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 640ms/step - accuracy: 1.0000 - loss: 7.6674e-04 - val_accuracy: 0.6667 - val_loss: 1.5224
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 645ms/step - accuracy: 1.0000 - loss: 7.2396e-04 - val_accuracy: 0.6667 - val_loss: 1.5303
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 619ms/step - accuracy: 1.0000 - loss: 6.9427e-04 - val_accuracy: 0.6667 - val_loss: 1.5362
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 668ms/step - accuracy: 1.0000 - loss: 6.6108e-04 - val_accuracy: 0.6667 - val_loss: 1.5443
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 750ms/step - accuracy: 1.0000 - loss: 6.3357e-04 - val_accuracy: 0.6667 - val_loss: 1.5503
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 755ms/step - accuracy: 1.0000 - loss: 5.9893e-04 - val_accuracy: 0.6667 - val_loss: 1.5573
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 663ms/step - accuracy: 1.0000 - loss: 5.7350e-04 - val_accuracy: 0.6667 - val_loss: 1.5595
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 610ms/step - accuracy: 1.0000 - loss: 5.4752e-04 - val_accuracy: 0.6667 - val_loss: 1.5636
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 654ms/step - accuracy: 1.0000 - loss: 5.3050e-04 - val_accuracy: 0.6667 - val_loss: 1.5700
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 655ms/step - accuracy: 1.0000 - loss: 5.0503e-04 - val_accuracy: 0.6667 - val_loss: 1.5739
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 614ms/step - accuracy: 1.0000 - loss: 4.8609e-04 - val_accuracy: 0.6667 - val_loss: 1.5764
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 595ms/step - accuracy: 1.0000 - loss: 4.7197e-04 - val_accuracy: 0.6667 - val_loss: 1.5782
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 607ms/step - accuracy: 1.0000 - loss: 4.5284e-04 - val_accuracy: 0.6667 - val_loss: 1.5830
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 649ms/step - accuracy: 1.0000 - loss: 4.3604e-04 - val_accuracy: 0.6667 - val_loss: 1.5871
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets        : [1, 2, 4, 5]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 1 : 86.67%
# Précision Sujet 2 : 64.44%
# Précision Sujet 4 : 76.67%
# Précision Sujet 5 : 63.33%
# ------------------------------
# MOYENNE GLOBALE TEST : 72.78%
# ------------------------------

# %% [markdown]
# # lstm 256 16 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)


def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)


def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)


def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(16, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)


print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 ---
# /tmp/ipykernel_8171/3636389391.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 812ms/step - accuracy: 0.3302 - loss: 1.9399 - val_accuracy: 0.0000e+00 - val_loss: 3.9429
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 766ms/step - accuracy: 0.5093 - loss: 1.3982 - val_accuracy: 0.0000e+00 - val_loss: 3.7279
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 742ms/step - accuracy: 0.5370 - loss: 1.0691 - val_accuracy: 0.0000e+00 - val_loss: 4.2551
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 700ms/step - accuracy: 0.6944 - loss: 0.7730 - val_accuracy: 0.0000e+00 - val_loss: 4.1495
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 754ms/step - accuracy: 0.7222 - loss: 0.7710 - val_accuracy: 0.0000e+00 - val_loss: 5.1450
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 771ms/step - accuracy: 0.7747 - loss: 0.6248 - val_accuracy: 0.0000e+00 - val_loss: 4.2718
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 707ms/step - accuracy: 0.8796 - loss: 0.4752 - val_accuracy: 0.0000e+00 - val_loss: 4.2852
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 773ms/step - accuracy: 0.8272 - loss: 0.4755 - val_accuracy: 0.0000e+00 - val_loss: 3.0409
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 754ms/step - accuracy: 0.7809 - loss: 0.5629 - val_accuracy: 0.0000e+00 - val_loss: 4.3028
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 702ms/step - accuracy: 0.8333 - loss: 0.4270 - val_accuracy: 0.0000e+00 - val_loss: 4.2727
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 751ms/step - accuracy: 0.8272 - loss: 0.3971 - val_accuracy: 0.0000e+00 - val_loss: 4.6184
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 752ms/step - accuracy: 0.8765 - loss: 0.3212 - val_accuracy: 0.0000e+00 - val_loss: 4.3448
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 684ms/step - accuracy: 0.9043 - loss: 0.2633 - val_accuracy: 0.0278 - val_loss: 2.9529
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 698ms/step - accuracy: 0.9198 - loss: 0.2229 - val_accuracy: 0.0833 - val_loss: 2.9987
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 728ms/step - accuracy: 0.8704 - loss: 0.3131 - val_accuracy: 0.0000e+00 - val_loss: 3.8910
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 688ms/step - accuracy: 0.8519 - loss: 0.3657 - val_accuracy: 0.1667 - val_loss: 3.4548
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 676ms/step - accuracy: 0.8179 - loss: 0.3879 - val_accuracy: 0.2500 - val_loss: 3.2572
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 672ms/step - accuracy: 0.8765 - loss: 0.3182 - val_accuracy: 0.0278 - val_loss: 4.4782
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 670ms/step - accuracy: 0.9136 - loss: 0.2354 - val_accuracy: 0.2222 - val_loss: 3.2585
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 680ms/step - accuracy: 0.9043 - loss: 0.2623 - val_accuracy: 0.0833 - val_loss: 4.6542
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 695ms/step - accuracy: 0.9043 - loss: 0.2481 - val_accuracy: 0.3056 - val_loss: 3.3383
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 733ms/step - accuracy: 0.9414 - loss: 0.1962 - val_accuracy: 0.3611 - val_loss: 3.4922
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 701ms/step - accuracy: 0.9537 - loss: 0.1395 - val_accuracy: 0.3889 - val_loss: 3.2402
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 692ms/step - accuracy: 0.9753 - loss: 0.0935 - val_accuracy: 0.3056 - val_loss: 4.1648
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 687ms/step - accuracy: 0.9753 - loss: 0.0786 - val_accuracy: 0.3333 - val_loss: 4.0291
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 731ms/step - accuracy: 0.9784 - loss: 0.0727 - val_accuracy: 0.3611 - val_loss: 3.6976
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 728ms/step - accuracy: 0.9691 - loss: 0.1070 - val_accuracy: 0.3611 - val_loss: 3.5834
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 746ms/step - accuracy: 0.9568 - loss: 0.1311 - val_accuracy: 0.1944 - val_loss: 3.9456
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 687ms/step - accuracy: 0.9383 - loss: 0.1819 - val_accuracy: 0.3056 - val_loss: 3.7562
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 736ms/step - accuracy: 0.9630 - loss: 0.1136 - val_accuracy: 0.3056 - val_loss: 3.8371
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 733ms/step - accuracy: 0.9630 - loss: 0.0932 - val_accuracy: 0.3889 - val_loss: 3.5934
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 675ms/step - accuracy: 0.9691 - loss: 0.0876 - val_accuracy: 0.1944 - val_loss: 5.4682
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 679ms/step - accuracy: 0.9691 - loss: 0.0785 - val_accuracy: 0.4167 - val_loss: 4.0638
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 749ms/step - accuracy: 0.9815 - loss: 0.0698 - val_accuracy: 0.3056 - val_loss: 3.6657
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 827ms/step - accuracy: 0.9815 - loss: 0.0561 - val_accuracy: 0.1667 - val_loss: 4.6486
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 734ms/step - accuracy: 0.8951 - loss: 0.4080 - val_accuracy: 0.3611 - val_loss: 2.8986
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 692ms/step - accuracy: 0.9198 - loss: 0.2235 - val_accuracy: 0.1111 - val_loss: 5.1758
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 666ms/step - accuracy: 0.9352 - loss: 0.1765 - val_accuracy: 0.3333 - val_loss: 3.7085
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 729ms/step - accuracy: 0.9753 - loss: 0.0989 - val_accuracy: 0.3889 - val_loss: 3.6441
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 740ms/step - accuracy: 0.9846 - loss: 0.0626 - val_accuracy: 0.2500 - val_loss: 3.5660
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 760ms/step - accuracy: 0.9691 - loss: 0.0996 - val_accuracy: 0.4444 - val_loss: 3.3347
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 688ms/step - accuracy: 0.9815 - loss: 0.0703 - val_accuracy: 0.1944 - val_loss: 4.6628
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 704ms/step - accuracy: 0.9784 - loss: 0.0600 - val_accuracy: 0.3611 - val_loss: 3.9057
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 678ms/step - accuracy: 0.9753 - loss: 0.0604 - val_accuracy: 0.3333 - val_loss: 3.5904
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 742ms/step - accuracy: 0.9722 - loss: 0.0965 - val_accuracy: 0.2778 - val_loss: 3.0496
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 732ms/step - accuracy: 0.9136 - loss: 0.2171 - val_accuracy: 0.2500 - val_loss: 3.9086
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 667ms/step - accuracy: 0.9660 - loss: 0.1096 - val_accuracy: 0.4722 - val_loss: 2.6541
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 728ms/step - accuracy: 0.9136 - loss: 0.2283 - val_accuracy: 0.2778 - val_loss: 4.1849
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 779ms/step - accuracy: 0.9321 - loss: 0.1746 - val_accuracy: 0.5000 - val_loss: 2.4482
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 703ms/step - accuracy: 0.9414 - loss: 0.1613 - val_accuracy: 0.3889 - val_loss: 3.8090
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets        : [6, 7, 8, 9, 10]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 6 : 81.11%
# Précision Sujet 7 : 84.44%
# Précision Sujet 8 : 86.67%
# Précision Sujet 9 : 84.44%
# Précision Sujet 10 : 74.44%
# ------------------------------
# MOYENNE GLOBALE TEST : 82.22%
# ------------------------------

# %% [markdown]
# # lstm 256 16 32 train 5 tets 4

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 3
TRAIN_SUBJECTS =   [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)


def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)


def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)


def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(16, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)


print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 3 ---
# /tmp/ipykernel_8171/3207689833.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 733ms/step - accuracy: 0.4296 - loss: 1.8456 - val_accuracy: 0.0000e+00 - val_loss: 4.9629
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 677ms/step - accuracy: 0.5580 - loss: 1.2535 - val_accuracy: 0.0000e+00 - val_loss: 6.7607
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 666ms/step - accuracy: 0.6889 - loss: 0.9491 - val_accuracy: 0.0000e+00 - val_loss: 4.7977
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 719ms/step - accuracy: 0.7506 - loss: 0.7162 - val_accuracy: 0.1556 - val_loss: 5.3869
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 720ms/step - accuracy: 0.8000 - loss: 0.5591 - val_accuracy: 0.3556 - val_loss: 5.7519
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 715ms/step - accuracy: 0.8543 - loss: 0.5262 - val_accuracy: 0.0667 - val_loss: 11.1690
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 668ms/step - accuracy: 0.9111 - loss: 0.3798 - val_accuracy: 0.2222 - val_loss: 6.3357
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 646ms/step - accuracy: 0.9457 - loss: 0.2279 - val_accuracy: 0.4667 - val_loss: 3.9364
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 694ms/step - accuracy: 0.9432 - loss: 0.1994 - val_accuracy: 0.4667 - val_loss: 3.0232
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 705ms/step - accuracy: 0.8938 - loss: 0.3128 - val_accuracy: 0.5333 - val_loss: 3.4406
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 693ms/step - accuracy: 0.9309 - loss: 0.2669 - val_accuracy: 0.7111 - val_loss: 1.7847
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 662ms/step - accuracy: 0.9679 - loss: 0.1460 - val_accuracy: 0.5333 - val_loss: 2.0902
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 702ms/step - accuracy: 0.9926 - loss: 0.0549 - val_accuracy: 0.4667 - val_loss: 3.0282
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 706ms/step - accuracy: 0.9827 - loss: 0.0644 - val_accuracy: 0.5333 - val_loss: 2.5802
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 710ms/step - accuracy: 0.9580 - loss: 0.1408 - val_accuracy: 0.4222 - val_loss: 4.0591
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 706ms/step - accuracy: 0.9827 - loss: 0.0884 - val_accuracy: 0.8667 - val_loss: 1.3607
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 663ms/step - accuracy: 0.9827 - loss: 0.0667 - val_accuracy: 0.4000 - val_loss: 3.6725
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 716ms/step - accuracy: 0.9951 - loss: 0.0312 - val_accuracy: 0.5778 - val_loss: 2.4895
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 711ms/step - accuracy: 0.9877 - loss: 0.0593 - val_accuracy: 0.6222 - val_loss: 2.4261
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 708ms/step - accuracy: 0.9951 - loss: 0.0311 - val_accuracy: 0.6222 - val_loss: 2.2431
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 678ms/step - accuracy: 0.9802 - loss: 0.0630 - val_accuracy: 0.4000 - val_loss: 3.2390
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 661ms/step - accuracy: 0.9704 - loss: 0.0775 - val_accuracy: 0.5556 - val_loss: 2.2058
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 689ms/step - accuracy: 0.9926 - loss: 0.0373 - val_accuracy: 0.5778 - val_loss: 2.2495
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 724ms/step - accuracy: 0.9951 - loss: 0.0192 - val_accuracy: 0.4667 - val_loss: 2.9884
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 737ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.4889 - val_loss: 2.9686
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 732ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.5333 - val_loss: 2.8060
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 694ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.4667 - val_loss: 2.8656
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 661ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.4667 - val_loss: 2.9194
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 706ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.4667 - val_loss: 2.9228
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 710ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.4667 - val_loss: 2.9334
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 699ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.4667 - val_loss: 2.9349
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 653ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.5111 - val_loss: 2.9282
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 673ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.5111 - val_loss: 2.9291
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 694ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.5556 - val_loss: 2.8989
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 694ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.5556 - val_loss: 2.8953
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 702ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.5556 - val_loss: 2.8824
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 648ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.5556 - val_loss: 2.8848
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 701ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.5556 - val_loss: 2.8688
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 698ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.5556 - val_loss: 2.8680
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 708ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5556 - val_loss: 2.8688
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 656ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5556 - val_loss: 2.8647
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 680ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.5556 - val_loss: 2.8632
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 709ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5556 - val_loss: 2.8465
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 707ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5556 - val_loss: 2.8443
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 694ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.5556 - val_loss: 2.8481
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 668ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5556 - val_loss: 2.8494
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 658ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5556 - val_loss: 2.8489
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 642ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5556 - val_loss: 2.8559
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 702ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5778 - val_loss: 2.8470
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 715ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5778 - val_loss: 2.8433
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets        : [1, 2, 4, 5]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 1 : 83.33%
# Précision Sujet 2 : 67.78%
# Précision Sujet 4 : 70.00%
# Précision Sujet 5 : 76.67%
# ------------------------------
# MOYENNE GLOBALE TEST : 74.44%
# ------------------------------

# %% [markdown]
# # lstm 256 64 16 train  4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)


def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)


def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(64, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1, verbose=1)


print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 ---
# /tmp/ipykernel_6552/1583071569.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.3395 - loss: 2.1842 - val_accuracy: 0.0000e+00 - val_loss: 2.3358
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.4784 - loss: 1.8047 - val_accuracy: 0.0000e+00 - val_loss: 2.4366
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.5401 - loss: 1.3606 - val_accuracy: 0.0000e+00 - val_loss: 3.1078
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.5864 - loss: 1.0782 - val_accuracy: 0.0000e+00 - val_loss: 3.8106
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.6574 - loss: 0.8902 - val_accuracy: 0.0000e+00 - val_loss: 4.1019
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.7685 - loss: 0.7081 - val_accuracy: 0.0000e+00 - val_loss: 4.2371
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8025 - loss: 0.5860 - val_accuracy: 0.0000e+00 - val_loss: 4.2735
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8241 - loss: 0.5115 - val_accuracy: 0.0000e+00 - val_loss: 4.0983
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8272 - loss: 0.4474 - val_accuracy: 0.0000e+00 - val_loss: 3.8223
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8611 - loss: 0.3870 - val_accuracy: 0.0000e+00 - val_loss: 3.4926
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8704 - loss: 0.3965 - val_accuracy: 0.0000e+00 - val_loss: 3.8869
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8827 - loss: 0.3368 - val_accuracy: 0.0000e+00 - val_loss: 3.4439
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.8951 - loss: 0.3001 - val_accuracy: 0.0000e+00 - val_loss: 3.2472
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.8951 - loss: 0.3101 - val_accuracy: 0.0000e+00 - val_loss: 3.4629
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.8858 - loss: 0.2835 - val_accuracy: 0.0000e+00 - val_loss: 2.8725
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9167 - loss: 0.2332 - val_accuracy: 0.0000e+00 - val_loss: 3.0930
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9198 - loss: 0.2498 - val_accuracy: 0.0000e+00 - val_loss: 2.7395
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8827 - loss: 0.2875 - val_accuracy: 0.0000e+00 - val_loss: 3.5445
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9043 - loss: 0.2118 - val_accuracy: 0.0000e+00 - val_loss: 3.3704
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9383 - loss: 0.1798 - val_accuracy: 0.1111 - val_loss: 3.2351
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9506 - loss: 0.1675 - val_accuracy: 0.0278 - val_loss: 3.2688
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 0.9352 - loss: 0.1937 - val_accuracy: 0.1389 - val_loss: 2.7755
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9167 - loss: 0.2168 - val_accuracy: 0.0556 - val_loss: 3.1143
# Epoch 24/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9475 - loss: 0.1705 - val_accuracy: 0.1389 - val_loss: 3.2252
# Epoch 25/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9475 - loss: 0.1532 - val_accuracy: 0.1667 - val_loss: 2.7215
# Epoch 26/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9660 - loss: 0.1140 - val_accuracy: 0.1389 - val_loss: 4.0527
# Epoch 27/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9691 - loss: 0.1093 - val_accuracy: 0.1389 - val_loss: 3.5460
# Epoch 28/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9784 - loss: 0.0814 - val_accuracy: 0.1389 - val_loss: 3.7932
# Epoch 29/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9630 - loss: 0.0991 - val_accuracy: 0.1389 - val_loss: 3.8155
# Epoch 30/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9506 - loss: 0.1169 - val_accuracy: 0.1944 - val_loss: 3.1215
# Epoch 31/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.9475 - loss: 0.1356 - val_accuracy: 0.1389 - val_loss: 4.6029
# Epoch 32/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9846 - loss: 0.0786 - val_accuracy: 0.1389 - val_loss: 3.7963
# Epoch 33/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9815 - loss: 0.0837 - val_accuracy: 0.1389 - val_loss: 3.8193
# Epoch 34/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9722 - loss: 0.0873 - val_accuracy: 0.1389 - val_loss: 4.3225
# Epoch 35/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9722 - loss: 0.0824 - val_accuracy: 0.1389 - val_loss: 3.8511
# Epoch 36/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9753 - loss: 0.0892 - val_accuracy: 0.1111 - val_loss: 3.8532
# Epoch 37/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9475 - loss: 0.1771 - val_accuracy: 0.0000e+00 - val_loss: 5.4005
# Epoch 38/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9506 - loss: 0.1651 - val_accuracy: 0.2500 - val_loss: 3.2337
# Epoch 39/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9784 - loss: 0.0946 - val_accuracy: 0.1389 - val_loss: 5.2074
# Epoch 40/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.9815 - loss: 0.0839 - val_accuracy: 0.1389 - val_loss: 4.1653
# Epoch 41/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9815 - loss: 0.0527 - val_accuracy: 0.1389 - val_loss: 4.3852
# Epoch 42/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9660 - loss: 0.1040 - val_accuracy: 0.1389 - val_loss: 3.9439
# Epoch 43/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9784 - loss: 0.0680 - val_accuracy: 0.1389 - val_loss: 4.8360
# Epoch 44/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9815 - loss: 0.0623 - val_accuracy: 0.1389 - val_loss: 4.7847
# Epoch 45/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9907 - loss: 0.0356 - val_accuracy: 0.1944 - val_loss: 4.0565
# Epoch 46/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9846 - loss: 0.0488 - val_accuracy: 0.1111 - val_loss: 5.1808
# Epoch 47/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9414 - loss: 0.2402 - val_accuracy: 0.3056 - val_loss: 3.0965
# Epoch 48/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9599 - loss: 0.1437 - val_accuracy: 0.2500 - val_loss: 3.6798
# Epoch 49/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.9815 - loss: 0.0563 - val_accuracy: 0.2222 - val_loss: 3.5532
# Epoch 50/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9506 - loss: 0.1136 - val_accuracy: 0.1389 - val_loss: 4.6818
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets        : [6, 7, 8, 9, 10]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 6 : 57.78%
# Précision Sujet 7 : 91.11%
# Précision Sujet 8 : 73.33%
# Précision Sujet 9 : 85.56%
# Précision Sujet 10 : 72.22%
# ------------------------------
# MOYENNE GLOBALE TEST : 76.00%
# ------------------------------

# %% [markdown]
# # lstm 256 64 16 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 3
TRAIN_SUBJECTS =   [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)


def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)


def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)


def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(64, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1, verbose=1)


print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 3 ---
# /tmp/ipykernel_8171/3775342649.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 24s 726ms/step - accuracy: 0.4914 - loss: 1.3792 - val_accuracy: 0.0000e+00 - val_loss: 4.0379
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 522ms/step - accuracy: 0.8049 - loss: 0.5595 - val_accuracy: 0.0000e+00 - val_loss: 4.2727
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 22s 541ms/step - accuracy: 0.8568 - loss: 0.4062 - val_accuracy: 0.2000 - val_loss: 2.8370
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 19s 525ms/step - accuracy: 0.8494 - loss: 0.3496 - val_accuracy: 0.4000 - val_loss: 2.7310
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 557ms/step - accuracy: 0.8889 - loss: 0.3109 - val_accuracy: 0.0667 - val_loss: 3.7276
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 527ms/step - accuracy: 0.9407 - loss: 0.1741 - val_accuracy: 0.3111 - val_loss: 3.0475
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 540ms/step - accuracy: 0.9383 - loss: 0.1694 - val_accuracy: 0.6000 - val_loss: 1.1727
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 548ms/step - accuracy: 0.9630 - loss: 0.1174 - val_accuracy: 0.8667 - val_loss: 0.6473
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 554ms/step - accuracy: 0.8815 - loss: 0.2790 - val_accuracy: 0.4667 - val_loss: 2.0685
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 552ms/step - accuracy: 0.9605 - loss: 0.1245 - val_accuracy: 0.7333 - val_loss: 1.1685
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 541ms/step - accuracy: 0.9778 - loss: 0.0515 - val_accuracy: 0.7778 - val_loss: 1.0032
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 564ms/step - accuracy: 0.9877 - loss: 0.0422 - val_accuracy: 0.2889 - val_loss: 3.3832
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 535ms/step - accuracy: 0.9284 - loss: 0.2391 - val_accuracy: 0.1333 - val_loss: 3.5711
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 545ms/step - accuracy: 0.9185 - loss: 0.2255 - val_accuracy: 0.8000 - val_loss: 0.7293
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 547ms/step - accuracy: 0.9753 - loss: 0.1006 - val_accuracy: 0.7333 - val_loss: 1.1430
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 539ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.5778 - val_loss: 1.6539
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 542ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.7333 - val_loss: 1.0055
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 526ms/step - accuracy: 0.9951 - loss: 0.0169 - val_accuracy: 0.6889 - val_loss: 0.9808
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 557ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.7111 - val_loss: 1.4244
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 530ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.6667 - val_loss: 1.5291
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 22s 572ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.7111 - val_loss: 1.3171
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 527ms/step - accuracy: 0.9704 - loss: 0.1238 - val_accuracy: 0.4889 - val_loss: 2.8151
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 519ms/step - accuracy: 0.9481 - loss: 0.1726 - val_accuracy: 0.5111 - val_loss: 2.2744
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 525ms/step - accuracy: 0.9654 - loss: 0.1054 - val_accuracy: 0.6000 - val_loss: 1.5713
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 540ms/step - accuracy: 0.9728 - loss: 0.0928 - val_accuracy: 0.5778 - val_loss: 1.5492
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 535ms/step - accuracy: 0.9877 - loss: 0.0518 - val_accuracy: 0.8222 - val_loss: 0.7930
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 548ms/step - accuracy: 0.9802 - loss: 0.0623 - val_accuracy: 0.9111 - val_loss: 0.5179
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 542ms/step - accuracy: 0.9951 - loss: 0.0296 - val_accuracy: 0.7778 - val_loss: 0.8244
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 555ms/step - accuracy: 0.9975 - loss: 0.0116 - val_accuracy: 0.8000 - val_loss: 0.9153
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 540ms/step - accuracy: 0.9975 - loss: 0.0093 - val_accuracy: 0.8000 - val_loss: 0.8574
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 528ms/step - accuracy: 0.9975 - loss: 0.0155 - val_accuracy: 0.6222 - val_loss: 1.3948
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 539ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.8222 - val_loss: 0.8412
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 525ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7556 - val_loss: 1.2275
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 548ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.7556 - val_loss: 1.2743
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 544ms/step - accuracy: 1.0000 - loss: 9.2527e-04 - val_accuracy: 0.7556 - val_loss: 1.2702
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 618ms/step - accuracy: 1.0000 - loss: 7.9586e-04 - val_accuracy: 0.7556 - val_loss: 1.2609
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 19s 557ms/step - accuracy: 1.0000 - loss: 7.0906e-04 - val_accuracy: 0.7556 - val_loss: 1.2614
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 567ms/step - accuracy: 1.0000 - loss: 6.5100e-04 - val_accuracy: 0.7556 - val_loss: 1.2576
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 542ms/step - accuracy: 1.0000 - loss: 6.0091e-04 - val_accuracy: 0.7556 - val_loss: 1.2599
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 535ms/step - accuracy: 1.0000 - loss: 5.5166e-04 - val_accuracy: 0.7556 - val_loss: 1.2650
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 540ms/step - accuracy: 1.0000 - loss: 5.1762e-04 - val_accuracy: 0.7556 - val_loss: 1.2688
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 542ms/step - accuracy: 1.0000 - loss: 4.7970e-04 - val_accuracy: 0.7556 - val_loss: 1.2687
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 560ms/step - accuracy: 1.0000 - loss: 4.5078e-04 - val_accuracy: 0.7556 - val_loss: 1.2730
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 527ms/step - accuracy: 1.0000 - loss: 4.2919e-04 - val_accuracy: 0.7556 - val_loss: 1.2757
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 532ms/step - accuracy: 1.0000 - loss: 3.9833e-04 - val_accuracy: 0.7556 - val_loss: 1.2774
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 538ms/step - accuracy: 1.0000 - loss: 3.8131e-04 - val_accuracy: 0.7556 - val_loss: 1.2803
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 527ms/step - accuracy: 1.0000 - loss: 3.6113e-04 - val_accuracy: 0.7556 - val_loss: 1.2859
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 538ms/step - accuracy: 1.0000 - loss: 3.4273e-04 - val_accuracy: 0.7556 - val_loss: 1.2880
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 529ms/step - accuracy: 1.0000 - loss: 3.2437e-04 - val_accuracy: 0.7556 - val_loss: 1.2903
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 14s 548ms/step - accuracy: 1.0000 - loss: 3.1020e-04 - val_accuracy: 0.7556 - val_loss: 1.2950
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets        : [1, 2, 4, 5]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 1 : 80.00%
# Précision Sujet 2 : 68.89%
# Précision Sujet 4 : 80.00%
# Précision Sujet 5 : 82.22%
# ------------------------------
# MOYENNE GLOBALE TEST : 77.78%
# ------------------------------

# %% [markdown]
# # lstm 256 64 64 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)


def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)


def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)


def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(64, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.1, verbose=1)


print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 ---
# /tmp/ipykernel_8171/1861078389.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 866ms/step - accuracy: 0.3858 - loss: 2.0042 - val_accuracy: 0.0000e+00 - val_loss: 4.0263
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 752ms/step - accuracy: 0.5185 - loss: 1.3008 - val_accuracy: 0.0000e+00 - val_loss: 5.1426
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 770ms/step - accuracy: 0.6142 - loss: 1.0844 - val_accuracy: 0.0000e+00 - val_loss: 4.9535
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 966ms/step - accuracy: 0.6265 - loss: 0.9486 - val_accuracy: 0.0000e+00 - val_loss: 4.4205
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 867ms/step - accuracy: 0.7346 - loss: 0.7523 - val_accuracy: 0.0000e+00 - val_loss: 4.6550
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 974ms/step - accuracy: 0.7438 - loss: 0.6427 - val_accuracy: 0.0000e+00 - val_loss: 4.3586
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 794ms/step - accuracy: 0.8241 - loss: 0.5214 - val_accuracy: 0.0000e+00 - val_loss: 3.7150
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 894ms/step - accuracy: 0.7346 - loss: 0.7247 - val_accuracy: 0.0000e+00 - val_loss: 3.9597
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 781ms/step - accuracy: 0.7716 - loss: 0.5800 - val_accuracy: 0.0000e+00 - val_loss: 3.4366
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 776ms/step - accuracy: 0.7932 - loss: 0.4856 - val_accuracy: 0.0000e+00 - val_loss: 3.1189
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 762ms/step - accuracy: 0.7778 - loss: 0.4997 - val_accuracy: 0.0000e+00 - val_loss: 3.3955
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 787ms/step - accuracy: 0.8210 - loss: 0.4218 - val_accuracy: 0.0000e+00 - val_loss: 2.5867
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 875ms/step - accuracy: 0.8549 - loss: 0.3470 - val_accuracy: 0.0833 - val_loss: 2.4904
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 847ms/step - accuracy: 0.8796 - loss: 0.2908 - val_accuracy: 0.2500 - val_loss: 2.6257
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 754ms/step - accuracy: 0.9074 - loss: 0.2382 - val_accuracy: 0.0556 - val_loss: 3.3405
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 805ms/step - accuracy: 0.9043 - loss: 0.2758 - val_accuracy: 0.0000e+00 - val_loss: 3.8404
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 737ms/step - accuracy: 0.8889 - loss: 0.2919 - val_accuracy: 0.0000e+00 - val_loss: 3.2263
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 753ms/step - accuracy: 0.9043 - loss: 0.2456 - val_accuracy: 0.0000e+00 - val_loss: 3.6824
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 850ms/step - accuracy: 0.9012 - loss: 0.2383 - val_accuracy: 0.0000e+00 - val_loss: 2.8900
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 767ms/step - accuracy: 0.9136 - loss: 0.2323 - val_accuracy: 0.1944 - val_loss: 2.1450
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 840ms/step - accuracy: 0.9290 - loss: 0.2014 - val_accuracy: 0.4167 - val_loss: 1.6620
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 734ms/step - accuracy: 0.8827 - loss: 0.2875 - val_accuracy: 0.0278 - val_loss: 2.3897
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 789ms/step - accuracy: 0.9012 - loss: 0.2334 - val_accuracy: 0.0278 - val_loss: 3.3854
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 767ms/step - accuracy: 0.9074 - loss: 0.2203 - val_accuracy: 0.2222 - val_loss: 2.0932
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 773ms/step - accuracy: 0.9043 - loss: 0.2440 - val_accuracy: 0.0833 - val_loss: 3.9158
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 877ms/step - accuracy: 0.8981 - loss: 0.3079 - val_accuracy: 0.3889 - val_loss: 2.5637
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 791ms/step - accuracy: 0.9414 - loss: 0.1779 - val_accuracy: 0.3056 - val_loss: 2.3737
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 887ms/step - accuracy: 0.9537 - loss: 0.1429 - val_accuracy: 0.3889 - val_loss: 2.1910
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 785ms/step - accuracy: 0.9537 - loss: 0.1681 - val_accuracy: 0.3611 - val_loss: 2.1521
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 841ms/step - accuracy: 0.9475 - loss: 0.1423 - val_accuracy: 0.3333 - val_loss: 2.3999
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 751ms/step - accuracy: 0.9352 - loss: 0.1709 - val_accuracy: 0.3889 - val_loss: 2.4736
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 748ms/step - accuracy: 0.8951 - loss: 0.2616 - val_accuracy: 0.3333 - val_loss: 2.5679
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 817ms/step - accuracy: 0.9074 - loss: 0.2162 - val_accuracy: 0.4167 - val_loss: 1.8922
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 748ms/step - accuracy: 0.9290 - loss: 0.1582 - val_accuracy: 0.4444 - val_loss: 1.8742
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 896ms/step - accuracy: 0.9660 - loss: 0.1149 - val_accuracy: 0.3611 - val_loss: 2.4664
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 918ms/step - accuracy: 0.9722 - loss: 0.0874 - val_accuracy: 0.3889 - val_loss: 2.6946
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 756ms/step - accuracy: 0.9815 - loss: 0.0815 - val_accuracy: 0.4167 - val_loss: 2.0819
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 767ms/step - accuracy: 0.9660 - loss: 0.1032 - val_accuracy: 0.4722 - val_loss: 1.7378
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 840ms/step - accuracy: 0.9815 - loss: 0.0692 - val_accuracy: 0.4444 - val_loss: 2.0693
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 920ms/step - accuracy: 0.9691 - loss: 0.1047 - val_accuracy: 0.5556 - val_loss: 2.3419
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 762ms/step - accuracy: 0.9691 - loss: 0.1068 - val_accuracy: 0.3889 - val_loss: 2.8576
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 916ms/step - accuracy: 0.9846 - loss: 0.0638 - val_accuracy: 0.4167 - val_loss: 2.9112
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 763ms/step - accuracy: 0.9877 - loss: 0.0501 - val_accuracy: 0.3611 - val_loss: 3.0516
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 822ms/step - accuracy: 0.9846 - loss: 0.0534 - val_accuracy: 0.3611 - val_loss: 2.9077
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 757ms/step - accuracy: 0.9877 - loss: 0.0449 - val_accuracy: 0.4167 - val_loss: 2.5484
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 774ms/step - accuracy: 0.9938 - loss: 0.0404 - val_accuracy: 0.3889 - val_loss: 2.9972
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 873ms/step - accuracy: 0.9907 - loss: 0.0268 - val_accuracy: 0.3889 - val_loss: 3.1608
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 935ms/step - accuracy: 0.9938 - loss: 0.0280 - val_accuracy: 0.3889 - val_loss: 2.9808
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 824ms/step - accuracy: 0.9938 - loss: 0.0276 - val_accuracy: 0.4167 - val_loss: 2.9126
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 765ms/step - accuracy: 0.9630 - loss: 0.1752 - val_accuracy: 0.3333 - val_loss: 3.1358
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets        : [6, 7, 8, 9, 10]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 6 : 65.56%
# Précision Sujet 7 : 90.00%
# Précision Sujet 8 : 67.78%
# Précision Sujet 9 : 86.67%
# Précision Sujet 10 : 63.33%
# ------------------------------
# MOYENNE GLOBALE TEST : 74.67%
# ------------------------------

# %% [markdown]
# # lstm 256 64 64 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4
TRAIN_SUBJECTS =   [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)


def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)


def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)


def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(64, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.1, verbose=1)


print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 ---
# /tmp/ipykernel_8171/1809712462.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 937ms/step - accuracy: 0.3654 - loss: 1.9289 - val_accuracy: 0.0000e+00 - val_loss: 3.4838
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 789ms/step - accuracy: 0.6346 - loss: 1.1132 - val_accuracy: 0.0000e+00 - val_loss: 4.6722
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 901ms/step - accuracy: 0.6988 - loss: 0.8133 - val_accuracy: 0.0000e+00 - val_loss: 4.6346
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 851ms/step - accuracy: 0.8049 - loss: 0.5407 - val_accuracy: 0.0000e+00 - val_loss: 4.3228
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 780ms/step - accuracy: 0.8593 - loss: 0.4186 - val_accuracy: 0.0000e+00 - val_loss: 3.5298
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 797ms/step - accuracy: 0.8642 - loss: 0.3452 - val_accuracy: 0.0222 - val_loss: 2.8020
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 864ms/step - accuracy: 0.8716 - loss: 0.3316 - val_accuracy: 0.5111 - val_loss: 1.8896
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 850ms/step - accuracy: 0.9160 - loss: 0.2471 - val_accuracy: 0.3333 - val_loss: 2.9266
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 764ms/step - accuracy: 0.9210 - loss: 0.2191 - val_accuracy: 0.5333 - val_loss: 2.3142
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 866ms/step - accuracy: 0.9531 - loss: 0.1433 - val_accuracy: 0.6000 - val_loss: 2.1531
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 759ms/step - accuracy: 0.9481 - loss: 0.1239 - val_accuracy: 0.5778 - val_loss: 2.3828
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 916ms/step - accuracy: 0.9802 - loss: 0.0733 - val_accuracy: 0.2667 - val_loss: 3.8627
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 884ms/step - accuracy: 0.9827 - loss: 0.0846 - val_accuracy: 0.5778 - val_loss: 2.4648
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 798ms/step - accuracy: 0.9877 - loss: 0.0655 - val_accuracy: 0.6222 - val_loss: 2.7812
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 874ms/step - accuracy: 0.9827 - loss: 0.0670 - val_accuracy: 0.5556 - val_loss: 2.2232
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 766ms/step - accuracy: 0.9778 - loss: 0.0715 - val_accuracy: 0.2667 - val_loss: 4.0698
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 757ms/step - accuracy: 0.9037 - loss: 0.2438 - val_accuracy: 0.8444 - val_loss: 0.8666
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 886ms/step - accuracy: 0.8765 - loss: 0.3534 - val_accuracy: 0.0000e+00 - val_loss: 4.0134
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 920ms/step - accuracy: 0.9358 - loss: 0.1695 - val_accuracy: 0.0889 - val_loss: 2.8955
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 938ms/step - accuracy: 0.9605 - loss: 0.1238 - val_accuracy: 0.3556 - val_loss: 2.4335
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 905ms/step - accuracy: 0.9852 - loss: 0.0596 - val_accuracy: 0.6667 - val_loss: 1.8684
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 775ms/step - accuracy: 0.9877 - loss: 0.0485 - val_accuracy: 0.5778 - val_loss: 1.9854
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 791ms/step - accuracy: 0.9975 - loss: 0.0178 - val_accuracy: 0.6222 - val_loss: 1.8138
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.5333 - val_loss: 2.2675
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9975 - loss: 0.0137 - val_accuracy: 0.5778 - val_loss: 2.2137
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 794ms/step - accuracy: 0.9877 - loss: 0.0424 - val_accuracy: 0.6000 - val_loss: 2.3348
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 788ms/step - accuracy: 0.9975 - loss: 0.0157 - val_accuracy: 0.5778 - val_loss: 2.5820
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 865ms/step - accuracy: 0.9901 - loss: 0.0218 - val_accuracy: 0.6222 - val_loss: 2.2250
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 770ms/step - accuracy: 0.9901 - loss: 0.0313 - val_accuracy: 0.5333 - val_loss: 2.4974
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 851ms/step - accuracy: 0.9926 - loss: 0.0390 - val_accuracy: 0.4889 - val_loss: 2.6805
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 789ms/step - accuracy: 0.9951 - loss: 0.0218 - val_accuracy: 0.3333 - val_loss: 3.1905
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 870ms/step - accuracy: 0.9951 - loss: 0.0153 - val_accuracy: 0.4889 - val_loss: 2.8782
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 794ms/step - accuracy: 0.9975 - loss: 0.0195 - val_accuracy: 0.5111 - val_loss: 2.7133
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 874ms/step - accuracy: 0.9827 - loss: 0.0433 - val_accuracy: 0.5556 - val_loss: 2.4916
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 773ms/step - accuracy: 0.9926 - loss: 0.0203 - val_accuracy: 0.5111 - val_loss: 2.6760
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 773ms/step - accuracy: 0.9951 - loss: 0.0170 - val_accuracy: 0.5111 - val_loss: 2.9949
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 765ms/step - accuracy: 0.9877 - loss: 0.0268 - val_accuracy: 0.4889 - val_loss: 3.1039
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 838ms/step - accuracy: 0.9877 - loss: 0.0531 - val_accuracy: 0.6000 - val_loss: 2.6044
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 801ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 0.4444 - val_loss: 3.1419
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 837ms/step - accuracy: 0.9951 - loss: 0.0156 - val_accuracy: 0.5778 - val_loss: 2.3047
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 796ms/step - accuracy: 0.9753 - loss: 0.0825 - val_accuracy: 0.5778 - val_loss: 2.0430
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 844ms/step - accuracy: 0.9877 - loss: 0.0321 - val_accuracy: 0.4667 - val_loss: 2.2539
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 766ms/step - accuracy: 0.9877 - loss: 0.0453 - val_accuracy: 0.4667 - val_loss: 2.4163
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 831ms/step - accuracy: 0.9901 - loss: 0.0244 - val_accuracy: 0.5111 - val_loss: 2.2391
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 863ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.5333 - val_loss: 2.3600
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 862ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.5778 - val_loss: 2.3645
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 865ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.5333 - val_loss: 2.4071
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 771ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.5556 - val_loss: 2.3959
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 941ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.5778 - val_loss: 2.4128
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 780ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.5778 - val_loss: 2.4394
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets        : [1, 2, 4, 5]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 1 : 78.89%
# Précision Sujet 2 : 61.11%
# Précision Sujet 4 : 80.00%
# Précision Sujet 5 : 75.56%
# ------------------------------
# MOYENNE GLOBALE TEST : 73.89%
# ------------------------------

# %% [markdown]
# # pas de nouvelle combinaison découverte

# %% [markdown]
# #B4 : transformer

# %% [markdown]
# # tranfo 64 128 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]


df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSVcorrigé")

df = pd.concat(df_list, ignore_index=True)



def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)


def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)



class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 64, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model



model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# Décompression terminée !
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# /tmp/ipykernel_2075/1158336435.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.1512 - loss: 2.3066 - val_accuracy: 0.0000e+00 - val_loss: 4.0373
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.1049 - loss: 2.2610 - val_accuracy: 0.0000e+00 - val_loss: 3.9208
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1512 - loss: 2.1831 - val_accuracy: 0.0000e+00 - val_loss: 3.8199
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3457 - loss: 1.7316 - val_accuracy: 0.0000e+00 - val_loss: 4.6613
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.5278 - loss: 1.0785 - val_accuracy: 0.0000e+00 - val_loss: 4.4208
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5957 - loss: 0.8851 - val_accuracy: 0.0000e+00 - val_loss: 3.6420
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.6975 - loss: 0.6698 - val_accuracy: 0.0000e+00 - val_loss: 4.1254
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7901 - loss: 0.5155 - val_accuracy: 0.0000e+00 - val_loss: 4.2189
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8364 - loss: 0.4451 - val_accuracy: 0.0833 - val_loss: 3.4410
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8519 - loss: 0.3813 - val_accuracy: 0.0000e+00 - val_loss: 4.0484
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8796 - loss: 0.3037 - val_accuracy: 0.0556 - val_loss: 3.5067
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9290 - loss: 0.2146 - val_accuracy: 0.0833 - val_loss: 3.7435
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9259 - loss: 0.2392 - val_accuracy: 0.1389 - val_loss: 3.6405
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9228 - loss: 0.2437 - val_accuracy: 0.2500 - val_loss: 2.3038
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9228 - loss: 0.2024 - val_accuracy: 0.2222 - val_loss: 2.6659
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9383 - loss: 0.1890 - val_accuracy: 0.1389 - val_loss: 4.7206
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9167 - loss: 0.2179 - val_accuracy: 0.4167 - val_loss: 2.4609
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9352 - loss: 0.2187 - val_accuracy: 0.3056 - val_loss: 3.3826
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9753 - loss: 0.0987 - val_accuracy: 0.1944 - val_loss: 2.3284
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9722 - loss: 0.0790 - val_accuracy: 0.3056 - val_loss: 3.7203
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9753 - loss: 0.0745 - val_accuracy: 0.1111 - val_loss: 3.7193
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9722 - loss: 0.0658 - val_accuracy: 0.3056 - val_loss: 3.5842
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9784 - loss: 0.0583 - val_accuracy: 0.4167 - val_loss: 3.6763
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9630 - loss: 0.1276 - val_accuracy: 0.3056 - val_loss: 3.2388
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9907 - loss: 0.0650 - val_accuracy: 0.0556 - val_loss: 4.8636
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9784 - loss: 0.0515 - val_accuracy: 0.3611 - val_loss: 3.1071
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9722 - loss: 0.0822 - val_accuracy: 0.2500 - val_loss: 4.2850
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9784 - loss: 0.0896 - val_accuracy: 0.3333 - val_loss: 2.9030
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9753 - loss: 0.0853 - val_accuracy: 0.3889 - val_loss: 2.5379
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9784 - loss: 0.0701 - val_accuracy: 0.3056 - val_loss: 4.0890
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9784 - loss: 0.0633 - val_accuracy: 0.3611 - val_loss: 2.6550
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9877 - loss: 0.0444 - val_accuracy: 0.4444 - val_loss: 1.8629
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9753 - loss: 0.0945 - val_accuracy: 0.2778 - val_loss: 3.9921
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9753 - loss: 0.1082 - val_accuracy: 0.1111 - val_loss: 4.4928
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9815 - loss: 0.0608 - val_accuracy: 0.4444 - val_loss: 1.3081
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0396 - val_accuracy: 0.1944 - val_loss: 3.9789
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9969 - loss: 0.0248 - val_accuracy: 0.0833 - val_loss: 3.4651
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9907 - loss: 0.0336 - val_accuracy: 0.2222 - val_loss: 3.3574
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.9907 - loss: 0.0262 - val_accuracy: 0.1667 - val_loss: 3.1852
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9877 - loss: 0.0281 - val_accuracy: 0.3333 - val_loss: 3.7183
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9846 - loss: 0.0549 - val_accuracy: 0.1389 - val_loss: 5.5646
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9537 - loss: 0.1877 - val_accuracy: 0.4167 - val_loss: 2.2772
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9290 - loss: 0.2018 - val_accuracy: 0.2500 - val_loss: 4.7949
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9568 - loss: 0.1315 - val_accuracy: 0.2500 - val_loss: 3.0126
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9691 - loss: 0.0964 - val_accuracy: 0.2778 - val_loss: 3.5270
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9877 - loss: 0.0564 - val_accuracy: 0.2778 - val_loss: 3.0927
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9846 - loss: 0.0389 - val_accuracy: 0.3333 - val_loss: 2.9829
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0247 - val_accuracy: 0.3611 - val_loss: 3.0029
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0251 - val_accuracy: 0.3611 - val_loss: 2.8864
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9969 - loss: 0.0180 - val_accuracy: 0.3611 - val_loss: 3.1896
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets         : [6, 7, 8, 9, 10]
# ========================================
# Sujet 6 : 72.22%
# Sujet 7 : 85.56%
# Sujet 8 : 82.22%
# Sujet 9 : 78.89%
# Sujet 10 : 68.89%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 77.56%
# ------------------------------

# %% [markdown]
# # traqnfo 64 128 32 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSVcorrigé")

df = pd.concat(df_list, ignore_index=True)




def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)



def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)



class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 64, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model



model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# /tmp/ipykernel_2075/3392432443.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.1259 - loss: 2.3914 - val_accuracy: 0.0000e+00 - val_loss: 3.5985
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.1481 - loss: 2.1945 - val_accuracy: 0.0000e+00 - val_loss: 4.3376
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.2593 - loss: 1.9037 - val_accuracy: 0.0000e+00 - val_loss: 4.5699
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.5679 - loss: 1.1157 - val_accuracy: 0.0000e+00 - val_loss: 4.7308
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8815 - loss: 0.4342 - val_accuracy: 0.0000e+00 - val_loss: 4.1390
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9432 - loss: 0.1953 - val_accuracy: 0.2000 - val_loss: 4.3521
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9852 - loss: 0.0617 - val_accuracy: 0.3778 - val_loss: 3.8777
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9951 - loss: 0.0315 - val_accuracy: 0.2889 - val_loss: 4.9361
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.9926 - loss: 0.0385 - val_accuracy: 0.4667 - val_loss: 4.8312
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9975 - loss: 0.0142 - val_accuracy: 0.4444 - val_loss: 4.4152
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9951 - loss: 0.0170 - val_accuracy: 0.4667 - val_loss: 4.9887
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9951 - loss: 0.0173 - val_accuracy: 0.5333 - val_loss: 4.4538
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9975 - loss: 0.0196 - val_accuracy: 0.3778 - val_loss: 5.4244
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9975 - loss: 0.0125 - val_accuracy: 0.5333 - val_loss: 4.4301
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.4889 - val_loss: 4.5524
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.5333 - val_loss: 4.6918
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.5333 - val_loss: 4.5745
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.5333 - val_loss: 4.7542
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.5333 - val_loss: 4.8232
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 9.2017e-04 - val_accuracy: 0.5333 - val_loss: 4.8882
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 9.8679e-04 - val_accuracy: 0.5333 - val_loss: 4.9015
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 5.9088e-04 - val_accuracy: 0.5333 - val_loss: 4.9407
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 8.2788e-04 - val_accuracy: 0.5111 - val_loss: 4.9847
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 6.1608e-04 - val_accuracy: 0.5111 - val_loss: 5.0242
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 7.7060e-04 - val_accuracy: 0.5111 - val_loss: 5.0691
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 5.4843e-04 - val_accuracy: 0.5111 - val_loss: 5.1142
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 6.9852e-04 - val_accuracy: 0.5111 - val_loss: 5.1389
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 5.9351e-04 - val_accuracy: 0.5333 - val_loss: 5.1246
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 5.8923e-04 - val_accuracy: 0.5333 - val_loss: 5.1498
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 5.7250e-04 - val_accuracy: 0.5333 - val_loss: 5.2071
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 4.2815e-04 - val_accuracy: 0.5333 - val_loss: 5.2588
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 1.0000 - loss: 3.9494e-04 - val_accuracy: 0.5333 - val_loss: 5.3145
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 1.0000 - loss: 4.4918e-04 - val_accuracy: 0.5333 - val_loss: 5.3290
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - accuracy: 1.0000 - loss: 3.9886e-04 - val_accuracy: 0.5333 - val_loss: 5.2985
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 1.0000 - loss: 4.0162e-04 - val_accuracy: 0.5111 - val_loss: 5.2820
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 1.0000 - loss: 3.6992e-04 - val_accuracy: 0.5111 - val_loss: 5.2627
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - accuracy: 1.0000 - loss: 3.7330e-04 - val_accuracy: 0.5111 - val_loss: 5.2943
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 3.7277e-04 - val_accuracy: 0.5111 - val_loss: 5.3378
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 3.7734e-04 - val_accuracy: 0.5111 - val_loss: 5.3409
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 2.4495e-04 - val_accuracy: 0.5111 - val_loss: 5.3336
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 3.1960e-04 - val_accuracy: 0.5111 - val_loss: 5.3518
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 3.0213e-04 - val_accuracy: 0.5111 - val_loss: 5.3763
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 2.8772e-04 - val_accuracy: 0.5111 - val_loss: 5.4078
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 1.0000 - loss: 2.3512e-04 - val_accuracy: 0.5111 - val_loss: 5.4353
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 3.0963e-04 - val_accuracy: 0.5111 - val_loss: 5.4549
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 2.5111e-04 - val_accuracy: 0.5111 - val_loss: 5.4685
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 2.4452e-04 - val_accuracy: 0.5111 - val_loss: 5.4808
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 3.1658e-04 - val_accuracy: 0.5111 - val_loss: 5.4867
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 1.0000 - loss: 2.7604e-04 - val_accuracy: 0.5111 - val_loss: 5.4909
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 2.4859e-04 - val_accuracy: 0.5111 - val_loss: 5.5186
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets         : [1, 2, 4, 5]
# ========================================
# Sujet 1 : 78.89%
# Sujet 2 : 61.11%
# Sujet 4 : 94.44%
# Sujet 5 : 67.78%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 75.56%
# ------------------------------

# %% [markdown]
# # tranqof 128 128 32 train 4 testv 5

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]


df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSVcorrigé")

df = pd.concat(df_list, ignore_index=True)




def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)



def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)



class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 128, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model



model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# /tmp/ipykernel_2075/2835205599.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.1296 - loss: 2.3100 - val_accuracy: 0.0000e+00 - val_loss: 5.0263
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.1049 - loss: 2.2630 - val_accuracy: 0.0000e+00 - val_loss: 4.4914
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1235 - loss: 2.1794 - val_accuracy: 0.0000e+00 - val_loss: 4.5911
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1420 - loss: 2.1253 - val_accuracy: 0.0000e+00 - val_loss: 4.0921
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4784 - loss: 1.4262 - val_accuracy: 0.0278 - val_loss: 2.4232
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7562 - loss: 0.7141 - val_accuracy: 0.0000e+00 - val_loss: 4.1410
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7932 - loss: 0.5151 - val_accuracy: 0.0000e+00 - val_loss: 4.4549
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8580 - loss: 0.3725 - val_accuracy: 0.2778 - val_loss: 2.4922
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8704 - loss: 0.3223 - val_accuracy: 0.0556 - val_loss: 3.6797
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8951 - loss: 0.2848 - val_accuracy: 0.3056 - val_loss: 3.6288
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8981 - loss: 0.2445 - val_accuracy: 0.2500 - val_loss: 2.6892
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8796 - loss: 0.2994 - val_accuracy: 0.1111 - val_loss: 5.5945
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9012 - loss: 0.2757 - val_accuracy: 0.2778 - val_loss: 3.3105
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8673 - loss: 0.3592 - val_accuracy: 0.1667 - val_loss: 5.3407
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9136 - loss: 0.2507 - val_accuracy: 0.1389 - val_loss: 3.6410
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9352 - loss: 0.1912 - val_accuracy: 0.3611 - val_loss: 2.9328
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9630 - loss: 0.1202 - val_accuracy: 0.1944 - val_loss: 4.3683
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9753 - loss: 0.0817 - val_accuracy: 0.2778 - val_loss: 4.2511
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9907 - loss: 0.0441 - val_accuracy: 0.3333 - val_loss: 3.2707
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9352 - loss: 0.1543 - val_accuracy: 0.2778 - val_loss: 4.0571
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9630 - loss: 0.0954 - val_accuracy: 0.4167 - val_loss: 3.1120
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9691 - loss: 0.0935 - val_accuracy: 0.5000 - val_loss: 2.7171
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9568 - loss: 0.1474 - val_accuracy: 0.5556 - val_loss: 2.4746
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9722 - loss: 0.0993 - val_accuracy: 0.4167 - val_loss: 3.4859
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9753 - loss: 0.0723 - val_accuracy: 0.3333 - val_loss: 2.4701
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9846 - loss: 0.0515 - val_accuracy: 0.4167 - val_loss: 2.2806
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0197 - val_accuracy: 0.4167 - val_loss: 2.7576
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9907 - loss: 0.0250 - val_accuracy: 0.3611 - val_loss: 2.2688
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9969 - loss: 0.0273 - val_accuracy: 0.5556 - val_loss: 2.2081
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9969 - loss: 0.0111 - val_accuracy: 0.5278 - val_loss: 2.4778
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.5000 - val_loss: 2.2678
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.5000 - val_loss: 2.2470
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.5000 - val_loss: 2.2386
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.5000 - val_loss: 2.2293
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.5000 - val_loss: 2.2288
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.5278 - val_loss: 2.2162
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.5000 - val_loss: 2.3223
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.4722 - val_loss: 2.4752
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.5000 - val_loss: 2.5536
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.4722 - val_loss: 2.6804
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.4722 - val_loss: 2.7044
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.4722 - val_loss: 2.7166
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.4722 - val_loss: 2.7417
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.4722 - val_loss: 2.6114
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.4722 - val_loss: 2.5725
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.4722 - val_loss: 2.5950
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.4722 - val_loss: 2.6338
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 9.4349e-04 - val_accuracy: 0.4722 - val_loss: 2.6772
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 9.1219e-04 - val_accuracy: 0.4722 - val_loss: 2.6934
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.4722 - val_loss: 2.6970
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets         : [6, 7, 8, 9, 10]
# ========================================
# Sujet 6 : 62.22%
# Sujet 7 : 77.78%
# Sujet 8 : 85.56%
# Sujet 9 : 81.11%
# Sujet 10 : 74.44%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 76.22%
# ------------------------------

# %% [markdown]
# # traqnfro 128 128 32 trzin 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf

if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]


df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)




def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)


def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)



class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 128, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model



model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# /tmp/ipykernel_2075/2589715833.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.1111 - loss: 2.3386 - val_accuracy: 0.0000e+00 - val_loss: 3.6657
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.1037 - loss: 2.2197 - val_accuracy: 0.0000e+00 - val_loss: 4.0426
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.1531 - loss: 2.1370 - val_accuracy: 0.0000e+00 - val_loss: 3.4690
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.4519 - loss: 1.3501 - val_accuracy: 0.0000e+00 - val_loss: 4.0331
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.6938 - loss: 0.7163 - val_accuracy: 0.0000e+00 - val_loss: 4.5941
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.7802 - loss: 0.4963 - val_accuracy: 0.2000 - val_loss: 3.6382
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.8741 - loss: 0.2895 - val_accuracy: 0.4667 - val_loss: 3.5203
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8938 - loss: 0.2398 - val_accuracy: 0.2889 - val_loss: 4.3177
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.8716 - loss: 0.2479 - val_accuracy: 0.4667 - val_loss: 3.5973
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.9210 - loss: 0.2500 - val_accuracy: 0.5111 - val_loss: 3.4802
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9185 - loss: 0.2288 - val_accuracy: 0.3556 - val_loss: 4.4462
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9259 - loss: 0.2000 - val_accuracy: 0.4667 - val_loss: 3.4989
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9531 - loss: 0.1272 - val_accuracy: 0.5333 - val_loss: 3.3593
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9753 - loss: 0.0859 - val_accuracy: 0.3556 - val_loss: 4.8993
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9679 - loss: 0.0968 - val_accuracy: 0.5111 - val_loss: 4.0357
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9778 - loss: 0.0825 - val_accuracy: 0.4889 - val_loss: 4.4998
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9728 - loss: 0.0691 - val_accuracy: 0.4444 - val_loss: 5.4888
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9877 - loss: 0.0515 - val_accuracy: 0.5333 - val_loss: 3.6967
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9852 - loss: 0.0421 - val_accuracy: 0.4444 - val_loss: 4.9643
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9802 - loss: 0.0691 - val_accuracy: 0.4889 - val_loss: 4.4383
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9877 - loss: 0.0342 - val_accuracy: 0.3333 - val_loss: 5.6084
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9877 - loss: 0.0334 - val_accuracy: 0.4222 - val_loss: 5.0007
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9852 - loss: 0.0426 - val_accuracy: 0.4222 - val_loss: 4.5698
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9951 - loss: 0.0226 - val_accuracy: 0.4667 - val_loss: 4.6113
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9975 - loss: 0.0170 - val_accuracy: 0.4667 - val_loss: 5.0275
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9975 - loss: 0.0130 - val_accuracy: 0.4667 - val_loss: 5.1359
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9975 - loss: 0.0074 - val_accuracy: 0.4667 - val_loss: 4.9428
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.4667 - val_loss: 4.9377
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.4667 - val_loss: 5.1494
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.4667 - val_loss: 5.3055
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.4667 - val_loss: 5.4768
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.4667 - val_loss: 5.5369
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.4667 - val_loss: 5.4877
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.4667 - val_loss: 5.3927
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.4667 - val_loss: 5.2795
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 8.7865e-04 - val_accuracy: 0.4667 - val_loss: 5.3086
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.4667 - val_loss: 5.3672
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 9.3858e-04 - val_accuracy: 0.4667 - val_loss: 5.4229
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.4667 - val_loss: 5.5360
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 8.7657e-04 - val_accuracy: 0.4667 - val_loss: 5.6508
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 8.6396e-04 - val_accuracy: 0.4667 - val_loss: 5.6019
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 1.0000 - loss: 8.7027e-04 - val_accuracy: 0.4667 - val_loss: 5.6414
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 6.8869e-04 - val_accuracy: 0.4667 - val_loss: 5.6633
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 6.7916e-04 - val_accuracy: 0.4667 - val_loss: 5.7816
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 7.2843e-04 - val_accuracy: 0.4667 - val_loss: 5.8676
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 6.6869e-04 - val_accuracy: 0.4667 - val_loss: 5.8779
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 5.9017e-04 - val_accuracy: 0.4667 - val_loss: 5.8065
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 7.1213e-04 - val_accuracy: 0.4667 - val_loss: 5.8105
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 8.6453e-04 - val_accuracy: 0.4667 - val_loss: 5.8272
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 5.7089e-04 - val_accuracy: 0.4667 - val_loss: 5.8697
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets         : [1, 2, 4, 5]
# ========================================
# Sujet 1 : 77.78%
# Sujet 2 : 61.11%
# Sujet 4 : 86.67%
# Sujet 5 : 66.67%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 73.06%
# ------------------------------

# %% [markdown]
# # trqsnfo 256 128 32 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSVcorrigé")

df = pd.concat(df_list, ignore_index=True)




def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)



def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)



class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model



model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s-
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# /tmp/ipykernel_2075/1492267384.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.1327 - loss: 2.3456 - val_accuracy: 0.0000e+00 - val_loss: 4.2971
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.0957 - loss: 2.2637 - val_accuracy: 0.0000e+00 - val_loss: 3.4499
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.1265 - loss: 2.1801 - val_accuracy: 0.0000e+00 - val_loss: 3.5016
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.2346 - loss: 1.9413 - val_accuracy: 0.0000e+00 - val_loss: 2.7987
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.6173 - loss: 1.0542 - val_accuracy: 0.0000e+00 - val_loss: 3.8720
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7438 - loss: 0.6446 - val_accuracy: 0.0000e+00 - val_loss: 6.0964
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7377 - loss: 0.6003 - val_accuracy: 0.0556 - val_loss: 4.2138
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8426 - loss: 0.4068 - val_accuracy: 0.0000e+00 - val_loss: 4.8544
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8735 - loss: 0.3442 - val_accuracy: 0.0000e+00 - val_loss: 4.6573
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8302 - loss: 0.4489 - val_accuracy: 0.0278 - val_loss: 5.0392
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8580 - loss: 0.3337 - val_accuracy: 0.0278 - val_loss: 4.7419
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9198 - loss: 0.2590 - val_accuracy: 0.0278 - val_loss: 5.4493
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9722 - loss: 0.1408 - val_accuracy: 0.0556 - val_loss: 5.1176
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9784 - loss: 0.0863 - val_accuracy: 0.0833 - val_loss: 5.0427
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9815 - loss: 0.0610 - val_accuracy: 0.1111 - val_loss: 4.8764
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9815 - loss: 0.0760 - val_accuracy: 0.0833 - val_loss: 5.7097
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.9722 - loss: 0.0959 - val_accuracy: 0.2222 - val_loss: 5.0128
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9846 - loss: 0.0511 - val_accuracy: 0.3333 - val_loss: 4.9631
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9938 - loss: 0.0272 - val_accuracy: 0.3611 - val_loss: 4.0539
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9907 - loss: 0.0286 - val_accuracy: 0.1111 - val_loss: 5.4842
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9969 - loss: 0.0191 - val_accuracy: 0.2222 - val_loss: 4.8949
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9969 - loss: 0.0130 - val_accuracy: 0.1111 - val_loss: 5.6169
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0170 - val_accuracy: 0.1111 - val_loss: 7.1117
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9938 - loss: 0.0251 - val_accuracy: 0.2222 - val_loss: 4.9980
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9969 - loss: 0.0240 - val_accuracy: 0.1111 - val_loss: 7.0538
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9877 - loss: 0.0275 - val_accuracy: 0.1389 - val_loss: 6.3692
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9907 - loss: 0.0336 - val_accuracy: 0.1389 - val_loss: 7.7784
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9969 - loss: 0.0150 - val_accuracy: 0.2500 - val_loss: 6.5337
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.9907 - loss: 0.0289 - val_accuracy: 0.2500 - val_loss: 6.3560
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9815 - loss: 0.0400 - val_accuracy: 0.1389 - val_loss: 6.1950
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9722 - loss: 0.0711 - val_accuracy: 0.1667 - val_loss: 6.1088
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9691 - loss: 0.0775 - val_accuracy: 0.1111 - val_loss: 6.3737
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9753 - loss: 0.0675 - val_accuracy: 0.0000e+00 - val_loss: 6.9323
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9753 - loss: 0.1011 - val_accuracy: 0.1944 - val_loss: 4.3723
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9352 - loss: 0.2352 - val_accuracy: 0.1944 - val_loss: 5.7672
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9475 - loss: 0.1850 - val_accuracy: 0.2222 - val_loss: 4.9772
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9537 - loss: 0.1453 - val_accuracy: 0.2222 - val_loss: 4.7820
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9784 - loss: 0.0687 - val_accuracy: 0.2222 - val_loss: 4.7231
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9846 - loss: 0.0354 - val_accuracy: 0.0556 - val_loss: 4.7439
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9414 - loss: 0.2318 - val_accuracy: 0.0278 - val_loss: 8.9918
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9568 - loss: 0.1508 - val_accuracy: 0.4444 - val_loss: 3.4066
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9630 - loss: 0.0637 - val_accuracy: 0.1389 - val_loss: 6.6735
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9938 - loss: 0.0287 - val_accuracy: 0.1389 - val_loss: 7.3765
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.1667 - val_loss: 7.0269
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.2500 - val_loss: 6.6931
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.2500 - val_loss: 6.5195
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.2500 - val_loss: 6.5327
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.2500 - val_loss: 6.5457
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.2778 - val_loss: 6.6275
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.2778 - val_loss: 6.7601
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets         : [6, 7, 8, 9, 10]
# ========================================
# Sujet 6 : 72.22%
# Sujet 7 : 92.22%
# Sujet 8 : 82.22%
# Sujet 9 : 80.00%
# Sujet 10 : 80.00%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 81.33%
# ------------------------------

# %% [markdown]
# # transfo 256 128 32 trzin 5 tedt 4

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]


df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSVcorrigé")

df = pd.concat(df_list, ignore_index=True)




def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)



def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)



class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model



model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# /tmp/ipykernel_2075/2060818367.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.0988 - loss: 2.3450 - val_accuracy: 0.0000e+00 - val_loss: 4.2509
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1284 - loss: 2.2394 - val_accuracy: 0.0000e+00 - val_loss: 4.1321
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1383 - loss: 2.1478 - val_accuracy: 0.0000e+00 - val_loss: 4.3108
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.3753 - loss: 1.6365 - val_accuracy: 0.0000e+00 - val_loss: 4.0381
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7753 - loss: 0.6426 - val_accuracy: 0.0000e+00 - val_loss: 3.8855
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9111 - loss: 0.2839 - val_accuracy: 0.1333 - val_loss: 2.8169
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9284 - loss: 0.2324 - val_accuracy: 0.6000 - val_loss: 2.0388
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9506 - loss: 0.1665 - val_accuracy: 0.3111 - val_loss: 3.2087
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9827 - loss: 0.1016 - val_accuracy: 0.6000 - val_loss: 2.3582
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9926 - loss: 0.0452 - val_accuracy: 0.8667 - val_loss: 1.1947
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9852 - loss: 0.0654 - val_accuracy: 0.3556 - val_loss: 3.0886
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.9901 - loss: 0.0233 - val_accuracy: 0.6222 - val_loss: 1.8566
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9951 - loss: 0.0309 - val_accuracy: 0.4444 - val_loss: 2.9945
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 25s 2s/step - accuracy: 0.9926 - loss: 0.0177 - val_accuracy: 0.6000 - val_loss: 2.6716
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.6222 - val_loss: 2.9114
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.6222 - val_loss: 3.0828
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.6000 - val_loss: 3.2029
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.6000 - val_loss: 3.2203
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.6000 - val_loss: 3.2467
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 25s 2s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6000 - val_loss: 3.2572
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6000 - val_loss: 3.2801
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6000 - val_loss: 3.3139
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6000 - val_loss: 3.3305
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 9.2304e-04 - val_accuracy: 0.6000 - val_loss: 3.2940
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 1.0000 - loss: 9.5018e-04 - val_accuracy: 0.6000 - val_loss: 3.2543
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 9.0189e-04 - val_accuracy: 0.6000 - val_loss: 3.2427
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 7.2807e-04 - val_accuracy: 0.6000 - val_loss: 3.2515
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 6.6455e-04 - val_accuracy: 0.6000 - val_loss: 3.2597
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 8.4042e-04 - val_accuracy: 0.6000 - val_loss: 3.2150
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 6.7228e-04 - val_accuracy: 0.6000 - val_loss: 3.2268
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 9.1458e-04 - val_accuracy: 0.6000 - val_loss: 3.2746
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 8.5998e-04 - val_accuracy: 0.6000 - val_loss: 3.3586
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 6.9862e-04 - val_accuracy: 0.5333 - val_loss: 3.4783
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 8.6000e-04 - val_accuracy: 0.5333 - val_loss: 3.4153
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 4.8911e-04 - val_accuracy: 0.5556 - val_loss: 3.3507
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 6.2542e-04 - val_accuracy: 0.5778 - val_loss: 3.2934
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 5.2128e-04 - val_accuracy: 0.6000 - val_loss: 3.2464
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 4.7756e-04 - val_accuracy: 0.6000 - val_loss: 3.2540
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 4.3103e-04 - val_accuracy: 0.6000 - val_loss: 3.2825
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 4.6273e-04 - val_accuracy: 0.6000 - val_loss: 3.2214
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 4.4406e-04 - val_accuracy: 0.6000 - val_loss: 3.2447
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 3.8520e-04 - val_accuracy: 0.6000 - val_loss: 3.2333
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 5.1568e-04 - val_accuracy: 0.6000 - val_loss: 3.2652
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 3.1464e-04 - val_accuracy: 0.6000 - val_loss: 3.2683
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 3.2414e-04 - val_accuracy: 0.6000 - val_loss: 3.2671
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 3.2939e-04 - val_accuracy: 0.6000 - val_loss: 3.2753
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 3.7936e-04 - val_accuracy: 0.6000 - val_loss: 3.2738
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 3.7404e-04 - val_accuracy: 0.6000 - val_loss: 3.2494
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 3.3838e-04 - val_accuracy: 0.6000 - val_loss: 3.2826
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 3.6076e-04 - val_accuracy: 0.6000 - val_loss: 3.3954
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets         : [1, 2, 4, 5]
# ========================================
# Sujet 1 : 76.67%
# Sujet 2 : 64.44%
# Sujet 4 : 86.67%
# Sujet 5 : 76.67%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 76.11%
# ------------------------------

# %% [markdown]
# # trasnfo 256 128 32 test sur sujet 3

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4

TRAIN_SUBJECTS = [1, 2, 4, 5, 6, 7, 8, 9, 10]

TEST_SUBJECTS = [3]

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSVcorrigé")

df = pd.concat(df_list, ignore_index=True)




def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)



def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)



class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model



model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# /tmp/ipykernel_7893/159801675.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.1193 - loss: 2.3190 - val_accuracy: 0.0000e+00 - val_loss: 3.7281
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.2277 - loss: 1.9548 - val_accuracy: 0.0000e+00 - val_loss: 4.1894
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.5391 - loss: 1.0709 - val_accuracy: 0.0000e+00 - val_loss: 4.7430
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.7229 - loss: 0.7205 - val_accuracy: 0.0000e+00 - val_loss: 3.9512
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.8477 - loss: 0.4284 - val_accuracy: 0.0247 - val_loss: 4.7353
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.8848 - loss: 0.3603 - val_accuracy: 0.2222 - val_loss: 3.3527
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9177 - loss: 0.2339 - val_accuracy: 0.5926 - val_loss: 1.7871
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9561 - loss: 0.1642 - val_accuracy: 0.4691 - val_loss: 2.5125
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9438 - loss: 0.1755 - val_accuracy: 0.5926 - val_loss: 1.8742
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9561 - loss: 0.1245 - val_accuracy: 0.6420 - val_loss: 2.0058
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9534 - loss: 0.1384 - val_accuracy: 0.3704 - val_loss: 2.7780
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9465 - loss: 0.1588 - val_accuracy: 0.5309 - val_loss: 1.9464
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9657 - loss: 0.1223 - val_accuracy: 0.4691 - val_loss: 2.6787
# Epoch 14/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9575 - loss: 0.1136 - val_accuracy: 0.5432 - val_loss: 2.1776
# Epoch 15/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9616 - loss: 0.1338 - val_accuracy: 0.3951 - val_loss: 3.9474
# Epoch 16/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9177 - loss: 0.2550 - val_accuracy: 0.4691 - val_loss: 3.5683
# Epoch 17/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9561 - loss: 0.1474 - val_accuracy: 0.3580 - val_loss: 3.1784
# Epoch 18/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9739 - loss: 0.0931 - val_accuracy: 0.3210 - val_loss: 4.0724
# Epoch 19/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9602 - loss: 0.1412 - val_accuracy: 0.5185 - val_loss: 2.4007
# Epoch 20/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9726 - loss: 0.0938 - val_accuracy: 0.6173 - val_loss: 2.4045
# Epoch 21/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9835 - loss: 0.0527 - val_accuracy: 0.5926 - val_loss: 2.8728
# Epoch 22/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9918 - loss: 0.0309 - val_accuracy: 0.2840 - val_loss: 4.5455
# Epoch 23/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9918 - loss: 0.0230 - val_accuracy: 0.5432 - val_loss: 3.2974
# Epoch 24/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9877 - loss: 0.0358 - val_accuracy: 0.6049 - val_loss: 2.5663
# Epoch 25/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9973 - loss: 0.0160 - val_accuracy: 0.5679 - val_loss: 3.2722
# Epoch 26/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.5556 - val_loss: 3.2535
# Epoch 27/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.5802 - val_loss: 3.2775
# Epoch 28/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.5679 - val_loss: 3.1944
# Epoch 29/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.5926 - val_loss: 3.1012
# Epoch 30/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9986 - loss: 0.0070 - val_accuracy: 0.6296 - val_loss: 3.0768
# Epoch 31/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9863 - loss: 0.0439 - val_accuracy: 0.5062 - val_loss: 3.6763
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9890 - loss: 0.0237 - val_accuracy: 0.5185 - val_loss: 3.5824
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9959 - loss: 0.0134 - val_accuracy: 0.5926 - val_loss: 3.2132
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9835 - loss: 0.0564 - val_accuracy: 0.3827 - val_loss: 4.0251
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9904 - loss: 0.0244 - val_accuracy: 0.5556 - val_loss: 3.1634
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9986 - loss: 0.0099 - val_accuracy: 0.6667 - val_loss: 2.8008
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9959 - loss: 0.0125 - val_accuracy: 0.5556 - val_loss: 3.7850
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9973 - loss: 0.0082 - val_accuracy: 0.5802 - val_loss: 3.2432
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.6296 - val_loss: 2.9596
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5679 - val_loss: 3.4136
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5802 - val_loss: 3.1260
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 1.0000 - loss: 7.9939e-04 - val_accuracy: 0.5802 - val_loss: 3.2301
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 1.0000 - loss: 6.3768e-04 - val_accuracy: 0.5802 - val_loss: 3.3141
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 1.0000 - loss: 7.3632e-04 - val_accuracy: 0.5802 - val_loss: 3.3319
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 1.0000 - loss: 5.6221e-04 - val_accuracy: 0.5802 - val_loss: 3.3654
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 1.0000 - loss: 4.5927e-04 - val_accuracy: 0.5802 - val_loss: 3.3707
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 1.0000 - loss: 5.7833e-04 - val_accuracy: 0.5802 - val_loss: 3.4230
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 1.0000 - loss: 4.1487e-04 - val_accuracy: 0.5802 - val_loss: 3.4097
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 1.0000 - loss: 3.5360e-04 - val_accuracy: 0.5802 - val_loss: 3.3764
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 1.0000 - loss: 3.3258e-04 - val_accuracy: 0.5802 - val_loss: 3.3682
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5, 6, 7, 8, 9, 10]
# Test sur sujets         : [3]
# ========================================
# Sujet 3 : 94.44%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 94.44%
# ------------------------------

# %% [markdown]
# # tzaqfo 256 64 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS =    [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSVcorrigé")

df = pd.concat(df_list, ignore_index=True)




def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)



def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)


class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model


model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# /tmp/ipykernel_2075/3091368324.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.1173 - loss: 2.4119 - val_accuracy: 0.0000e+00 - val_loss: 3.7501
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.1235 - loss: 2.2187 - val_accuracy: 0.0000e+00 - val_loss: 3.9053
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1080 - loss: 2.2559 - val_accuracy: 0.0000e+00 - val_loss: 3.5985
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1605 - loss: 2.1504 - val_accuracy: 0.0000e+00 - val_loss: 4.3578
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.1543 - loss: 2.1437 - val_accuracy: 0.0000e+00 - val_loss: 4.1825
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.3210 - loss: 1.7328 - val_accuracy: 0.0000e+00 - val_loss: 5.6558
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5154 - loss: 1.1629 - val_accuracy: 0.0000e+00 - val_loss: 5.5357
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.6944 - loss: 0.7926 - val_accuracy: 0.0000e+00 - val_loss: 6.0784
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7654 - loss: 0.5949 - val_accuracy: 0.0000e+00 - val_loss: 4.5955
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.7593 - loss: 0.5474 - val_accuracy: 0.0000e+00 - val_loss: 3.3970
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8086 - loss: 0.4666 - val_accuracy: 0.0556 - val_loss: 4.0951
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8704 - loss: 0.3547 - val_accuracy: 0.0000e+00 - val_loss: 6.8019
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8364 - loss: 0.3961 - val_accuracy: 0.2778 - val_loss: 3.8918
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8611 - loss: 0.3284 - val_accuracy: 0.2500 - val_loss: 3.7232
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8796 - loss: 0.2821 - val_accuracy: 0.3333 - val_loss: 3.2911
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9290 - loss: 0.2439 - val_accuracy: 0.1944 - val_loss: 3.6626
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8827 - loss: 0.4090 - val_accuracy: 0.2778 - val_loss: 4.1029
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9043 - loss: 0.3417 - val_accuracy: 0.3611 - val_loss: 3.7419
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8796 - loss: 0.2715 - val_accuracy: 0.2778 - val_loss: 5.5668
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9136 - loss: 0.2310 - val_accuracy: 0.2222 - val_loss: 4.2165
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9444 - loss: 0.1520 - val_accuracy: 0.5833 - val_loss: 2.1698
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9259 - loss: 0.2131 - val_accuracy: 0.3611 - val_loss: 2.7195
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.8827 - loss: 0.2782 - val_accuracy: 0.1667 - val_loss: 5.0921
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8858 - loss: 0.3174 - val_accuracy: 0.1944 - val_loss: 4.9971
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9290 - loss: 0.1838 - val_accuracy: 0.1944 - val_loss: 4.3608
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9167 - loss: 0.2183 - val_accuracy: 0.3056 - val_loss: 3.8232
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9722 - loss: 0.0955 - val_accuracy: 0.4722 - val_loss: 2.2656
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9691 - loss: 0.0845 - val_accuracy: 0.6111 - val_loss: 2.4661
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9660 - loss: 0.0808 - val_accuracy: 0.5000 - val_loss: 3.0253
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9722 - loss: 0.0716 - val_accuracy: 0.3056 - val_loss: 4.2608
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9938 - loss: 0.0408 - val_accuracy: 0.4167 - val_loss: 4.1897
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9877 - loss: 0.0421 - val_accuracy: 0.6111 - val_loss: 2.1566
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9691 - loss: 0.0920 - val_accuracy: 0.5833 - val_loss: 2.9174
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9846 - loss: 0.0522 - val_accuracy: 0.4722 - val_loss: 4.3992
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9784 - loss: 0.0630 - val_accuracy: 0.4167 - val_loss: 3.3813
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9784 - loss: 0.0636 - val_accuracy: 0.4167 - val_loss: 5.4146
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9753 - loss: 0.0693 - val_accuracy: 0.6944 - val_loss: 2.1554
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9846 - loss: 0.0550 - val_accuracy: 0.5556 - val_loss: 3.3065
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9877 - loss: 0.0540 - val_accuracy: 0.6111 - val_loss: 2.4640
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9691 - loss: 0.1227 - val_accuracy: 0.4722 - val_loss: 5.5061
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9599 - loss: 0.1365 - val_accuracy: 0.6111 - val_loss: 2.4246
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.9506 - loss: 0.1771 - val_accuracy: 0.4167 - val_loss: 3.6121
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9815 - loss: 0.0945 - val_accuracy: 0.3611 - val_loss: 3.0554
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9784 - loss: 0.0636 - val_accuracy: 0.5556 - val_loss: 3.2479
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9907 - loss: 0.0351 - val_accuracy: 0.3611 - val_loss: 3.5134
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9969 - loss: 0.0285 - val_accuracy: 0.3333 - val_loss: 3.3890
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9907 - loss: 0.0233 - val_accuracy: 0.5833 - val_loss: 3.0162
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9969 - loss: 0.0142 - val_accuracy: 0.4444 - val_loss: 3.6844
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9969 - loss: 0.0138 - val_accuracy: 0.4722 - val_loss: 3.3863
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.4722 - val_loss: 3.1688
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets         : [6, 7, 8, 9, 10]
# ========================================
# Sujet 6 : 67.78%
# Sujet 7 : 77.78%
# Sujet 8 : 84.44%
# Sujet 9 : 73.33%
# Sujet 10 : 74.44%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 75.56%
# ------------------------------

# %% [markdown]
# # traqfo 256 64 32 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS =      [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]


df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSVcorrigé")

df = pd.concat(df_list, ignore_index=True)




def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)



def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)



class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model



model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# /tmp/ipykernel_2075/2908309012.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.1185 - loss: 2.3802 - val_accuracy: 0.0000e+00 - val_loss: 3.6094
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.0988 - loss: 2.2446 - val_accuracy: 0.0000e+00 - val_loss: 3.5884
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1457 - loss: 2.1690 - val_accuracy: 0.0000e+00 - val_loss: 3.9223
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3951 - loss: 1.6900 - val_accuracy: 0.0000e+00 - val_loss: 5.2896
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.6444 - loss: 1.0252 - val_accuracy: 0.0000e+00 - val_loss: 3.8536
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.7383 - loss: 0.7152 - val_accuracy: 0.0000e+00 - val_loss: 4.1042
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8025 - loss: 0.4756 - val_accuracy: 0.0222 - val_loss: 4.5909
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.8840 - loss: 0.3427 - val_accuracy: 0.2444 - val_loss: 4.1307
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9160 - loss: 0.2735 - val_accuracy: 0.4000 - val_loss: 4.1606
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9185 - loss: 0.2207 - val_accuracy: 0.4667 - val_loss: 3.2159
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9556 - loss: 0.2010 - val_accuracy: 0.4889 - val_loss: 3.3445
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9136 - loss: 0.2056 - val_accuracy: 0.0222 - val_loss: 6.4100
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.9358 - loss: 0.2171 - val_accuracy: 0.4000 - val_loss: 4.2236
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9654 - loss: 0.1204 - val_accuracy: 0.5778 - val_loss: 1.5837
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9679 - loss: 0.0938 - val_accuracy: 0.5333 - val_loss: 3.0525
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9704 - loss: 0.1022 - val_accuracy: 0.5556 - val_loss: 2.4986
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9802 - loss: 0.0532 - val_accuracy: 0.4222 - val_loss: 3.4688
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9975 - loss: 0.0231 - val_accuracy: 0.5333 - val_loss: 3.7495
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9975 - loss: 0.0183 - val_accuracy: 0.5556 - val_loss: 3.7214
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9951 - loss: 0.0162 - val_accuracy: 0.5333 - val_loss: 3.7080
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9951 - loss: 0.0286 - val_accuracy: 0.4222 - val_loss: 4.1141
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9951 - loss: 0.0164 - val_accuracy: 0.5556 - val_loss: 3.4115
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9951 - loss: 0.0374 - val_accuracy: 0.5556 - val_loss: 3.3414
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9901 - loss: 0.0376 - val_accuracy: 0.5111 - val_loss: 4.2603
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9975 - loss: 0.0177 - val_accuracy: 0.3333 - val_loss: 5.6855
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9901 - loss: 0.0474 - val_accuracy: 0.5111 - val_loss: 3.3198
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9802 - loss: 0.0637 - val_accuracy: 0.4222 - val_loss: 5.6045
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9457 - loss: 0.1920 - val_accuracy: 0.3111 - val_loss: 5.7657
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9259 - loss: 0.2820 - val_accuracy: 0.1111 - val_loss: 6.5751
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9630 - loss: 0.1050 - val_accuracy: 0.3111 - val_loss: 4.8328
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9852 - loss: 0.0567 - val_accuracy: 0.6667 - val_loss: 2.1966
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.9827 - loss: 0.0593 - val_accuracy: 0.3333 - val_loss: 3.8639
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.9901 - loss: 0.0262 - val_accuracy: 0.5556 - val_loss: 1.9156
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9951 - loss: 0.0197 - val_accuracy: 0.4000 - val_loss: 4.5775
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9975 - loss: 0.0181 - val_accuracy: 0.4222 - val_loss: 3.2403
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.4889 - val_loss: 4.1711
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.5111 - val_loss: 4.1552
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.4889 - val_loss: 4.0357
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.4667 - val_loss: 3.8587
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.5333 - val_loss: 3.6502
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.5333 - val_loss: 3.6545
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.5333 - val_loss: 3.6573
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.5333 - val_loss: 3.5391
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5333 - val_loss: 3.4518
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.5333 - val_loss: 3.4281
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.5333 - val_loss: 3.4236
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5556 - val_loss: 3.3614
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5556 - val_loss: 3.3134
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5333 - val_loss: 3.3237
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5333 - val_loss: 3.3293
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets         : [1, 2, 4, 5]
# ========================================
# Sujet 1 : 78.89%
# Sujet 2 : 63.33%
# Sujet 4 : 87.78%
# Sujet 5 : 81.11%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 77.78%
# ------------------------------

# %% [markdown]
# # tranfo 256 32 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS =    [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSVcorrigé")

df = pd.concat(df_list, ignore_index=True)




def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)


def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)



class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(32, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model


model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# Décompression terminée !
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# Nombre total d'observations chargées : 126156
# /tmp/ipykernel_798/3594712538.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 19s 952ms/step - accuracy: 0.1296 - loss: 2.3964 - val_accuracy: 0.0000e+00 - val_loss: 4.7912
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1358 - loss: 2.2491 - val_accuracy: 0.0000e+00 - val_loss: 4.2956
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1790 - loss: 2.0599 - val_accuracy: 0.0000e+00 - val_loss: 3.8118
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 912ms/step - accuracy: 0.5802 - loss: 1.2159 - val_accuracy: 0.0000e+00 - val_loss: 5.5288
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7469 - loss: 0.7032 - val_accuracy: 0.0000e+00 - val_loss: 5.3707
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8333 - loss: 0.4603 - val_accuracy: 0.0000e+00 - val_loss: 4.9631
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8488 - loss: 0.3832 - val_accuracy: 0.0000e+00 - val_loss: 5.2419
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 879ms/step - accuracy: 0.8457 - loss: 0.4332 - val_accuracy: 0.0000e+00 - val_loss: 4.1770
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9074 - loss: 0.2546 - val_accuracy: 0.1111 - val_loss: 3.4540
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9414 - loss: 0.2022 - val_accuracy: 0.0278 - val_loss: 4.3624
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9321 - loss: 0.1996 - val_accuracy: 0.0556 - val_loss: 4.1410
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9630 - loss: 0.1198 - val_accuracy: 0.1111 - val_loss: 4.5075
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 988ms/step - accuracy: 0.9722 - loss: 0.1021 - val_accuracy: 0.1389 - val_loss: 2.6667
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 995ms/step - accuracy: 0.9568 - loss: 0.1768 - val_accuracy: 0.0556 - val_loss: 4.5944
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9722 - loss: 0.0922 - val_accuracy: 0.1667 - val_loss: 4.4632
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9198 - loss: 0.2313 - val_accuracy: 0.2500 - val_loss: 2.8553
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 957ms/step - accuracy: 0.9568 - loss: 0.1705 - val_accuracy: 0.0000e+00 - val_loss: 4.9543
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 881ms/step - accuracy: 0.9784 - loss: 0.0937 - val_accuracy: 0.2222 - val_loss: 2.3578
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 965ms/step - accuracy: 0.9568 - loss: 0.1648 - val_accuracy: 0.3333 - val_loss: 2.3926
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9846 - loss: 0.0736 - val_accuracy: 0.1944 - val_loss: 3.6157
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9784 - loss: 0.0679 - val_accuracy: 0.2222 - val_loss: 2.7708
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 916ms/step - accuracy: 0.9815 - loss: 0.0590 - val_accuracy: 0.1944 - val_loss: 3.7743
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 856ms/step - accuracy: 0.9599 - loss: 0.1208 - val_accuracy: 0.2222 - val_loss: 3.1962
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 977ms/step - accuracy: 0.9506 - loss: 0.1212 - val_accuracy: 0.2778 - val_loss: 2.6591
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 986ms/step - accuracy: 0.9753 - loss: 0.0754 - val_accuracy: 0.1944 - val_loss: 2.8634
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 973ms/step - accuracy: 0.9907 - loss: 0.0273 - val_accuracy: 0.2222 - val_loss: 3.3232
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0247 - val_accuracy: 0.1111 - val_loss: 4.3793
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - accuracy: 0.9938 - loss: 0.0268 - val_accuracy: 0.0833 - val_loss: 4.3218
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 920ms/step - accuracy: 0.9969 - loss: 0.0181 - val_accuracy: 0.4167 - val_loss: 2.7439
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.2500 - val_loss: 3.2484
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9969 - loss: 0.0138 - val_accuracy: 0.2778 - val_loss: 3.9688
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.2222 - val_loss: 3.9986
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 985ms/step - accuracy: 0.9969 - loss: 0.0162 - val_accuracy: 0.2222 - val_loss: 4.0856
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 878ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.1944 - val_loss: 4.2324
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.1944 - val_loss: 3.9048
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.2778 - val_loss: 3.8417
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.2500 - val_loss: 4.1368
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.2222 - val_loss: 4.3288
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 925ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.2222 - val_loss: 4.1528
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 882ms/step - accuracy: 0.9969 - loss: 0.0076 - val_accuracy: 0.2778 - val_loss: 3.6384
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 995ms/step - accuracy: 0.9969 - loss: 0.0055 - val_accuracy: 0.2778 - val_loss: 3.9541
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.1944 - val_loss: 4.2529
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.1944 - val_loss: 4.3603
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.1944 - val_loss: 4.4963
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.1944 - val_loss: 4.5541
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 998ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.1944 - val_loss: 4.5154
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 9.1387e-04 - val_accuracy: 0.1944 - val_loss: 4.4536
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.1667 - val_loss: 4.3557
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 897ms/step - accuracy: 1.0000 - loss: 9.8788e-04 - val_accuracy: 0.1389 - val_loss: 4.4014
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 973ms/step - accuracy: 1.0000 - loss: 9.8334e-04 - val_accuracy: 0.1667 - val_loss: 4.4954
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets         : [6, 7, 8, 9, 10]
# ========================================
# Sujet 6 : 76.67%
# Sujet 7 : 91.11%
# Sujet 8 : 85.56%
# Sujet 9 : 88.89%
# Sujet 10 : 85.56%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 85.56%
# ------------------------------

# %% [markdown]
# # tr 256 32 32 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS =      [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]


df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSVcorrigé")

df = pd.concat(df_list, ignore_index=True)




def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)


def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)


class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(32, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model



model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# Décompression terminée !
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# /tmp/ipykernel_6552/3998335562.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.1160 - loss: 2.3588 - val_accuracy: 0.0000e+00 - val_loss: 2.4631
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.1185 - loss: 2.2997 - val_accuracy: 0.0000e+00 - val_loss: 2.3256
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1235 - loss: 2.2956 - val_accuracy: 0.0000e+00 - val_loss: 2.3388
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.1235 - loss: 2.2924 - val_accuracy: 0.0000e+00 - val_loss: 2.3522
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.1235 - loss: 2.2893 - val_accuracy: 0.0000e+00 - val_loss: 2.3658
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1235 - loss: 2.2863 - val_accuracy: 0.0000e+00 - val_loss: 2.3792
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.1235 - loss: 2.2833 - val_accuracy: 0.0000e+00 - val_loss: 2.3928
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.1235 - loss: 2.2804 - val_accuracy: 0.0000e+00 - val_loss: 2.4061
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1235 - loss: 2.2777 - val_accuracy: 0.0000e+00 - val_loss: 2.4193
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1235 - loss: 2.2749 - val_accuracy: 0.0000e+00 - val_loss: 2.4328
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1235 - loss: 2.2722 - val_accuracy: 0.0000e+00 - val_loss: 2.4460
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1235 - loss: 2.2696 - val_accuracy: 0.0000e+00 - val_loss: 2.4588
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.1235 - loss: 2.2671 - val_accuracy: 0.0000e+00 - val_loss: 2.4717
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.1235 - loss: 2.2646 - val_accuracy: 0.0000e+00 - val_loss: 2.4845
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1235 - loss: 2.2622 - val_accuracy: 0.0000e+00 - val_loss: 2.4978
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1235 - loss: 2.2597 - val_accuracy: 0.0000e+00 - val_loss: 2.5105
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1235 - loss: 2.2574 - val_accuracy: 0.0000e+00 - val_loss: 2.5231
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1235 - loss: 2.2552 - val_accuracy: 0.0000e+00 - val_loss: 2.5358
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1235 - loss: 2.2530 - val_accuracy: 0.0000e+00 - val_loss: 2.5482
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1235 - loss: 2.2507 - val_accuracy: 0.0000e+00 - val_loss: 2.5603
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1235 - loss: 2.2486 - val_accuracy: 0.0000e+00 - val_loss: 2.5730
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1235 - loss: 2.2466 - val_accuracy: 0.0000e+00 - val_loss: 2.5848
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1235 - loss: 2.2446 - val_accuracy: 0.0000e+00 - val_loss: 2.5971
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.1235 - loss: 2.2426 - val_accuracy: 0.0000e+00 - val_loss: 2.6094
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.1235 - loss: 2.2406 - val_accuracy: 0.0000e+00 - val_loss: 2.6214
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1235 - loss: 2.2387 - val_accuracy: 0.0000e+00 - val_loss: 2.6332
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.1235 - loss: 2.2369 - val_accuracy: 0.0000e+00 - val_loss: 2.6453
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.1235 - loss: 2.2350 - val_accuracy: 0.0000e+00 - val_loss: 2.6568
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.1235 - loss: 2.2332 - val_accuracy: 0.0000e+00 - val_loss: 2.6687
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.1235 - loss: 2.2315 - val_accuracy: 0.0000e+00 - val_loss: 2.6803
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1235 - loss: 2.2298 - val_accuracy: 0.0000e+00 - val_loss: 2.6915
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.1235 - loss: 2.2281 - val_accuracy: 0.0000e+00 - val_loss: 2.7031
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1235 - loss: 2.2265 - val_accuracy: 0.0000e+00 - val_loss: 2.7145
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1235 - loss: 2.2249 - val_accuracy: 0.0000e+00 - val_loss: 2.7257
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1235 - loss: 2.2233 - val_accuracy: 0.0000e+00 - val_loss: 2.7372
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.1235 - loss: 2.2217 - val_accuracy: 0.0000e+00 - val_loss: 2.7486
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.1235 - loss: 2.2202 - val_accuracy: 0.0000e+00 - val_loss: 2.7597
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.1235 - loss: 2.2187 - val_accuracy: 0.0000e+00 - val_loss: 2.7709
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1235 - loss: 2.2173 - val_accuracy: 0.0000e+00 - val_loss: 2.7818
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1235 - loss: 2.2158 - val_accuracy: 0.0000e+00 - val_loss: 2.7924
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1235 - loss: 2.2145 - val_accuracy: 0.0000e+00 - val_loss: 2.8035
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.1235 - loss: 2.2131 - val_accuracy: 0.0000e+00 - val_loss: 2.8142
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1235 - loss: 2.2118 - val_accuracy: 0.0000e+00 - val_loss: 2.8252
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.1235 - loss: 2.2104 - val_accuracy: 0.0000e+00 - val_loss: 2.8360
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.1235 - loss: 2.2091 - val_accuracy: 0.0000e+00 - val_loss: 2.8462
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.1235 - loss: 2.2079 - val_accuracy: 0.0000e+00 - val_loss: 2.8569
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.1235 - loss: 2.2066 - val_accuracy: 0.0000e+00 - val_loss: 2.8675
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1235 - loss: 2.2054 - val_accuracy: 0.0000e+00 - val_loss: 2.8778
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.1235 - loss: 2.2043 - val_accuracy: 0.0000e+00 - val_loss: 2.8880
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1235 - loss: 2.2031 - val_accuracy: 0.0000e+00 - val_loss: 2.8987
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets         : [1, 2, 4, 5]
# ========================================
# Sujet 1 : 11.11%
# Sujet 2 : 11.11%
# Sujet 4 : 11.11%
# Sujet 5 : 11.11%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 11.11%
# ------------------------------

# %% [markdown]
# # tranqof 256 128 16 teain 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS =    [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSVcorrigé")

df = pd.concat(df_list, ignore_index=True)



def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)


def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)



class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model



model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# /tmp/ipykernel_2075/3082803845.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.1327 - loss: 2.4195 - val_accuracy: 0.0000e+00 - val_loss: 3.6928
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.1235 - loss: 2.2168 - val_accuracy: 0.0000e+00 - val_loss: 4.2571
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.2778 - loss: 1.8339 - val_accuracy: 0.0000e+00 - val_loss: 3.5845
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 31s 689ms/step - accuracy: 0.5000 - loss: 1.2158 - val_accuracy: 0.0000e+00 - val_loss: 3.8617
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 666ms/step - accuracy: 0.5926 - loss: 0.8990 - val_accuracy: 0.0000e+00 - val_loss: 4.9787
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 652ms/step - accuracy: 0.6944 - loss: 0.7411 - val_accuracy: 0.0000e+00 - val_loss: 5.0897
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 19s 932ms/step - accuracy: 0.7593 - loss: 0.5879 - val_accuracy: 0.0000e+00 - val_loss: 6.4540
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 645ms/step - accuracy: 0.7500 - loss: 0.5857 - val_accuracy: 0.0556 - val_loss: 4.3801
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 688ms/step - accuracy: 0.8117 - loss: 0.3972 - val_accuracy: 0.0278 - val_loss: 4.8553
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 651ms/step - accuracy: 0.8056 - loss: 0.4948 - val_accuracy: 0.0000e+00 - val_loss: 5.9804
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 645ms/step - accuracy: 0.8117 - loss: 0.3771 - val_accuracy: 0.0278 - val_loss: 5.1296
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 639ms/step - accuracy: 0.8210 - loss: 0.3697 - val_accuracy: 0.1389 - val_loss: 3.8365
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 643ms/step - accuracy: 0.8642 - loss: 0.3233 - val_accuracy: 0.0000e+00 - val_loss: 7.4480
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 669ms/step - accuracy: 0.8920 - loss: 0.3236 - val_accuracy: 0.1944 - val_loss: 4.0340
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 689ms/step - accuracy: 0.9290 - loss: 0.2099 - val_accuracy: 0.0833 - val_loss: 5.7647
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 627ms/step - accuracy: 0.9321 - loss: 0.1802 - val_accuracy: 0.1667 - val_loss: 4.6376
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 641ms/step - accuracy: 0.9444 - loss: 0.1810 - val_accuracy: 0.1944 - val_loss: 2.7995
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 642ms/step - accuracy: 0.9599 - loss: 0.1418 - val_accuracy: 0.1667 - val_loss: 5.1198
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 643ms/step - accuracy: 0.9630 - loss: 0.1144 - val_accuracy: 0.3056 - val_loss: 4.0242
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 654ms/step - accuracy: 0.9660 - loss: 0.1080 - val_accuracy: 0.2222 - val_loss: 3.0386
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 638ms/step - accuracy: 0.8364 - loss: 0.5982 - val_accuracy: 0.3333 - val_loss: 3.1219
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 644ms/step - accuracy: 0.9352 - loss: 0.2429 - val_accuracy: 0.1667 - val_loss: 4.1626
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 639ms/step - accuracy: 0.9383 - loss: 0.2116 - val_accuracy: 0.4167 - val_loss: 2.1390
# Epoch 24/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 645ms/step - accuracy: 0.9568 - loss: 0.1367 - val_accuracy: 0.2222 - val_loss: 4.6318
# Epoch 25/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 657ms/step - accuracy: 0.9475 - loss: 0.1978 - val_accuracy: 0.2222 - val_loss: 4.1470
# Epoch 26/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 653ms/step - accuracy: 0.9506 - loss: 0.1965 - val_accuracy: 0.1667 - val_loss: 5.0380
# Epoch 27/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 649ms/step - accuracy: 0.9537 - loss: 0.2102 - val_accuracy: 0.5278 - val_loss: 2.9445
# Epoch 28/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 636ms/step - accuracy: 0.9290 - loss: 0.2149 - val_accuracy: 0.2500 - val_loss: 3.9993
# Epoch 29/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 634ms/step - accuracy: 0.9630 - loss: 0.1527 - val_accuracy: 0.4722 - val_loss: 2.1686
# Epoch 30/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 693ms/step - accuracy: 0.9815 - loss: 0.0669 - val_accuracy: 0.3333 - val_loss: 2.9723
# Epoch 31/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 647ms/step - accuracy: 0.9938 - loss: 0.0277 - val_accuracy: 0.3056 - val_loss: 3.1706
# Epoch 32/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 638ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.2778 - val_loss: 3.3694
# Epoch 33/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 645ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.3056 - val_loss: 3.3170
# Epoch 34/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 607ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.2778 - val_loss: 3.5090
# Epoch 35/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 638ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.2778 - val_loss: 3.5522
# Epoch 36/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 636ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.3333 - val_loss: 3.4354
# Epoch 37/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 639ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.3333 - val_loss: 3.4558
# Epoch 38/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 645ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.2778 - val_loss: 3.5928
# Epoch 39/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 635ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.2778 - val_loss: 3.7033
# Epoch 40/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 636ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.3056 - val_loss: 3.5663
# Epoch 41/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 631ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.3611 - val_loss: 3.4140
# Epoch 42/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 637ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.3611 - val_loss: 3.2283
# Epoch 43/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 634ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.3611 - val_loss: 3.2576
# Epoch 44/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 644ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.3611 - val_loss: 3.3461
# Epoch 45/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 637ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.3611 - val_loss: 3.4319
# Epoch 46/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 650ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.3611 - val_loss: 3.5038
# Epoch 47/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 634ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.3611 - val_loss: 3.5507
# Epoch 48/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 14s 649ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.3611 - val_loss: 3.6189
# Epoch 49/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 635ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.3611 - val_loss: 3.6518
# Epoch 50/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 638ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.3611 - val_loss: 3.6961
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets         : [6, 7, 8, 9, 10]
# ========================================
# Sujet 6 : 80.00%
# Sujet 7 : 92.22%
# Sujet 8 : 84.44%
# Sujet 9 : 85.56%
# Sujet 10 : 93.33%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 87.11%
# ------------------------------

# %% [markdown]
# # tranfof 256 128 16 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS =      [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]


df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSVcorrigé")

df = pd.concat(df_list, ignore_index=True)




def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)



def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)



class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model



model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# /tmp/ipykernel_2075/3834966396.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 27s 751ms/step - accuracy: 0.1259 - loss: 2.2890 - val_accuracy: 0.0000e+00 - val_loss: 4.2646
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 638ms/step - accuracy: 0.2222 - loss: 2.0060 - val_accuracy: 0.0889 - val_loss: 3.9403
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 648ms/step - accuracy: 0.6494 - loss: 0.9159 - val_accuracy: 0.1556 - val_loss: 4.1154
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 641ms/step - accuracy: 0.7951 - loss: 0.5172 - val_accuracy: 0.0444 - val_loss: 4.4411
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 646ms/step - accuracy: 0.8049 - loss: 0.5100 - val_accuracy: 0.0000e+00 - val_loss: 5.0772
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 22s 691ms/step - accuracy: 0.8296 - loss: 0.3905 - val_accuracy: 0.3333 - val_loss: 2.2092
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 645ms/step - accuracy: 0.9185 - loss: 0.2145 - val_accuracy: 0.0444 - val_loss: 6.1982
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 670ms/step - accuracy: 0.9481 - loss: 0.1745 - val_accuracy: 0.2667 - val_loss: 4.7326
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 634ms/step - accuracy: 0.9531 - loss: 0.1864 - val_accuracy: 0.3778 - val_loss: 4.5124
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 642ms/step - accuracy: 0.9358 - loss: 0.1781 - val_accuracy: 0.5778 - val_loss: 3.1631
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 689ms/step - accuracy: 0.9728 - loss: 0.0906 - val_accuracy: 0.5556 - val_loss: 3.9319
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 646ms/step - accuracy: 0.9679 - loss: 0.1400 - val_accuracy: 0.5111 - val_loss: 4.9549
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 651ms/step - accuracy: 0.9654 - loss: 0.1054 - val_accuracy: 0.5556 - val_loss: 4.6965
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 641ms/step - accuracy: 0.9852 - loss: 0.0792 - val_accuracy: 0.5111 - val_loss: 3.9988
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 644ms/step - accuracy: 1.0000 - loss: 0.0233 - val_accuracy: 0.4889 - val_loss: 4.1945
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 672ms/step - accuracy: 0.9877 - loss: 0.0354 - val_accuracy: 0.5556 - val_loss: 3.6445
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 660ms/step - accuracy: 0.9704 - loss: 0.0876 - val_accuracy: 0.4000 - val_loss: 4.6151
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 643ms/step - accuracy: 0.9704 - loss: 0.0899 - val_accuracy: 0.4222 - val_loss: 4.4056
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 706ms/step - accuracy: 0.9901 - loss: 0.0556 - val_accuracy: 0.5111 - val_loss: 3.8451
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 648ms/step - accuracy: 0.9951 - loss: 0.0198 - val_accuracy: 0.5111 - val_loss: 4.0447
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 641ms/step - accuracy: 0.9877 - loss: 0.0613 - val_accuracy: 0.2222 - val_loss: 6.6788
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 22s 676ms/step - accuracy: 0.9531 - loss: 0.1562 - val_accuracy: 0.0000e+00 - val_loss: 7.5791
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 654ms/step - accuracy: 0.9630 - loss: 0.1099 - val_accuracy: 0.3111 - val_loss: 3.9554
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 668ms/step - accuracy: 0.9728 - loss: 0.0967 - val_accuracy: 0.5333 - val_loss: 5.0620
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 713ms/step - accuracy: 0.9802 - loss: 0.0590 - val_accuracy: 0.4667 - val_loss: 5.2848
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 679ms/step - accuracy: 0.9926 - loss: 0.0275 - val_accuracy: 0.5333 - val_loss: 4.8859
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 686ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.5333 - val_loss: 5.4471
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 648ms/step - accuracy: 0.9926 - loss: 0.0195 - val_accuracy: 0.4889 - val_loss: 5.9291
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 22s 694ms/step - accuracy: 0.9926 - loss: 0.0389 - val_accuracy: 0.5333 - val_loss: 5.6455
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 634ms/step - accuracy: 0.9926 - loss: 0.0240 - val_accuracy: 0.4444 - val_loss: 4.5039
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 643ms/step - accuracy: 0.9975 - loss: 0.0056 - val_accuracy: 0.5556 - val_loss: 4.0102
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 688ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.5556 - val_loss: 4.5435
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 644ms/step - accuracy: 1.0000 - loss: 9.7916e-04 - val_accuracy: 0.5556 - val_loss: 4.7214
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 22s 689ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5333 - val_loss: 4.8237
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 657ms/step - accuracy: 1.0000 - loss: 9.8046e-04 - val_accuracy: 0.5333 - val_loss: 4.8930
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 645ms/step - accuracy: 1.0000 - loss: 7.1303e-04 - val_accuracy: 0.5333 - val_loss: 4.9445
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 643ms/step - accuracy: 1.0000 - loss: 6.5201e-04 - val_accuracy: 0.5333 - val_loss: 5.0708
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 642ms/step - accuracy: 1.0000 - loss: 5.3475e-04 - val_accuracy: 0.5333 - val_loss: 5.0893
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 650ms/step - accuracy: 1.0000 - loss: 4.5180e-04 - val_accuracy: 0.5333 - val_loss: 5.1159
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 669ms/step - accuracy: 1.0000 - loss: 7.0941e-04 - val_accuracy: 0.5333 - val_loss: 5.0812
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 656ms/step - accuracy: 1.0000 - loss: 4.7064e-04 - val_accuracy: 0.5333 - val_loss: 5.0998
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 652ms/step - accuracy: 1.0000 - loss: 3.5660e-04 - val_accuracy: 0.5333 - val_loss: 5.1321
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 643ms/step - accuracy: 1.0000 - loss: 4.8620e-04 - val_accuracy: 0.5333 - val_loss: 5.1633
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 646ms/step - accuracy: 1.0000 - loss: 4.8777e-04 - val_accuracy: 0.5333 - val_loss: 5.1634
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 18s 711ms/step - accuracy: 1.0000 - loss: 3.2986e-04 - val_accuracy: 0.5333 - val_loss: 5.2068
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 655ms/step - accuracy: 1.0000 - loss: 3.0467e-04 - val_accuracy: 0.5333 - val_loss: 5.2472
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 641ms/step - accuracy: 1.0000 - loss: 2.6672e-04 - val_accuracy: 0.5333 - val_loss: 5.2872
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 22s 690ms/step - accuracy: 1.0000 - loss: 3.5266e-04 - val_accuracy: 0.5333 - val_loss: 5.3154
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 646ms/step - accuracy: 1.0000 - loss: 2.8062e-04 - val_accuracy: 0.5333 - val_loss: 5.3363
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 22s 700ms/step - accuracy: 1.0000 - loss: 2.5062e-04 - val_accuracy: 0.5333 - val_loss: 5.3489
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets         : [1, 2, 4, 5]
# ========================================
# Sujet 1 : 78.89%
# Sujet 2 : 56.67%
# Sujet 4 : 88.89%
# Sujet 5 : 73.33%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 74.44%
# ------------------------------

# %% [markdown]
# # transfo 256 128 16 test sur le sujet 3

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4

TRAIN_SUBJECTS = [1, 2, 4, 5, 6, 7, 8, 9, 10]

TEST_SUBJECTS = [3]

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)



def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)



def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)



class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model


model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# /tmp/ipykernel_7893/1489246465.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 697ms/step - accuracy: 0.1303 - loss: 2.2917 - val_accuracy: 0.0000e+00 - val_loss: 4.0553
# Epoch 2/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 695ms/step - accuracy: 0.2455 - loss: 1.9197 - val_accuracy: 0.0000e+00 - val_loss: 5.8193
# Epoch 3/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 701ms/step - accuracy: 0.6529 - loss: 0.7890 - val_accuracy: 0.1481 - val_loss: 4.3012
# Epoch 4/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 707ms/step - accuracy: 0.6982 - loss: 0.6520 - val_accuracy: 0.1728 - val_loss: 4.0629
# Epoch 5/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 42s 731ms/step - accuracy: 0.8176 - loss: 0.4946 - val_accuracy: 0.0370 - val_loss: 6.0976
# Epoch 6/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 39s 689ms/step - accuracy: 0.8368 - loss: 0.4651 - val_accuracy: 0.1852 - val_loss: 3.6221
# Epoch 7/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 33s 710ms/step - accuracy: 0.8834 - loss: 0.3020 - val_accuracy: 0.4198 - val_loss: 3.4720
# Epoch 8/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 668ms/step - accuracy: 0.9314 - loss: 0.2170 - val_accuracy: 0.0000e+00 - val_loss: 6.8983
# Epoch 9/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 669ms/step - accuracy: 0.9355 - loss: 0.1856 - val_accuracy: 0.1975 - val_loss: 4.7618
# Epoch 10/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 706ms/step - accuracy: 0.9492 - loss: 0.1598 - val_accuracy: 0.2099 - val_loss: 4.1057
# Epoch 11/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 681ms/step - accuracy: 0.8999 - loss: 0.2972 - val_accuracy: 0.0000e+00 - val_loss: 6.9425
# Epoch 12/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 677ms/step - accuracy: 0.9067 - loss: 0.2838 - val_accuracy: 0.2346 - val_loss: 3.3685
# Epoch 13/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 706ms/step - accuracy: 0.9506 - loss: 0.1481 - val_accuracy: 0.2099 - val_loss: 3.9987
# Epoch 14/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 693ms/step - accuracy: 0.9698 - loss: 0.0995 - val_accuracy: 0.2469 - val_loss: 4.5761
# Epoch 15/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 699ms/step - accuracy: 0.9849 - loss: 0.0641 - val_accuracy: 0.1358 - val_loss: 4.7919
# Epoch 16/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 675ms/step - accuracy: 0.9822 - loss: 0.0632 - val_accuracy: 0.1605 - val_loss: 4.3266
# Epoch 17/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 691ms/step - accuracy: 0.9822 - loss: 0.0619 - val_accuracy: 0.1605 - val_loss: 4.7806
# Epoch 18/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 42s 707ms/step - accuracy: 0.9794 - loss: 0.0669 - val_accuracy: 0.5062 - val_loss: 3.7165
# Epoch 19/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 682ms/step - accuracy: 0.9369 - loss: 0.2335 - val_accuracy: 0.0247 - val_loss: 8.3533
# Epoch 20/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 33s 715ms/step - accuracy: 0.9575 - loss: 0.1423 - val_accuracy: 0.6173 - val_loss: 3.0433
# Epoch 21/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 698ms/step - accuracy: 0.9726 - loss: 0.0996 - val_accuracy: 0.1235 - val_loss: 6.3734
# Epoch 22/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 39s 676ms/step - accuracy: 0.9630 - loss: 0.1218 - val_accuracy: 0.3827 - val_loss: 4.5348
# Epoch 23/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 42s 701ms/step - accuracy: 0.9822 - loss: 0.0598 - val_accuracy: 0.3580 - val_loss: 4.4306
# Epoch 24/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 33s 706ms/step - accuracy: 0.9671 - loss: 0.1282 - val_accuracy: 0.1975 - val_loss: 5.3019
# Epoch 25/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 33s 717ms/step - accuracy: 0.9739 - loss: 0.0958 - val_accuracy: 0.5062 - val_loss: 3.7244
# Epoch 26/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 681ms/step - accuracy: 0.9794 - loss: 0.0699 - val_accuracy: 0.2222 - val_loss: 5.1686
# Epoch 27/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 677ms/step - accuracy: 0.9698 - loss: 0.0740 - val_accuracy: 0.3457 - val_loss: 3.7542
# Epoch 28/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 716ms/step - accuracy: 0.9781 - loss: 0.0752 - val_accuracy: 0.2222 - val_loss: 5.9010
# Epoch 29/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 715ms/step - accuracy: 0.9767 - loss: 0.0847 - val_accuracy: 0.2222 - val_loss: 7.0289
# Epoch 30/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 38s 667ms/step - accuracy: 0.9712 - loss: 0.1183 - val_accuracy: 0.1605 - val_loss: 6.1707
# Epoch 31/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 43s 706ms/step - accuracy: 0.9616 - loss: 0.1402 - val_accuracy: 0.1975 - val_loss: 6.2551
# Epoch 32/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 689ms/step - accuracy: 0.9767 - loss: 0.0718 - val_accuracy: 0.4198 - val_loss: 5.0619
# Epoch 33/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 683ms/step - accuracy: 0.9849 - loss: 0.0502 - val_accuracy: 0.3580 - val_loss: 4.5265
# Epoch 34/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 33s 707ms/step - accuracy: 0.9726 - loss: 0.1055 - val_accuracy: 0.0123 - val_loss: 10.4710
# Epoch 35/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 673ms/step - accuracy: 0.9314 - loss: 0.2508 - val_accuracy: 0.0123 - val_loss: 8.3403
# Epoch 36/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 706ms/step - accuracy: 0.9739 - loss: 0.1060 - val_accuracy: 0.2469 - val_loss: 6.1994
# Epoch 37/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 40s 684ms/step - accuracy: 0.9918 - loss: 0.0280 - val_accuracy: 0.2593 - val_loss: 6.1895
# Epoch 38/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 687ms/step - accuracy: 0.9945 - loss: 0.0237 - val_accuracy: 0.2099 - val_loss: 7.0761
# Epoch 39/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 675ms/step - accuracy: 0.9945 - loss: 0.0251 - val_accuracy: 0.1852 - val_loss: 7.2257
# Epoch 40/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 676ms/step - accuracy: 0.9822 - loss: 0.0871 - val_accuracy: 0.0864 - val_loss: 7.6451
# Epoch 41/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 42s 702ms/step - accuracy: 0.9575 - loss: 0.1606 - val_accuracy: 0.1975 - val_loss: 5.6148
# Epoch 42/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 668ms/step - accuracy: 0.9534 - loss: 0.1740 - val_accuracy: 0.1358 - val_loss: 6.3200
# Epoch 43/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 695ms/step - accuracy: 0.9630 - loss: 0.1393 - val_accuracy: 0.4444 - val_loss: 4.6829
# Epoch 44/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 30s 663ms/step - accuracy: 0.9630 - loss: 0.1309 - val_accuracy: 0.2222 - val_loss: 5.3692
# Epoch 45/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 680ms/step - accuracy: 0.9767 - loss: 0.0780 - val_accuracy: 0.3827 - val_loss: 4.9584
# Epoch 46/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 42s 701ms/step - accuracy: 0.9808 - loss: 0.0682 - val_accuracy: 0.1975 - val_loss: 6.7438
# Epoch 47/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 684ms/step - accuracy: 0.9767 - loss: 0.0969 - val_accuracy: 0.0123 - val_loss: 8.4442
# Epoch 48/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 32s 697ms/step - accuracy: 0.9904 - loss: 0.0442 - val_accuracy: 0.1852 - val_loss: 7.0059
# Epoch 49/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 41s 684ms/step - accuracy: 0.9794 - loss: 0.0897 - val_accuracy: 0.1481 - val_loss: 6.6415
# Epoch 50/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 31s 673ms/step - accuracy: 0.9863 - loss: 0.0659 - val_accuracy: 0.0247 - val_loss: 8.0880
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5, 6, 7, 8, 9, 10]
# Test sur sujets         : [3]
# ========================================
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7cffdefe0ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7cffdefe0ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Sujet 3 : 68.89%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 68.89%
# ------------------------------

# %% [markdown]
# transfo 256 128 64 tain 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS =    [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]


df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN4_CSVcorrigé")

df = pd.concat(df_list, ignore_index=True)




def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)



def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)



class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model



model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# /tmp/ipykernel_2075/930449010.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 24s 3s/step - accuracy: 0.0988 - loss: 2.5041 - val_accuracy: 0.0000e+00 - val_loss: 3.4115
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.0895 - loss: 2.3667 - val_accuracy: 0.0000e+00 - val_loss: 3.9171
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.0802 - loss: 2.3106 - val_accuracy: 0.0000e+00 - val_loss: 4.0236
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.1698 - loss: 2.2161 - val_accuracy: 0.0000e+00 - val_loss: 4.4277
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.1451 - loss: 2.1838 - val_accuracy: 0.0000e+00 - val_loss: 4.2322
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.1883 - loss: 2.0847 - val_accuracy: 0.0000e+00 - val_loss: 4.2010
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.4074 - loss: 1.6919 - val_accuracy: 0.0000e+00 - val_loss: 3.0678
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.5833 - loss: 1.0829 - val_accuracy: 0.0000e+00 - val_loss: 4.2779
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.6667 - loss: 0.7723 - val_accuracy: 0.0000e+00 - val_loss: 4.4290
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.7623 - loss: 0.5618 - val_accuracy: 0.0000e+00 - val_loss: 4.3242
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.7840 - loss: 0.5538 - val_accuracy: 0.0278 - val_loss: 3.1122
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.7840 - loss: 0.5353 - val_accuracy: 0.0556 - val_loss: 3.9159
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.8642 - loss: 0.3415 - val_accuracy: 0.1944 - val_loss: 2.2572
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8704 - loss: 0.2711 - val_accuracy: 0.0833 - val_loss: 4.8163
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.8981 - loss: 0.2502 - val_accuracy: 0.1944 - val_loss: 3.1299
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.8673 - loss: 0.3361 - val_accuracy: 0.0000e+00 - val_loss: 5.3369
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8488 - loss: 0.4671 - val_accuracy: 0.1944 - val_loss: 3.0540
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8241 - loss: 0.3618 - val_accuracy: 0.1667 - val_loss: 3.7210
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9136 - loss: 0.2248 - val_accuracy: 0.1667 - val_loss: 4.2159
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.9414 - loss: 0.1630 - val_accuracy: 0.3056 - val_loss: 3.9460
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.9228 - loss: 0.1593 - val_accuracy: 0.2778 - val_loss: 3.9530
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.9568 - loss: 0.1253 - val_accuracy: 0.2500 - val_loss: 4.0268
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.9722 - loss: 0.0890 - val_accuracy: 0.3056 - val_loss: 4.0755
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.9753 - loss: 0.0811 - val_accuracy: 0.2778 - val_loss: 4.1696
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 0.9784 - loss: 0.0663 - val_accuracy: 0.1944 - val_loss: 4.9146
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.9722 - loss: 0.0815 - val_accuracy: 0.2778 - val_loss: 4.4362
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.9815 - loss: 0.0767 - val_accuracy: 0.1667 - val_loss: 4.3366
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.9753 - loss: 0.0677 - val_accuracy: 0.3611 - val_loss: 3.1339
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.9846 - loss: 0.0491 - val_accuracy: 0.3333 - val_loss: 3.2799
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.9969 - loss: 0.0246 - val_accuracy: 0.2778 - val_loss: 3.7851
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.9969 - loss: 0.0240 - val_accuracy: 0.2500 - val_loss: 3.8287
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9938 - loss: 0.0183 - val_accuracy: 0.2222 - val_loss: 3.7778
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.9969 - loss: 0.0136 - val_accuracy: 0.2500 - val_loss: 3.7043
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9969 - loss: 0.0137 - val_accuracy: 0.3333 - val_loss: 3.2438
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.3889 - val_loss: 3.0212
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9969 - loss: 0.0086 - val_accuracy: 0.4444 - val_loss: 2.9271
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.4444 - val_loss: 2.9189
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.4167 - val_loss: 3.0294
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.4167 - val_loss: 3.1066
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.4167 - val_loss: 3.1547
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.4444 - val_loss: 3.1687
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.4444 - val_loss: 3.1605
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.4722 - val_loss: 3.1348
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.4722 - val_loss: 3.1673
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.4722 - val_loss: 3.2297
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.4444 - val_loss: 3.3075
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.4167 - val_loss: 3.3704
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.4167 - val_loss: 3.4020
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.4167 - val_loss: 3.4163
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.4167 - val_loss: 3.4406
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets         : [6, 7, 8, 9, 10]
# ========================================
# Sujet 6 : 67.78%
# Sujet 7 : 84.44%
# Sujet 8 : 83.33%
# Sujet 9 : 80.00%
# Sujet 10 : 90.00%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 81.11%
# ------------------------------

# %% [markdown]
# # traqnfo 256 128 64 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print("Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS =      [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]


df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN4_CSVcorrigé")

df = pd.concat(df_list, ignore_index=True)




def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)


def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)



class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model



model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 4 (Transformer) ---
# /tmp/ipykernel_2075/2320674280.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.1062 - loss: 2.5368 - val_accuracy: 0.0000e+00 - val_loss: 5.0658
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.1259 - loss: 2.2353 - val_accuracy: 0.0000e+00 - val_loss: 4.4159
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.1086 - loss: 2.1869 - val_accuracy: 0.0000e+00 - val_loss: 3.7176
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.2247 - loss: 2.0651 - val_accuracy: 0.0000e+00 - val_loss: 4.2562
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.5432 - loss: 1.3824 - val_accuracy: 0.0000e+00 - val_loss: 3.8163
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.7136 - loss: 0.7901 - val_accuracy: 0.0000e+00 - val_loss: 4.2209
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 3s/step - accuracy: 0.8370 - loss: 0.5064 - val_accuracy: 0.0000e+00 - val_loss: 4.8823
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8716 - loss: 0.3387 - val_accuracy: 0.0889 - val_loss: 4.1774
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9383 - loss: 0.2083 - val_accuracy: 0.4667 - val_loss: 2.5801
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.9457 - loss: 0.1535 - val_accuracy: 0.3111 - val_loss: 4.2346
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9630 - loss: 0.1091 - val_accuracy: 0.4667 - val_loss: 3.2828
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9704 - loss: 0.0854 - val_accuracy: 0.4444 - val_loss: 3.3240
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9753 - loss: 0.0742 - val_accuracy: 0.4889 - val_loss: 3.5655
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9531 - loss: 0.1513 - val_accuracy: 0.4889 - val_loss: 3.6164
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.9457 - loss: 0.1479 - val_accuracy: 0.4667 - val_loss: 4.5700
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.9827 - loss: 0.0744 - val_accuracy: 0.4222 - val_loss: 4.2568
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 23s 3s/step - accuracy: 0.9679 - loss: 0.0906 - val_accuracy: 0.4444 - val_loss: 4.0368
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9753 - loss: 0.0867 - val_accuracy: 0.4444 - val_loss: 3.7518
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9333 - loss: 0.2023 - val_accuracy: 0.4667 - val_loss: 4.0964
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.9605 - loss: 0.0972 - val_accuracy: 0.3556 - val_loss: 4.3963
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9778 - loss: 0.0840 - val_accuracy: 0.4000 - val_loss: 3.7963
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9901 - loss: 0.0393 - val_accuracy: 0.3556 - val_loss: 5.0523
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9926 - loss: 0.0352 - val_accuracy: 0.3778 - val_loss: 4.4225
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 23s 3s/step - accuracy: 0.9926 - loss: 0.0275 - val_accuracy: 0.3111 - val_loss: 5.2222
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9778 - loss: 0.0433 - val_accuracy: 0.3111 - val_loss: 6.0090
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9827 - loss: 0.0538 - val_accuracy: 0.3778 - val_loss: 5.4159
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.9852 - loss: 0.0454 - val_accuracy: 0.4444 - val_loss: 4.9263
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9951 - loss: 0.0165 - val_accuracy: 0.4000 - val_loss: 5.3341
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9827 - loss: 0.0440 - val_accuracy: 0.4889 - val_loss: 4.8782
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9802 - loss: 0.0742 - val_accuracy: 0.3556 - val_loss: 5.2659
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9951 - loss: 0.0224 - val_accuracy: 0.4000 - val_loss: 5.1443
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9926 - loss: 0.0250 - val_accuracy: 0.3778 - val_loss: 5.5180
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9975 - loss: 0.0111 - val_accuracy: 0.3778 - val_loss: 5.4445
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.4000 - val_loss: 5.2000
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9975 - loss: 0.0054 - val_accuracy: 0.4222 - val_loss: 5.1201
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.4444 - val_loss: 5.1395
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.4889 - val_loss: 5.0591
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9975 - loss: 0.0048 - val_accuracy: 0.4444 - val_loss: 5.4771
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9975 - loss: 0.0060 - val_accuracy: 0.4889 - val_loss: 5.0439
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9926 - loss: 0.0287 - val_accuracy: 0.4000 - val_loss: 5.5037
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.9901 - loss: 0.0321 - val_accuracy: 0.4667 - val_loss: 4.5492
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9802 - loss: 0.0653 - val_accuracy: 0.1333 - val_loss: 7.4003
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.9877 - loss: 0.0274 - val_accuracy: 0.4444 - val_loss: 5.1667
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9951 - loss: 0.0212 - val_accuracy: 0.3556 - val_loss: 5.9402
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9951 - loss: 0.0186 - val_accuracy: 0.4667 - val_loss: 5.2060
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9975 - loss: 0.0137 - val_accuracy: 0.5111 - val_loss: 4.9316
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 18s 3s/step - accuracy: 0.9951 - loss: 0.0128 - val_accuracy: 0.3778 - val_loss: 6.3607
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.2889 - val_loss: 7.1532
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.3333 - val_loss: 6.3908
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.3333 - val_loss: 6.2867
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets         : [1, 2, 4, 5]
# ========================================
# Sujet 1 : 80.00%
# Sujet 2 : 64.44%
# Sujet 4 : 84.44%
# Sujet 5 : 75.56%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 76.11%
# ------------------------------

# %% [markdown]
# # nouvelle combinasion trouvée : 256 128 16 transformer

# %% [markdown]
# # B5 : DTW

# %% [markdown]
# # dtw knn 3 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print(" Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]


df_list = []
print(f"--- 1. Chargement : Train sur {TRAIN_SUBJECTS}, Test sur {TEST_SUBJECTS} ---")

for subject in (TRAIN_SUBJECTS + TEST_SUBJECTS):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

df = pd.concat(df_list, ignore_index=True)

def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling (100 points)...")
df100 = resample_gesture(df, target_len=100)


def eucl_dist(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def dtw_dist(seq1, seq2):
    n, m = len(seq1), len(seq2)
    dtw = np.full((n+1, m+1), np.inf)
    dtw[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = eucl_dist(seq1[i-1], seq2[j-1])
            dtw[i, j] = cost + min(dtw[i-1, j], dtw[i, j-1], dtw[i-1, j-1])
    return dtw[n, m]

def knn_dtw_predict(reference_seq, train_dict, k=3):
    distances = []
    for gesture, sequences in train_dict.items():
        for seq in sequences:
            dist = dtw_dist(reference_seq, seq)
            distances.append((gesture, dist))
    distances.sort(key=lambda x: x[1])
    return Counter([g for g, _ in distances[:k]]).most_common(1)[0][0]

def run_evaluation_by_subject(df_prep, train_list, test_list, k=3):

    train_df = df_prep[df_prep["subject"].isin(train_list)]
    dict_train = defaultdict(list)
    for (g, s, it), group in train_df.groupby(["gesture", "subject", "iter"]):
        dict_train[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())

    all_true, all_pred = [], []

    print(f"\n--- Début des tests sur les sujets {test_list} ---")


    for subj_id in test_list:
        subj_df = df_prep[df_prep["subject"] == subj_id]
        y_true_subj, y_pred_subj = [], []


        for (g, it), group in subj_df.groupby(["gesture", "iter"]):
            seq = group[["x_std", "y_std", "z_std"]].values.tolist()
            pred = knn_dtw_predict(seq, dict_train, k=k)
            y_true_subj.append(g)
            y_pred_subj.append(pred)

        acc_subj = accuracy_score(y_true_subj, y_pred_subj)
        print(f"Résultat Sujet {subj_id} : {acc_subj:.2%}")

        all_true.extend(y_true_subj)
        all_pred.extend(y_pred_subj)


    print("-" * 30)
    print(f" PRÉCISION GLOBALE : {accuracy_score(all_true, all_pred):.2%}")




run_evaluation_by_subject(df100, TRAIN_SUBJECTS, TEST_SUBJECTS, k=3)
# Out:
#  Décompression terminée !
# --- 1. Chargement : Train sur [1, 2, 4, 5], Test sur [6, 7, 8, 9, 10] ---
# Standardisation...
# /tmp/ipykernel_9129/3831591423.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling (100 points)...
#
# --- Début des tests sur les sujets [6, 7, 8, 9, 10] ---
# Résultat Sujet 6 : 86.67%
# Résultat Sujet 7 : 95.56%
# Résultat Sujet 8 : 86.67%
# Résultat Sujet 9 : 97.78%
# Résultat Sujet 10 : 64.44%
# ------------------------------
#  PRÉCISION GLOBALE : 86.22%

# %% [markdown]
# # dtw knn 3 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print(" Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS = [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]


df_list = []
print(f"--- 1. Chargement : Train sur {TRAIN_SUBJECTS}, Test sur {TEST_SUBJECTS} ---")

for subject in (TRAIN_SUBJECTS + TEST_SUBJECTS):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

df = pd.concat(df_list, ignore_index=True)


def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling (100 points)...")
df100 = resample_gesture(df, target_len=100)


def eucl_dist(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def dtw_dist(seq1, seq2):
    n, m = len(seq1), len(seq2)
    dtw = np.full((n+1, m+1), np.inf)
    dtw[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = eucl_dist(seq1[i-1], seq2[j-1])
            dtw[i, j] = cost + min(dtw[i-1, j], dtw[i, j-1], dtw[i-1, j-1])
    return dtw[n, m]

def knn_dtw_predict(reference_seq, train_dict, k=3):
    distances = []
    for gesture, sequences in train_dict.items():
        for seq in sequences:
            dist = dtw_dist(reference_seq, seq)
            distances.append((gesture, dist))
    distances.sort(key=lambda x: x[1])
    return Counter([g for g, _ in distances[:k]]).most_common(1)[0][0]


def run_evaluation_by_subject(df_prep, train_list, test_list, k=3):

    train_df = df_prep[df_prep["subject"].isin(train_list)]
    dict_train = defaultdict(list)
    for (g, s, it), group in train_df.groupby(["gesture", "subject", "iter"]):
        dict_train[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())

    all_true, all_pred = [], []

    print(f"\n--- Début des tests sur les sujets {test_list} ---")


    for subj_id in test_list:
        subj_df = df_prep[df_prep["subject"] == subj_id]
        y_true_subj, y_pred_subj = [], []


        for (g, it), group in subj_df.groupby(["gesture", "iter"]):
            seq = group[["x_std", "y_std", "z_std"]].values.tolist()
            pred = knn_dtw_predict(seq, dict_train, k=k)
            y_true_subj.append(g)
            y_pred_subj.append(pred)

        acc_subj = accuracy_score(y_true_subj, y_pred_subj)
        print(f"Résultat Sujet {subj_id} : {acc_subj:.2%}")

        all_true.extend(y_true_subj)
        all_pred.extend(y_pred_subj)


    print("-" * 30)
    print(f" PRÉCISION GLOBALE : {accuracy_score(all_true, all_pred):.2%}")




run_evaluation_by_subject(df100, TRAIN_SUBJECTS, TEST_SUBJECTS, k=3)
# Out:
# --- 1. Chargement : Train sur [6, 7, 8, 9, 10], Test sur [1, 2, 4, 5] ---
# Standardisation...
# /tmp/ipykernel_9129/307850412.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling (100 points)...
#
# --- Début des tests sur les sujets [1, 2, 4, 5] ---
# Résultat Sujet 1 : 85.56%
# Résultat Sujet 2 : 91.11%
# Résultat Sujet 4 : 96.67%
# Résultat Sujet 5 : 71.11%
# ------------------------------
#  PRÉCISION GLOBALE : 86.11%

# %% [markdown]
# # dtw knn 5 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print(" Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []
print(f"--- 1. Chargement : Train sur {TRAIN_SUBJECTS}, Test sur {TEST_SUBJECTS} ---")

for subject in (TRAIN_SUBJECTS + TEST_SUBJECTS):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

df = pd.concat(df_list, ignore_index=True)


def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling (100 points)...")
df100 = resample_gesture(df, target_len=100)


def eucl_dist(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def dtw_dist(seq1, seq2):
    n, m = len(seq1), len(seq2)
    dtw = np.full((n+1, m+1), np.inf)
    dtw[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = eucl_dist(seq1[i-1], seq2[j-1])
            dtw[i, j] = cost + min(dtw[i-1, j], dtw[i, j-1], dtw[i-1, j-1])
    return dtw[n, m]

def knn_dtw_predict(reference_seq, train_dict, k=5):
    distances = []
    for gesture, sequences in train_dict.items():
        for seq in sequences:
            dist = dtw_dist(reference_seq, seq)
            distances.append((gesture, dist))
    distances.sort(key=lambda x: x[1])
    return Counter([g for g, _ in distances[:k]]).most_common(1)[0][0]

def run_evaluation_by_subject(df_prep, train_list, test_list, k=5):
    train_df = df_prep[df_prep["subject"].isin(train_list)]
    dict_train = defaultdict(list)
    for (g, s, it), group in train_df.groupby(["gesture", "subject", "iter"]):
        dict_train[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())

    all_true, all_pred = [], []

    print(f"\n--- Début des tests sur les sujets {test_list} ---")

    for subj_id in test_list:
        subj_df = df_prep[df_prep["subject"] == subj_id]
        y_true_subj, y_pred_subj = [], []


        for (g, it), group in subj_df.groupby(["gesture", "iter"]):
            seq = group[["x_std", "y_std", "z_std"]].values.tolist()
            pred = knn_dtw_predict(seq, dict_train, k=k)
            y_true_subj.append(g)
            y_pred_subj.append(pred)

        acc_subj = accuracy_score(y_true_subj, y_pred_subj)
        print(f"Résultat Sujet {subj_id} : {acc_subj:.2%}")

        all_true.extend(y_true_subj)
        all_pred.extend(y_pred_subj)


    print("-" * 30)
    print(f" PRÉCISION GLOBALE : {accuracy_score(all_true, all_pred):.2%}")




run_evaluation_by_subject(df100, TRAIN_SUBJECTS, TEST_SUBJECTS, k=5)
# Out:
# --- 1. Chargement : Train sur [1, 2, 4, 5], Test sur [6, 7, 8, 9, 10] ---
# Standardisation...
# /tmp/ipykernel_9129/2372950618.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling (100 points)...
#
# --- Début des tests sur les sujets [6, 7, 8, 9, 10] ---
# Résultat Sujet 6 : 83.33%
# Résultat Sujet 7 : 94.44%
# Résultat Sujet 8 : 82.22%
# Résultat Sujet 9 : 100.00%
# Résultat Sujet 10 : 66.67%
# ------------------------------
#  PRÉCISION GLOBALE : 85.33%

# %% [markdown]
# # dtw knn 5 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print(" Décompression terminée !")

DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS = [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]


df_list = []
print(f"--- 1. Chargement : Train sur {TRAIN_SUBJECTS}, Test sur {TEST_SUBJECTS} ---")

for subject in (TRAIN_SUBJECTS + TEST_SUBJECTS):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

df = pd.concat(df_list, ignore_index=True)


def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling (100 points)...")
df100 = resample_gesture(df, target_len=100)


def eucl_dist(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def dtw_dist(seq1, seq2):
    n, m = len(seq1), len(seq2)
    dtw = np.full((n+1, m+1), np.inf)
    dtw[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = eucl_dist(seq1[i-1], seq2[j-1])
            dtw[i, j] = cost + min(dtw[i-1, j], dtw[i, j-1], dtw[i-1, j-1])
    return dtw[n, m]

def knn_dtw_predict(reference_seq, train_dict, k=5):
    distances = []
    for gesture, sequences in train_dict.items():
        for seq in sequences:
            dist = dtw_dist(reference_seq, seq)
            distances.append((gesture, dist))
    distances.sort(key=lambda x: x[1])
    return Counter([g for g, _ in distances[:k]]).most_common(1)[0][0]


def run_evaluation_by_subject(df_prep, train_list, test_list, k=5):

    train_df = df_prep[df_prep["subject"].isin(train_list)]
    dict_train = defaultdict(list)
    for (g, s, it), group in train_df.groupby(["gesture", "subject", "iter"]):
        dict_train[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())

    all_true, all_pred = [], []

    print(f"\n--- Début des tests sur les sujets {test_list} ---")


    for subj_id in test_list:
        subj_df = df_prep[df_prep["subject"] == subj_id]
        y_true_subj, y_pred_subj = [], []


        for (g, it), group in subj_df.groupby(["gesture", "iter"]):
            seq = group[["x_std", "y_std", "z_std"]].values.tolist()
            pred = knn_dtw_predict(seq, dict_train, k=k)
            y_true_subj.append(g)
            y_pred_subj.append(pred)

        acc_subj = accuracy_score(y_true_subj, y_pred_subj)
        print(f"Résultat Sujet {subj_id} : {acc_subj:.2%}")

        all_true.extend(y_true_subj)
        all_pred.extend(y_pred_subj)


    print("-" * 30)
    print(f" PRÉCISION GLOBALE : {accuracy_score(all_true, all_pred):.2%}")




run_evaluation_by_subject(df100, TRAIN_SUBJECTS, TEST_SUBJECTS, k=5)
# Out:
# --- 1. Chargement : Train sur [6, 7, 8, 9, 10], Test sur [1, 2, 4, 5] ---
# Standardisation...
# /tmp/ipykernel_9129/851468705.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling (100 points)...
#
# --- Début des tests sur les sujets [1, 2, 4, 5] ---
# Résultat Sujet 1 : 83.33%
# Résultat Sujet 2 : 91.11%
# Résultat Sujet 4 : 93.33%
# Résultat Sujet 5 : 73.33%
# ------------------------------
#  PRÉCISION GLOBALE : 85.28%

# %% [markdown]
# # dtw knn 7 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print(" Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]


df_list = []
print(f"--- 1. Chargement : Train sur {TRAIN_SUBJECTS}, Test sur {TEST_SUBJECTS} ---")

for subject in (TRAIN_SUBJECTS + TEST_SUBJECTS):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

df = pd.concat(df_list, ignore_index=True)


def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling (100 points)...")
df100 = resample_gesture(df, target_len=100)


def eucl_dist(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def dtw_dist(seq1, seq2):
    n, m = len(seq1), len(seq2)
    dtw = np.full((n+1, m+1), np.inf)
    dtw[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = eucl_dist(seq1[i-1], seq2[j-1])
            dtw[i, j] = cost + min(dtw[i-1, j], dtw[i, j-1], dtw[i-1, j-1])
    return dtw[n, m]

def knn_dtw_predict(reference_seq, train_dict, k=7):
    distances = []
    for gesture, sequences in train_dict.items():
        for seq in sequences:
            dist = dtw_dist(reference_seq, seq)
            distances.append((gesture, dist))
    distances.sort(key=lambda x: x[1])
    return Counter([g for g, _ in distances[:k]]).most_common(1)[0][0]


def run_evaluation_by_subject(df_prep, train_list, test_list, k=7):

    train_df = df_prep[df_prep["subject"].isin(train_list)]
    dict_train = defaultdict(list)
    for (g, s, it), group in train_df.groupby(["gesture", "subject", "iter"]):
        dict_train[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())

    all_true, all_pred = [], []

    print(f"\n--- Début des tests sur les sujets {test_list} ---")


    for subj_id in test_list:
        subj_df = df_prep[df_prep["subject"] == subj_id]
        y_true_subj, y_pred_subj = [], []


        for (g, it), group in subj_df.groupby(["gesture", "iter"]):
            seq = group[["x_std", "y_std", "z_std"]].values.tolist()
            pred = knn_dtw_predict(seq, dict_train, k=k)
            y_true_subj.append(g)
            y_pred_subj.append(pred)

        acc_subj = accuracy_score(y_true_subj, y_pred_subj)
        print(f"Résultat Sujet {subj_id} : {acc_subj:.2%}")

        all_true.extend(y_true_subj)
        all_pred.extend(y_pred_subj)


    print("-" * 30)
    print(f" PRÉCISION GLOBALE : {accuracy_score(all_true, all_pred):.2%}")




run_evaluation_by_subject(df100, TRAIN_SUBJECTS, TEST_SUBJECTS, k=7)
# Out:
#  Décompression terminée !
# --- 1. Chargement : Train sur [1, 2, 4, 5], Test sur [6, 7, 8, 9, 10] ---
# Standardisation...
# /tmp/ipykernel_1071/1533852638.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling (100 points)...
#
# --- Début des tests sur les sujets [6, 7, 8, 9, 10] ---
# Résultat Sujet 6 : 83.33%
# Résultat Sujet 7 : 93.33%
# Résultat Sujet 8 : 82.22%
# Résultat Sujet 9 : 98.89%
# Résultat Sujet 10 : 66.67%
# ------------------------------
#  PRÉCISION GLOBALE : 84.89%

# %% [markdown]
# # dtw knn 7 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d


if not os.path.exists("/content/temp_data/DOMAIN4_CSVcorrigé"):
    # !unzip -q /content/DOMAIN4_CSVcorrigé.zip -d /content/temp_data
    print(" Décompression terminée !")


DOMAIN_FOLDER = "/content/temp_data/DOMAIN4_CSVcorrigé"
DOMAIN_ID = 4


TRAIN_SUBJECTS = [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]


df_list = []
print(f"--- 1. Chargement : Train sur {TRAIN_SUBJECTS}, Test sur {TEST_SUBJECTS} ---")

for subject in (TRAIN_SUBJECTS + TEST_SUBJECTS):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

df = pd.concat(df_list, ignore_index=True)

def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling (100 points)...")
df100 = resample_gesture(df, target_len=100)

def eucl_dist(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def dtw_dist(seq1, seq2):
    n, m = len(seq1), len(seq2)
    dtw = np.full((n+1, m+1), np.inf)
    dtw[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = eucl_dist(seq1[i-1], seq2[j-1])
            dtw[i, j] = cost + min(dtw[i-1, j], dtw[i, j-1], dtw[i-1, j-1])
    return dtw[n, m]

def knn_dtw_predict(reference_seq, train_dict, k=7):
    distances = []
    for gesture, sequences in train_dict.items():
        for seq in sequences:
            dist = dtw_dist(reference_seq, seq)
            distances.append((gesture, dist))
    distances.sort(key=lambda x: x[1])
    return Counter([g for g, _ in distances[:k]]).most_common(1)[0][0]

def run_evaluation_by_subject(df_prep, train_list, test_list, k=7):

    train_df = df_prep[df_prep["subject"].isin(train_list)]
    dict_train = defaultdict(list)
    for (g, s, it), group in train_df.groupby(["gesture", "subject", "iter"]):
        dict_train[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())

    all_true, all_pred = [], []

    print(f"\n--- Début des tests sur les sujets {test_list} ---")


    for subj_id in test_list:
        subj_df = df_prep[df_prep["subject"] == subj_id]
        y_true_subj, y_pred_subj = [], []

        for (g, it), group in subj_df.groupby(["gesture", "iter"]):
            seq = group[["x_std", "y_std", "z_std"]].values.tolist()
            pred = knn_dtw_predict(seq, dict_train, k=k)
            y_true_subj.append(g)
            y_pred_subj.append(pred)

        acc_subj = accuracy_score(y_true_subj, y_pred_subj)
        print(f"Résultat Sujet {subj_id} : {acc_subj:.2%}")

        all_true.extend(y_true_subj)
        all_pred.extend(y_pred_subj)


    print("-" * 30)
    print(f" PRÉCISION GLOBALE : {accuracy_score(all_true, all_pred):.2%}")




run_evaluation_by_subject(df100, TRAIN_SUBJECTS, TEST_SUBJECTS, k=7)
# Out:
# --- 1. Chargement : Train sur [6, 7, 8, 9, 10], Test sur [1, 2, 4, 5] ---
# Standardisation...
# /tmp/ipykernel_1071/87478730.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling (100 points)...
#
# --- Début des tests sur les sujets [1, 2, 4, 5] ---
# Résultat Sujet 1 : 84.44%
# Résultat Sujet 2 : 92.22%
# Résultat Sujet 4 : 93.33%
# Résultat Sujet 5 : 72.22%
# ------------------------------
#  PRÉCISION GLOBALE : 85.56%

# %% [markdown]
# # C : analyses statistiques

# %% [markdown]
# # C1 : analyses préliminaires

# %% [markdown]
# # C1A : test nelini et friedman préliminaire

# %%
# !pip install scikit_posthocs
# Out:
# Collecting scikit_posthocs
#   Downloading scikit_posthocs-0.14.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from scikit_posthocs) (2.0.2)
# Requirement already satisfied: scipy>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from scikit_posthocs) (1.16.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from scikit_posthocs) (0.14.6)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from scikit_posthocs) (2.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from scikit_posthocs) (0.13.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from scikit_posthocs) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.20.0->scikit_posthocs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.20.0->scikit_posthocs) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.20.0->scikit_posthocs) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikit_posthocs) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikit_posthocs) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikit_posthocs) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikit_posthocs) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikit_posthocs) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikit_posthocs) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikit_posthocs) (3.3.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels->scikit_posthocs) (1.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->scikit_posthocs) (1.17.0)
# Downloading scikit_posthocs-0.14.0-py3-none-any.whl (36 kB)
# Installing collected packages: scikit_posthocs
# Successfully installed scikit_posthocs-0.14.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import friedmanchisquare


data = np.array([
    [96, 93, 94, 99, 95], [90, 87, 87, 88, 82], [100, 98, 92, 99, 98],
    [100, 98, 100, 100, 96], [89, 90, 84, 98, 95], [70, 55, 72, 93, 93],
    [95, 89, 89, 93, 100], [94, 96, 94, 100, 99], [100, 99, 99, 96, 100],
    [90, 93, 85, 93, 96], [100, 98, 99, 98, 96], [97, 93, 88, 94, 83],
    [94, 95, 95, 100, 100], [100, 97, 96, 100, 99], [97, 83, 87, 97, 99],
    [97, 76, 93, 93, 97], [98, 89, 92, 94, 98], [96, 81, 80, 95, 95],
    [98, 91, 98, 98, 99], [98, 91, 96, 98, 96], [98, 99, 95, 95, 96],
    [94, 88, 90, 99, 96], [100, 98, 98, 94, 99], [100, 98, 99, 96, 98],
    [96, 92, 90, 88, 93], [86, 76, 80, 90, 90], [95, 89, 89, 90, 91],
    [98, 97, 97, 100, 100], [100, 95, 96, 94, 100], [99, 95, 98, 94, 100],
    [88, 82, 94, 93, 97], [90, 77, 87, 89, 71], [87, 74, 85, 87, 94],
    [95, 86, 87, 98, 87], [85, 77, 78, 85, 91], [88, 80, 87, 84, 81],
    [98, 95, 99, 92, 95], [86, 86, 94, 81, 94], [100, 100, 100, 100, 100],
    [74, 75, 86, 78, 81]
])

model_names = ['DTW', 'LCSQ', 'EDIT-DIST', 'LSTM', 'TRANSF']
n_obs = data.shape[0]
k_models = data.shape[1]


stat, p_value = friedmanchisquare(*data.T)


df = pd.DataFrame(data, columns=model_names)
ranks = df.rank(axis=1, ascending=False)
mean_ranks = ranks.mean().sort_values()


q_alpha = 2.728
cd = q_alpha * np.sqrt((k_models * (k_models + 1)) / (6 * n_obs))


plt.figure(figsize=(10, 6))


plt.errorbar(mean_ranks.values, range(len(mean_ranks)), xerr=cd/2, fmt='o',
             color='#2563eb', ecolor='#bfdbfe', elinewidth=12, capsize=0, markersize=8)


stats_text = (f"Test de Friedman :\n"
              f"  - Observations (N) = {n_obs}\n"
              f"  - Statistique = {stat:.2f}\n"
              f"  - p-value = {p_value:.2e}\n"
              f"  - ddl = {k_models - 1}")

plt.text(0.95, 0.05, stats_text, transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='bottom', horizontalalignment='right',
         bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))


plt.yticks(range(len(mean_ranks)), mean_ranks.index)
plt.xlabel('Rang Moyen (plus petit = meilleur)')
plt.title('Test de Nemenyi : Comparaison des Modèles (95% CI)')
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()


print(stats_text)
# Out:
# Test de Friedman :
#   - Observations (N) = 40
#   - Statistique = 38.85
#   - p-value = 7.47e-08
#   - ddl = 4

# %% [markdown]
# # C1B :  test de wilcoxon préliminaire

# %%
import numpy as np
import pandas as pd
from scipy.stats import wilcoxon


model_names = ['DTW', 'LCSS', 'Edit Dist', 'LSTM', 'Transformer']
data = np.array([
    [96, 93, 94, 99, 95], [90, 87, 87, 88, 82], [100, 98, 92, 99, 98],
    [100, 98, 100, 100, 96], [89, 90, 84, 98, 95], [70, 55, 72, 93, 93],
    [95, 89, 89, 93, 100], [94, 96, 94, 100, 99], [100, 99, 99, 96, 100],
    [90, 93, 85, 93, 96], [100, 98, 99, 98, 96], [97, 93, 88, 94, 83],
    [94, 95, 95, 100, 100], [100, 97, 96, 100, 99], [97, 83, 87, 97, 99],
    [97, 76, 93, 93, 97], [98, 89, 92, 94, 98], [96, 81, 80, 95, 95],
    [98, 91, 98, 98, 99], [98, 91, 96, 98, 96], [98, 99, 95, 95, 96],
    [94, 88, 90, 99, 96], [100, 98, 98, 94, 99], [100, 98, 99, 96, 98],
    [96, 92, 90, 88, 93], [86, 76, 80, 90, 90], [95, 89, 89, 90, 91],
    [98, 97, 97, 100, 100], [100, 95, 96, 94, 100], [99, 95, 98, 94, 100],
    [88, 82, 94, 93, 97], [90, 77, 87, 89, 71], [87, 74, 85, 87, 94],
    [95, 86, 87, 98, 87], [85, 77, 78, 85, 91], [88, 80, 87, 84, 81],
    [98, 95, 99, 92, 95], [86, 86, 94, 81, 94], [100, 100, 100, 100, 100],
    [74, 75, 86, 78, 81]
])

df_scores = pd.DataFrame(data, columns=model_names)


wilcoxon_table = pd.DataFrame(index=model_names, columns=model_names)

for m_row in model_names:
    for m_col in model_names:
        if m_row == m_col:
            wilcoxon_table.loc[m_row, m_col] = "/"
        else:

            stat, p_value = wilcoxon(df_scores[m_row], df_scores[m_col], zero_method='pratt')

            wilcoxon_table.loc[m_row, m_col] = round(p_value, 4)


print("Tableau des P-values (Wilcoxon signed-rank test) :")
print(wilcoxon_table)
# Out:
# Tableau des P-values (Wilcoxon signed-rank test) :
#                 DTW    LCSS Edit Dist    LSTM Transformer
# DTW               /     0.0    0.0003  0.3613      0.7566
# LCSS            0.0       /    0.0121  0.0002      0.0001
# Edit Dist    0.0003  0.0121         /  0.0224       0.006
# LSTM         0.3613  0.0002    0.0224       /      0.2516
# Transformer  0.7566  0.0001     0.006  0.2516           /

# %% [markdown]
# # C2 : analyses approfondis

# %% [markdown]
# #  C2A : nemini et friedman de la phase approfondis

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import friedmanchisquare


data = np.array([
    [96, 93, 94, 99, 95], [90, 87, 87, 88, 82], [100, 98, 92, 99, 98],
    [100, 98, 100, 100, 96], [89, 90, 84, 98, 95], [70, 55, 72, 93, 93],
    [95, 89, 89, 93, 100], [94, 96, 94, 100, 99], [100, 99, 99, 96, 100],
    [90, 93, 85, 93, 96], [100, 98, 99, 98, 96], [97, 93, 88, 94, 83],
    [94, 95, 95, 100, 100], [100, 97, 96, 100, 99], [97, 83, 87, 97, 99],
    [97, 76, 93, 93, 97], [98, 89, 92, 94, 98], [96, 81, 80, 95, 95],
    [98, 91, 98, 98, 99], [98, 91, 96, 98, 96], [98, 99, 99, 100, 97],
    [94, 88, 92, 93, 94], [100, 98, 99, 100, 98], [100, 98, 95, 91, 99],
    [96, 92, 89, 89, 92], [86, 76, 84, 89, 100], [95, 89, 90, 89, 95],
    [98, 97, 99, 100, 100], [100, 95, 98, 100, 100], [99, 95, 94, 100, 99],
     [88, 82, 94, 93, 96], [90, 77, 87, 89, 83], [87, 74, 85, 87, 89],
    [95, 86, 87, 98, 94], [85, 77, 78, 85, 71], [88, 80, 87, 84, 87],
    [98, 95, 99, 92, 97], [86, 86, 94, 81, 90], [100, 100, 100, 100, 100],
    [74, 75, 86, 78, 92]
])

model_names = ['DTW', 'LCSQ', 'EDIT-DIST', 'LSTM', 'TRANSF']
n_obs = data.shape[0]
k_models = data.shape[1]


stat, p_value = friedmanchisquare(*data.T)


df = pd.DataFrame(data, columns=model_names)
ranks = df.rank(axis=1, ascending=False)
mean_ranks = ranks.mean().sort_values()


q_alpha = 2.728
cd = q_alpha * np.sqrt((k_models * (k_models + 1)) / (6 * n_obs))


plt.figure(figsize=(10, 6))


plt.errorbar(mean_ranks.values, range(len(mean_ranks)), xerr=cd/2, fmt='o',
             color='#2563eb', ecolor='#bfdbfe', elinewidth=12, capsize=0, markersize=8)


stats_text = (f"Test de Friedman :\n"
              f"  - Observations (N) = {n_obs}\n"
              f"  - Statistique = {stat:.2f}\n"
              f"  - p-value = {p_value:.2e}\n"
              f"  - ddl = {k_models - 1}")

plt.text(0.95, 0.05, stats_text, transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='bottom', horizontalalignment='right',
         bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

# Mise en forme
plt.yticks(range(len(mean_ranks)), mean_ranks.index)
plt.xlabel('Rang Moyen (plus petit = meilleur)')
plt.title('Test de Nemenyi : Comparaison des Modèles (95% CI)')
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()


print(stats_text)
# Out:
# Test de Friedman :
#   - Observations (N) = 40
#   - Statistique = 42.19
#   - p-value = 1.52e-08
#   - ddl = 4

# %% [markdown]
# #  C2B :wicoxon de la phase approfondis

# %%
import numpy as np
import pandas as pd
from scipy.stats import wilcoxon


model_names = ['DTW', 'LCSS', 'Edit Dist', 'LSTM', 'Transformer']
data = np.array([
    [96, 93, 94, 99, 95], [90, 87, 87, 88, 82], [100, 98, 92, 99, 98],
    [100, 98, 100, 100, 96], [89, 90, 84, 98, 95], [70, 55, 72, 93, 93],
    [95, 89, 89, 93, 100], [94, 96, 94, 100, 99], [100, 99, 99, 96, 100],
    [90, 93, 85, 93, 96], [100, 98, 99, 98, 96], [97, 93, 88, 94, 83],
    [94, 95, 95, 100, 100], [100, 97, 96, 100, 99], [97, 83, 87, 97, 99],
    [97, 76, 93, 93, 97], [98, 89, 92, 94, 98], [96, 81, 80, 95, 95],
    [98, 91, 98, 98, 99], [98, 91, 96, 98, 96], [98, 99, 99, 100, 97],
    [94, 88, 92, 93, 94], [100, 98, 99, 100, 98], [100, 98, 95, 91, 99],
    [96, 92, 89, 89, 92], [86, 76, 84, 89, 100], [95, 89, 90, 89, 95],
    [98, 97, 99, 100, 100], [100, 95, 98, 100, 100], [99, 95, 94, 100, 99],
     [88, 82, 94, 93, 96], [90, 77, 87, 89, 83], [87, 74, 85, 87, 89],
    [95, 86, 87, 98, 94], [85, 77, 78, 85, 71], [88, 80, 87, 84, 87],
    [98, 95, 99, 92, 97], [86, 86, 94, 81, 90], [100, 100, 100, 100, 100],
    [74, 75, 86, 78, 92]
])
df_scores = pd.DataFrame(data, columns=model_names)


wilcoxon_table = pd.DataFrame(index=model_names, columns=model_names)

for m_row in model_names:
    for m_col in model_names:
        if m_row == m_col:
            wilcoxon_table.loc[m_row, m_col] = "/"
        else:

            stat, p_value = wilcoxon(df_scores[m_row], df_scores[m_col], zero_method='pratt')

            wilcoxon_table.loc[m_row, m_col] = round(p_value, 4)


print("Tableau des P-values (Wilcoxon signed-rank test) :")
print(wilcoxon_table)
# Out:
# Tableau des P-values (Wilcoxon signed-rank test) :
#                 DTW    LCSS Edit Dist    LSTM Transformer
# DTW               /     0.0    0.0007  0.6396      0.9084
# LCSS            0.0       /    0.0096     0.0      0.0001
# Edit Dist    0.0007  0.0096         /  0.0044      0.0028
# LSTM         0.6396     0.0    0.0044       /      0.4581
# Transformer  0.9084  0.0001    0.0028  0.4581           /

# %% [markdown]
# # C3 : analyses pour la question supplémentaire

# %% [markdown]
# # C3A : nemenyi et friedman quesiton supplémentaire ( DTW + MDS)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import friedmanchisquare


data = np.array([
    [98,96, 93, 94, 99, 95], [90,90, 87, 87, 88, 82], [100,100, 98, 92, 99, 98],
    [100,100, 98, 100, 100, 96], [97,89, 90, 84, 98, 95], [86,70, 55, 72, 93, 93],
    [98,95, 89, 89, 93, 100], [98,94, 96, 94, 100, 99], [100,100, 99, 99, 96, 100],
    [99,90, 93, 85, 93, 96], [100,100, 98, 99, 98, 96], [97,97, 93, 88, 94, 83],
    [100,94, 95, 95, 100, 100], [100,100, 97, 96, 100, 99], [99,97, 83, 87, 97, 99],
    [94,97, 76, 93, 93, 97], [99,98, 89, 92, 94, 98], [97,96, 81, 80, 95, 95],
    [100,98, 91, 98, 98, 99], [100,98, 91, 96, 98, 96], [97,98, 99, 99, 100, 97],
    [97,94, 88, 92, 93, 94], [98,100, 98, 99, 100, 98], [100,100, 98, 95, 91, 99],
    [96,96, 92, 89, 89, 92], [85,86, 76, 84, 89, 100], [94,95, 89, 90, 89, 95],
    [100,98, 97, 99, 100, 100], [100,100, 95, 98, 100, 100], [100,99, 95, 94, 100, 99],
     [92,88, 82, 94, 93, 96], [93,90, 77, 87, 89, 83], [89,87, 74, 85, 87, 89],
    [77,95, 86, 87, 98, 94], [81,85, 77, 78, 85, 71], [87,88, 80, 87, 84, 87],
    [99,98, 95, 99, 92, 97], [97,86, 86, 94, 81, 90], [100,100, 100, 100, 100, 100],
    [81,74, 75, 86, 78, 92]
])

model_names = ['DTW + MDS ','DTW', 'LCSS', 'Edit Dist', 'LSTM', 'Transformer']
n_obs = data.shape[0]
k_models = data.shape[1]


stat, p_value = friedmanchisquare(*data.T)


df = pd.DataFrame(data, columns=model_names)
ranks = df.rank(axis=1, ascending=False)
mean_ranks = ranks.mean().sort_values()


q_alpha = 2.728
cd = q_alpha * np.sqrt((k_models * (k_models + 1)) / (6 * n_obs))


plt.figure(figsize=(10, 6))


plt.errorbar(mean_ranks.values, range(len(mean_ranks)), xerr=cd/2, fmt='o',
             color='#2563eb', ecolor='#bfdbfe', elinewidth=12, capsize=0, markersize=8)


stats_text = (f"Test de Friedman :\n"
              f"  - Observations (N) = {n_obs}\n"
              f"  - Statistique = {stat:.2f}\n"
              f"  - p-value = {p_value:.2e}\n"
              f"  - ddl = {k_models - 1}")

plt.text(0.95, 0.05, stats_text, transform=plt.gca().transAxes,
         fontsize=10, verticalalignment='bottom', horizontalalignment='right',
         bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

# Mise en forme
plt.yticks(range(len(mean_ranks)), mean_ranks.index)
plt.xlabel('Rang Moyen (plus petit = meilleur)')
plt.title('Test de Nemenyi : Comparaison des Modèles (95% CI)')
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()


print(stats_text)
# Out:
# Test de Friedman :
#   - Observations (N) = 40
#   - Statistique = 63.18
#   - p-value = 2.67e-12
#   - ddl = 5

# %% [markdown]
# # C3B : Wilxocon quesiton supplémentaire ( DTW + MDS)

# %%
import numpy as np
import pandas as pd
from scipy.stats import wilcoxon


model_names = ['DTW + MDS','DTW', 'LCSQ', 'EDIT-DIST', 'LSTM', 'TRANSF']
data = np.array([
    [98,96, 93, 94, 99, 95], [90,90, 87, 87, 88, 82], [100,100, 98, 92, 99, 98],
    [100,100, 98, 100, 100, 96], [97,89, 90, 84, 98, 95], [86,70, 55, 72, 93, 93],
    [98,95, 89, 89, 93, 100], [98,94, 96, 94, 100, 99], [100,100, 99, 99, 96, 100],
    [99,90, 93, 85, 93, 96], [100,100, 98, 99, 98, 96], [97,97, 93, 88, 94, 83],
    [100,94, 95, 95, 100, 100], [100,100, 97, 96, 100, 99], [99,97, 83, 87, 97, 99],
    [94,97, 76, 93, 93, 97], [99,98, 89, 92, 94, 98], [97,96, 81, 80, 95, 95],
    [100,98, 91, 98, 98, 99], [100,98, 91, 96, 98, 96], [97,98, 99, 99, 100, 97],
    [97,94, 88, 92, 93, 94], [98,100, 98, 99, 100, 98], [100,100, 98, 95, 91, 99],
    [96,96, 92, 89, 89, 92], [85,86, 76, 84, 89, 100], [94,95, 89, 90, 89, 95],
    [100,98, 97, 99, 100, 100], [100,100, 95, 98, 100, 100], [100,99, 95, 94, 100, 99],
     [92,88, 82, 94, 93, 96], [93,90, 77, 87, 89, 83], [89,87, 74, 85, 87, 89],
    [77,95, 86, 87, 98, 94], [81,85, 77, 78, 85, 71], [87,88, 80, 87, 84, 87],
    [99,98, 95, 99, 92, 97], [97,86, 86, 94, 81, 90], [100,100, 100, 100, 100, 100],
    [81,74, 75, 86, 78, 92]
])
df_scores = pd.DataFrame(data, columns=model_names)


wilcoxon_table = pd.DataFrame(index=model_names, columns=model_names)

for m_row in model_names:
    for m_col in model_names:
        if m_row == m_col:
            wilcoxon_table.loc[m_row, m_col] = "/"
        else:

            stat, p_value = wilcoxon(df_scores[m_row], df_scores[m_col], zero_method='pratt')

            wilcoxon_table.loc[m_row, m_col] = round(p_value, 4)


print("Tableau des P-values (Wilcoxon signed-rank test) :")
print(wilcoxon_table)
# Out:
# Tableau des P-values (Wilcoxon signed-rank test) :
#           DTW + MDS     DTW    LCSQ EDIT-DIST    LSTM  TRANSF
# DTW + MDS         /  0.0091     0.0       0.0  0.0171   0.072
# DTW          0.0091       /     0.0    0.0007  0.6396  0.9084
# LCSQ            0.0     0.0       /    0.0096     0.0  0.0001
# EDIT-DIST       0.0  0.0007  0.0096         /  0.0044  0.0028
# LSTM         0.0171  0.6396     0.0    0.0044       /  0.4581
# TRANSF        0.072  0.9084  0.0001    0.0028  0.4581       /

# %% [markdown]
# #D : nouvelle combinaison

# %% [markdown]
# # D1 : transformer

# %% [markdown]
# # trasnfo final 256 128 16

# %%
import pandas as pd
import numpy as np
import os
import shutil
import glob
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf


zip_path = "/content/DOMAIN4_CSVcorrigé.zip"
extract_path = "/content/temp_data"

if os.path.exists(zip_path):
    if os.path.exists(extract_path): shutil.rmtree(extract_path)
    os.makedirs(extract_path, exist_ok=True)

    # !unzip -o -q "{zip_path}" -d "{extract_path}"
else:
    raise FileNotFoundError(f"Fichier {zip_path} introuvable. Upload-le dans Colab.")


all_dirs = [d for d in glob.glob(os.path.join(extract_path, "**/"), recursive=True)
            if "__MACOSX" not in d and d != extract_path]
DOMAIN_FOLDER = max(all_dirs, key=len) if all_dirs else extract_path
DOMAIN_ID = 4


df_list = []
print(f"--- Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:

                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue


                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier n'a été chargé. Vérifiez le contenu du ZIP.")

df = pd.concat(df_list, ignore_index=True)
for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)




def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'),
            'y_std': interp('y_std'),
            'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)


class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model


def test_transformer_user_independent(df_data, epochs=50, batch_size=16):
    total_true, total_pred = [], []
    subjects = sorted(df_data['subject'].unique())

    for subj_out in subjects:
        print(f"\n--- Test subject OUT : {subj_out} ---")
        train_df = df_data[df_data['subject'] != subj_out]
        test_df = df_data[df_data['subject'] == subj_out]

        def df_to_array(df_target):
            X, y = [], []
            for _, group in df_target.groupby(['gesture', 'subject', 'iter']):
                X.append(group[['x_std', 'y_std', 'z_std']].values)
                y.append(group['gesture'].iloc[0])
            return np.array(X), np.array(y)

        X_train, y_train = df_to_array(train_df)
        X_test, y_test = df_to_array(test_df)

        model = create_transformer_model(input_shape=(100, 3), num_classes=10)
        model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)

        y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
        print(f"Exactitude subject {subj_out} : {accuracy_score(y_test, y_pred):.2%}")
        total_true.extend(y_test); total_pred.extend(y_pred)

    print(f"\nExactitude globale Transformer : {accuracy_score(total_true, total_pred):.2%}")
    cm = confusion_matrix(total_true, total_pred)
    ConfusionMatrixDisplay(cm).plot(cmap="Blues"); plt.show()

test_transformer_user_independent(df100)
# Out:
# --- Début du Chargement du Domaine 4 ---
# Standardisation...
# /tmp/ipykernel_2663/2798512447.py:76: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling...
#
# --- Test subject OUT : 1 ---
# Exactitude subject 1 : 96.00%
#
# --- Test subject OUT : 2 ---
# Exactitude subject 2 : 83.00%
#
# --- Test subject OUT : 3 ---
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a265a73a520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a265a73a520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exactitude subject 3 : 89.00%
#
# --- Test subject OUT : 4 ---
# Exactitude subject 4 : 94.00%
#
# --- Test subject OUT : 5 ---
# Exactitude subject 5 : 71.00%
#
# --- Test subject OUT : 6 ---
# Exactitude subject 6 : 87.00%
#
# --- Test subject OUT : 7 ---
# Exactitude subject 7 : 97.00%
#
# --- Test subject OUT : 8 ---
# Exactitude subject 8 : 90.00%
#
# --- Test subject OUT : 9 ---
# Exactitude subject 9 : 100.00%
#
# --- Test subject OUT : 10 ---
# Exactitude subject 10 : 92.00%
#
# Exactitude globale Transformer : 89.90%

# %% [markdown]
# # E : quesiton supplémentaire test ( DTW + MDS)

# %% [markdown]
# # dtw m = 30

# %%
import pandas as pd
import numpy as np
import os
import zipfile
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from scipy.linalg import eigh
from scipy.spatial.distance import cdist


ZIP_PATH = '/content/DOMAIN4_CSVcorrigé.zip'
EXTRACT_FOLDER = '/content/dataset'

if not os.path.exists(EXTRACT_FOLDER):
    with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
        zip_ref.extractall(EXTRACT_FOLDER)
    print("Extraction terminée.")


DOMAIN_FOLDER = os.path.join(EXTRACT_FOLDER, "DOMAIN4_CSVcorrigé")
if not os.path.exists(DOMAIN_FOLDER):
    DOMAIN_FOLDER = EXTRACT_FOLDER


df_list = []
print(f"--- Début du Chargement ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2:
                    continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')

                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = int(number)
                file_df['subject'] = int(subject)
                file_df['iter'] = int(iteration)

                df_list.append(file_df)
            except (FileNotFoundError, Exception):
                continue


df = pd.concat(df_list, ignore_index=True)



def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling à 100 points...")
df100 = resample_gesture(df, target_len=100)


def dtw_dist(seq1, seq2):
    dists = cdist(seq1, seq2, metric='sqeuclidean')
    n, m = dists.shape
    dtw_matrix = np.full((n + 1, m + 1), np.inf)
    dtw_matrix[0, 0] = 0
    for i in range(1, n + 1):
        for j in range(1, m + 1):
            dtw_matrix[i, j] = dists[i-1, j-1] + min(dtw_matrix[i-1, j],
                                                    dtw_matrix[i, j-1],
                                                    dtw_matrix[i-1, j-1])
    return np.sqrt(dtw_matrix[n, m])

def apply_mds_transform(dist_matrix, m=30):
    n = dist_matrix.shape[0]
    D2 = dist_matrix**2
    H = np.eye(n) - np.ones((n, n)) / n
    K = -0.5 * H @ D2 @ H
    vals, vecs = eigh(K, subset_by_index=[n-m, n-1])
    idx = np.argsort(vals)[::-1]
    vals, vecs = vals[idx], vecs[:, idx]
    vals = np.maximum(vals, 0)
    return vecs @ np.diag(np.sqrt(vals))


def run_mds_experiment(df_prep, loop_range=10, m_dims=30):
    all_sequences = []
    all_labels = []
    all_subjects = []

    groups = list(df_prep.groupby(['gesture', 'subject', 'iter']))
    for (g, s, it), group in groups:
        all_sequences.append(group[["x_std", "y_std", "z_std"]].values)
        all_labels.append(g)
        all_subjects.append(s)

    n_total = len(all_sequences)
    print(f"\nCalcul de la matrice de distances DTW ({n_total}x{n_total})...")

    dist_matrix = np.zeros((n_total, n_total))
    for i in range(n_total):
        if i % 50 == 0: print(f"Ligne {i}/{n_total} en cours...")
        for j in range(i + 1, n_total):
            d = dtw_dist(all_sequences[i], all_sequences[j])
            dist_matrix[i, j] = dist_matrix[j, i] = d


    X_features = apply_mds_transform(dist_matrix, m=m_dims)
    y_labels = np.array(all_labels)
    subjects = np.array(all_subjects)

    total_true, total_pred = [], []

    print("\n--- Début des tests Subject-Out ---")
    for s_out in range(1, loop_range + 1):
        train_idx = np.where(subjects != s_out)[0]
        test_idx = np.where(subjects == s_out)[0]

        if len(test_idx) == 0: continue

        X_train, X_test = X_features[train_idx], X_features[test_idx]
        y_train, y_test = y_labels[train_idx], y_labels[test_idx]

        clf = LogisticRegression(max_iter=2000, multi_class='ovr')
        clf.fit(X_train, y_train)
        preds = clf.predict(X_test)

        acc = accuracy_score(y_test, preds)
        print(f"Précision Sujet {s_out} : {acc:.2%}")
        total_true.extend(y_test)
        total_pred.extend(preds)

    print("\n" + "="*30)
    print(f" PRÉCISION GLOBALE MDS+LOGISTIC : {accuracy_score(total_true, total_pred):.2%}")
    print("="*30)

    cm = confusion_matrix(total_true, total_pred)
    disp = ConfusionMatrixDisplay(cm)
    disp.plot(cmap="Blues")
    plt.show()


run_mds_experiment(df100, loop_range=10, m_dims=30)
# Out:
# Extraction terminée.
# --- Début du Chargement ---
# Standardisation...
# /tmp/ipykernel_4405/505342380.py:68: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling à 100 points...
#
# Calcul de la matrice de distances DTW (1000x1000)...
# Ligne 0/1000 en cours...
# Ligne 50/1000 en cours...
# Ligne 100/1000 en cours...
# Ligne 150/1000 en cours...
# Ligne 200/1000 en cours...
# Ligne 250/1000 en cours...
# Ligne 300/1000 en cours...
# Ligne 350/1000 en cours...
# Ligne 400/1000 en cours...
# Ligne 450/1000 en cours...
# Ligne 500/1000 en cours...
# Ligne 550/1000 en cours...
# Ligne 600/1000 en cours...
# Ligne 650/1000 en cours...
# Ligne 700/1000 en cours...
# Ligne 750/1000 en cours...
# Ligne 800/1000 en cours...
# Ligne 850/1000 en cours...
# Ligne 900/1000 en cours...
# Ligne 950/1000 en cours...
#
# --- Début des tests Subject-Out ---
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Précision Sujet 1 : 92.00%
# Précision Sujet 2 : 93.00%
# Précision Sujet 3 : 89.00%
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Précision Sujet 4 : 77.00%
# Précision Sujet 5 : 81.00%
# Précision Sujet 6 : 87.00%
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Précision Sujet 7 : 99.00%
# Précision Sujet 8 : 97.00%
# Précision Sujet 9 : 100.00%
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Précision Sujet 10 : 81.00%
#
# ==============================
#  PRÉCISION GLOBALE MDS+LOGISTIC : 89.60%
# ==============================
