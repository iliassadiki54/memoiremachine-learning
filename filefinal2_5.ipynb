# %% [markdown]
# # transformer

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf



DOMAIN_FOLDER =r"\\student.fucam.ac.be\users$\isadiki\Downloads\Domain2base\DOMAIN2_CSVcorrigé"
DOMAIN_ID = 2


df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")
print(f"Dossier source : {DOMAIN_FOLDER}")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:

                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2: continue


                data = file[0].str.strip('"').str.split(',', expand=True)

                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])


                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)


                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration

                df_list.append(file_df)

            except FileNotFoundError:
                continue
            except Exception:
                continue


if not df_list:
    raise ValueError("Aucun fichier n'a pu être chargé. Vérifiez le chemin et le format des fichiers.")

df = pd.concat(df_list, ignore_index=True)

for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Nombre total d'observations chargées : {len(df)}")


grouped = df.groupby(['gesture', 'iter'])
sequence_lengths = grouped.size().reset_index(name='length')
mean_lengths = sequence_lengths.groupby('gesture')['length'].mean().reset_index()
mean_lengths.columns = ['Chiffre', 'Frames moyennes']

plt.figure(figsize=(8, 5))
plt.bar(mean_lengths["Chiffre"], mean_lengths["Frames moyennes"])
plt.title("Nombre moyen de coordonnées par chiffre")
plt.xlabel("Chiffre")
plt.ylabel("Nombre moyen de coordonnées")
plt.xticks(mean_lengths["Chiffre"])
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

durations = df.groupby(['gesture', 'iter'])['t'].agg(lambda x: x.max() - x.min()).reset_index(name='duration')
mean_durations = durations.groupby('gesture')['duration'].mean()
for gesture, mean_dur in mean_durations.items():
    print(f"Chiffre {gesture} : {mean_dur:.2f} s")




def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        if std == 0 or np.isnan(std):
            df_copy[f'{axis}_std'] = 0.0
        else:
            df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)




def resample_gesture(df_in, target_len=100):
    resampled_data = []

    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue

        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'),
            'y_std': interp('y_std'),
            'z_std': interp('z_std')
        }))

    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)




def create_user_independent_split(df_in, subj_out):
    train_df = df_in[df_in['subject'] != subj_out]
    test_df = df_in[df_in['subject'] == subj_out]

    def df_to_array(df_target):
        X, y = [], []
        for (gesture, subject, iteration), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(gesture)
        return np.array(X), np.array(y)

    X_train, y_train = df_to_array(train_df)
    X_test, y_test = df_to_array(test_df)
    return X_train, y_train, X_test, y_test




class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]




def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)

    ffn = models.Sequential([
        layers.Dense(dff, activation="relu"),
        layers.Dense(d_model),
    ])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    out2 = layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)
    return out2

def create_transformer_model(input_shape, num_classes, seq_len=100):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2

    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(seq_len, d_model)(x)

    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)

    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model




def test_transformer_user_independent(df_data, loop_range=10, epochs=30, batch_size=32, verbose_fit=1):
    total_true, total_pred = [], []

    for subj_out in range(1, loop_range + 1):
        if df_data[df_data['subject'] == subj_out].empty: continue

        print(f"\n--- Test subject OUT : {subj_out} ---")
        X_train, y_train, X_test, y_test = create_user_independent_split(df_data, subj_out)

        n_classes = len(np.unique(df_data['gesture']))
        input_shape = (X_train.shape[1], X_train.shape[2])

        model = create_transformer_model(input_shape=input_shape, num_classes=n_classes)
        model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=verbose_fit)

        y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
        acc = accuracy_score(y_test, y_pred)
        print(f"Exactitude subject {subj_out} : {acc:.2%}")

        total_true.extend(y_test)
        total_pred.extend(y_pred)

    final_acc = accuracy_score(total_true, total_pred)
    print(f"\nExactitude globale Transformer : {final_acc:.2%}")

    cm = confusion_matrix(total_true, total_pred)
    disp = ConfusionMatrixDisplay(cm)
    disp.plot(cmap="Blues")
    plt.title("Matrice de confusion – Transformer")
    plt.show()


test_transformer_user_independent(df100, loop_range=10, epochs=50, batch_size=32, verbose_fit=1)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# Dossier source : \\student.fucam.ac.be\users$\isadiki\Downloads\Domain2base\DOMAIN2_CSVcorrigé
# Nombre total d'observations chargées : 79866
# Chiffre 0 : 3980.00 s
# Chiffre 1 : 3567.20 s
# Chiffre 2 : 2570.50 s
# Chiffre 3 : 4037.70 s
# Chiffre 4 : 3087.10 s
# Chiffre 5 : 5395.70 s
# Chiffre 6 : 4499.00 s
# Chiffre 7 : 4250.90 s
# Chiffre 8 : 2463.70 s
# Chiffre 9 : 3477.00 s
# C:\Users\Isadiki\AppData\Local\Temp\ipykernel_16848\2611384756.py:108: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# --- Test subject OUT : 1 ---
# WARNING:tensorflow:From \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 12s 224ms/step - accuracy: 0.0967 - loss: 2.4345
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.1989 - loss: 2.1510
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.7322 - loss: 0.7452
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.8500 - loss: 0.4441
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9522 - loss: 0.1556
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9644 - loss: 0.1257
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - accuracy: 0.9856 - loss: 0.0668
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 227ms/step - accuracy: 0.9833 - loss: 0.0431
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 226ms/step - accuracy: 0.9911 - loss: 0.0314
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - accuracy: 0.9667 - loss: 0.1039
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 227ms/step - accuracy: 0.9722 - loss: 0.0852
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9800 - loss: 0.0768
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9600 - loss: 0.1382
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9744 - loss: 0.0817
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9822 - loss: 0.0606
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 0.9944 - loss: 0.0183
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.9844 - loss: 0.0590
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 0.9933 - loss: 0.0166
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9978 - loss: 0.0087
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 268ms/step - accuracy: 0.9978 - loss: 0.0115
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9978 - loss: 0.0097
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.9789 - loss: 0.0658
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9911 - loss: 0.0370
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 231ms/step - accuracy: 0.9778 - loss: 0.0839
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 234ms/step - accuracy: 0.9956 - loss: 0.0207
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9922 - loss: 0.0272
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9922 - loss: 0.0321
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9978 - loss: 0.0100
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9989 - loss: 0.0049
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9978 - loss: 0.0110
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9989 - loss: 0.0048
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9989 - loss: 0.0041
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 1.0000 - loss: 9.6111e-04
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 1.0000 - loss: 7.6937e-04
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 1.0000 - loss: 8.0798e-04
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 7.4559e-04
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 1.0000 - loss: 5.4929e-04
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 7.3531e-04
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 1.0000 - loss: 5.3432e-04
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 1.0000 - loss: 8.0732e-04
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9978 - loss: 0.0031
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9844 - loss: 0.0583
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 235ms/step - accuracy: 0.9356 - loss: 0.2248
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9222 - loss: 0.2511
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9633 - loss: 0.1136
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9900 - loss: 0.0376
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9800 - loss: 0.0581
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9900 - loss: 0.0352
# Exactitude subject 1 : 96.00%
#
# --- Test subject OUT : 2 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 236ms/step - accuracy: 0.0856 - loss: 2.4146
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.1344 - loss: 2.2774
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.5478 - loss: 1.1759
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.8300 - loss: 0.4418
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9000 - loss: 0.2927
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 0.9611 - loss: 0.1107
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9467 - loss: 0.1696
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9511 - loss: 0.1530
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.9867 - loss: 0.0477
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.9878 - loss: 0.0404
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9967 - loss: 0.0142
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9956 - loss: 0.0195
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9944 - loss: 0.0204
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 258ms/step - accuracy: 0.9967 - loss: 0.0137
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 264ms/step - accuracy: 0.9867 - loss: 0.0482
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9889 - loss: 0.0315
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9944 - loss: 0.0105
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 258ms/step - accuracy: 0.9900 - loss: 0.0339
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.9911 - loss: 0.0194
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9867 - loss: 0.0324
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.9922 - loss: 0.0311
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 263ms/step - accuracy: 0.9567 - loss: 0.1305
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 262ms/step - accuracy: 0.9478 - loss: 0.1497
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.9844 - loss: 0.0576
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.9989 - loss: 0.0086
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.9889 - loss: 0.0364
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9878 - loss: 0.0640
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 261ms/step - accuracy: 0.9911 - loss: 0.0356
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 0.9933 - loss: 0.0192
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.9900 - loss: 0.0453
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 0.9989 - loss: 0.0060
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.9978 - loss: 0.0042
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 261ms/step - accuracy: 0.9989 - loss: 0.0094
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 262ms/step - accuracy: 0.9978 - loss: 0.0042
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 274ms/step - accuracy: 0.9922 - loss: 0.0249
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 276ms/step - accuracy: 0.9856 - loss: 0.0500
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 282ms/step - accuracy: 0.9911 - loss: 0.0529
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 284ms/step - accuracy: 0.9778 - loss: 0.0937
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 285ms/step - accuracy: 0.9589 - loss: 0.1255
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 0.9944 - loss: 0.0282
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 262ms/step - accuracy: 0.9844 - loss: 0.0500
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 268ms/step - accuracy: 0.9744 - loss: 0.1110
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 262ms/step - accuracy: 0.9900 - loss: 0.0320
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 279ms/step - accuracy: 0.9922 - loss: 0.0300
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 266ms/step - accuracy: 0.9967 - loss: 0.0231
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 1.0000 - loss: 0.0015
# Exactitude subject 2 : 83.00%
#
# --- Test subject OUT : 3 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 12s 263ms/step - accuracy: 0.1022 - loss: 2.4421
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.2300 - loss: 2.0439
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 261ms/step - accuracy: 0.8067 - loss: 0.6559
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 262ms/step - accuracy: 0.9467 - loss: 0.2251
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 269ms/step - accuracy: 0.9211 - loss: 0.2621
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step - accuracy: 0.9633 - loss: 0.1267
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9722 - loss: 0.1264
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 273ms/step - accuracy: 0.9922 - loss: 0.0359
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 258ms/step - accuracy: 0.9622 - loss: 0.1237
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9567 - loss: 0.1484
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.9622 - loss: 0.1571
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 261ms/step - accuracy: 0.9933 - loss: 0.0279
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 265ms/step - accuracy: 0.9911 - loss: 0.0261
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.9889 - loss: 0.0468
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9822 - loss: 0.0737
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9922 - loss: 0.0358
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9967 - loss: 0.0216
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9956 - loss: 0.0107
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.9944 - loss: 0.0200
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 258ms/step - accuracy: 0.9878 - loss: 0.0435
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9944 - loss: 0.0283
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9989 - loss: 0.0045
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 1.0000 - loss: 8.0167e-04
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 6.5337e-04
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 1.0000 - loss: 7.3177e-04
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 1.0000 - loss: 5.9467e-04
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 5.7313e-04
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 5.2831e-04
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 1.0000 - loss: 5.5428e-04
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 1.0000 - loss: 4.9738e-04
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 1.0000 - loss: 4.3300e-04
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 4.1747e-04
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 4.0130e-04
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 1.0000 - loss: 3.9156e-04
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 1.0000 - loss: 5.4326e-04
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 1.0000 - loss: 4.1919e-04
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 1.0000 - loss: 3.4829e-04
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 2.8087e-04
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 3.2087e-04
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 1.0000 - loss: 2.7773e-04
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 242ms/step - accuracy: 1.0000 - loss: 2.9238e-04
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 1.0000 - loss: 2.7442e-04
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - accuracy: 1.0000 - loss: 2.2703e-04
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 2.8245e-04
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 2.1898e-04
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000023B97335C60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000023B97335C60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exactitude subject 3 : 100.00%
#
# --- Test subject OUT : 4 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 252ms/step - accuracy: 0.0900 - loss: 2.4365
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.1700 - loss: 2.2633
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.6067 - loss: 1.0624
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.8800 - loss: 0.3935
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.9322 - loss: 0.2278
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.9767 - loss: 0.0789
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.9778 - loss: 0.0836
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.9878 - loss: 0.0642
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.9867 - loss: 0.0510
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9867 - loss: 0.0403
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9878 - loss: 0.0578
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9800 - loss: 0.0680
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.9700 - loss: 0.1039
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.9867 - loss: 0.0476
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.9889 - loss: 0.0346
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.9878 - loss: 0.0560
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9867 - loss: 0.0416
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 0.9878 - loss: 0.0430
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9700 - loss: 0.0979
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 0.9567 - loss: 0.1513
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9733 - loss: 0.1186
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9878 - loss: 0.0398
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9956 - loss: 0.0234
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9944 - loss: 0.0285
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 0.9978 - loss: 0.0097
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.9967 - loss: 0.0136
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9922 - loss: 0.0445
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 0.9978 - loss: 0.0168
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.9967 - loss: 0.0224
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9978 - loss: 0.0041
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 1.0000 - loss: 6.3739e-04
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 270ms/step - accuracy: 1.0000 - loss: 6.5256e-04
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 263ms/step - accuracy: 1.0000 - loss: 5.1665e-04
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 271ms/step - accuracy: 1.0000 - loss: 5.2975e-04
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 258ms/step - accuracy: 1.0000 - loss: 4.2822e-04
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 1.0000 - loss: 3.6297e-04
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 1.0000 - loss: 3.4674e-04
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 258ms/step - accuracy: 1.0000 - loss: 3.4080e-04
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 1.0000 - loss: 4.5026e-04
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 262ms/step - accuracy: 1.0000 - loss: 2.8330e-04
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 1.0000 - loss: 3.2742e-04
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 256ms/step - accuracy: 1.0000 - loss: 3.0273e-04
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 1.0000 - loss: 2.8949e-04
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 1.0000 - loss: 3.2414e-04
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 1.0000 - loss: 2.3475e-04
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 1.0000 - loss: 2.7726e-04
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 1.0000 - loss: 2.3420e-04
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 270ms/step - accuracy: 1.0000 - loss: 2.2147e-04
# Exactitude subject 4 : 99.00%
#
# --- Test subject OUT : 5 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 11s 261ms/step - accuracy: 0.1111 - loss: 2.4078
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.2322 - loss: 2.1126
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.8300 - loss: 0.5719
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.9311 - loss: 0.2331
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9522 - loss: 0.1780
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9611 - loss: 0.1193
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 0.9700 - loss: 0.1086
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.9667 - loss: 0.1140
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9633 - loss: 0.1099
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9889 - loss: 0.0439
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9911 - loss: 0.0356
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9978 - loss: 0.0131
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9967 - loss: 0.0109
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9978 - loss: 0.0126
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 0.9867 - loss: 0.0388
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9778 - loss: 0.0789
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9767 - loss: 0.0899
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9678 - loss: 0.1308
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9844 - loss: 0.0605
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9878 - loss: 0.0544
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9944 - loss: 0.0234
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9956 - loss: 0.0182
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9967 - loss: 0.0112
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9989 - loss: 0.0100
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 8.7973e-04
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 1.0000 - loss: 5.5487e-04
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 4.2951e-04
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 1.0000 - loss: 4.9000e-04
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 1.0000 - loss: 4.0452e-04
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 1.0000 - loss: 4.9049e-04
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 3.5011e-04
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 1.0000 - loss: 3.8740e-04
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 3.0927e-04
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 1.0000 - loss: 5.5183e-04
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 3.1708e-04
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 1.0000 - loss: 2.6784e-04
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 1.0000 - loss: 2.7655e-04
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 1.0000 - loss: 2.7493e-04
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 1.0000 - loss: 2.5796e-04
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 1.0000 - loss: 2.2475e-04
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 1.0000 - loss: 2.5349e-04
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 1.8730e-04
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 2.0822e-04
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 2.0454e-04
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 1.0000 - loss: 1.7104e-04
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 1.0000 - loss: 1.6607e-04
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 2.0449e-04
# Exactitude subject 5 : 99.00%
#
# --- Test subject OUT : 6 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 239ms/step - accuracy: 0.0944 - loss: 2.4972
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.3589 - loss: 1.7827
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.8056 - loss: 0.5846
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9389 - loss: 0.2097
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9611 - loss: 0.1408
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9778 - loss: 0.0891
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9378 - loss: 0.1798
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 0.9756 - loss: 0.1102
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9922 - loss: 0.0288
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9944 - loss: 0.0250
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9956 - loss: 0.0183
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9911 - loss: 0.0297
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9833 - loss: 0.0624
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9911 - loss: 0.0275
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 0.9789 - loss: 0.0678
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9778 - loss: 0.0793
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9744 - loss: 0.1173
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9711 - loss: 0.0865
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9744 - loss: 0.0798
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9833 - loss: 0.0691
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 0.9944 - loss: 0.0304
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9900 - loss: 0.0417
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9933 - loss: 0.0240
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9978 - loss: 0.0111
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 0.9989 - loss: 0.0035
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9989 - loss: 0.0022
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9933 - loss: 0.0298
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 0.9989 - loss: 0.0024
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9989 - loss: 0.0122
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 1.0000 - loss: 7.4400e-04
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 1.0000 - loss: 8.5161e-04
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 1.0000 - loss: 4.7045e-04
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 1.0000 - loss: 5.5606e-04
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 1.0000 - loss: 4.7069e-04
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 4.2663e-04
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 3.8797e-04
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 1.0000 - loss: 4.8465e-04
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 1.0000 - loss: 3.1579e-04
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 1.0000 - loss: 2.6329e-04
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 1.0000 - loss: 2.5961e-04
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 1.0000 - loss: 3.0995e-04
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 1.0000 - loss: 2.4422e-04
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 1.0000 - loss: 2.3686e-04
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 2.2656e-04
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 1.0000 - loss: 2.4484e-04
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 2.3678e-04
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 1.0000 - loss: 1.7578e-04
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 1.0000 - loss: 2.7219e-04
# Exactitude subject 6 : 97.00%
#
# --- Test subject OUT : 7 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 11s 259ms/step - accuracy: 0.0933 - loss: 2.3991
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.2411 - loss: 2.1160
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.7600 - loss: 0.7106
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.9356 - loss: 0.2459
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9533 - loss: 0.1549
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 261ms/step - accuracy: 0.9811 - loss: 0.0900
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9933 - loss: 0.0440
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9889 - loss: 0.0364
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.9789 - loss: 0.0801
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 257ms/step - accuracy: 0.9833 - loss: 0.0587
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.9700 - loss: 0.1034
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9856 - loss: 0.0726
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9867 - loss: 0.0388
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9900 - loss: 0.0304
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.9967 - loss: 0.0186
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9944 - loss: 0.0151
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9989 - loss: 0.0047
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9889 - loss: 0.0332
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 262ms/step - accuracy: 0.9811 - loss: 0.0526
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9722 - loss: 0.0904
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9844 - loss: 0.0735
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.9933 - loss: 0.0349
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 258ms/step - accuracy: 0.9900 - loss: 0.0246
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.9922 - loss: 0.0288
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9933 - loss: 0.0363
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 263ms/step - accuracy: 0.9933 - loss: 0.0254
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 262ms/step - accuracy: 0.9889 - loss: 0.0385
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.9789 - loss: 0.0732
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 261ms/step - accuracy: 0.9500 - loss: 0.1864
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.9767 - loss: 0.0749
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 263ms/step - accuracy: 0.9878 - loss: 0.0743
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 262ms/step - accuracy: 0.9789 - loss: 0.0581
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9900 - loss: 0.0349
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.9922 - loss: 0.0371
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9867 - loss: 0.0485
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 0.9889 - loss: 0.0270
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9956 - loss: 0.0223
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9989 - loss: 0.0043
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9933 - loss: 0.0358
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9878 - loss: 0.0572
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9956 - loss: 0.0173
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9978 - loss: 0.0062
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9822 - loss: 0.0767
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.9700 - loss: 0.1306
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9322 - loss: 0.2839
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.9722 - loss: 0.1104
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.9889 - loss: 0.0416
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9956 - loss: 0.0161
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9989 - loss: 0.0087
# Exactitude subject 7 : 98.00%
#
# --- Test subject OUT : 8 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 11s 252ms/step - accuracy: 0.1089 - loss: 2.4186
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.2778 - loss: 1.9528
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.8389 - loss: 0.5187
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.9389 - loss: 0.2166
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.9589 - loss: 0.1183
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 257ms/step - accuracy: 0.9511 - loss: 0.1823
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9600 - loss: 0.1244
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.9833 - loss: 0.0655
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 0.9789 - loss: 0.0642
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 261ms/step - accuracy: 0.9789 - loss: 0.0701
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 257ms/step - accuracy: 0.9833 - loss: 0.0446
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9833 - loss: 0.0453
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.9789 - loss: 0.0523
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.9833 - loss: 0.0550
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.9889 - loss: 0.0461
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9922 - loss: 0.0232
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9944 - loss: 0.0208
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.9856 - loss: 0.0378
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9911 - loss: 0.0274
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.9733 - loss: 0.1407
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 0.9911 - loss: 0.0395
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 258ms/step - accuracy: 0.9956 - loss: 0.0195
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9978 - loss: 0.0138
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.9989 - loss: 0.0068
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9978 - loss: 0.0053
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9944 - loss: 0.0179
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.9978 - loss: 0.0138
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9989 - loss: 0.0037
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9978 - loss: 0.0066
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9989 - loss: 0.0020
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9989 - loss: 0.0106
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9989 - loss: 0.0054
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.9978 - loss: 0.0090
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.9989 - loss: 0.0042
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - accuracy: 1.0000 - loss: 6.0269e-04
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9989 - loss: 0.0017
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9989 - loss: 0.0028
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9989 - loss: 0.0040
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 8.8318e-04
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9989 - loss: 0.0014
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.9978 - loss: 0.0083
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 1.0000 - loss: 4.4478e-04
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 1.0000 - loss: 4.7761e-04
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 8.6780e-04
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 1.0000 - loss: 3.9480e-04
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 2.8381e-04
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 2.8627e-04
# Exactitude subject 8 : 95.00%
#
# --- Test subject OUT : 9 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 244ms/step - accuracy: 0.0800 - loss: 2.4239
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.1844 - loss: 2.1768
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.6700 - loss: 0.9408
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9467 - loss: 0.2089
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 0.9733 - loss: 0.0988
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9333 - loss: 0.2079
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9711 - loss: 0.0979
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9867 - loss: 0.0384
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9867 - loss: 0.0606
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9933 - loss: 0.0305
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.9844 - loss: 0.0514
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.9956 - loss: 0.0190
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.9967 - loss: 0.0148
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 1.0000 - loss: 9.0219e-04
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 8.4092e-04
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 1.0000 - loss: 7.1057e-04
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 7.4330e-04
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 7.8728e-04
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 1.0000 - loss: 6.1471e-04
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 5.3059e-04
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 5.2317e-04
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 6.3759e-04
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 1.0000 - loss: 3.9351e-04
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 1.0000 - loss: 3.9077e-04
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 1.0000 - loss: 3.9162e-04
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 1.0000 - loss: 3.5575e-04
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 1.0000 - loss: 3.3716e-04
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 1.0000 - loss: 3.2017e-04
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 1.0000 - loss: 3.5395e-04
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 1.0000 - loss: 2.5185e-04
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 1.0000 - loss: 2.9505e-04
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 1.0000 - loss: 4.6095e-04
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 1.0000 - loss: 2.8066e-04
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 1.0000 - loss: 2.7876e-04
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 1.0000 - loss: 4.0066e-04
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 1.0000 - loss: 2.5871e-04
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 2.2827e-04
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 1.0000 - loss: 2.6064e-04
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 1.0000 - loss: 2.2549e-04
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 237ms/step - accuracy: 1.0000 - loss: 1.8195e-04
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 1.0000 - loss: 2.4134e-04
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 1.0000 - loss: 1.8873e-04
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 1.0000 - loss: 2.0402e-04
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 1.0000 - loss: 1.4041e-04
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 1.0000 - loss: 1.6383e-04
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - accuracy: 1.0000 - loss: 1.3794e-04
# Exactitude subject 9 : 99.00%
#
# --- Test subject OUT : 10 ---
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 240ms/step - accuracy: 0.1167 - loss: 2.4542
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.1733 - loss: 2.1973
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.5967 - loss: 1.1582
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.8000 - loss: 0.5424
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.8211 - loss: 0.4268
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.8656 - loss: 0.3308
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9144 - loss: 0.2185
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 0.9422 - loss: 0.1586
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9367 - loss: 0.1816
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9744 - loss: 0.0854
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.9789 - loss: 0.0678
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.9867 - loss: 0.0423
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 0.9733 - loss: 0.0667
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9833 - loss: 0.0624
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9822 - loss: 0.0518
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9789 - loss: 0.0677
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 240ms/step - accuracy: 0.9678 - loss: 0.0927
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9433 - loss: 0.1781
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9900 - loss: 0.0458
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 0.9889 - loss: 0.0328
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9833 - loss: 0.0542
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9911 - loss: 0.0403
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.9878 - loss: 0.0548
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 0.9933 - loss: 0.0253
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9689 - loss: 0.0970
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.9856 - loss: 0.0539
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 0.9956 - loss: 0.0158
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 266ms/step - accuracy: 0.9956 - loss: 0.0198
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 0.9933 - loss: 0.0284
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9911 - loss: 0.0260
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 247ms/step - accuracy: 0.9889 - loss: 0.0311
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 0.9922 - loss: 0.0308
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9967 - loss: 0.0124
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.9989 - loss: 0.0050
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.9989 - loss: 0.0032
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 1.0000 - loss: 9.5178e-04
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 258ms/step - accuracy: 1.0000 - loss: 7.9686e-04
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 1.0000 - loss: 7.2766e-04
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 1.0000 - loss: 6.5017e-04
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 245ms/step - accuracy: 1.0000 - loss: 5.8274e-04
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 243ms/step - accuracy: 1.0000 - loss: 6.4779e-04
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 1.0000 - loss: 4.0577e-04
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 1.0000 - loss: 7.5937e-04
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 1.0000 - loss: 3.9853e-04
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 1.0000 - loss: 3.8576e-04
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 249ms/step - accuracy: 1.0000 - loss: 3.1785e-04
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 1.0000 - loss: 4.2081e-04
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 241ms/step - accuracy: 1.0000 - loss: 4.6543e-04
# Exactitude subject 10 : 96.00%
#
# Exactitude globale Transformer : 96.20%

# %% [markdown]
# # lstm

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers




DOMAIN_FOLDER = r"\\student.fucam.ac.be\users$\isadiki\Downloads\Domain2base\DOMAIN2_CSVcorrigé"
DOMAIN_ID = 2

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")
print(f"Dossier source : {DOMAIN_FOLDER}")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:

                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2: continue


                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])


                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)


                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration

                df_list.append(file_df)

            except (FileNotFoundError, Exception):
                continue


if not df_list:
    raise ValueError(" Aucun fichier n'a été chargé. Vérifiez le chemin : " + DOMAIN_FOLDER)

df = pd.concat(df_list, ignore_index=True)


for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f" Nombre total d'observations chargées : {len(df)}")



print("\n--- 2. Analyse Exploratoire ---")
grouped = df.groupby(['gesture', 'iter'])
sequence_lengths = grouped.size().reset_index(name='length')
mean_lengths = sequence_lengths.groupby('gesture')['length'].mean().reset_index()
mean_lengths.columns = ['Chiffre', 'Frames moyennes']

plt.figure(figsize=(8, 5))
plt.bar(mean_lengths["Chiffre"], mean_lengths["Frames moyennes"])
plt.title("Nombre moyen de coordonnées par chiffre")
plt.xlabel("Chiffre")
plt.ylabel("Nombre moyen de coordonnées")
plt.xticks(mean_lengths["Chiffre"])
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

durations = df.groupby(['gesture', 'iter'])['t'].agg(lambda x: x.max() - x.min()).reset_index(name='duration')
mean_durations = durations.groupby('gesture')['duration'].mean()
for gesture, mean_dur in mean_durations.items():
    print(f"Chiffre {gesture} : {mean_dur:.2f} s")



def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        if std == 0 or np.isnan(std):
            df_copy[f'{axis}_std'] = 0.0
        else:
            df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std
    return df_copy

print("\nStandardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'),
            'y_std': interp('y_std'),
            'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling à longueur 100...")
df100 = resample_gesture(df)



def create_user_independent_split(df_in, subj_out):
    train_df = df_in[df_in['subject'] != subj_out]
    test_df = df_in[df_in['subject'] == subj_out]

    def df_to_array(df_target):
        X, y = [], []
        for (gesture, subject, iteration), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(gesture)
        return np.array(X), np.array(y)

    X_train, y_train = df_to_array(train_df)
    X_test, y_test = df_to_array(test_df)
    return X_train, y_train, X_test, y_test



def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, dropout=0.2, input_shape=input_shape),
        layers.LSTM(256, dropout=0.3),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model



def test_lstm_user_independent(df_data, loop_range=10, epochs=50, batch_size=16):
    total_true, total_pred = [], []
    subjects = sorted(df_data['subject'].unique())

    for subj_out in subjects:
        print(f"\n--- Test subject OUT : {subj_out} ---")
        X_train, y_train, X_test, y_test = create_user_independent_split(df_data, subj_out)


        all_labels = np.unique(df_data['gesture'])
        num_classes = int(max(all_labels) + 1)

        model = create_lstm_model(input_shape=(X_train.shape[1], X_train.shape[2]), num_classes=num_classes)


        model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)


        y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
        acc = accuracy_score(y_test, y_pred)
        print(f"Exactitude subject {subj_out} : {acc:.2%}")

        total_true.extend(y_test)
        total_pred.extend(y_pred)

    final_acc = accuracy_score(total_true, total_pred)
    print(f"\nExactitude globale LSTM : {final_acc:.2%}")


    cm = confusion_matrix(total_true, total_pred)
    disp = ConfusionMatrixDisplay(cm)
    disp.plot(cmap="Blues")
    plt.title("Matrice de confusion – LSTM")
    plt.show()


test_lstm_user_independent(df100)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# Dossier source : \\student.fucam.ac.be\users$\isadiki\Downloads\Domain2base\DOMAIN2_CSVcorrigé
# ✅ Nombre total d'observations chargées : 79866
#
# --- 2. Analyse Exploratoire ---
# Chiffre 0 : 3980.00 s
# Chiffre 1 : 3567.20 s
# Chiffre 2 : 2570.50 s
# Chiffre 3 : 4037.70 s
# Chiffre 4 : 3087.10 s
# Chiffre 5 : 5395.70 s
# Chiffre 6 : 4499.00 s
# Chiffre 7 : 4250.90 s
# Chiffre 8 : 2463.70 s
# Chiffre 9 : 3477.00 s
#
# Standardisation...
# C:\Users\Isadiki\AppData\Local\Temp\ipykernel_18748\2095607127.py:105: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling à longueur 100...
#
# --- Test subject OUT : 1 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 1 : 98.00%
#
# --- Test subject OUT : 2 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 2 : 94.00%
#
# --- Test subject OUT : 3 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001F698A93240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001F698A93240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exactitude subject 3 : 100.00%
#
# --- Test subject OUT : 4 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 4 : 100.00%
#
# --- Test subject OUT : 5 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 5 : 97.00%
#
# --- Test subject OUT : 6 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 6 : 93.00%
#
# --- Test subject OUT : 7 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 7 : 94.00%
#
# --- Test subject OUT : 8 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 8 : 95.00%
#
# --- Test subject OUT : 9 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 9 : 98.00%
#
# --- Test subject OUT : 10 ---
# \\student.fucam.ac.be\users$\isadiki\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 10 : 98.00%
#
# Exactitude globale LSTM : 96.70%

# %% [markdown]
# # edit distance dans cluster corssvalide

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d




DOMAIN_FOLDER = r"\\student.fucam.ac.be\users$\isadiki\Downloads\Domain2base\DOMAIN2_CSVcorrigé"

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
print(f"Dossier source : {DOMAIN_FOLDER}")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:

                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2:
                    continue


                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])


                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)


                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration

                df = pd.concat([df, file_df], ignore_index=True)

            except FileNotFoundError:
                continue
            except Exception:
                continue

print(f"Nombre total d'observations chargées : {len(df)}")


for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)



def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = res[axis].std()
        res[f"{axis}_std"] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation des données...")
df = df.groupby(["subject", "gesture", "iter"], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    groups = df_input.groupby(["gesture", "subject", "iter"])

    for (gesture, subject, iteration), group in groups:
        n = len(group)
        if n < 2: continue

        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)

        res_dict = {
            "gesture": [gesture]*target_len,
            "subject": [subject]*target_len,
            "iter": [iteration]*target_len
        }

        for col in ["x_std", "y_std", "z_std"]:
            res_dict[col] = interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame(res_dict))

    return pd.concat(resampled_data, ignore_index=True)

print("Resampling à 100 points...")
df100 = resample_gesture(df)



def edit_distance(s1, s2):
    n, m = len(s1), len(s2)
    M = [[0]*(m+1) for _ in range(n+1)]
    for i in range(n+1): M[i][0] = i
    for j in range(m+1): M[0][j] = j
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = 0 if s1[i-1] == s2[j-1] else 1
            M[i][j] = min(M[i-1][j] + 1, M[i][j-1] + 1, M[i-1][j-1] + cost)
    return M[n][m]

def gesture_to_sequence(df_sym):
    seq_dict = defaultdict(list)
    for (gesture, subject, iteration), group in df_sym.groupby(["gesture", "subject", "iter"]):
        seq = "".join(group["symbol"].tolist())
        seq_dict[gesture].append(seq)
    return seq_dict

def cluster_and_convert(df_train, df_test, k_clusters=50):
    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = df_train[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def assign_symbols(df_local):
        pts = df_local[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)
        symbols = [chr(ord('A') + (c % 26)) for c in clusters]
        df_copy = df_local.copy()
        df_copy["symbol"] = symbols
        return df_copy

    return gesture_to_sequence(assign_symbols(df_train)), gesture_to_sequence(assign_symbols(df_test))

def knn_edit_predict(seq, train_dict, k=7):
    distances = []
    for gesture, sequences in train_dict.items():
        for s in sequences:
            d = edit_distance(seq, s)
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def dict_creation_userout(df_in, subj_out):
    return df_in[df_in["subject"] != subj_out], df_in[df_in["subject"] == subj_out]

def testmodel(df_target, loop_range=10, k_knn=7, k_clusters=50):
    total_true, total_pred = [], []

    for i in range(1, loop_range + 1):
        print(f"Test sur sujet sorti : {i}")
        train_df, test_df = dict_creation_userout(df_target, i)

        if test_df.empty: continue

        train_seq, test_seq = cluster_and_convert(train_df, test_df, k_clusters)

        y_true, y_pred = [], []
        for gesture, sequences in test_seq.items():
            for seq in sequences:
                pred = knn_edit_predict(seq, train_seq, k=k_knn)
                y_true.append(gesture)
                y_pred.append(pred)

        total_true.extend(y_true)
        total_pred.extend(y_pred)
        print(f"Précision split : {accuracy_score(y_true, y_pred):.2%}")


    print(f"\n=== EXACTITUDE GLOBALE : {accuracy_score(total_true, total_pred):.2%} ===")
    cm = confusion_matrix(total_true, total_pred)
    disp = ConfusionMatrixDisplay(cm)
    disp.plot(cmap="Blues")
    plt.title("Matrice de Confusion")
    plt.show()

testmodel(df100)
# Out:
# --- Début du Chargement ---
# Dossier source : \\student.fucam.ac.be\users$\isadiki\Downloads\Domain2base\DOMAIN2_CSVcorrigé
# C:\Users\Isadiki\AppData\Local\Temp\ipykernel_17552\221923040.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Nombre total d'observations chargées : 79866
# Standardisation des données...
# C:\Users\Isadiki\AppData\Local\Temp\ipykernel_17552\221923040.py:73: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(["subject", "gesture", "iter"], group_keys=False).apply(standardize_gesture)
# Resampling à 100 points...
# Test sur sujet sorti : 1
# Précision split : 99.00%
# Test sur sujet sorti : 2
# Précision split : 88.00%
# Test sur sujet sorti : 3
# Précision split : 95.00%
# Test sur sujet sorti : 4
# Précision split : 96.00%
# Test sur sujet sorti : 5
# Précision split : 87.00%
# Test sur sujet sorti : 6
# Précision split : 93.00%
# Test sur sujet sorti : 7
# Précision split : 92.00%
# Test sur sujet sorti : 8
# Précision split : 80.00%
# Test sur sujet sorti : 9
# Précision split : 98.00%
# Test sur sujet sorti : 10
# Précision split : 96.00%
#
# === EXACTITUDE GLOBALE : 92.40% ===

# %% [markdown]
# # lcss knn 3 cluster 20 cluster dedans

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d




DOMAIN_FOLDER = r"\\student.fucam.ac.be\users$\isadiki\Downloads\Domain2base\DOMAIN2_CSVcorrigé"

df = pd.DataFrame(columns=['x', 'y', 'z', 't', 'gesture', 'subject', 'iter'])

print(f"--- Début du Chargement ---")
print(f"Dossier source : {DOMAIN_FOLDER}")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:

                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2:
                    continue


                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])


                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)


                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration

                df = pd.concat([df, file_df], ignore_index=True)

            except FileNotFoundError:
                continue
            except Exception:
                continue


for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f"Nombre total d'observations chargées : {len(df)}")



def standardize_gesture(df_group):
    res = df_group.copy()
    for axis in ['x', 'y', 'z']:

        std = res[axis].std()
        res[f'{axis}_std'] = (res[axis] - res[axis].mean()) / std if std != 0 else 0
    return res

print("Standardisation en cours...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_input, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_input.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'),
            'y_std': interp('y_std'),
            'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling en cours...")
df100 = resample_gesture(df)



def cluster_and_symbolize(train_df, test_df, k_clusters=20):

    kmeans = KMeans(n_clusters=k_clusters, random_state=42, n_init=10)
    train_points = train_df[['x_std', 'y_std', 'z_std']].values
    kmeans.fit(train_points)

    def to_seq_dict(df_target):
        pts = df_target[['x_std', 'y_std', 'z_std']].values
        clusters = kmeans.predict(pts)

        symbols = [chr(ord('A') + (c % 26)) for c in clusters]

        temp_df = df_target.copy()
        temp_df['symbol'] = symbols

        seq_dict = defaultdict(list)
        for (gest, subj, it), group in temp_df.groupby(['gesture', 'subject', 'iter']):
            seq_dict[gest].append("".join(group['symbol'].tolist()))
        return seq_dict

    return to_seq_dict(train_df), to_seq_dict(test_df)



def lcs_length(s1, s2):
    n, m = len(s1), len(s2)
    dp = [[0]*(m+1) for _ in range(n+1)]
    for i in range(1, n+1):
        for j in range(1, m+1):
            if s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1] + 1
            else:
                dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    return dp[n][m]

def lcs_distance(s1, s2):

    return len(s1) + len(s2) - 2 * lcs_length(s1, s2)

def knn_lcs_predict(seq, train_dict, k=3):
    distances = []
    for gesture, sequences in train_dict.items():
        for s in sequences:
            d = lcs_distance(seq, s)
            distances.append((gesture, d))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def testmodel(df_input, loop_range=10, k_knn=3, k_clusters=20):
    total_true, total_pred = [], []

    for i in range(1, loop_range + 1):

        train_df = df_input[df_input["subject"] != i]
        test_df = df_input[df_input["subject"] == i]

        if test_df.empty:
            continue

        print(f"\n--- TEST SUJET SORTI : {i} ---")


        train_dict, test_dict = cluster_and_symbolize(train_df, test_df, k_clusters)

        y_true, y_pred = [], []
        for gesture, sequences in test_dict.items():
            for seq in sequences:
                pred = knn_lcs_predict(seq, train_dict, k=k_knn)
                y_true.append(gesture)
                y_pred.append(pred)

        acc = accuracy_score(y_true, y_pred)
        print(f"Précision sujet {i} : {acc:.2%}")
        total_true.extend(y_true)
        total_pred.extend(y_pred)

    final_acc = accuracy_score(total_true, total_pred)
    print(f"\n=== EXACTITUDE GLOBALE KNN-LCSS : {final_acc:.2%} ===")


    cm = confusion_matrix(total_true, total_pred)
    disp = ConfusionMatrixDisplay(cm)
    disp.plot(cmap="Blues")
    plt.title("Matrice de confusion – KNN + LCSS (Clustering In-Loop)")
    plt.show()


testmodel(df100)
# Out:
# --- Début du Chargement ---
# Dossier source : \\student.fucam.ac.be\users$\isadiki\Downloads\Domain2base\DOMAIN2_CSVcorrigé
# C:\Users\Isadiki\AppData\Local\Temp\ipykernel_12812\2244727691.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, file_df], ignore_index=True)
# Nombre total d'observations chargées : 79866
# Standardisation en cours...
# C:\Users\Isadiki\AppData\Local\Temp\ipykernel_12812\2244727691.py:74: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling en cours...
#
# --- TEST SUJET SORTI : 1 ---
# Précision sujet 1 : 98.00%
#
# --- TEST SUJET SORTI : 2 ---
# Précision sujet 2 : 93.00%
#
# --- TEST SUJET SORTI : 3 ---
# Précision sujet 3 : 95.00%
#
# --- TEST SUJET SORTI : 4 ---
# Précision sujet 4 : 97.00%
#
# --- TEST SUJET SORTI : 5 ---
# Précision sujet 5 : 83.00%
#
# --- TEST SUJET SORTI : 6 ---
# Précision sujet 6 : 76.00%
#
# --- TEST SUJET SORTI : 7 ---
# Précision sujet 7 : 89.00%
#
# --- TEST SUJET SORTI : 8 ---
# Précision sujet 8 : 81.00%
#
# --- TEST SUJET SORTI : 9 ---
# Précision sujet 9 : 91.00%
#
# --- TEST SUJET SORTI : 10 ---
# Précision sujet 10 : 91.00%
#
# === EXACTITUDE GLOBALE KNN-LCSS : 89.40% ===

# %% [markdown]
# #installe matplotlib

# %%
import sys
!"{sys.executable}" -m pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in \\student.fucam.ac.be\users$\isadiki\appdata\roaming\python\python313\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in \\student.fucam.ac.be\users$\isadiki\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in \\student.fucam.ac.be\users$\isadiki\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in \\student.fucam.ac.be\users$\isadiki\appdata\roaming\python\python313\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in \\student.fucam.ac.be\users$\isadiki\appdata\roaming\python\python313\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\program files\python313\lib\site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\program files\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in \\student.fucam.ac.be\users$\isadiki\appdata\roaming\python\python313\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in \\student.fucam.ac.be\users$\isadiki\appdata\roaming\python\python313\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\program files\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\program files\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #dtw

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import interp1d
import seaborn as sns



DOMAIN_FOLDER =r"\\student.fucam.ac.be\users$\isadiki\Downloads\Domain2base\DOMAIN2_CSVcorrigé"

df_list = []

print("--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:

                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2:
                    continue


                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])


                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)


                file_df['gesture'] = int(number)
                file_df['subject'] = int(subject)
                file_df['iter'] = int(iteration)

                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("❌ Aucun fichier chargé. Vérifiez le chemin : " + DOMAIN_FOLDER)

df = pd.concat(df_list, ignore_index=True)
for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)

print(f" Données chargées : {len(df)} lignes.")



subdf = df.loc[(df['gesture'] == 0) & (df['subject'] == 10) & (df['iter'] == 1)]

if not subdf.empty:
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(subdf['x'], subdf['y'], subdf['z'], c='red', s=20)
    ax.set_title("Visualisation 3D du geste (Sujet 10, Geste 0, Iter 1)")
    ax.set_xlabel('X'); ax.set_ylabel('Y'); ax.set_zlabel('Z')
    plt.show()




durations = df.groupby(['gesture', 'iter'])['t'].agg(lambda x: x.max() - x.min()).reset_index(name='duration')
mean_durations = durations.groupby('gesture')['duration'].mean()
print("\n--- Durée moyenne des gestes (s) ---")
print(mean_durations)


mean_coords_user = df.groupby(['subject', 'gesture'])[['x', 'y', 'z']].mean().reset_index()
mean_coords_global = df.groupby('gesture')[['x', 'y', 'z']].mean().reset_index().rename(
    columns={'x':'x_global', 'y':'y_global', 'z':'z_global'})

merged = pd.merge(mean_coords_user, mean_coords_global, on='gesture')
merged['dist_to_global'] = np.sqrt((merged['x']-merged['x_global'])**2 +
                                   (merged['y']-merged['y_global'])**2 +
                                   (merged['z']-merged['z_global'])**2)

pivot = merged.pivot(index='subject', columns='gesture', values='dist_to_global')
plt.figure(figsize=(10, 6))
sns.heatmap(pivot, annot=True, fmt=".3f", cmap='Blues')
plt.title("Écart entre la moyenne de l'utilisateur et la moyenne globale")
plt.show()



def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def eucl_dist(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def dtw_dist(seq1, seq2):
    n, m = len(seq1), len(seq2)
    dtw = np.full((n+1, m+1), np.inf)
    dtw[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = eucl_dist(seq1[i-1], seq2[j-1])
            dtw[i, j] = cost + min(dtw[i-1, j], dtw[i, j-1], dtw[i-1, j-1])
    return dtw[n, m]

def knn_dtw_predict(reference_seq, train_dict, k=3):
    distances = []
    for gesture, sequences in train_dict.items():
        for seq in sequences:
            dist = dtw_dist(reference_seq, seq)
            distances.append((gesture, dist))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def dict_creation_userout(df, subj_out):
    test_df = df[df["subject"] == subj_out]
    train_df = df[df["subject"] != subj_out]

    dict_train = defaultdict(list)
    dict_test = defaultdict(list)

    for (g, s, it), group in train_df.groupby(["gesture", "subject", "iter"]):
        dict_train[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())
    for (g, s, it), group in test_df.groupby(["gesture", "subject", "iter"]):
        dict_test[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())
    return dict_train, dict_test

def testmodel(DictCreationFunc, df, loop_range=10, k=3):
    total_true, total_pred = [], []
    for i in range(1, loop_range + 1):
        print(f"\n--- Test Split OUT : {i} ---")
        coord_train, coord_test = DictCreationFunc(df, i)
        y_true, y_pred = [], []
        for gesture, sequences in coord_test.items():
            for seq in sequences:
                pred = knn_dtw_predict(seq, coord_train, k=k)
                y_true.append(gesture)
                y_pred.append(pred)

        acc = accuracy_score(y_true, y_pred)
        total_true.extend(y_true); total_pred.extend(y_pred)
        print(f"Précision split {i} : {acc:.2%}")

    print(f"\nPrécision GLOBALE : {accuracy_score(total_true, total_pred):.2%}")
    cm = confusion_matrix(total_true, total_pred)
    ConfusionMatrixDisplay(cm).plot(cmap="Blues")
    plt.title("Matrice de Confusion Finale")
    plt.show()


testmodel(dict_creation_userout, df100, loop_range=10, k=3)
# Out:
# --- Début du Chargement ---
# ✅ Données chargées : 79866 lignes.
# --- Durée moyenne des gestes (s) ---
# gesture
# 0    3980.0
# 1    3567.2
# 2    2570.5
# 3    4037.7
# 4    3087.1
# 5    5395.7
# 6    4499.0
# 7    4250.9
# 8    2463.7
# 9    3477.0
# Name: duration, dtype: float64
# Standardisation...
# C:\Users\Isadiki\AppData\Local\Temp\ipykernel_18484\2285233954.py:112: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling...
#
# --- Test Split OUT : 1 ---
# Précision split 1 : 100.00%
#
# --- Test Split OUT : 2 ---
# Précision split 2 : 97.00%
#
# --- Test Split OUT : 3 ---
# Précision split 3 : 94.00%
#
# --- Test Split OUT : 4 ---
# Précision split 4 : 100.00%
#
# --- Test Split OUT : 5 ---
# Précision split 5 : 97.00%
#
# --- Test Split OUT : 6 ---
# Précision split 6 : 97.00%
#
# --- Test Split OUT : 7 ---
# Précision split 7 : 98.00%
#
# --- Test Split OUT : 8 ---
# Précision split 8 : 96.00%
#
# --- Test Split OUT : 9 ---
# Précision split 9 : 98.00%
#
# --- Test Split OUT : 10 ---
# Précision split 10 : 98.00%
#
# ✅ Précision GLOBALE : 97.50%

# %%
import os

# Ce script va chercher où se cachent tes fichiers .csv
for root, dirs, files in os.walk("/content/temp_data"):
    csv_files = [f for f in files if f.endswith('.csv')]
    if len(csv_files) > 0:
        print(f"✅ TROUVÉ ! Tes fichiers sont ici : {root}")
        print(f"Exemple de fichier : {csv_files[0]}")
        # On met à jour le chemin automatiquement
        DOMAIN_FOLDER = root
        break
# Out:
# ✅ TROUVÉ ! Tes fichiers sont ici : /content/temp_data/DOMAIN2_CSV
# Exemple de fichier : Subject6-1-8.csv

# %% [markdown]
# # lstm 64 32 32 test 5 train 4

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

# --- 2. Prétraitement ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. Séparation Train / Test ---
def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. Modèle ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(64, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(64),
        layers.Dense(32, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

# --- 5. Évaluation Détaillée ---
print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# /tmp/ipykernel_415/3547428122.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - accuracy: 0.2068 - loss: 2.2594 - val_accuracy: 0.0000e+00 - val_loss: 2.6716
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.2809 - loss: 2.1132 - val_accuracy: 0.0000e+00 - val_loss: 2.9940
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.3951 - loss: 1.8706 - val_accuracy: 0.0000e+00 - val_loss: 3.5799
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - accuracy: 0.4321 - loss: 1.5766 - val_accuracy: 0.0000e+00 - val_loss: 3.9222
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.5710 - loss: 1.3223 - val_accuracy: 0.0000e+00 - val_loss: 3.7979
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.6759 - loss: 1.0718 - val_accuracy: 0.0000e+00 - val_loss: 4.0497
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.7469 - loss: 0.8459 - val_accuracy: 0.0000e+00 - val_loss: 4.1569
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.8302 - loss: 0.6693 - val_accuracy: 0.0000e+00 - val_loss: 3.9479
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.8765 - loss: 0.5350 - val_accuracy: 0.0000e+00 - val_loss: 3.7350
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.8951 - loss: 0.4151 - val_accuracy: 0.0000e+00 - val_loss: 3.2224
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9105 - loss: 0.3407 - val_accuracy: 0.0000e+00 - val_loss: 3.8392
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.9136 - loss: 0.3066 - val_accuracy: 0.0000e+00 - val_loss: 3.6475
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step - accuracy: 0.9228 - loss: 0.2476 - val_accuracy: 0.0000e+00 - val_loss: 3.0383
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - accuracy: 0.8951 - loss: 0.2810 - val_accuracy: 0.0000e+00 - val_loss: 4.0284
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9228 - loss: 0.2561 - val_accuracy: 0.0000e+00 - val_loss: 2.9645
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9259 - loss: 0.2042 - val_accuracy: 0.0000e+00 - val_loss: 3.0135
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9414 - loss: 0.1785 - val_accuracy: 0.0000e+00 - val_loss: 3.0282
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9722 - loss: 0.1175 - val_accuracy: 0.0278 - val_loss: 3.3398
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9815 - loss: 0.0740 - val_accuracy: 0.3333 - val_loss: 2.4308
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9907 - loss: 0.0617 - val_accuracy: 0.4167 - val_loss: 2.2704
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 1.0000 - loss: 0.0323 - val_accuracy: 0.2778 - val_loss: 2.5485
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.9907 - loss: 0.0508 - val_accuracy: 0.2222 - val_loss: 2.5564
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.9938 - loss: 0.0427 - val_accuracy: 0.4444 - val_loss: 2.0690
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9753 - loss: 0.0926 - val_accuracy: 0.0000e+00 - val_loss: 4.6508
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9506 - loss: 0.1383 - val_accuracy: 0.0556 - val_loss: 2.1610
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9321 - loss: 0.1682 - val_accuracy: 0.0000e+00 - val_loss: 3.1954
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9691 - loss: 0.1239 - val_accuracy: 0.1667 - val_loss: 2.7561
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9784 - loss: 0.0813 - val_accuracy: 0.3611 - val_loss: 2.0555
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9938 - loss: 0.0431 - val_accuracy: 0.5833 - val_loss: 1.5485
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.9969 - loss: 0.0289 - val_accuracy: 0.6667 - val_loss: 1.4379
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 225ms/step - accuracy: 0.9846 - loss: 0.0468 - val_accuracy: 0.4722 - val_loss: 1.9788
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - accuracy: 1.0000 - loss: 0.0192 - val_accuracy: 0.5556 - val_loss: 1.9686
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.6667 - val_loss: 1.6151
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.6389 - val_loss: 1.5013
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.6111 - val_loss: 1.5070
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.5833 - val_loss: 1.5968
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.5556 - val_loss: 1.6947
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.5556 - val_loss: 1.8235
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.5556 - val_loss: 1.8585
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.5000 - val_loss: 1.8342
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.4722 - val_loss: 1.8290
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.4722 - val_loss: 1.8344
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.4722 - val_loss: 1.8379
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.4722 - val_loss: 1.8521
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.5000 - val_loss: 1.8790
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.4722 - val_loss: 1.8919
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.5000 - val_loss: 1.8905
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.5000 - val_loss: 1.8879
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.5000 - val_loss: 1.8754
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.5000 - val_loss: 1.8897
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets        : [6, 7, 8, 9, 10]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 6 : 80.00%
# Précision Sujet 7 : 74.44%
# Précision Sujet 8 : 64.44%
# Précision Sujet 9 : 73.33%
# Précision Sujet 10 : 73.33%
# ------------------------------
# MOYENNE GLOBALE TEST : 73.11%
# ------------------------------

# %% [markdown]
# # lstm 64 32 32 train 5V test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2
TRAIN_SUBJECTS = [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

# --- 2. Prétraitement ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. Séparation Train / Test ---
def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. Modèle ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(64, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(64),
        layers.Dense(32, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

# --- 5. Évaluation Détaillée ---
print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# /tmp/ipykernel_415/3592229362.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - accuracy: 0.1753 - loss: 2.2155 - val_accuracy: 0.0000e+00 - val_loss: 2.7392
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.2914 - loss: 1.9707 - val_accuracy: 0.0000e+00 - val_loss: 3.3571
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.6025 - loss: 1.5267 - val_accuracy: 0.0000e+00 - val_loss: 4.1821
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.7457 - loss: 0.9646 - val_accuracy: 0.0000e+00 - val_loss: 4.6085
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.8148 - loss: 0.6123 - val_accuracy: 0.0000e+00 - val_loss: 4.2639
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.8642 - loss: 0.4163 - val_accuracy: 0.0000e+00 - val_loss: 4.7597
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9037 - loss: 0.3053 - val_accuracy: 0.0000e+00 - val_loss: 4.4874
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9210 - loss: 0.2703 - val_accuracy: 0.0000e+00 - val_loss: 4.6560
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9160 - loss: 0.2262 - val_accuracy: 0.0667 - val_loss: 3.8795
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9679 - loss: 0.1500 - val_accuracy: 0.2222 - val_loss: 3.0009
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9926 - loss: 0.0886 - val_accuracy: 0.2222 - val_loss: 2.9734
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9852 - loss: 0.0767 - val_accuracy: 0.1111 - val_loss: 3.8873
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.9926 - loss: 0.0583 - val_accuracy: 0.0889 - val_loss: 4.7449
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.9827 - loss: 0.0781 - val_accuracy: 0.2222 - val_loss: 3.7627
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - accuracy: 0.9852 - loss: 0.0758 - val_accuracy: 0.1111 - val_loss: 4.1148
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - accuracy: 0.9852 - loss: 0.0617 - val_accuracy: 0.1111 - val_loss: 4.4964
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.9728 - loss: 0.0986 - val_accuracy: 0.2000 - val_loss: 3.4954
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.9679 - loss: 0.1164 - val_accuracy: 0.0667 - val_loss: 5.9037
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 228ms/step - accuracy: 0.9654 - loss: 0.1259 - val_accuracy: 0.2000 - val_loss: 4.1338
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9753 - loss: 0.0828 - val_accuracy: 0.0222 - val_loss: 5.5522
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.9877 - loss: 0.0438 - val_accuracy: 0.1333 - val_loss: 3.8892
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 283ms/step - accuracy: 0.9926 - loss: 0.0421 - val_accuracy: 0.1333 - val_loss: 3.8540
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 248ms/step - accuracy: 1.0000 - loss: 0.0179 - val_accuracy: 0.0889 - val_loss: 4.4691
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.9951 - loss: 0.0146 - val_accuracy: 0.0889 - val_loss: 4.6312
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.0889 - val_loss: 4.6141
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 170ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.0889 - val_loss: 4.6797
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.0889 - val_loss: 4.7062
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.0889 - val_loss: 4.8022
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.0889 - val_loss: 4.8719
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.0889 - val_loss: 4.9080
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.0889 - val_loss: 4.9316
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.0889 - val_loss: 4.9559
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.0889 - val_loss: 5.0405
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.0889 - val_loss: 5.0562
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.0889 - val_loss: 5.0461
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.0889 - val_loss: 5.0454
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 173ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.0889 - val_loss: 5.0627
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.1111 - val_loss: 5.0536
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.1111 - val_loss: 5.0704
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.0889 - val_loss: 5.1219
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.0889 - val_loss: 5.2112
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.1111 - val_loss: 5.2329
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.0889 - val_loss: 5.2223
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.1111 - val_loss: 5.2201
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.1111 - val_loss: 5.2504
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 224ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.1111 - val_loss: 5.3040
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.1111 - val_loss: 5.3190
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.1111 - val_loss: 5.3704
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.1111 - val_loss: 5.3991
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.1111 - val_loss: 5.3709
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets        : [1, 2, 4, 5]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 1 : 82.22%
# Précision Sujet 2 : 60.00%
# Précision Sujet 4 : 74.44%
# Précision Sujet 5 : 73.33%
# ------------------------------
# MOYENNE GLOBALE TEST : 72.50%
# ------------------------------

# %% [markdown]
# # lstm 128 32 32 traéin 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

# --- 2. Prétraitement ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. Séparation Train / Test ---
def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. Modèle ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(128, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(128),
        layers.Dense(32, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

# --- 5. Évaluation Détaillée ---
print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# /tmp/ipykernel_415/775837281.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 301ms/step - accuracy: 0.2284 - loss: 2.1352 - val_accuracy: 0.0000e+00 - val_loss: 2.7475
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 297ms/step - accuracy: 0.4043 - loss: 1.7821 - val_accuracy: 0.0000e+00 - val_loss: 3.0973
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 347ms/step - accuracy: 0.5401 - loss: 1.4022 - val_accuracy: 0.0000e+00 - val_loss: 3.8395
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 294ms/step - accuracy: 0.7099 - loss: 1.0369 - val_accuracy: 0.0000e+00 - val_loss: 5.3545
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - accuracy: 0.6914 - loss: 0.8333 - val_accuracy: 0.0000e+00 - val_loss: 5.5179
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - accuracy: 0.8148 - loss: 0.6030 - val_accuracy: 0.0000e+00 - val_loss: 5.0638
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 307ms/step - accuracy: 0.8364 - loss: 0.5312 - val_accuracy: 0.0000e+00 - val_loss: 5.4457
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 330ms/step - accuracy: 0.8951 - loss: 0.3776 - val_accuracy: 0.0000e+00 - val_loss: 5.5408
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 263ms/step - accuracy: 0.8611 - loss: 0.3821 - val_accuracy: 0.0000e+00 - val_loss: 5.4620
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 258ms/step - accuracy: 0.9321 - loss: 0.2780 - val_accuracy: 0.0000e+00 - val_loss: 3.6130
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 259ms/step - accuracy: 0.9414 - loss: 0.2372 - val_accuracy: 0.0000e+00 - val_loss: 5.2974
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - accuracy: 0.9444 - loss: 0.2338 - val_accuracy: 0.0278 - val_loss: 5.2084
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 569ms/step - accuracy: 0.9012 - loss: 0.2892 - val_accuracy: 0.0278 - val_loss: 3.9180
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 766ms/step - accuracy: 0.9568 - loss: 0.1685 - val_accuracy: 0.1111 - val_loss: 3.2196
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 493ms/step - accuracy: 0.9630 - loss: 0.1196 - val_accuracy: 0.1944 - val_loss: 2.4477
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 632ms/step - accuracy: 0.9444 - loss: 0.1852 - val_accuracy: 0.0000e+00 - val_loss: 3.7367
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 259ms/step - accuracy: 0.9722 - loss: 0.1127 - val_accuracy: 0.0278 - val_loss: 3.2787
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 406ms/step - accuracy: 0.9907 - loss: 0.0680 - val_accuracy: 0.1944 - val_loss: 3.1742
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 259ms/step - accuracy: 0.9938 - loss: 0.0391 - val_accuracy: 0.4167 - val_loss: 2.4092
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - accuracy: 0.9691 - loss: 0.0857 - val_accuracy: 0.4444 - val_loss: 2.4174
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - accuracy: 1.0000 - loss: 0.0376 - val_accuracy: 0.1667 - val_loss: 4.1858
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 402ms/step - accuracy: 0.9691 - loss: 0.0970 - val_accuracy: 0.3611 - val_loss: 2.7823
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 260ms/step - accuracy: 0.9691 - loss: 0.1213 - val_accuracy: 0.2778 - val_loss: 2.8605
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 259ms/step - accuracy: 0.9969 - loss: 0.0403 - val_accuracy: 0.2778 - val_loss: 3.1570
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 356ms/step - accuracy: 0.9907 - loss: 0.0566 - val_accuracy: 0.4722 - val_loss: 2.4241
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 396ms/step - accuracy: 0.9444 - loss: 0.1583 - val_accuracy: 0.3056 - val_loss: 2.6891
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 589ms/step - accuracy: 0.9753 - loss: 0.0749 - val_accuracy: 0.3056 - val_loss: 3.1317
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 515ms/step - accuracy: 0.9938 - loss: 0.0429 - val_accuracy: 0.3333 - val_loss: 3.2299
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 558ms/step - accuracy: 1.0000 - loss: 0.0181 - val_accuracy: 0.3889 - val_loss: 3.3121
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 522ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.3333 - val_loss: 3.6115
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 399ms/step - accuracy: 0.9938 - loss: 0.0199 - val_accuracy: 0.3611 - val_loss: 3.7735
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - accuracy: 0.9753 - loss: 0.1351 - val_accuracy: 0.0278 - val_loss: 4.7540
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 306ms/step - accuracy: 0.8765 - loss: 0.3588 - val_accuracy: 0.6389 - val_loss: 1.9052
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 350ms/step - accuracy: 0.8951 - loss: 0.3497 - val_accuracy: 0.0278 - val_loss: 4.0661
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 294ms/step - accuracy: 0.9074 - loss: 0.2709 - val_accuracy: 0.1944 - val_loss: 2.9626
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 261ms/step - accuracy: 0.9290 - loss: 0.2633 - val_accuracy: 0.0000e+00 - val_loss: 3.8186
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 0.9506 - loss: 0.1720 - val_accuracy: 0.5000 - val_loss: 1.7444
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 373ms/step - accuracy: 0.9691 - loss: 0.1168 - val_accuracy: 0.1944 - val_loss: 2.9258
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 261ms/step - accuracy: 0.9784 - loss: 0.0796 - val_accuracy: 0.2222 - val_loss: 2.7007
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 261ms/step - accuracy: 0.9877 - loss: 0.0646 - val_accuracy: 0.2778 - val_loss: 3.1334
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 422ms/step - accuracy: 0.9938 - loss: 0.0311 - val_accuracy: 0.5278 - val_loss: 2.0444
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 265ms/step - accuracy: 1.0000 - loss: 0.0176 - val_accuracy: 0.3056 - val_loss: 2.9507
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 264ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.3333 - val_loss: 3.0583
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 338ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.3333 - val_loss: 3.1790
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 292ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.3056 - val_loss: 3.3524
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 255ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.3056 - val_loss: 3.4489
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.3056 - val_loss: 3.4843
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 294ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.3056 - val_loss: 3.5373
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 344ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.3056 - val_loss: 3.5414
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.3056 - val_loss: 3.5514
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets        : [6, 7, 8, 9, 10]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 6 : 83.33%
# Précision Sujet 7 : 82.22%
# Précision Sujet 8 : 81.11%
# Précision Sujet 9 : 83.33%
# Précision Sujet 10 : 94.44%
# ------------------------------
# MOYENNE GLOBALE TEST : 84.89%
# ------------------------------

# %% [markdown]
# # lstm 128 32 32 train 5 tets 4

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2
TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

# --- 2. Prétraitement ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. Séparation Train / Test ---
def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. Modèle ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(128, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(128),
        layers.Dense(32, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

# --- 5. Évaluation Détaillée ---
print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# /tmp/ipykernel_415/3731310584.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 473ms/step - accuracy: 0.2444 - loss: 2.1520 - val_accuracy: 0.0000e+00 - val_loss: 3.2729
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 277ms/step - accuracy: 0.5852 - loss: 1.4437 - val_accuracy: 0.0000e+00 - val_loss: 4.3261
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 298ms/step - accuracy: 0.8667 - loss: 0.6313 - val_accuracy: 0.0000e+00 - val_loss: 4.3941
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 273ms/step - accuracy: 0.9185 - loss: 0.3851 - val_accuracy: 0.0000e+00 - val_loss: 4.2838
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 279ms/step - accuracy: 0.9556 - loss: 0.2033 - val_accuracy: 0.0000e+00 - val_loss: 4.1216
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 372ms/step - accuracy: 0.9457 - loss: 0.1971 - val_accuracy: 0.0000e+00 - val_loss: 4.8055
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 269ms/step - accuracy: 0.9383 - loss: 0.1791 - val_accuracy: 0.0222 - val_loss: 3.1656
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 270ms/step - accuracy: 0.9778 - loss: 0.0960 - val_accuracy: 0.1333 - val_loss: 2.9974
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 401ms/step - accuracy: 0.9802 - loss: 0.0781 - val_accuracy: 0.0889 - val_loss: 3.0067
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 288ms/step - accuracy: 0.9951 - loss: 0.0428 - val_accuracy: 0.2222 - val_loss: 1.6618
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 281ms/step - accuracy: 0.9926 - loss: 0.0328 - val_accuracy: 0.3333 - val_loss: 1.7941
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.9901 - loss: 0.0542 - val_accuracy: 0.4667 - val_loss: 1.9883
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.9309 - loss: 0.2302 - val_accuracy: 0.1111 - val_loss: 2.2547
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - accuracy: 0.9630 - loss: 0.1322 - val_accuracy: 0.1778 - val_loss: 2.1366
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 375ms/step - accuracy: 0.9827 - loss: 0.0538 - val_accuracy: 0.1778 - val_loss: 2.6889
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 0.9975 - loss: 0.0264 - val_accuracy: 0.1333 - val_loss: 2.9562
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 0.9975 - loss: 0.0192 - val_accuracy: 0.2222 - val_loss: 2.4178
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 403ms/step - accuracy: 0.9802 - loss: 0.0753 - val_accuracy: 0.2000 - val_loss: 3.3913
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 0.9852 - loss: 0.0600 - val_accuracy: 0.2667 - val_loss: 3.1996
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 278ms/step - accuracy: 0.9926 - loss: 0.0309 - val_accuracy: 0.0889 - val_loss: 3.9084
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 402ms/step - accuracy: 0.9852 - loss: 0.0561 - val_accuracy: 0.2222 - val_loss: 2.8001
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 272ms/step - accuracy: 0.9975 - loss: 0.0199 - val_accuracy: 0.1556 - val_loss: 4.0311
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 273ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.2222 - val_loss: 3.7019
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 374ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.2667 - val_loss: 3.4159
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 276ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.2667 - val_loss: 3.5586
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 265ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.2444 - val_loss: 3.7751
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 286ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.2444 - val_loss: 3.8718
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 364ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.2222 - val_loss: 3.9461
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.2222 - val_loss: 3.9857
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.2222 - val_loss: 4.0481
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 337ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.2222 - val_loss: 4.0717
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.2000 - val_loss: 4.1089
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 272ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.2000 - val_loss: 4.1403
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 407ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.2000 - val_loss: 4.1837
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.2000 - val_loss: 4.2285
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.2000 - val_loss: 4.2604
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 384ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.2000 - val_loss: 4.2896
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.2000 - val_loss: 4.2958
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.2000 - val_loss: 4.3292
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 296ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.2000 - val_loss: 4.3620
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 350ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.2000 - val_loss: 4.3700
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 273ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.2000 - val_loss: 4.3890
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 271ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.2000 - val_loss: 4.4173
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 392ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.2000 - val_loss: 4.4483
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 267ms/step - accuracy: 1.0000 - loss: 9.8877e-04 - val_accuracy: 0.2000 - val_loss: 4.4825
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 268ms/step - accuracy: 1.0000 - loss: 9.2820e-04 - val_accuracy: 0.2000 - val_loss: 4.5019
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 383ms/step - accuracy: 1.0000 - loss: 9.1475e-04 - val_accuracy: 0.2222 - val_loss: 4.5012
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - accuracy: 1.0000 - loss: 8.7095e-04 - val_accuracy: 0.2000 - val_loss: 4.5388
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 267ms/step - accuracy: 1.0000 - loss: 8.4522e-04 - val_accuracy: 0.2222 - val_loss: 4.5510
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 284ms/step - accuracy: 1.0000 - loss: 8.3108e-04 - val_accuracy: 0.2222 - val_loss: 4.5734
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets        : [1, 2, 4, 5]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 1 : 78.89%
# Précision Sujet 2 : 57.78%
# Précision Sujet 4 : 83.33%
# Précision Sujet 5 : 81.11%
# ------------------------------
# MOYENNE GLOBALE TEST : 75.28%
# ------------------------------

# %% [markdown]
# # lstm 256 32 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

# --- 2. Prétraitement ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. Séparation Train / Test ---
def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. Modèle ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(32, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

# --- 5. Évaluation Détaillée ---
print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# /tmp/ipykernel_415/1119343803.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 936ms/step - accuracy: 0.2901 - loss: 1.9951 - val_accuracy: 0.0000e+00 - val_loss: 3.5803
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 831ms/step - accuracy: 0.4784 - loss: 1.4601 - val_accuracy: 0.0000e+00 - val_loss: 4.1073
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 751ms/step - accuracy: 0.7562 - loss: 0.8453 - val_accuracy: 0.0000e+00 - val_loss: 5.4073
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 882ms/step - accuracy: 0.7623 - loss: 0.6504 - val_accuracy: 0.0000e+00 - val_loss: 5.4413
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 893ms/step - accuracy: 0.8488 - loss: 0.5230 - val_accuracy: 0.0000e+00 - val_loss: 5.1965
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 752ms/step - accuracy: 0.8858 - loss: 0.3627 - val_accuracy: 0.0000e+00 - val_loss: 5.5889
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 888ms/step - accuracy: 0.9136 - loss: 0.3193 - val_accuracy: 0.0000e+00 - val_loss: 4.3829
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 891ms/step - accuracy: 0.9167 - loss: 0.2684 - val_accuracy: 0.0000e+00 - val_loss: 4.2155
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 787ms/step - accuracy: 0.8827 - loss: 0.3328 - val_accuracy: 0.0000e+00 - val_loss: 3.4528
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 759ms/step - accuracy: 0.9444 - loss: 0.1793 - val_accuracy: 0.0000e+00 - val_loss: 2.4549
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 889ms/step - accuracy: 0.9012 - loss: 0.3202 - val_accuracy: 0.0000e+00 - val_loss: 3.4987
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 894ms/step - accuracy: 0.7747 - loss: 0.7082 - val_accuracy: 0.0556 - val_loss: 2.3182
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 762ms/step - accuracy: 0.8765 - loss: 0.3514 - val_accuracy: 0.0833 - val_loss: 2.2833
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 783ms/step - accuracy: 0.9568 - loss: 0.1620 - val_accuracy: 0.0000e+00 - val_loss: 2.8099
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 902ms/step - accuracy: 0.9784 - loss: 0.0846 - val_accuracy: 0.0278 - val_loss: 2.3893
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 892ms/step - accuracy: 0.9722 - loss: 0.0723 - val_accuracy: 0.5000 - val_loss: 1.4649
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 733ms/step - accuracy: 0.9722 - loss: 0.0798 - val_accuracy: 0.0278 - val_loss: 3.4639
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 885ms/step - accuracy: 0.9815 - loss: 0.0481 - val_accuracy: 0.1111 - val_loss: 2.3756
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 902ms/step - accuracy: 1.0000 - loss: 0.0231 - val_accuracy: 0.0833 - val_loss: 3.5352
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 808ms/step - accuracy: 0.9907 - loss: 0.0348 - val_accuracy: 0.1111 - val_loss: 3.3056
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 795ms/step - accuracy: 0.9938 - loss: 0.0297 - val_accuracy: 0.6111 - val_loss: 1.3424
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 885ms/step - accuracy: 0.9938 - loss: 0.0332 - val_accuracy: 0.5556 - val_loss: 1.4433
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 883ms/step - accuracy: 0.9877 - loss: 0.0451 - val_accuracy: 0.4444 - val_loss: 2.4237
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 744ms/step - accuracy: 0.9444 - loss: 0.2316 - val_accuracy: 0.6667 - val_loss: 1.2712
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 890ms/step - accuracy: 0.9691 - loss: 0.1119 - val_accuracy: 0.0000e+00 - val_loss: 3.8879
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 892ms/step - accuracy: 0.9815 - loss: 0.0592 - val_accuracy: 0.1944 - val_loss: 1.7602
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 817ms/step - accuracy: 0.9877 - loss: 0.0508 - val_accuracy: 0.3056 - val_loss: 1.9318
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 763ms/step - accuracy: 0.9877 - loss: 0.0424 - val_accuracy: 0.6944 - val_loss: 1.0012
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 874ms/step - accuracy: 0.9969 - loss: 0.0373 - val_accuracy: 0.8056 - val_loss: 0.6218
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 847ms/step - accuracy: 0.9938 - loss: 0.0384 - val_accuracy: 0.1389 - val_loss: 3.6750
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 739ms/step - accuracy: 0.9660 - loss: 0.1348 - val_accuracy: 0.0000e+00 - val_loss: 4.9420
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 887ms/step - accuracy: 0.8426 - loss: 0.6339 - val_accuracy: 0.7500 - val_loss: 1.1538
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 881ms/step - accuracy: 0.9074 - loss: 0.2747 - val_accuracy: 0.3611 - val_loss: 2.4882
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 751ms/step - accuracy: 0.9753 - loss: 0.0830 - val_accuracy: 0.5000 - val_loss: 2.0573
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 888ms/step - accuracy: 0.9815 - loss: 0.0683 - val_accuracy: 0.7222 - val_loss: 1.4551
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 886ms/step - accuracy: 0.9691 - loss: 0.1030 - val_accuracy: 0.5278 - val_loss: 2.1070
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 749ms/step - accuracy: 0.9815 - loss: 0.0615 - val_accuracy: 0.2778 - val_loss: 3.3306
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 740ms/step - accuracy: 0.9753 - loss: 0.0546 - val_accuracy: 0.5278 - val_loss: 1.9686
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 894ms/step - accuracy: 0.9568 - loss: 0.1283 - val_accuracy: 0.5278 - val_loss: 1.9797
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 914ms/step - accuracy: 0.9846 - loss: 0.0774 - val_accuracy: 0.0278 - val_loss: 3.8354
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 768ms/step - accuracy: 0.9846 - loss: 0.0533 - val_accuracy: 0.8056 - val_loss: 1.0405
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 854ms/step - accuracy: 0.9969 - loss: 0.0197 - val_accuracy: 0.2500 - val_loss: 3.5276
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 899ms/step - accuracy: 0.9969 - loss: 0.0186 - val_accuracy: 0.5833 - val_loss: 1.8525
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 816ms/step - accuracy: 0.9969 - loss: 0.0162 - val_accuracy: 0.6389 - val_loss: 2.1592
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 763ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.6667 - val_loss: 1.9090
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 793ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.6944 - val_loss: 1.7643
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 905ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.6944 - val_loss: 1.8314
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 894ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.6667 - val_loss: 1.9220
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 754ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.6667 - val_loss: 1.9694
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 849ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.6389 - val_loss: 2.0007
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets        : [6, 7, 8, 9, 10]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 6 : 93.33%
# Précision Sujet 7 : 81.11%
# Précision Sujet 8 : 85.56%
# Précision Sujet 9 : 86.67%
# Précision Sujet 10 : 91.11%
# ------------------------------
# MOYENNE GLOBALE TEST : 87.56%
# ------------------------------

# %% [markdown]
# # lstm 256 32 32 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2
TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

# --- 2. Prétraitement ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. Séparation Train / Test ---
def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. Modèle ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(32, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

# --- 5. Évaluation Détaillée ---
print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# /tmp/ipykernel_415/3506793184.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 865ms/step - accuracy: 0.4395 - loss: 1.8378 - val_accuracy: 0.0000e+00 - val_loss: 4.0772
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 767ms/step - accuracy: 0.7926 - loss: 0.6778 - val_accuracy: 0.0000e+00 - val_loss: 4.0729
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 877ms/step - accuracy: 0.8938 - loss: 0.3246 - val_accuracy: 0.0000e+00 - val_loss: 3.3967
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 879ms/step - accuracy: 0.8889 - loss: 0.3213 - val_accuracy: 0.0000e+00 - val_loss: 2.3733
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 775ms/step - accuracy: 0.9383 - loss: 0.1938 - val_accuracy: 0.0000e+00 - val_loss: 2.5883
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 802ms/step - accuracy: 0.9704 - loss: 0.1108 - val_accuracy: 0.3111 - val_loss: 2.1658
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 864ms/step - accuracy: 0.9457 - loss: 0.1508 - val_accuracy: 0.0889 - val_loss: 2.6592
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 886ms/step - accuracy: 0.9235 - loss: 0.2459 - val_accuracy: 0.1333 - val_loss: 2.2868
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 870ms/step - accuracy: 0.9160 - loss: 0.2428 - val_accuracy: 0.5111 - val_loss: 1.5577
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 858ms/step - accuracy: 0.9704 - loss: 0.1132 - val_accuracy: 0.0222 - val_loss: 3.8291
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 754ms/step - accuracy: 0.9778 - loss: 0.0742 - val_accuracy: 0.3111 - val_loss: 1.9342
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 846ms/step - accuracy: 0.9926 - loss: 0.0319 - val_accuracy: 0.2000 - val_loss: 3.4183
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 864ms/step - accuracy: 0.9926 - loss: 0.0294 - val_accuracy: 0.2667 - val_loss: 2.9182
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 875ms/step - accuracy: 0.9926 - loss: 0.0216 - val_accuracy: 0.2667 - val_loss: 2.5994
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 858ms/step - accuracy: 0.9630 - loss: 0.1083 - val_accuracy: 0.5111 - val_loss: 1.4024
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 886ms/step - accuracy: 0.9753 - loss: 0.0928 - val_accuracy: 0.2444 - val_loss: 3.9715
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 872ms/step - accuracy: 0.9926 - loss: 0.0272 - val_accuracy: 0.2667 - val_loss: 2.8727
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 870ms/step - accuracy: 0.9975 - loss: 0.0146 - val_accuracy: 0.2444 - val_loss: 2.7623
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 753ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.5556 - val_loss: 1.1790
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 874ms/step - accuracy: 0.9951 - loss: 0.0117 - val_accuracy: 0.0000e+00 - val_loss: 5.8938
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 909ms/step - accuracy: 0.9901 - loss: 0.0700 - val_accuracy: 0.2667 - val_loss: 2.0936
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 804ms/step - accuracy: 0.9877 - loss: 0.0451 - val_accuracy: 0.2889 - val_loss: 1.9609
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 812ms/step - accuracy: 0.9877 - loss: 0.0421 - val_accuracy: 0.2889 - val_loss: 2.3009
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 890ms/step - accuracy: 0.9926 - loss: 0.0193 - val_accuracy: 0.2889 - val_loss: 2.6386
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 883ms/step - accuracy: 0.9975 - loss: 0.0075 - val_accuracy: 0.2444 - val_loss: 2.8687
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 879ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.2444 - val_loss: 3.0978
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 873ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.2444 - val_loss: 3.2209
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 786ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.2444 - val_loss: 3.2854
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 792ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.2444 - val_loss: 3.3960
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 864ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.2444 - val_loss: 3.4466
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 867ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.2444 - val_loss: 3.4469
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 815ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.2444 - val_loss: 3.4839
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 759ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.2444 - val_loss: 3.4598
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 865ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.2444 - val_loss: 3.5167
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 858ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.2444 - val_loss: 3.5770
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 857ms/step - accuracy: 1.0000 - loss: 9.5491e-04 - val_accuracy: 0.2444 - val_loss: 3.5926
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 763ms/step - accuracy: 1.0000 - loss: 8.9063e-04 - val_accuracy: 0.2444 - val_loss: 3.6192
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 843ms/step - accuracy: 1.0000 - loss: 8.2860e-04 - val_accuracy: 0.2444 - val_loss: 3.6354
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 876ms/step - accuracy: 1.0000 - loss: 7.9103e-04 - val_accuracy: 0.2444 - val_loss: 3.6918
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 893ms/step - accuracy: 1.0000 - loss: 7.2694e-04 - val_accuracy: 0.2444 - val_loss: 3.7239
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 839ms/step - accuracy: 1.0000 - loss: 6.9639e-04 - val_accuracy: 0.2444 - val_loss: 3.7170
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 901ms/step - accuracy: 1.0000 - loss: 6.5525e-04 - val_accuracy: 0.2444 - val_loss: 3.7569
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 877ms/step - accuracy: 1.0000 - loss: 6.2679e-04 - val_accuracy: 0.2444 - val_loss: 3.8069
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 886ms/step - accuracy: 1.0000 - loss: 5.9137e-04 - val_accuracy: 0.2444 - val_loss: 3.8097
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 812ms/step - accuracy: 1.0000 - loss: 5.4912e-04 - val_accuracy: 0.2444 - val_loss: 3.8410
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 919ms/step - accuracy: 1.0000 - loss: 5.3025e-04 - val_accuracy: 0.2444 - val_loss: 3.8638
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 895ms/step - accuracy: 1.0000 - loss: 5.0996e-04 - val_accuracy: 0.2444 - val_loss: 3.9058
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 890ms/step - accuracy: 1.0000 - loss: 4.7303e-04 - val_accuracy: 0.2444 - val_loss: 3.9185
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 796ms/step - accuracy: 1.0000 - loss: 4.4952e-04 - val_accuracy: 0.2444 - val_loss: 3.9411
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 818ms/step - accuracy: 1.0000 - loss: 4.3735e-04 - val_accuracy: 0.2444 - val_loss: 3.9503
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets        : [1, 2, 4, 5]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 1 : 85.56%
# Précision Sujet 2 : 58.89%
# Précision Sujet 4 : 80.00%
# Précision Sujet 5 : 81.11%
# ------------------------------
# MOYENNE GLOBALE TEST : 76.39%
# ------------------------------

# %% [markdown]
# # lstm 256 dense 64 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

# --- 2. Prétraitement ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. Séparation Train / Test ---
def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. Modèle ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(64, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

# --- 5. Évaluation Détaillée ---
print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# /tmp/ipykernel_415/2548489233.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2562 - loss: 1.9979 - val_accuracy: 0.0000e+00 - val_loss: 2.9513
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.6049 - loss: 1.1750 - val_accuracy: 0.0000e+00 - val_loss: 3.5221
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.7284 - loss: 0.7856 - val_accuracy: 0.0000e+00 - val_loss: 2.9401
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.7593 - loss: 0.6631 - val_accuracy: 0.0000e+00 - val_loss: 4.3399
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.8395 - loss: 0.4706 - val_accuracy: 0.0000e+00 - val_loss: 3.7769
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9228 - loss: 0.2638 - val_accuracy: 0.0000e+00 - val_loss: 3.6226
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 894ms/step - accuracy: 0.6821 - loss: 1.2203 - val_accuracy: 0.0000e+00 - val_loss: 2.6173
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 899ms/step - accuracy: 0.7994 - loss: 0.5667 - val_accuracy: 0.0000e+00 - val_loss: 3.4702
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9012 - loss: 0.3022 - val_accuracy: 0.0000e+00 - val_loss: 2.9747
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.9105 - loss: 0.2417 - val_accuracy: 0.0000e+00 - val_loss: 3.1094
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7562 - loss: 0.7854 - val_accuracy: 0.0000e+00 - val_loss: 2.7602
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 18s 916ms/step - accuracy: 0.7994 - loss: 0.5878 - val_accuracy: 0.0000e+00 - val_loss: 3.1868
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 819ms/step - accuracy: 0.8488 - loss: 0.4368 - val_accuracy: 0.0000e+00 - val_loss: 2.4072
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 794ms/step - accuracy: 0.9167 - loss: 0.2734 - val_accuracy: 0.0000e+00 - val_loss: 2.3830
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 907ms/step - accuracy: 0.9043 - loss: 0.2365 - val_accuracy: 0.0833 - val_loss: 1.7273
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 899ms/step - accuracy: 0.9630 - loss: 0.1279 - val_accuracy: 0.0000e+00 - val_loss: 3.8076
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 761ms/step - accuracy: 0.9537 - loss: 0.1390 - val_accuracy: 0.0278 - val_loss: 2.0796
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 893ms/step - accuracy: 0.9753 - loss: 0.0953 - val_accuracy: 0.1667 - val_loss: 1.7851
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 951ms/step - accuracy: 0.9753 - loss: 0.0676 - val_accuracy: 0.5000 - val_loss: 1.7435
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 846ms/step - accuracy: 0.9907 - loss: 0.0374 - val_accuracy: 0.6944 - val_loss: 1.4930
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 757ms/step - accuracy: 0.9969 - loss: 0.0185 - val_accuracy: 0.6389 - val_loss: 1.8144
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 887ms/step - accuracy: 0.9969 - loss: 0.0173 - val_accuracy: 0.0000e+00 - val_loss: 5.8135
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 888ms/step - accuracy: 0.6975 - loss: 1.2525 - val_accuracy: 0.0000e+00 - val_loss: 2.1867
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 764ms/step - accuracy: 0.7593 - loss: 0.7023 - val_accuracy: 0.0000e+00 - val_loss: 2.8444
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9290 - loss: 0.2949 - val_accuracy: 0.0000e+00 - val_loss: 3.2334
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 896ms/step - accuracy: 0.9722 - loss: 0.1228 - val_accuracy: 0.0556 - val_loss: 1.9897
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 867ms/step - accuracy: 0.9907 - loss: 0.0590 - val_accuracy: 0.4444 - val_loss: 1.5682
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 748ms/step - accuracy: 0.9969 - loss: 0.0317 - val_accuracy: 0.4722 - val_loss: 1.7805
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 908ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.5556 - val_loss: 1.5769
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 883ms/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 0.5556 - val_loss: 1.5060
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 790ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.6111 - val_loss: 1.5927
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 751ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.6111 - val_loss: 1.5033
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 781ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.6111 - val_loss: 1.4793
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 893ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.6111 - val_loss: 1.5206
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 887ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.6111 - val_loss: 1.5265
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 745ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.6111 - val_loss: 1.5240
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 884ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.6111 - val_loss: 1.5313
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 898ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.6111 - val_loss: 1.5185
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 750ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.6389 - val_loss: 1.5049
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 741ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.6389 - val_loss: 1.5040
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 819ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.6389 - val_loss: 1.5107
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 888ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.6389 - val_loss: 1.5081
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 869ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.6389 - val_loss: 1.5153
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 752ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.6389 - val_loss: 1.5572
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 897ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.6667 - val_loss: 1.5602
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 884ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.6667 - val_loss: 1.5513
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 753ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.6667 - val_loss: 1.5507
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 892ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.6667 - val_loss: 1.5561
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 876ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6667 - val_loss: 1.5583
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 825ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.6667 - val_loss: 1.5492
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets        : [6, 7, 8, 9, 10]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 6 : 76.67%
# Précision Sujet 7 : 84.44%
# Précision Sujet 8 : 80.00%
# Précision Sujet 9 : 87.78%
# Précision Sujet 10 : 85.56%
# ------------------------------
# MOYENNE GLOBALE TEST : 82.89%
# ------------------------------

# %% [markdown]
# # lstm 256 dense 64 32 trin 5 test *4*

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2
TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

# --- 2. Prétraitement ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. Séparation Train / Test ---
def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. Modèle ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(64, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

# --- 5. Évaluation Détaillée ---
print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# /tmp/ipykernel_415/1441021667.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 923ms/step - accuracy: 0.3580 - loss: 1.8688 - val_accuracy: 0.0000e+00 - val_loss: 5.8391
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 902ms/step - accuracy: 0.7333 - loss: 0.7912 - val_accuracy: 0.0000e+00 - val_loss: 4.5649
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 780ms/step - accuracy: 0.8889 - loss: 0.3687 - val_accuracy: 0.0000e+00 - val_loss: 4.6195
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 853ms/step - accuracy: 0.9407 - loss: 0.1665 - val_accuracy: 0.0444 - val_loss: 4.0276
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 930ms/step - accuracy: 0.9531 - loss: 0.1509 - val_accuracy: 0.0000e+00 - val_loss: 4.8623
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 896ms/step - accuracy: 0.9531 - loss: 0.1753 - val_accuracy: 0.4667 - val_loss: 2.1853
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 877ms/step - accuracy: 0.9556 - loss: 0.1256 - val_accuracy: 0.1111 - val_loss: 4.5791
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 790ms/step - accuracy: 0.9556 - loss: 0.1482 - val_accuracy: 0.2000 - val_loss: 2.9671
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 832ms/step - accuracy: 0.9481 - loss: 0.1581 - val_accuracy: 0.4444 - val_loss: 1.4607
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 895ms/step - accuracy: 0.9062 - loss: 0.3083 - val_accuracy: 0.2444 - val_loss: 3.6164
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 891ms/step - accuracy: 0.9333 - loss: 0.2090 - val_accuracy: 0.1111 - val_loss: 4.0941
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 881ms/step - accuracy: 0.9481 - loss: 0.2071 - val_accuracy: 0.1111 - val_loss: 3.4150
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 781ms/step - accuracy: 0.9728 - loss: 0.1169 - val_accuracy: 0.1556 - val_loss: 3.1138
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 923ms/step - accuracy: 0.9901 - loss: 0.0363 - val_accuracy: 0.2444 - val_loss: 3.1818
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 896ms/step - accuracy: 0.9901 - loss: 0.0412 - val_accuracy: 0.3556 - val_loss: 3.4324
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 850ms/step - accuracy: 0.9975 - loss: 0.0164 - val_accuracy: 0.2000 - val_loss: 3.2103
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 773ms/step - accuracy: 0.9951 - loss: 0.0108 - val_accuracy: 0.2444 - val_loss: 3.3129
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 889ms/step - accuracy: 0.9901 - loss: 0.0321 - val_accuracy: 0.2000 - val_loss: 4.1523
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 881ms/step - accuracy: 0.9556 - loss: 0.1803 - val_accuracy: 0.0222 - val_loss: 5.9306
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 815ms/step - accuracy: 0.9580 - loss: 0.1505 - val_accuracy: 0.3111 - val_loss: 1.6311
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 853ms/step - accuracy: 0.9877 - loss: 0.0447 - val_accuracy: 0.4222 - val_loss: 1.4967
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 894ms/step - accuracy: 0.9975 - loss: 0.0139 - val_accuracy: 0.5333 - val_loss: 1.5019
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 884ms/step - accuracy: 0.9975 - loss: 0.0088 - val_accuracy: 0.4000 - val_loss: 1.6527
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 887ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.6222 - val_loss: 1.1195
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 828ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.6444 - val_loss: 1.0174
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 933ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.5778 - val_loss: 1.1864
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 894ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.4667 - val_loss: 1.3598
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 775ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.5111 - val_loss: 1.3325
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 913ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.5111 - val_loss: 1.3375
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 930ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.5111 - val_loss: 1.2997
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 925ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5333 - val_loss: 1.2905
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 950ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.5111 - val_loss: 1.3438
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 957ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5111 - val_loss: 1.3738
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 920ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5333 - val_loss: 1.3298
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 941ms/step - accuracy: 1.0000 - loss: 9.7512e-04 - val_accuracy: 0.5333 - val_loss: 1.3602
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 936ms/step - accuracy: 1.0000 - loss: 9.1676e-04 - val_accuracy: 0.5333 - val_loss: 1.3176
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 906ms/step - accuracy: 1.0000 - loss: 8.6531e-04 - val_accuracy: 0.5333 - val_loss: 1.3160
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 927ms/step - accuracy: 1.0000 - loss: 8.2513e-04 - val_accuracy: 0.5556 - val_loss: 1.3110
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 902ms/step - accuracy: 1.0000 - loss: 7.5396e-04 - val_accuracy: 0.5333 - val_loss: 1.3548
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 937ms/step - accuracy: 1.0000 - loss: 7.1335e-04 - val_accuracy: 0.5333 - val_loss: 1.3509
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 896ms/step - accuracy: 1.0000 - loss: 6.8952e-04 - val_accuracy: 0.5333 - val_loss: 1.3394
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 857ms/step - accuracy: 1.0000 - loss: 6.5957e-04 - val_accuracy: 0.5333 - val_loss: 1.3283
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 890ms/step - accuracy: 1.0000 - loss: 6.1157e-04 - val_accuracy: 0.5778 - val_loss: 1.3193
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 881ms/step - accuracy: 1.0000 - loss: 5.7483e-04 - val_accuracy: 0.5778 - val_loss: 1.2967
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 832ms/step - accuracy: 1.0000 - loss: 5.6358e-04 - val_accuracy: 0.5778 - val_loss: 1.3166
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 780ms/step - accuracy: 1.0000 - loss: 5.3142e-04 - val_accuracy: 0.5778 - val_loss: 1.2886
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 885ms/step - accuracy: 1.0000 - loss: 5.0269e-04 - val_accuracy: 0.5778 - val_loss: 1.3024
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 902ms/step - accuracy: 1.0000 - loss: 4.8806e-04 - val_accuracy: 0.5778 - val_loss: 1.3161
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 902ms/step - accuracy: 1.0000 - loss: 4.6539e-04 - val_accuracy: 0.5778 - val_loss: 1.3141
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 830ms/step - accuracy: 1.0000 - loss: 4.4194e-04 - val_accuracy: 0.5778 - val_loss: 1.3149
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets        : [1, 2, 4, 5]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 1 : 90.00%
# Précision Sujet 2 : 62.22%
# Précision Sujet 4 : 80.00%
# Précision Sujet 5 : 91.11%
# ------------------------------
# MOYENNE GLOBALE TEST : 80.83%
# ------------------------------

# %% [markdown]
# # lstm 256 dense 16 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_smatrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

# --- 2. Prétraitement ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. Séparation Train / Test ---
def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. Modèle ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(16, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

# --- 5. Évaluation Détaillée ---
print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# /tmp/ipykernel_415/4041218132.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.2377 - loss: 2.0361 - val_accuracy: 0.0000e+00 - val_loss: 4.1202
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 17s 737ms/step - accuracy: 0.5062 - loss: 1.4153 - val_accuracy: 0.0000e+00 - val_loss: 5.5806
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 878ms/step - accuracy: 0.5340 - loss: 1.2771 - val_accuracy: 0.0000e+00 - val_loss: 6.1432
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 873ms/step - accuracy: 0.6883 - loss: 1.0012 - val_accuracy: 0.0000e+00 - val_loss: 6.6470
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 734ms/step - accuracy: 0.7438 - loss: 0.8872 - val_accuracy: 0.0000e+00 - val_loss: 8.2991
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 845ms/step - accuracy: 0.7469 - loss: 0.7164 - val_accuracy: 0.0000e+00 - val_loss: 7.2837
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 917ms/step - accuracy: 0.8117 - loss: 0.5830 - val_accuracy: 0.0000e+00 - val_loss: 8.2930
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 805ms/step - accuracy: 0.8827 - loss: 0.4589 - val_accuracy: 0.0000e+00 - val_loss: 7.1210
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 773ms/step - accuracy: 0.9105 - loss: 0.3877 - val_accuracy: 0.0000e+00 - val_loss: 8.1566
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 878ms/step - accuracy: 0.9414 - loss: 0.2694 - val_accuracy: 0.0000e+00 - val_loss: 7.9607
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 956ms/step - accuracy: 0.8426 - loss: 0.4922 - val_accuracy: 0.0000e+00 - val_loss: 5.8806
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9383 - loss: 0.2490 - val_accuracy: 0.0000e+00 - val_loss: 6.6855
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9722 - loss: 0.1444 - val_accuracy: 0.0000e+00 - val_loss: 6.3816
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9753 - loss: 0.0944 - val_accuracy: 0.0000e+00 - val_loss: 7.6348
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.9722 - loss: 0.1157 - val_accuracy: 0.0556 - val_loss: 7.3253
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9599 - loss: 0.1090 - val_accuracy: 0.1389 - val_loss: 5.7723
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9321 - loss: 0.3492 - val_accuracy: 0.3333 - val_loss: 4.0603
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 18s 969ms/step - accuracy: 0.9321 - loss: 0.2746 - val_accuracy: 0.0278 - val_loss: 6.8816
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9506 - loss: 0.1739 - val_accuracy: 0.0278 - val_loss: 7.5466
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9321 - loss: 0.2840 - val_accuracy: 0.0000e+00 - val_loss: 6.1256
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 18s 887ms/step - accuracy: 0.9660 - loss: 0.1257 - val_accuracy: 0.1389 - val_loss: 5.4968
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 890ms/step - accuracy: 0.9660 - loss: 0.1043 - val_accuracy: 0.1111 - val_loss: 6.5945
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 737ms/step - accuracy: 0.9815 - loss: 0.0839 - val_accuracy: 0.2222 - val_loss: 5.7183
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 743ms/step - accuracy: 0.9846 - loss: 0.1236 - val_accuracy: 0.1389 - val_loss: 6.3952
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 898ms/step - accuracy: 0.9599 - loss: 0.1628 - val_accuracy: 0.0278 - val_loss: 6.5917
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 931ms/step - accuracy: 0.9074 - loss: 0.3737 - val_accuracy: 0.0556 - val_loss: 5.3421
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 728ms/step - accuracy: 0.8642 - loss: 0.4013 - val_accuracy: 0.1667 - val_loss: 4.1586
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 935ms/step - accuracy: 0.9630 - loss: 0.1400 - val_accuracy: 0.0000e+00 - val_loss: 6.2310
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 885ms/step - accuracy: 0.9722 - loss: 0.1492 - val_accuracy: 0.1111 - val_loss: 6.2422
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 838ms/step - accuracy: 0.9630 - loss: 0.1528 - val_accuracy: 0.0000e+00 - val_loss: 6.9232
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 746ms/step - accuracy: 0.9012 - loss: 0.3721 - val_accuracy: 0.1111 - val_loss: 4.5560
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 782ms/step - accuracy: 0.9537 - loss: 0.1685 - val_accuracy: 0.1389 - val_loss: 4.6149
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 889ms/step - accuracy: 0.9907 - loss: 0.0534 - val_accuracy: 0.3889 - val_loss: 3.9047
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 902ms/step - accuracy: 1.0000 - loss: 0.0242 - val_accuracy: 0.3333 - val_loss: 4.2290
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 737ms/step - accuracy: 1.0000 - loss: 0.0165 - val_accuracy: 0.3056 - val_loss: 3.9458
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 883ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.4167 - val_loss: 3.6807
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 933ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.4167 - val_loss: 3.6869
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 746ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.4167 - val_loss: 3.7513
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 745ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.4167 - val_loss: 3.8213
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 888ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.4167 - val_loss: 3.8878
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 881ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.3889 - val_loss: 3.9406
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 769ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.4167 - val_loss: 3.9926
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 834ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.4167 - val_loss: 4.0342
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 888ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.3611 - val_loss: 4.0801
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 852ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.3611 - val_loss: 4.1127
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 742ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.3611 - val_loss: 4.1392
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 851ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.3611 - val_loss: 4.1669
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 874ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.3611 - val_loss: 4.2019
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 775ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.3611 - val_loss: 4.2119
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 812ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.3611 - val_loss: 4.2413
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets        : [6, 7, 8, 9, 10]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 6 : 77.78%
# Précision Sujet 7 : 80.00%
# Précision Sujet 8 : 82.22%
# Précision Sujet 9 : 87.78%
# Précision Sujet 10 : 85.56%
# ------------------------------
# MOYENNE GLOBALE TEST : 82.67%
# ------------------------------

# %% [markdown]
# # lstm 256 densde 16 32 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2
TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

# --- 2. Prétraitement ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. Séparation Train / Test ---
def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. Modèle ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(16, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

# --- 5. Évaluation Détaillée ---
print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# /tmp/ipykernel_415/4054484375.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 947ms/step - accuracy: 0.3383 - loss: 1.9043 - val_accuracy: 0.0000e+00 - val_loss: 3.9508
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 899ms/step - accuracy: 0.7457 - loss: 0.8227 - val_accuracy: 0.0000e+00 - val_loss: 5.7983
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 796ms/step - accuracy: 0.9160 - loss: 0.3740 - val_accuracy: 0.0000e+00 - val_loss: 4.9072
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 869ms/step - accuracy: 0.9284 - loss: 0.2808 - val_accuracy: 0.0000e+00 - val_loss: 6.7744
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 897ms/step - accuracy: 0.8963 - loss: 0.3492 - val_accuracy: 0.0000e+00 - val_loss: 3.6507
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 885ms/step - accuracy: 0.9506 - loss: 0.2237 - val_accuracy: 0.0000e+00 - val_loss: 4.3365
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 809ms/step - accuracy: 0.9580 - loss: 0.1740 - val_accuracy: 0.1111 - val_loss: 3.0567
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 909ms/step - accuracy: 0.9753 - loss: 0.1074 - val_accuracy: 0.0000e+00 - val_loss: 5.5495
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 886ms/step - accuracy: 0.9728 - loss: 0.1060 - val_accuracy: 0.3111 - val_loss: 3.0394
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 878ms/step - accuracy: 0.9901 - loss: 0.0462 - val_accuracy: 0.5778 - val_loss: 1.9044
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 781ms/step - accuracy: 0.9827 - loss: 0.0637 - val_accuracy: 0.0222 - val_loss: 4.2638
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 851ms/step - accuracy: 0.9951 - loss: 0.0360 - val_accuracy: 0.1778 - val_loss: 2.7618
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 896ms/step - accuracy: 0.9852 - loss: 0.0547 - val_accuracy: 0.2889 - val_loss: 3.1657
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 894ms/step - accuracy: 0.9901 - loss: 0.0570 - val_accuracy: 0.2444 - val_loss: 3.7334
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 859ms/step - accuracy: 0.9975 - loss: 0.0185 - val_accuracy: 0.2667 - val_loss: 3.3298
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 896ms/step - accuracy: 0.9975 - loss: 0.0168 - val_accuracy: 0.2667 - val_loss: 3.2318
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 904ms/step - accuracy: 0.9901 - loss: 0.0298 - val_accuracy: 0.3111 - val_loss: 2.4702
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 898ms/step - accuracy: 0.9556 - loss: 0.1443 - val_accuracy: 0.0667 - val_loss: 4.6861
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 853ms/step - accuracy: 0.9407 - loss: 0.1982 - val_accuracy: 0.1111 - val_loss: 3.1024
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 909ms/step - accuracy: 0.9012 - loss: 0.3361 - val_accuracy: 0.2889 - val_loss: 1.9375
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 925ms/step - accuracy: 0.9852 - loss: 0.0898 - val_accuracy: 0.2889 - val_loss: 2.0228
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 914ms/step - accuracy: 0.9877 - loss: 0.0516 - val_accuracy: 0.0889 - val_loss: 3.5851
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 900ms/step - accuracy: 0.9753 - loss: 0.0773 - val_accuracy: 0.3111 - val_loss: 2.4859
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 895ms/step - accuracy: 0.9309 - loss: 0.1791 - val_accuracy: 0.0222 - val_loss: 4.4419
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 889ms/step - accuracy: 0.9778 - loss: 0.0791 - val_accuracy: 0.2667 - val_loss: 2.8290
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 791ms/step - accuracy: 0.9778 - loss: 0.1027 - val_accuracy: 0.0889 - val_loss: 5.9192
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 885ms/step - accuracy: 0.9951 - loss: 0.0336 - val_accuracy: 0.2444 - val_loss: 4.2424
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 931ms/step - accuracy: 0.9975 - loss: 0.0128 - val_accuracy: 0.2444 - val_loss: 4.6541
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 936ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.2667 - val_loss: 4.4302
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 885ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.2667 - val_loss: 4.5621
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 818ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.2667 - val_loss: 4.7154
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 917ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.2667 - val_loss: 4.8567
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 921ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.2667 - val_loss: 4.9703
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 904ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.2444 - val_loss: 5.0828
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 931ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.2444 - val_loss: 5.1715
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 850ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.2444 - val_loss: 5.2181
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 924ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.2444 - val_loss: 5.2656
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 890ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.2444 - val_loss: 5.3102
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 913ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.2444 - val_loss: 5.3620
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 890ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.2444 - val_loss: 5.3886
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 822ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.2444 - val_loss: 5.4378
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 890ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.2444 - val_loss: 5.4734
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 907ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.2444 - val_loss: 5.5266
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 894ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.2444 - val_loss: 5.5478
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 782ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.2444 - val_loss: 5.5638
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 815ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.2444 - val_loss: 5.5801
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 882ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.2444 - val_loss: 5.6255
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 913ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.2444 - val_loss: 5.6393
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 820ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.2444 - val_loss: 5.6616
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 881ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.2444 - val_loss: 5.6843
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets        : [1, 2, 4, 5]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 1 : 84.44%
# Précision Sujet 2 : 60.00%
# Précision Sujet 4 : 80.00%
# Précision Sujet 5 : 81.11%
# ------------------------------
# MOYENNE GLOBALE TEST : 76.39%
# ------------------------------

# %% [markdown]
# # lstm 256 32 batch size 64 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

# --- 2. Prétraitement ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. Séparation Train / Test ---
def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. Modèle ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(32, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.1, verbose=1)

# --- 5. Évaluation Détaillée ---
print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# /tmp/ipykernel_415/2298156250.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.2130 - loss: 2.1421 - val_accuracy: 0.0000e+00 - val_loss: 3.9197
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 997ms/step - accuracy: 0.4537 - loss: 1.6331 - val_accuracy: 0.0000e+00 - val_loss: 4.8213
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.5741 - loss: 1.1720 - val_accuracy: 0.0000e+00 - val_loss: 7.0682
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.6296 - loss: 1.0012 - val_accuracy: 0.0000e+00 - val_loss: 6.2847
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.6790 - loss: 0.8268 - val_accuracy: 0.0000e+00 - val_loss: 5.3604
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7377 - loss: 0.7122 - val_accuracy: 0.0000e+00 - val_loss: 5.2279
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.7531 - loss: 0.6186 - val_accuracy: 0.0000e+00 - val_loss: 4.8276
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7901 - loss: 0.5830 - val_accuracy: 0.0000e+00 - val_loss: 5.1892
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.7870 - loss: 0.6243 - val_accuracy: 0.0000e+00 - val_loss: 5.0576
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8549 - loss: 0.4021 - val_accuracy: 0.0000e+00 - val_loss: 4.1966
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8735 - loss: 0.3539 - val_accuracy: 0.0000e+00 - val_loss: 4.9944
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8981 - loss: 0.2932 - val_accuracy: 0.0000e+00 - val_loss: 3.6003
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.8580 - loss: 0.3820 - val_accuracy: 0.0000e+00 - val_loss: 4.2270
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.8951 - loss: 0.2797 - val_accuracy: 0.0000e+00 - val_loss: 4.6363
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.8951 - loss: 0.3488 - val_accuracy: 0.0000e+00 - val_loss: 6.1325
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9136 - loss: 0.2534 - val_accuracy: 0.0000e+00 - val_loss: 4.7625
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 990ms/step - accuracy: 0.8642 - loss: 0.3005 - val_accuracy: 0.0000e+00 - val_loss: 4.0384
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 986ms/step - accuracy: 0.8580 - loss: 0.3868 - val_accuracy: 0.0000e+00 - val_loss: 4.3658
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.9352 - loss: 0.2059 - val_accuracy: 0.0000e+00 - val_loss: 3.9579
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 988ms/step - accuracy: 0.9167 - loss: 0.2105 - val_accuracy: 0.0000e+00 - val_loss: 2.8569
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9383 - loss: 0.1703 - val_accuracy: 0.0000e+00 - val_loss: 2.9003
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.9630 - loss: 0.1198 - val_accuracy: 0.0833 - val_loss: 1.6133
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8117 - loss: 0.6692 - val_accuracy: 0.0000e+00 - val_loss: 2.5649
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.8117 - loss: 0.5900 - val_accuracy: 0.0000e+00 - val_loss: 2.7833
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 996ms/step - accuracy: 0.6944 - loss: 0.7981 - val_accuracy: 0.0000e+00 - val_loss: 2.8986
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 988ms/step - accuracy: 0.7377 - loss: 0.5914 - val_accuracy: 0.0000e+00 - val_loss: 2.3156
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8796 - loss: 0.3430 - val_accuracy: 0.0000e+00 - val_loss: 2.4524
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9105 - loss: 0.2993 - val_accuracy: 0.3611 - val_loss: 2.1929
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8920 - loss: 0.2633 - val_accuracy: 0.0000e+00 - val_loss: 2.7372
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 988ms/step - accuracy: 0.9383 - loss: 0.2004 - val_accuracy: 0.0000e+00 - val_loss: 2.6259
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9383 - loss: 0.1956 - val_accuracy: 0.0000e+00 - val_loss: 3.1942
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 982ms/step - accuracy: 0.9444 - loss: 0.1671 - val_accuracy: 0.0833 - val_loss: 3.7651
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9198 - loss: 0.1565 - val_accuracy: 0.0833 - val_loss: 3.1417
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9691 - loss: 0.1342 - val_accuracy: 0.0833 - val_loss: 3.1497
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 994ms/step - accuracy: 0.9537 - loss: 0.1408 - val_accuracy: 0.0000e+00 - val_loss: 3.5449
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 982ms/step - accuracy: 0.9568 - loss: 0.1332 - val_accuracy: 0.1389 - val_loss: 3.7537
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 993ms/step - accuracy: 0.9722 - loss: 0.1063 - val_accuracy: 0.0833 - val_loss: 4.6466
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.9877 - loss: 0.0793 - val_accuracy: 0.0833 - val_loss: 2.9613
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 966ms/step - accuracy: 0.9630 - loss: 0.0978 - val_accuracy: 0.0278 - val_loss: 4.0400
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.9877 - loss: 0.0753 - val_accuracy: 0.1944 - val_loss: 3.7399
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 990ms/step - accuracy: 0.9877 - loss: 0.0707 - val_accuracy: 0.1111 - val_loss: 4.4122
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9969 - loss: 0.0395 - val_accuracy: 0.0556 - val_loss: 4.3449
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.9938 - loss: 0.0322 - val_accuracy: 0.1111 - val_loss: 3.9650
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.9969 - loss: 0.0273 - val_accuracy: 0.1389 - val_loss: 4.4035
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.0223 - val_accuracy: 0.1389 - val_loss: 4.7668
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 1.0000 - loss: 0.0195 - val_accuracy: 0.1111 - val_loss: 4.7500
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.0165 - val_accuracy: 0.1111 - val_loss: 4.4225
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 0.1389 - val_loss: 4.4042
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.1389 - val_loss: 4.6496
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.1111 - val_loss: 4.9617
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets        : [6, 7, 8, 9, 10]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 6 : 76.67%
# Précision Sujet 7 : 75.56%
# Précision Sujet 8 : 77.78%
# Précision Sujet 9 : 84.44%
# Précision Sujet 10 : 84.44%
# ------------------------------
# MOYENNE GLOBALE TEST : 79.78%
# ------------------------------

# %% [markdown]
# # lstm 256 32 64 tain 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2
TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

# --- 2. Prétraitement ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. Séparation Train / Test ---
def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. Modèle ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(32, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.1, verbose=1)

# --- 5. Évaluation Détaillée ---
print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# /tmp/ipykernel_415/491001597.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.2321 - loss: 2.0839 - val_accuracy: 0.0000e+00 - val_loss: 4.0696
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.6000 - loss: 1.2470 - val_accuracy: 0.0000e+00 - val_loss: 5.8421
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.7630 - loss: 0.6939 - val_accuracy: 0.0000e+00 - val_loss: 5.6979
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.8420 - loss: 0.4931 - val_accuracy: 0.0000e+00 - val_loss: 6.1204
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9136 - loss: 0.2709 - val_accuracy: 0.0000e+00 - val_loss: 4.0144
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9235 - loss: 0.2813 - val_accuracy: 0.0000e+00 - val_loss: 3.9176
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9481 - loss: 0.1688 - val_accuracy: 0.0000e+00 - val_loss: 3.8636
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9580 - loss: 0.1341 - val_accuracy: 0.0889 - val_loss: 3.1906
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.9753 - loss: 0.0943 - val_accuracy: 0.2667 - val_loss: 2.5092
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9556 - loss: 0.1192 - val_accuracy: 0.0000e+00 - val_loss: 6.0961
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9852 - loss: 0.0683 - val_accuracy: 0.1333 - val_loss: 3.6651
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9901 - loss: 0.0459 - val_accuracy: 0.2889 - val_loss: 3.9256
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9975 - loss: 0.0196 - val_accuracy: 0.1333 - val_loss: 4.3972
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.1333 - val_loss: 4.5769
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.1556 - val_loss: 4.4253
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.1556 - val_loss: 4.4606
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.1778 - val_loss: 4.5741
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.2000 - val_loss: 4.6374
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.2000 - val_loss: 4.7121
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.2000 - val_loss: 4.7683
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.2000 - val_loss: 4.8189
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.2000 - val_loss: 4.8606
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.2000 - val_loss: 4.9040
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.2000 - val_loss: 4.9377
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.2000 - val_loss: 4.9658
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.2000 - val_loss: 4.9928
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.2000 - val_loss: 4.9923
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.2000 - val_loss: 4.9847
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.2000 - val_loss: 4.9981
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.2000 - val_loss: 5.0139
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.2000 - val_loss: 5.0716
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.2000 - val_loss: 5.0915
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.2000 - val_loss: 5.1049
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.2000 - val_loss: 5.1182
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.2000 - val_loss: 5.1090
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.2000 - val_loss: 5.1192
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.2000 - val_loss: 5.1242
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 1.0000 - loss: 9.8188e-04 - val_accuracy: 0.2000 - val_loss: 5.1078
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 1.0000 - loss: 9.4000e-04 - val_accuracy: 0.2000 - val_loss: 5.0884
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 8.9713e-04 - val_accuracy: 0.2000 - val_loss: 5.0765
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 8.6418e-04 - val_accuracy: 0.2000 - val_loss: 5.0726
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 1.0000 - loss: 8.2463e-04 - val_accuracy: 0.2000 - val_loss: 5.0768
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 7.8891e-04 - val_accuracy: 0.2000 - val_loss: 5.0735
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 7.6980e-04 - val_accuracy: 0.2000 - val_loss: 5.0579
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 1.0000 - loss: 7.4243e-04 - val_accuracy: 0.2000 - val_loss: 5.0425
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 7.0327e-04 - val_accuracy: 0.2000 - val_loss: 5.0324
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 6.7866e-04 - val_accuracy: 0.2000 - val_loss: 5.0440
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 1.0000 - loss: 6.5524e-04 - val_accuracy: 0.2000 - val_loss: 5.0504
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 6.2657e-04 - val_accuracy: 0.2000 - val_loss: 5.0431
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 1.0000 - loss: 6.0760e-04 - val_accuracy: 0.2000 - val_loss: 5.0544
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets        : [1, 2, 4, 5]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 1 : 82.22%
# Précision Sujet 2 : 55.56%
# Précision Sujet 4 : 83.33%
# Précision Sujet 5 : 80.00%
# ------------------------------
# MOYENNE GLOBALE TEST : 75.28%
# ------------------------------

# %% [markdown]
# # lstm 256 32 batch size 16 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

# --- 2. Prétraitement ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. Séparation Train / Test ---
def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. Modèle ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(32, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1, verbose=1)

# --- 5. Évaluation Détaillée ---
print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# /tmp/ipykernel_415/1878308852.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 17s 640ms/step - accuracy: 0.3302 - loss: 1.7874 - val_accuracy: 0.0000e+00 - val_loss: 5.4703
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 608ms/step - accuracy: 0.6636 - loss: 1.0112 - val_accuracy: 0.0000e+00 - val_loss: 6.7690
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 606ms/step - accuracy: 0.7716 - loss: 0.6738 - val_accuracy: 0.0000e+00 - val_loss: 4.8033
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 602ms/step - accuracy: 0.8673 - loss: 0.4063 - val_accuracy: 0.0000e+00 - val_loss: 4.9810
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 579ms/step - accuracy: 0.8488 - loss: 0.5366 - val_accuracy: 0.0000e+00 - val_loss: 4.3776
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 607ms/step - accuracy: 0.7870 - loss: 0.7290 - val_accuracy: 0.0000e+00 - val_loss: 3.8153
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 615ms/step - accuracy: 0.9290 - loss: 0.2846 - val_accuracy: 0.0000e+00 - val_loss: 3.7231
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 607ms/step - accuracy: 0.9383 - loss: 0.1918 - val_accuracy: 0.0000e+00 - val_loss: 5.4460
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 598ms/step - accuracy: 0.8272 - loss: 0.4979 - val_accuracy: 0.0000e+00 - val_loss: 2.1522
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 594ms/step - accuracy: 0.9228 - loss: 0.2186 - val_accuracy: 0.0000e+00 - val_loss: 2.1423
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 594ms/step - accuracy: 0.9753 - loss: 0.1016 - val_accuracy: 0.0000e+00 - val_loss: 3.2246
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 593ms/step - accuracy: 0.9660 - loss: 0.1111 - val_accuracy: 0.3889 - val_loss: 2.0419
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 589ms/step - accuracy: 0.9969 - loss: 0.0293 - val_accuracy: 0.3889 - val_loss: 2.3436
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 564ms/step - accuracy: 0.9630 - loss: 0.0752 - val_accuracy: 0.3889 - val_loss: 1.8919
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 559ms/step - accuracy: 0.9660 - loss: 0.1110 - val_accuracy: 0.0000e+00 - val_loss: 5.1729
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 607ms/step - accuracy: 0.9660 - loss: 0.1559 - val_accuracy: 0.0000e+00 - val_loss: 4.2416
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 611ms/step - accuracy: 0.9599 - loss: 0.1300 - val_accuracy: 0.0000e+00 - val_loss: 1.8503
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 603ms/step - accuracy: 0.9568 - loss: 0.1371 - val_accuracy: 0.3056 - val_loss: 1.7080
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 601ms/step - accuracy: 0.9599 - loss: 0.0980 - val_accuracy: 0.0000e+00 - val_loss: 2.9245
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 595ms/step - accuracy: 0.9846 - loss: 0.0533 - val_accuracy: 0.0000e+00 - val_loss: 2.3870
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 605ms/step - accuracy: 0.9846 - loss: 0.0300 - val_accuracy: 0.5833 - val_loss: 1.4914
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 604ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.6944 - val_loss: 1.2503
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 574ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.6389 - val_loss: 1.6585
# Epoch 24/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 545ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.6389 - val_loss: 1.7359
# Epoch 25/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 596ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.6389 - val_loss: 1.6895
# Epoch 26/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 590ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.6667 - val_loss: 1.7161
# Epoch 27/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 595ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.6667 - val_loss: 1.7503
# Epoch 28/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 575ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.6667 - val_loss: 1.7581
# Epoch 29/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 549ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.6667 - val_loss: 1.7631
# Epoch 30/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 591ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.6667 - val_loss: 1.7961
# Epoch 31/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 588ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6667 - val_loss: 1.8335
# Epoch 32/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 592ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6667 - val_loss: 1.8161
# Epoch 33/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 572ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6667 - val_loss: 1.8330
# Epoch 34/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 11s 527ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6667 - val_loss: 1.8694
# Epoch 35/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 589ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.6667 - val_loss: 1.8767
# Epoch 36/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 589ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6667 - val_loss: 1.8966
# Epoch 37/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 611ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6667 - val_loss: 1.9190
# Epoch 38/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 605ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.6667 - val_loss: 1.9258
# Epoch 39/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 597ms/step - accuracy: 1.0000 - loss: 9.4749e-04 - val_accuracy: 0.6667 - val_loss: 1.9316
# Epoch 40/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 558ms/step - accuracy: 1.0000 - loss: 8.9267e-04 - val_accuracy: 0.6667 - val_loss: 1.9311
# Epoch 41/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 590ms/step - accuracy: 1.0000 - loss: 8.4480e-04 - val_accuracy: 0.6667 - val_loss: 1.9402
# Epoch 42/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 632ms/step - accuracy: 1.0000 - loss: 8.0064e-04 - val_accuracy: 0.6667 - val_loss: 1.9528
# Epoch 43/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 608ms/step - accuracy: 1.0000 - loss: 7.6820e-04 - val_accuracy: 0.6667 - val_loss: 1.9632
# Epoch 44/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 602ms/step - accuracy: 1.0000 - loss: 7.3582e-04 - val_accuracy: 0.6667 - val_loss: 1.9742
# Epoch 45/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 610ms/step - accuracy: 1.0000 - loss: 6.9871e-04 - val_accuracy: 0.6667 - val_loss: 1.9797
# Epoch 46/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 607ms/step - accuracy: 1.0000 - loss: 6.6900e-04 - val_accuracy: 0.6667 - val_loss: 1.9910
# Epoch 47/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 607ms/step - accuracy: 1.0000 - loss: 6.3963e-04 - val_accuracy: 0.6667 - val_loss: 2.0047
# Epoch 48/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 577ms/step - accuracy: 1.0000 - loss: 6.1062e-04 - val_accuracy: 0.6667 - val_loss: 2.0000
# Epoch 49/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 610ms/step - accuracy: 1.0000 - loss: 5.8411e-04 - val_accuracy: 0.6667 - val_loss: 2.0521
# Epoch 50/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 603ms/step - accuracy: 1.0000 - loss: 5.6341e-04 - val_accuracy: 0.6667 - val_loss: 2.0637
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets        : [6, 7, 8, 9, 10]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 6 : 88.89%
# Précision Sujet 7 : 86.67%
# Précision Sujet 8 : 85.56%
# Précision Sujet 9 : 88.89%
# Précision Sujet 10 : 87.78%
# ------------------------------
# MOYENNE GLOBALE TEST : 87.56%
# ------------------------------

# %% [markdown]
# # lstm 256 32 16 trian 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2
TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

# --- 2. Prétraitement ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. Séparation Train / Test ---
def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. Modèle ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(32, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1, verbose=1)

# --- 5. Évaluation Détaillée ---
print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 ---
# /tmp/ipykernel_415/3265003976.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 19s 615ms/step - accuracy: 0.4469 - loss: 1.6106 - val_accuracy: 0.0000e+00 - val_loss: 3.3719
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 625ms/step - accuracy: 0.8593 - loss: 0.4908 - val_accuracy: 0.0000e+00 - val_loss: 3.6643
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 591ms/step - accuracy: 0.9086 - loss: 0.3245 - val_accuracy: 0.0000e+00 - val_loss: 3.5990
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 593ms/step - accuracy: 0.9185 - loss: 0.2613 - val_accuracy: 0.0000e+00 - val_loss: 3.1403
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 586ms/step - accuracy: 0.9358 - loss: 0.2019 - val_accuracy: 0.0222 - val_loss: 3.4733
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 22s 620ms/step - accuracy: 0.9432 - loss: 0.1737 - val_accuracy: 0.3556 - val_loss: 1.6153
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 593ms/step - accuracy: 0.9185 - loss: 0.2340 - val_accuracy: 0.1111 - val_loss: 1.8461
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 615ms/step - accuracy: 0.9852 - loss: 0.0845 - val_accuracy: 0.2667 - val_loss: 2.0692
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 643ms/step - accuracy: 0.9951 - loss: 0.0270 - val_accuracy: 0.2444 - val_loss: 2.5340
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 19s 587ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.1333 - val_loss: 3.5441
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 587ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.1778 - val_loss: 3.3432
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 587ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.1556 - val_loss: 3.6542
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 603ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.2000 - val_loss: 3.6580
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 600ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.2222 - val_loss: 3.6446
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 600ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.2222 - val_loss: 3.6804
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 593ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.2222 - val_loss: 3.8913
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 613ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.2222 - val_loss: 3.9174
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 603ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.2222 - val_loss: 4.0090
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 593ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.2222 - val_loss: 4.0444
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 594ms/step - accuracy: 1.0000 - loss: 9.6813e-04 - val_accuracy: 0.2222 - val_loss: 4.0880
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 604ms/step - accuracy: 1.0000 - loss: 8.7755e-04 - val_accuracy: 0.2444 - val_loss: 4.1409
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 619ms/step - accuracy: 1.0000 - loss: 7.7609e-04 - val_accuracy: 0.2667 - val_loss: 4.0638
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 611ms/step - accuracy: 1.0000 - loss: 7.1258e-04 - val_accuracy: 0.2222 - val_loss: 4.2853
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 643ms/step - accuracy: 1.0000 - loss: 6.4014e-04 - val_accuracy: 0.2444 - val_loss: 4.2592
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 26s 851ms/step - accuracy: 1.0000 - loss: 5.8965e-04 - val_accuracy: 0.2444 - val_loss: 4.2924
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 1.0000 - loss: 5.3668e-04 - val_accuracy: 0.2667 - val_loss: 4.3027
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 22s 854ms/step - accuracy: 1.0000 - loss: 4.9202e-04 - val_accuracy: 0.2444 - val_loss: 4.4915
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 44s 954ms/step - accuracy: 1.0000 - loss: 4.5664e-04 - val_accuracy: 0.2667 - val_loss: 4.4222
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 35s 673ms/step - accuracy: 1.0000 - loss: 4.3516e-04 - val_accuracy: 0.2667 - val_loss: 4.4725
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 578ms/step - accuracy: 1.0000 - loss: 4.0339e-04 - val_accuracy: 0.2667 - val_loss: 4.4988
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 583ms/step - accuracy: 1.0000 - loss: 3.7127e-04 - val_accuracy: 0.2667 - val_loss: 4.5369
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 596ms/step - accuracy: 1.0000 - loss: 3.5072e-04 - val_accuracy: 0.2667 - val_loss: 4.5116
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 628ms/step - accuracy: 1.0000 - loss: 3.2839e-04 - val_accuracy: 0.2667 - val_loss: 4.5205
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 23s 867ms/step - accuracy: 1.0000 - loss: 3.0830e-04 - val_accuracy: 0.2889 - val_loss: 4.5497
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 35s 624ms/step - accuracy: 1.0000 - loss: 2.9116e-04 - val_accuracy: 0.2889 - val_loss: 4.6202
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 23s 885ms/step - accuracy: 1.0000 - loss: 2.7669e-04 - val_accuracy: 0.2889 - val_loss: 4.6714
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 1.0000 - loss: 2.6154e-04 - val_accuracy: 0.2889 - val_loss: 4.7906
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 30s 834ms/step - accuracy: 1.0000 - loss: 2.4488e-04 - val_accuracy: 0.2889 - val_loss: 4.7291
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 1.0000 - loss: 2.3714e-04 - val_accuracy: 0.2889 - val_loss: 4.7735
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 19s 716ms/step - accuracy: 1.0000 - loss: 2.2152e-04 - val_accuracy: 0.2889 - val_loss: 4.7701
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 592ms/step - accuracy: 1.0000 - loss: 2.1190e-04 - val_accuracy: 0.2889 - val_loss: 4.8579
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 602ms/step - accuracy: 1.0000 - loss: 2.0114e-04 - val_accuracy: 0.2889 - val_loss: 4.8382
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 1.0000 - loss: 1.8874e-04 - val_accuracy: 0.2889 - val_loss: 4.8275
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 31s 606ms/step - accuracy: 1.0000 - loss: 1.8436e-04 - val_accuracy: 0.2889 - val_loss: 4.9767
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 617ms/step - accuracy: 1.0000 - loss: 1.7585e-04 - val_accuracy: 0.2889 - val_loss: 4.9636
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 590ms/step - accuracy: 1.0000 - loss: 1.6899e-04 - val_accuracy: 0.2889 - val_loss: 4.9760
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 587ms/step - accuracy: 1.0000 - loss: 1.6039e-04 - val_accuracy: 0.2889 - val_loss: 4.9579
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 25s 779ms/step - accuracy: 1.0000 - loss: 1.5332e-04 - val_accuracy: 0.2889 - val_loss: 4.9849
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 594ms/step - accuracy: 1.0000 - loss: 1.4650e-04 - val_accuracy: 0.2889 - val_loss: 4.9617
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 598ms/step - accuracy: 1.0000 - loss: 1.4330e-04 - val_accuracy: 0.2889 - val_loss: 4.9596
#
# ========================================
# CONFIGURATION DU TEST
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets        : [1, 2, 4, 5]
# ========================================
#
# --- RÉSULTATS DÉTAILLÉS ---
# Précision Sujet 1 : 83.33%
# Précision Sujet 2 : 56.67%
# Précision Sujet 4 : 84.44%
# Précision Sujet 5 : 83.33%
# ------------------------------
# MOYENNE GLOBALE TEST : 76.94%
# ------------------------------

# %%
import pandas as pd
import numpy as np
import os
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSVcorrige"):
    # !unzip -q /content/DOMAIN2_CSVcorrige.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSVcorrige"
DOMAIN_ID = 2
TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]

df_list = []
print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(f"Aucun fichier chargé.")

df = pd.concat(df_list, ignore_index=True)

# --- 2. Prétraitement ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len, 'x_std': interp('x_std'),
            'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. Séparation Train / Test ---
def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. Modèle ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, input_shape=input_shape),
        layers.Dropout(0.2),
        layers.LSTM(256),
        layers.Dense(32, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = create_lstm_model((X_train.shape[1], X_train.shape[2]), 10)
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1, verbose=1)

# --- 5. Évaluation Détaillée ---
print(f"\n" + "="*40)
print(f"CONFIGURATION DU TEST")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets        : {TEST_SUBJECTS}")
print("="*40)

print(f"\n--- RÉSULTATS DÉTAILLÉS ---")
y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

subject_scores = {}
for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Précision Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TEST : {mean_acc:.2%}")
print("-" * 30)
# Out:
# replace /content/temp_data/__MACOSX/._DOMAIN2_CSVcorrigé? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/temp_data/DOMAIN2_CSVcorrigé/Subject1-9-2.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/temp_data/__MACOSX/DOMAIN2_CSVcorrigé/._Subject1-9-2.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/temp_data/DOMAIN2_CSVcorrigé/Subject4-1-10.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/temp_data/__MACOSX/DOMAIN2_CSVcorrigé/._Subject4-1-10.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/temp_data/DOMAIN2_CSVcorrigé/Subject10-8-8.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/temp_data/__MACOSX/DOMAIN2_CSVcorrigé/._Subject10-8-8.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/temp_data/DOMAIN2_CSVcorrigé/Subject5-1-10.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/temp_data/__MACOSX/DOMAIN2_CSVcorrigé/._Subject5-1-10.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/temp_data/DOMAIN2_CSVcorrigé/Subject6-2-1.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# replace /content/temp_data/__MACOSX/DOMAIN2_CSVcorrigé/._Subject6-2-1.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# Décompression terminée !
# --- 1. Début du Chargement du Domaine 2 ---
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3199/1586070242.py in <cell line: 0>()
#      42
#      43 if not df_list:
# ---> 44     raise ValueError(f"Aucun fichier chargé.")
#      45
#      46 df = pd.concat(df_list, ignore_index=True)
#
# ValueError: Aucun fichier chargé.

# %% [markdown]
# # transformer

# %% [markdown]
# # tranhsfo 64 64 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Sujets demandés
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]
# Le sujet 3 est exclu car absent des listes ci-dessus.

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)
print(f"Nombre total d'observations chargées : {len(df)}")

# --- 2. PRÉTRAITEMENT ---

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. SÉPARATION TRAIN / TEST ---

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. ARCHITECTURE TRANSFORMER ---

class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 64, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# --- 5. ENTRAÎNEMENT ET ÉVALUATION ---

model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 (Transformer) ---
# Nombre total d'observations chargées : 72077
# /tmp/ipykernel_415/1521607308.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.1019 - loss: 2.3549 - val_accuracy: 0.0000e+00 - val_loss: 3.2132
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1142 - loss: 2.2392 - val_accuracy: 0.0000e+00 - val_loss: 3.4486
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1327 - loss: 2.2310 - val_accuracy: 0.0000e+00 - val_loss: 4.0374
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1451 - loss: 2.1972 - val_accuracy: 0.0000e+00 - val_loss: 3.3411
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1574 - loss: 2.1582 - val_accuracy: 0.0000e+00 - val_loss: 3.6126
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.4321 - loss: 1.7147 - val_accuracy: 0.0000e+00 - val_loss: 4.7113
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7407 - loss: 0.8483 - val_accuracy: 0.0000e+00 - val_loss: 4.8955
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8333 - loss: 0.5770 - val_accuracy: 0.0000e+00 - val_loss: 4.0936
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8642 - loss: 0.4425 - val_accuracy: 0.0000e+00 - val_loss: 4.5695
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8981 - loss: 0.3373 - val_accuracy: 0.0000e+00 - val_loss: 4.3707
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8920 - loss: 0.4028 - val_accuracy: 0.0000e+00 - val_loss: 4.5710
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9414 - loss: 0.1987 - val_accuracy: 0.0278 - val_loss: 2.1898
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.8951 - loss: 0.3562 - val_accuracy: 0.0000e+00 - val_loss: 2.6819
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9414 - loss: 0.1889 - val_accuracy: 0.0000e+00 - val_loss: 3.5455
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9691 - loss: 0.1254 - val_accuracy: 0.0000e+00 - val_loss: 2.7046
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9722 - loss: 0.0817 - val_accuracy: 0.0000e+00 - val_loss: 2.8245
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9815 - loss: 0.0684 - val_accuracy: 0.6111 - val_loss: 1.0628
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0420 - val_accuracy: 0.0556 - val_loss: 2.9431
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9846 - loss: 0.0397 - val_accuracy: 0.4722 - val_loss: 1.6533
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0231 - val_accuracy: 0.3611 - val_loss: 2.3372
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.4722 - val_loss: 1.8424
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0249 - val_accuracy: 0.2778 - val_loss: 2.6186
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9938 - loss: 0.0216 - val_accuracy: 0.5278 - val_loss: 1.7075
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9969 - loss: 0.0182 - val_accuracy: 0.4444 - val_loss: 2.0753
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9938 - loss: 0.0215 - val_accuracy: 0.5556 - val_loss: 1.1850
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9969 - loss: 0.0218 - val_accuracy: 0.4444 - val_loss: 2.4346
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9907 - loss: 0.0214 - val_accuracy: 0.3889 - val_loss: 2.4744
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9753 - loss: 0.0563 - val_accuracy: 0.6944 - val_loss: 1.0987
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9815 - loss: 0.1072 - val_accuracy: 0.6944 - val_loss: 0.7294
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9722 - loss: 0.0960 - val_accuracy: 0.4167 - val_loss: 1.9411
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9846 - loss: 0.0918 - val_accuracy: 0.6667 - val_loss: 1.1357
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9877 - loss: 0.0365 - val_accuracy: 0.6389 - val_loss: 1.0233
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9969 - loss: 0.0124 - val_accuracy: 0.5833 - val_loss: 1.5752
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9938 - loss: 0.0164 - val_accuracy: 0.5278 - val_loss: 1.6777
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9784 - loss: 0.0691 - val_accuracy: 0.6944 - val_loss: 0.9178
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9660 - loss: 0.1044 - val_accuracy: 0.4722 - val_loss: 2.4268
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9722 - loss: 0.0699 - val_accuracy: 0.1111 - val_loss: 5.1172
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9846 - loss: 0.0439 - val_accuracy: 0.5278 - val_loss: 1.3324
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0263 - val_accuracy: 0.4722 - val_loss: 2.2608
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.4444 - val_loss: 2.9059
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0179 - val_accuracy: 0.5833 - val_loss: 1.7246
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9907 - loss: 0.0365 - val_accuracy: 0.6389 - val_loss: 1.5428
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9846 - loss: 0.0696 - val_accuracy: 0.7500 - val_loss: 0.9584
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.3611 - val_loss: 2.8968
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9907 - loss: 0.0326 - val_accuracy: 0.7500 - val_loss: 0.8550
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9969 - loss: 0.0142 - val_accuracy: 0.6389 - val_loss: 1.3457
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9938 - loss: 0.0193 - val_accuracy: 0.6389 - val_loss: 2.1003
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9938 - loss: 0.0157 - val_accuracy: 0.7500 - val_loss: 1.1768
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8056 - val_loss: 0.9403
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8056 - val_loss: 0.8615
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets         : [6, 7, 8, 9, 10]
# ========================================
# Sujet 6 : 88.89%
# Sujet 7 : 86.67%
# Sujet 8 : 88.89%
# Sujet 9 : 94.44%
# Sujet 10 : 92.22%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 90.22%
# ------------------------------

# %% [markdown]
# # tranfo 64 64 32 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Sujets demandés
TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]
# Le sujet 3 est exclu car absent des listes ci-dessus.

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)
print(f"Nombre total d'observations chargées : {len(df)}")

# --- 2. PRÉTRAITEMENT ---

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. SÉPARATION TRAIN / TEST ---

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. ARCHITECTURE TRANSFORMER ---

class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 64, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# --- 5. ENTRAÎNEMENT ET ÉVALUATION ---

model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 (Transformer) ---
# Nombre total d'observations chargées : 72077
# /tmp/ipykernel_415/3414571980.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.1210 - loss: 2.3818 - val_accuracy: 0.0000e+00 - val_loss: 3.7280
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.1457 - loss: 2.1949 - val_accuracy: 0.0000e+00 - val_loss: 3.6017
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.2593 - loss: 1.8862 - val_accuracy: 0.0000e+00 - val_loss: 4.2615
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.7432 - loss: 0.8278 - val_accuracy: 0.0000e+00 - val_loss: 5.3163
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.9185 - loss: 0.3074 - val_accuracy: 0.0000e+00 - val_loss: 3.8666
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9630 - loss: 0.1584 - val_accuracy: 0.4889 - val_loss: 2.0742
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.9852 - loss: 0.0793 - val_accuracy: 0.5778 - val_loss: 1.9157
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9877 - loss: 0.0580 - val_accuracy: 0.6444 - val_loss: 1.3787
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.9951 - loss: 0.0292 - val_accuracy: 0.6667 - val_loss: 1.5131
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 0.6444 - val_loss: 1.5971
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.9975 - loss: 0.0137 - val_accuracy: 0.6000 - val_loss: 2.0563
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.6000 - val_loss: 1.9545
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.6222 - val_loss: 2.0235
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.6222 - val_loss: 2.1027
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.6000 - val_loss: 2.1813
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.6667 - val_loss: 1.8865
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.6444 - val_loss: 1.9728
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.7111 - val_loss: 1.6902
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.7111 - val_loss: 1.6877
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.6444 - val_loss: 1.8353
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.6444 - val_loss: 1.8957
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.6222 - val_loss: 1.9856
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.6222 - val_loss: 2.0696
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.6000 - val_loss: 2.2411
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.6444 - val_loss: 2.0563
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6444 - val_loss: 1.9865
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.6444 - val_loss: 1.9107
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6444 - val_loss: 2.0102
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6222 - val_loss: 2.1394
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6222 - val_loss: 2.2007
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6222 - val_loss: 2.2751
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6667 - val_loss: 2.2152
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 8.7196e-04 - val_accuracy: 0.6889 - val_loss: 2.1436
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.6667 - val_loss: 2.2709
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 9.5503e-04 - val_accuracy: 0.6444 - val_loss: 2.3232
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6444 - val_loss: 2.3223
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 9.3047e-04 - val_accuracy: 0.6444 - val_loss: 2.2397
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6667 - val_loss: 2.0985
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.6889 - val_loss: 2.1336
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.6444 - val_loss: 2.3747
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6444 - val_loss: 2.4663
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 8.3340e-04 - val_accuracy: 0.6667 - val_loss: 2.4645
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 9.5594e-04 - val_accuracy: 0.7111 - val_loss: 2.0763
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.7556 - val_loss: 1.8410
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.7111 - val_loss: 1.8272
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 5.5799e-04 - val_accuracy: 0.6667 - val_loss: 1.9418
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 5.1906e-04 - val_accuracy: 0.7111 - val_loss: 1.9493
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 6.5564e-04 - val_accuracy: 0.7111 - val_loss: 1.9853
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 7.2354e-04 - val_accuracy: 0.6667 - val_loss: 2.2187
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 6.4919e-04 - val_accuracy: 0.6667 - val_loss: 2.2469
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets         : [1, 2, 4, 5]
# ========================================
# Sujet 1 : 91.11%
# Sujet 2 : 60.00%
# Sujet 4 : 92.22%
# Sujet 5 : 87.78%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 82.78%
# ------------------------------

# %% [markdown]
# # transo 128 64 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Sujets demandés
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]
# Le sujet 3 est exclu car absent des listes ci-dessus.

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)
print(f"Nombre total d'observations chargées : {len(df)}")

# --- 2. PRÉTRAITEMENT ---

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. SÉPARATION TRAIN / TEST ---

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. ARCHITECTURE TRANSFORMER ---

class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 128, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# --- 5. ENTRAÎNEMENT ET ÉVALUATION ---

model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 (Transformer) ---
# Nombre total d'observations chargées : 72077
# /tmp/ipykernel_415/3837281654.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1111 - loss: 2.4145 - val_accuracy: 0.0000e+00 - val_loss: 4.1606
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1080 - loss: 2.2348 - val_accuracy: 0.0000e+00 - val_loss: 3.8783
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.1111 - loss: 2.2049 - val_accuracy: 0.0000e+00 - val_loss: 4.2049
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.1080 - loss: 2.2343 - val_accuracy: 0.0000e+00 - val_loss: 3.6918
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1358 - loss: 2.1759 - val_accuracy: 0.0000e+00 - val_loss: 3.9725
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1944 - loss: 2.0325 - val_accuracy: 0.0000e+00 - val_loss: 4.7664
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5340 - loss: 1.3620 - val_accuracy: 0.0000e+00 - val_loss: 4.8821
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.6944 - loss: 0.7914 - val_accuracy: 0.0000e+00 - val_loss: 4.5357
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8210 - loss: 0.4969 - val_accuracy: 0.0000e+00 - val_loss: 3.8986
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8981 - loss: 0.3630 - val_accuracy: 0.0000e+00 - val_loss: 2.4942
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9352 - loss: 0.2518 - val_accuracy: 0.0000e+00 - val_loss: 2.6481
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9475 - loss: 0.1928 - val_accuracy: 0.0000e+00 - val_loss: 4.8100
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9537 - loss: 0.1503 - val_accuracy: 0.0556 - val_loss: 4.6300
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9784 - loss: 0.0854 - val_accuracy: 0.3611 - val_loss: 3.7248
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9846 - loss: 0.1050 - val_accuracy: 0.6667 - val_loss: 1.4300
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9877 - loss: 0.0448 - val_accuracy: 0.4444 - val_loss: 2.4980
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9753 - loss: 0.0749 - val_accuracy: 0.9167 - val_loss: 0.8027
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9815 - loss: 0.0711 - val_accuracy: 0.7222 - val_loss: 1.9339
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9784 - loss: 0.0518 - val_accuracy: 0.6944 - val_loss: 2.0283
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9722 - loss: 0.1162 - val_accuracy: 0.6389 - val_loss: 2.9639
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9691 - loss: 0.0767 - val_accuracy: 0.5278 - val_loss: 2.8834
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9877 - loss: 0.0760 - val_accuracy: 0.5278 - val_loss: 2.7346
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0307 - val_accuracy: 0.6667 - val_loss: 2.0279
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9907 - loss: 0.0301 - val_accuracy: 0.7222 - val_loss: 1.6888
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0493 - val_accuracy: 0.8889 - val_loss: 0.7427
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9969 - loss: 0.0330 - val_accuracy: 0.6944 - val_loss: 1.9340
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9969 - loss: 0.0164 - val_accuracy: 0.4722 - val_loss: 2.8735
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9969 - loss: 0.0188 - val_accuracy: 0.7500 - val_loss: 1.6586
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.7500 - val_loss: 1.5259
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.7500 - val_loss: 1.4537
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8056 - val_loss: 1.4782
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.8056 - val_loss: 1.4978
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.8056 - val_loss: 1.5384
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8056 - val_loss: 1.5634
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8056 - val_loss: 1.5595
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8056 - val_loss: 1.5458
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8056 - val_loss: 1.5246
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8056 - val_loss: 1.5384
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8056 - val_loss: 1.5633
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8056 - val_loss: 1.5813
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8056 - val_loss: 1.5950
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8056 - val_loss: 1.5880
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8056 - val_loss: 1.5917
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8056 - val_loss: 1.5932
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8056 - val_loss: 1.6292
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 8.2665e-04 - val_accuracy: 0.8333 - val_loss: 1.6448
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8333 - val_loss: 1.6652
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8333 - val_loss: 1.6783
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8333 - val_loss: 1.6959
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8333 - val_loss: 1.7108
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets         : [6, 7, 8, 9, 10]
# ========================================
# Sujet 6 : 94.44%
# Sujet 7 : 83.33%
# Sujet 8 : 92.22%
# Sujet 9 : 87.78%
# Sujet 10 : 85.56%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 88.67%
# ------------------------------

# %% [markdown]
# # tranqgfo 128 64 32 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Sujets demandés
TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]
# Le sujet 3 est exclu car absent des listes ci-dessus.

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)
print(f"Nombre total d'observations chargées : {len(df)}")

# --- 2. PRÉTRAITEMENT ---

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. SÉPARATION TRAIN / TEST ---

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. ARCHITECTURE TRANSFORMER ---

class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 128, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# --- 5. ENTRAÎNEMENT ET ÉVALUATION ---

model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 (Transformer) ---
# Nombre total d'observations chargées : 72077
# /tmp/ipykernel_415/1208839577.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.1457 - loss: 2.3192 - val_accuracy: 0.0000e+00 - val_loss: 2.9732
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.1383 - loss: 2.2477 - val_accuracy: 0.0000e+00 - val_loss: 3.4291
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1358 - loss: 2.2193 - val_accuracy: 0.0000e+00 - val_loss: 3.3000
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3481 - loss: 1.7253 - val_accuracy: 0.0000e+00 - val_loss: 5.2192
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.7827 - loss: 0.7532 - val_accuracy: 0.0889 - val_loss: 3.6690
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9778 - loss: 0.1703 - val_accuracy: 0.2222 - val_loss: 3.7786
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9877 - loss: 0.0639 - val_accuracy: 0.0889 - val_loss: 4.6546
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9877 - loss: 0.0531 - val_accuracy: 0.2444 - val_loss: 3.1682
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 0.4000 - val_loss: 3.4406
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9975 - loss: 0.0184 - val_accuracy: 0.3556 - val_loss: 3.6594
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9877 - loss: 0.0392 - val_accuracy: 0.3333 - val_loss: 3.3625
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9951 - loss: 0.0172 - val_accuracy: 0.3333 - val_loss: 3.1326
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.3333 - val_loss: 3.7519
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.3778 - val_loss: 3.7642
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.5778 - val_loss: 2.6922
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.2444 - val_loss: 5.6936
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.3556 - val_loss: 4.2819
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.3556 - val_loss: 3.8674
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.3778 - val_loss: 3.8490
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.3778 - val_loss: 3.7862
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.4444 - val_loss: 3.6522
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.4222 - val_loss: 3.7725
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.3778 - val_loss: 3.9249
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.3556 - val_loss: 4.3462
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.3556 - val_loss: 4.2322
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.3778 - val_loss: 4.0709
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.4222 - val_loss: 3.7233
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 8.7319e-04 - val_accuracy: 0.4222 - val_loss: 3.6247
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.4222 - val_loss: 3.7735
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.4222 - val_loss: 3.9177
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 7.0018e-04 - val_accuracy: 0.4000 - val_loss: 4.1382
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 7.5148e-04 - val_accuracy: 0.4000 - val_loss: 4.1896
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.4222 - val_loss: 3.9770
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 6.5426e-04 - val_accuracy: 0.4222 - val_loss: 3.8204
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 7.9208e-04 - val_accuracy: 0.4444 - val_loss: 3.8088
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 6.3736e-04 - val_accuracy: 0.4222 - val_loss: 3.9407
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 7.1059e-04 - val_accuracy: 0.4444 - val_loss: 3.8331
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 5.3906e-04 - val_accuracy: 0.4444 - val_loss: 3.8800
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 5.0085e-04 - val_accuracy: 0.4444 - val_loss: 3.9491
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 4.1537e-04 - val_accuracy: 0.4444 - val_loss: 4.0160
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 7.4228e-04 - val_accuracy: 0.4444 - val_loss: 3.9265
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 4.1368e-04 - val_accuracy: 0.4444 - val_loss: 3.8645
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 3.7572e-04 - val_accuracy: 0.4444 - val_loss: 3.8913
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 5.2827e-04 - val_accuracy: 0.4444 - val_loss: 3.9910
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 5.8714e-04 - val_accuracy: 0.4444 - val_loss: 4.0741
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 5.0735e-04 - val_accuracy: 0.4444 - val_loss: 4.0236
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 3.7815e-04 - val_accuracy: 0.4222 - val_loss: 4.1862
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 4.2054e-04 - val_accuracy: 0.4222 - val_loss: 4.1870
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 4.4751e-04 - val_accuracy: 0.4222 - val_loss: 4.2495
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 5.2252e-04 - val_accuracy: 0.4222 - val_loss: 4.3834
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets         : [1, 2, 4, 5]
# ========================================
# Sujet 1 : 88.89%
# Sujet 2 : 60.00%
# Sujet 4 : 92.22%
# Sujet 5 : 84.44%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 81.39%
# ------------------------------

# %% [markdown]
# # traqnfo 256 64 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Sujets demandés
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]
# Le sujet 3 est exclu car absent des listes ci-dessus.

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)
print(f"Nombre total d'observations chargées : {len(df)}")

# --- 2. PRÉTRAITEMENT ---

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. SÉPARATION TRAIN / TEST ---

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. ARCHITECTURE TRANSFORMER ---

class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# --- 5. ENTRAÎNEMENT ET ÉVALUATION ---

model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 (Transformer) ---
# Nombre total d'observations chargées : 72077
# /tmp/ipykernel_415/3482554458.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - accuracy: 0.1019 - loss: 2.3340 - val_accuracy: 0.0000e+00 - val_loss: 3.2358
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.1204 - loss: 2.2315 - val_accuracy: 0.0000e+00 - val_loss: 3.4481
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.1173 - loss: 2.2130 - val_accuracy: 0.0000e+00 - val_loss: 3.0754
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.1265 - loss: 2.1995 - val_accuracy: 0.0000e+00 - val_loss: 3.7027
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.1111 - loss: 2.2019 - val_accuracy: 0.0000e+00 - val_loss: 3.5433
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.1975 - loss: 2.1144 - val_accuracy: 0.0000e+00 - val_loss: 4.5727
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 25s 2s/step - accuracy: 0.2654 - loss: 1.8422 - val_accuracy: 0.0000e+00 - val_loss: 4.8040
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.3642 - loss: 1.6578 - val_accuracy: 0.0000e+00 - val_loss: 5.4981
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.4877 - loss: 1.4021 - val_accuracy: 0.0000e+00 - val_loss: 6.4458
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.6451 - loss: 1.0748 - val_accuracy: 0.0000e+00 - val_loss: 5.8770
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7037 - loss: 0.9564 - val_accuracy: 0.0000e+00 - val_loss: 4.5082
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.7346 - loss: 0.7901 - val_accuracy: 0.0000e+00 - val_loss: 5.7848
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8302 - loss: 0.5133 - val_accuracy: 0.0000e+00 - val_loss: 4.6875
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8611 - loss: 0.3600 - val_accuracy: 0.0000e+00 - val_loss: 4.0566
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8981 - loss: 0.2998 - val_accuracy: 0.1667 - val_loss: 3.0418
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9259 - loss: 0.2341 - val_accuracy: 0.0000e+00 - val_loss: 3.7269
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9475 - loss: 0.1779 - val_accuracy: 0.0000e+00 - val_loss: 4.0531
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9691 - loss: 0.1332 - val_accuracy: 0.0278 - val_loss: 4.1599
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9475 - loss: 0.1692 - val_accuracy: 0.1944 - val_loss: 3.1274
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9691 - loss: 0.1276 - val_accuracy: 0.3611 - val_loss: 4.0445
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9877 - loss: 0.0757 - val_accuracy: 0.3611 - val_loss: 4.1817
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0362 - val_accuracy: 0.3056 - val_loss: 3.6499
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9938 - loss: 0.0324 - val_accuracy: 0.4167 - val_loss: 3.2824
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9938 - loss: 0.0273 - val_accuracy: 0.3333 - val_loss: 3.7488
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9938 - loss: 0.0186 - val_accuracy: 0.3056 - val_loss: 4.0634
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9938 - loss: 0.0204 - val_accuracy: 0.6111 - val_loss: 1.0566
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9938 - loss: 0.0248 - val_accuracy: 0.5278 - val_loss: 1.6478
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0297 - val_accuracy: 0.2222 - val_loss: 6.8505
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9846 - loss: 0.0580 - val_accuracy: 0.1667 - val_loss: 5.3045
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9877 - loss: 0.0498 - val_accuracy: 0.5556 - val_loss: 3.9785
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9877 - loss: 0.0704 - val_accuracy: 0.4444 - val_loss: 3.1681
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0354 - val_accuracy: 0.4167 - val_loss: 3.5512
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9907 - loss: 0.0249 - val_accuracy: 0.6667 - val_loss: 1.7518
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9877 - loss: 0.0549 - val_accuracy: 0.8056 - val_loss: 0.9815
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9815 - loss: 0.0631 - val_accuracy: 0.4444 - val_loss: 4.5052
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.9969 - loss: 0.0165 - val_accuracy: 0.3611 - val_loss: 4.0061
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9969 - loss: 0.0241 - val_accuracy: 0.4722 - val_loss: 2.9128
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.5833 - val_loss: 1.6990
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.5833 - val_loss: 2.1840
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.5278 - val_loss: 2.5616
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.5278 - val_loss: 2.8076
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.5556 - val_loss: 2.8753
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.5556 - val_loss: 2.8683
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.5556 - val_loss: 2.8281
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.5278 - val_loss: 2.9590
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.5556 - val_loss: 2.7177
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.5556 - val_loss: 2.6771
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.5556 - val_loss: 2.7091
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.5556 - val_loss: 2.5951
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.5556 - val_loss: 2.6573
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets         : [6, 7, 8, 9, 10]
# ========================================
# Sujet 6 : 82.22%
# Sujet 7 : 83.33%
# Sujet 8 : 86.67%
# Sujet 9 : 86.67%
# Sujet 10 : 84.44%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 84.67%
# ------------------------------

# %% [markdown]
# # trasnfo 256 64 32 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Sujets demandés
TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]
# Le sujet 3 est exclu car absent des listes ci-dessus.

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)
print(f"Nombre total d'observations chargées : {len(df)}")

# --- 2. PRÉTRAITEMENT ---

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. SÉPARATION TRAIN / TEST ---

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. ARCHITECTURE TRANSFORMER ---

class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 256, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# --- 5. ENTRAÎNEMENT ET ÉVALUATION ---

model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 (Transformer) ---
# Nombre total d'observations chargées : 72077
# /tmp/ipykernel_415/2064435102.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.1407 - loss: 2.4308 - val_accuracy: 0.0000e+00 - val_loss: 4.0907
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.1556 - loss: 2.2081 - val_accuracy: 0.0000e+00 - val_loss: 4.1893
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.1506 - loss: 2.1372 - val_accuracy: 0.0000e+00 - val_loss: 3.4722
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5432 - loss: 1.4243 - val_accuracy: 0.0000e+00 - val_loss: 3.6337
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9407 - loss: 0.3304 - val_accuracy: 0.0000e+00 - val_loss: 4.9876
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9679 - loss: 0.1284 - val_accuracy: 0.4444 - val_loss: 2.5984
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9852 - loss: 0.0789 - val_accuracy: 0.6000 - val_loss: 1.6182
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9852 - loss: 0.0723 - val_accuracy: 0.0000e+00 - val_loss: 5.2980
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9877 - loss: 0.0627 - val_accuracy: 0.6667 - val_loss: 1.2126
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9951 - loss: 0.0337 - val_accuracy: 0.3333 - val_loss: 4.9170
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9975 - loss: 0.0199 - val_accuracy: 0.3556 - val_loss: 4.4673
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.3778 - val_loss: 3.3877
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9951 - loss: 0.0213 - val_accuracy: 0.6000 - val_loss: 1.4858
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.4000 - val_loss: 3.7256
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.9951 - loss: 0.0096 - val_accuracy: 0.3333 - val_loss: 3.5792
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.4000 - val_loss: 3.0073
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.4444 - val_loss: 2.9571
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.4444 - val_loss: 3.2366
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.4444 - val_loss: 3.5647
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.4222 - val_loss: 3.6495
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.4222 - val_loss: 3.6001
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.4222 - val_loss: 3.6175
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.4222 - val_loss: 3.6800
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.3778 - val_loss: 3.7116
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.4000 - val_loss: 3.6606
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.4222 - val_loss: 3.5913
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.4222 - val_loss: 3.5774
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 9.9453e-04 - val_accuracy: 0.4000 - val_loss: 3.6262
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 7.3048e-04 - val_accuracy: 0.4000 - val_loss: 3.6345
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 9.7536e-04 - val_accuracy: 0.4222 - val_loss: 3.6296
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 5.6090e-04 - val_accuracy: 0.4444 - val_loss: 3.5754
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 9.2828e-04 - val_accuracy: 0.4444 - val_loss: 3.6016
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 7.7331e-04 - val_accuracy: 0.4222 - val_loss: 3.6483
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 6.8199e-04 - val_accuracy: 0.4000 - val_loss: 3.6893
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 6.7859e-04 - val_accuracy: 0.4000 - val_loss: 3.7572
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 1.0000 - loss: 6.0173e-04 - val_accuracy: 0.4000 - val_loss: 3.7811
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 5.3683e-04 - val_accuracy: 0.4000 - val_loss: 3.7587
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 7.1820e-04 - val_accuracy: 0.4000 - val_loss: 3.7907
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 4.8110e-04 - val_accuracy: 0.4000 - val_loss: 3.7214
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 5.2836e-04 - val_accuracy: 0.4000 - val_loss: 3.6971
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.4000 - val_loss: 3.8699
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 5.8395e-04 - val_accuracy: 0.4000 - val_loss: 3.8225
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 4.8461e-04 - val_accuracy: 0.4000 - val_loss: 3.7788
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 3.6970e-04 - val_accuracy: 0.4000 - val_loss: 3.7481
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 6.3213e-04 - val_accuracy: 0.4000 - val_loss: 3.7735
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 1.0000 - loss: 3.1908e-04 - val_accuracy: 0.4000 - val_loss: 3.7896
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 3.2665e-04 - val_accuracy: 0.4000 - val_loss: 3.8321
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 4.3842e-04 - val_accuracy: 0.4000 - val_loss: 3.9247
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 3.7726e-04 - val_accuracy: 0.4000 - val_loss: 3.9791
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 4.7076e-04 - val_accuracy: 0.4000 - val_loss: 4.0426
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets         : [1, 2, 4, 5]
# ========================================
# Sujet 1 : 86.67%
# Sujet 2 : 57.78%
# Sujet 4 : 84.44%
# Sujet 5 : 78.89%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 76.94%
# ------------------------------

# %% [markdown]
# # transofd 64 128 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Sujets demandés
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]
# Le sujet 3 est exclu car absent des listes ci-dessus.

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)
print(f"Nombre total d'observations chargées : {len(df)}")

# --- 2. PRÉTRAITEMENT ---

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. SÉPARATION TRAIN / TEST ---

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. ARCHITECTURE TRANSFORMER ---

class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 64, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# --- 5. ENTRAÎNEMENT ET ÉVALUATION ---

model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 (Transformer) ---
# Nombre total d'observations chargées : 72077
# /tmp/ipykernel_415/431561522.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.1049 - loss: 2.4087 - val_accuracy: 0.0000e+00 - val_loss: 4.2819
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.1111 - loss: 2.2527 - val_accuracy: 0.0000e+00 - val_loss: 4.1356
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.1574 - loss: 2.1447 - val_accuracy: 0.0000e+00 - val_loss: 4.5139
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3117 - loss: 1.7735 - val_accuracy: 0.0000e+00 - val_loss: 4.9064
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.5648 - loss: 1.1324 - val_accuracy: 0.0000e+00 - val_loss: 3.7891
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8302 - loss: 0.5363 - val_accuracy: 0.0556 - val_loss: 3.4605
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.8735 - loss: 0.3265 - val_accuracy: 0.0000e+00 - val_loss: 4.5447
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9414 - loss: 0.1704 - val_accuracy: 0.3056 - val_loss: 3.5891
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9599 - loss: 0.1472 - val_accuracy: 0.4444 - val_loss: 2.7112
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9907 - loss: 0.0678 - val_accuracy: 0.6389 - val_loss: 1.7876
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9938 - loss: 0.0340 - val_accuracy: 0.4167 - val_loss: 2.3097
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9877 - loss: 0.0434 - val_accuracy: 0.5278 - val_loss: 2.0550
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9907 - loss: 0.0333 - val_accuracy: 0.5833 - val_loss: 2.2117
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9846 - loss: 0.0351 - val_accuracy: 0.5556 - val_loss: 1.9262
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9846 - loss: 0.0575 - val_accuracy: 0.5000 - val_loss: 2.0286
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0285 - val_accuracy: 0.5278 - val_loss: 1.8716
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 0.5556 - val_loss: 2.1083
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.5556 - val_loss: 1.7790
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.6111 - val_loss: 1.3609
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.6389 - val_loss: 1.4013
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.5833 - val_loss: 1.6327
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.5833 - val_loss: 1.7754
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.6389 - val_loss: 1.7303
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 1000ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.6389 - val_loss: 1.7646
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.5556 - val_loss: 1.8742
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5556 - val_loss: 1.9278
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5556 - val_loss: 1.9283
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5833 - val_loss: 1.9339
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 9.9410e-04 - val_accuracy: 0.5833 - val_loss: 1.9511
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6111 - val_loss: 1.8972
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6111 - val_loss: 1.8129
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 9.9335e-04 - val_accuracy: 0.6389 - val_loss: 1.7360
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 8.9868e-04 - val_accuracy: 0.6389 - val_loss: 1.7656
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6389 - val_loss: 1.7465
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6389 - val_loss: 1.6783
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6111 - val_loss: 1.6492
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 8.6243e-04 - val_accuracy: 0.6111 - val_loss: 1.7144
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 9.9017e-04 - val_accuracy: 0.6111 - val_loss: 1.7514
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 9.8918e-04 - val_accuracy: 0.6111 - val_loss: 1.8543
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 9.5059e-04 - val_accuracy: 0.6111 - val_loss: 1.9335
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.5833 - val_loss: 2.1280
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 6.2241e-04 - val_accuracy: 0.5833 - val_loss: 2.1426
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 7.2959e-04 - val_accuracy: 0.6111 - val_loss: 2.1062
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 8.3640e-04 - val_accuracy: 0.6111 - val_loss: 2.0678
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 7.9034e-04 - val_accuracy: 0.6111 - val_loss: 2.0655
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 7.4430e-04 - val_accuracy: 0.6111 - val_loss: 2.0886
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 5.9285e-04 - val_accuracy: 0.6111 - val_loss: 2.0855
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 5.8780e-04 - val_accuracy: 0.6111 - val_loss: 2.0961
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 5.9527e-04 - val_accuracy: 0.6111 - val_loss: 2.1183
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 5.9104e-04 - val_accuracy: 0.6111 - val_loss: 2.1108
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets         : [6, 7, 8, 9, 10]
# ========================================
# Sujet 6 : 100.00%
# Sujet 7 : 84.44%
# Sujet 8 : 94.44%
# Sujet 9 : 90.00%
# Sujet 10 : 88.89%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 91.56%
# ------------------------------

# %% [markdown]
# # trnsof 64 128 32 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Sujets demandés
TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]
# Le sujet 3 est exclu car absent des listes ci-dessus.

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)
print(f"Nombre total d'observations chargées : {len(df)}")

# --- 2. PRÉTRAITEMENT ---

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. SÉPARATION TRAIN / TEST ---

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. ARCHITECTURE TRANSFORMER ---

class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 64, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# --- 5. ENTRAÎNEMENT ET ÉVALUATION ---

model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 (Transformer) ---
# Nombre total d'observations chargées : 72077
# /tmp/ipykernel_415/1243580802.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.1309 - loss: 2.3152 - val_accuracy: 0.0000e+00 - val_loss: 4.1058
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1235 - loss: 2.1952 - val_accuracy: 0.0000e+00 - val_loss: 4.7802
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2914 - loss: 1.9302 - val_accuracy: 0.0000e+00 - val_loss: 4.3433
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.7877 - loss: 0.6669 - val_accuracy: 0.0444 - val_loss: 3.9812
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.9605 - loss: 0.1615 - val_accuracy: 0.3778 - val_loss: 2.6581
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9852 - loss: 0.0650 - val_accuracy: 0.5111 - val_loss: 2.2113
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9852 - loss: 0.0384 - val_accuracy: 0.6667 - val_loss: 2.2261
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9951 - loss: 0.0278 - val_accuracy: 0.5778 - val_loss: 2.5667
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.9901 - loss: 0.0393 - val_accuracy: 0.4222 - val_loss: 3.2985
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.9778 - loss: 0.0472 - val_accuracy: 0.1778 - val_loss: 4.1598
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.9753 - loss: 0.0848 - val_accuracy: 0.6222 - val_loss: 2.5805
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.9802 - loss: 0.0884 - val_accuracy: 0.4444 - val_loss: 3.7632
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.9901 - loss: 0.0272 - val_accuracy: 0.4444 - val_loss: 3.8164
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.5333 - val_loss: 3.3899
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.5778 - val_loss: 3.1991
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.5556 - val_loss: 3.2069
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5556 - val_loss: 3.2240
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.6000 - val_loss: 3.2102
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.6000 - val_loss: 3.2073
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 9.4541e-04 - val_accuracy: 0.6444 - val_loss: 3.2076
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 7.9045e-04 - val_accuracy: 0.6444 - val_loss: 3.2111
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 6.5683e-04 - val_accuracy: 0.6444 - val_loss: 3.2039
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 6.5676e-04 - val_accuracy: 0.6444 - val_loss: 3.2251
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 6.2095e-04 - val_accuracy: 0.6444 - val_loss: 3.2316
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 7.0758e-04 - val_accuracy: 0.6667 - val_loss: 3.1814
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 7.4767e-04 - val_accuracy: 0.6667 - val_loss: 3.1891
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 5.2861e-04 - val_accuracy: 0.6667 - val_loss: 3.2235
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 6.3983e-04 - val_accuracy: 0.6667 - val_loss: 3.2574
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 5.6604e-04 - val_accuracy: 0.6667 - val_loss: 3.2902
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 4.7461e-04 - val_accuracy: 0.6667 - val_loss: 3.3189
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 5.8053e-04 - val_accuracy: 0.6667 - val_loss: 3.3206
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 3.9723e-04 - val_accuracy: 0.6667 - val_loss: 3.3322
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 5.2290e-04 - val_accuracy: 0.6667 - val_loss: 3.3094
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 4.4185e-04 - val_accuracy: 0.6667 - val_loss: 3.3005
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 4.3980e-04 - val_accuracy: 0.6667 - val_loss: 3.3135
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 3.6390e-04 - val_accuracy: 0.6667 - val_loss: 3.3295
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 3.6539e-04 - val_accuracy: 0.6667 - val_loss: 3.3482
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 3.8087e-04 - val_accuracy: 0.6667 - val_loss: 3.3607
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 3.6937e-04 - val_accuracy: 0.6667 - val_loss: 3.4080
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 3.0257e-04 - val_accuracy: 0.6667 - val_loss: 3.4281
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 2.9497e-04 - val_accuracy: 0.6667 - val_loss: 3.4377
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 3.7627e-04 - val_accuracy: 0.6667 - val_loss: 3.4306
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 2.9075e-04 - val_accuracy: 0.6667 - val_loss: 3.4192
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 2.7982e-04 - val_accuracy: 0.6667 - val_loss: 3.4232
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 2.8496e-04 - val_accuracy: 0.6667 - val_loss: 3.4311
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 2.6199e-04 - val_accuracy: 0.6667 - val_loss: 3.4417
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 1.9424e-04 - val_accuracy: 0.6667 - val_loss: 3.4509
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 2.4867e-04 - val_accuracy: 0.6667 - val_loss: 3.4739
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 1.0000 - loss: 2.2505e-04 - val_accuracy: 0.6667 - val_loss: 3.4761
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 2.4014e-04 - val_accuracy: 0.6667 - val_loss: 3.4989
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets         : [1, 2, 4, 5]
# ========================================
# Sujet 1 : 92.22%
# Sujet 2 : 64.44%
# Sujet 4 : 86.67%
# Sujet 5 : 85.56%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 82.22%
# ------------------------------

# %% [markdown]
# # transfo 64 64 32 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Sujets demandés
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]
# Le sujet 3 est exclu car absent des listes ci-dessus.

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)
print(f"Nombre total d'observations chargées : {len(df)}")

# --- 2. PRÉTRAITEMENT ---

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. SÉPARATION TRAIN / TEST ---

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. ARCHITECTURE TRANSFORMER ---

class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 64, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# --- 5. ENTRAÎNEMENT ET ÉVALUATION ---

model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 (Transformer) ---
# Nombre total d'observations chargées : 72077
# /tmp/ipykernel_415/2236919269.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.1019 - loss: 2.4696 - val_accuracy: 0.0000e+00 - val_loss: 2.7346
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1481 - loss: 2.2347 - val_accuracy: 0.0000e+00 - val_loss: 3.3134
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.1512 - loss: 2.2580 - val_accuracy: 0.0000e+00 - val_loss: 3.5769
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.2315 - loss: 2.0300 - val_accuracy: 0.0000e+00 - val_loss: 3.9456
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.4383 - loss: 1.4314 - val_accuracy: 0.0000e+00 - val_loss: 5.4078
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5710 - loss: 1.0250 - val_accuracy: 0.0000e+00 - val_loss: 4.5891
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7963 - loss: 0.5852 - val_accuracy: 0.0000e+00 - val_loss: 3.9523
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9043 - loss: 0.3275 - val_accuracy: 0.0000e+00 - val_loss: 2.7335
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.9352 - loss: 0.2028 - val_accuracy: 0.1944 - val_loss: 2.6385
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9753 - loss: 0.1099 - val_accuracy: 0.3056 - val_loss: 3.4248
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9660 - loss: 0.1160 - val_accuracy: 0.2500 - val_loss: 3.1074
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9599 - loss: 0.0959 - val_accuracy: 0.1111 - val_loss: 4.5613
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9784 - loss: 0.0987 - val_accuracy: 0.1667 - val_loss: 3.7090
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9599 - loss: 0.1262 - val_accuracy: 0.4167 - val_loss: 1.7721
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9846 - loss: 0.0620 - val_accuracy: 0.3333 - val_loss: 2.9708
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9938 - loss: 0.0527 - val_accuracy: 0.4167 - val_loss: 3.6178
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.9907 - loss: 0.0318 - val_accuracy: 0.4722 - val_loss: 2.6521
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9846 - loss: 0.0671 - val_accuracy: 0.4444 - val_loss: 3.6657
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9938 - loss: 0.0278 - val_accuracy: 0.3889 - val_loss: 3.7312
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 0.6111 - val_loss: 1.6942
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9969 - loss: 0.0206 - val_accuracy: 0.3611 - val_loss: 4.0116
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9938 - loss: 0.0160 - val_accuracy: 0.3333 - val_loss: 3.5124
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.3611 - val_loss: 3.6696
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.5000 - val_loss: 3.4179
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.5000 - val_loss: 3.4320
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.4167 - val_loss: 3.7435
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.4167 - val_loss: 3.9779
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.3889 - val_loss: 4.1491
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.3611 - val_loss: 4.2498
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.3611 - val_loss: 4.3270
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.3889 - val_loss: 4.3468
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.3889 - val_loss: 4.3514
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.3889 - val_loss: 4.3915
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.3889 - val_loss: 4.4473
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.3889 - val_loss: 4.5218
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.4167 - val_loss: 4.3995
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.4722 - val_loss: 4.3856
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.4167 - val_loss: 4.4391
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.4167 - val_loss: 4.5126
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.3611 - val_loss: 4.5966
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.3611 - val_loss: 4.5966
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.3611 - val_loss: 4.5978
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.3611 - val_loss: 4.5985
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 9.0744e-04 - val_accuracy: 0.3889 - val_loss: 4.5853
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 8.2075e-04 - val_accuracy: 0.3889 - val_loss: 4.6417
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.3889 - val_loss: 4.7755
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 7.2970e-04 - val_accuracy: 0.3889 - val_loss: 4.8013
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.3889 - val_loss: 4.7736
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.3889 - val_loss: 4.7504
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 9.1115e-04 - val_accuracy: 0.4444 - val_loss: 4.7925
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets         : [6, 7, 8, 9, 10]
# ========================================
# Sujet 6 : 98.89%
# Sujet 7 : 77.78%
# Sujet 8 : 90.00%
# Sujet 9 : 88.89%
# Sujet 10 : 85.56%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 88.22%
# ------------------------------

# %% [markdown]
# # transfo 64 64 32 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Sujets demandés
TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]
# Le sujet 3 est exclu car absent des listes ci-dessus.

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)
print(f"Nombre total d'observations chargées : {len(df)}")

# --- 2. PRÉTRAITEMENT ---

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. SÉPARATION TRAIN / TEST ---

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. ARCHITECTURE TRANSFORMER ---

class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 64, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# --- 5. ENTRAÎNEMENT ET ÉVALUATION ---

model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 (Transformer) ---
# Nombre total d'observations chargées : 72077
# /tmp/ipykernel_415/3414571980.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.1259 - loss: 2.3301 - val_accuracy: 0.0000e+00 - val_loss: 3.0191
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.1136 - loss: 2.2210 - val_accuracy: 0.0000e+00 - val_loss: 3.1747
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1457 - loss: 2.1936 - val_accuracy: 0.0000e+00 - val_loss: 3.3296
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.4346 - loss: 1.6032 - val_accuracy: 0.0000e+00 - val_loss: 4.7885
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.8593 - loss: 0.5367 - val_accuracy: 0.0000e+00 - val_loss: 3.6587
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.9580 - loss: 0.2300 - val_accuracy: 0.2222 - val_loss: 2.7045
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.9852 - loss: 0.1115 - val_accuracy: 0.1111 - val_loss: 3.3426
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.9827 - loss: 0.0775 - val_accuracy: 0.4222 - val_loss: 2.3336
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9901 - loss: 0.0466 - val_accuracy: 0.2222 - val_loss: 2.8935
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9901 - loss: 0.0474 - val_accuracy: 0.3778 - val_loss: 2.8195
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.9877 - loss: 0.0371 - val_accuracy: 0.7778 - val_loss: 0.8560
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9728 - loss: 0.1194 - val_accuracy: 0.3333 - val_loss: 3.2746
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.9556 - loss: 0.1607 - val_accuracy: 0.4000 - val_loss: 2.6341
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9802 - loss: 0.0897 - val_accuracy: 0.3333 - val_loss: 3.1010
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.9951 - loss: 0.0471 - val_accuracy: 0.4667 - val_loss: 1.9245
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9975 - loss: 0.0253 - val_accuracy: 0.4889 - val_loss: 1.9129
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9975 - loss: 0.0143 - val_accuracy: 0.4889 - val_loss: 2.2472
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.9951 - loss: 0.0140 - val_accuracy: 0.5333 - val_loss: 2.1299
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.5333 - val_loss: 2.0598
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.9975 - loss: 0.0125 - val_accuracy: 0.6667 - val_loss: 1.8528
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.6667 - val_loss: 1.8257
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.6667 - val_loss: 1.8706
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.6667 - val_loss: 1.9618
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.6444 - val_loss: 1.9736
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.5778 - val_loss: 2.0692
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.5556 - val_loss: 2.2040
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.5778 - val_loss: 2.2180
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6000 - val_loss: 2.0933
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.6667 - val_loss: 2.1358
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6889 - val_loss: 2.1902
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5778 - val_loss: 2.2825
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.5778 - val_loss: 2.3102
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.5778 - val_loss: 2.3798
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.5556 - val_loss: 2.6737
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.5333 - val_loss: 2.6893
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.5111 - val_loss: 2.6140
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 9.3768e-04 - val_accuracy: 0.5111 - val_loss: 2.5599
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 9.7931e-04 - val_accuracy: 0.5111 - val_loss: 2.5752
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.5111 - val_loss: 2.5917
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.5111 - val_loss: 2.5150
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 7.3581e-04 - val_accuracy: 0.5111 - val_loss: 2.4908
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 7.8175e-04 - val_accuracy: 0.5111 - val_loss: 2.5174
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 1.0000 - loss: 8.1341e-04 - val_accuracy: 0.4889 - val_loss: 2.5452
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 1.0000 - loss: 6.3262e-04 - val_accuracy: 0.4889 - val_loss: 2.5500
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 1.0000 - loss: 5.1168e-04 - val_accuracy: 0.4889 - val_loss: 2.5527
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 1.0000 - loss: 9.1983e-04 - val_accuracy: 0.5111 - val_loss: 2.4653
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 5.3336e-04 - val_accuracy: 0.5111 - val_loss: 2.4442
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 1.0000 - loss: 6.7484e-04 - val_accuracy: 0.5333 - val_loss: 2.3967
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 4.1908e-04 - val_accuracy: 0.5111 - val_loss: 2.3676
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 1.0000 - loss: 9.1922e-04 - val_accuracy: 0.5111 - val_loss: 2.3688
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets         : [1, 2, 4, 5]
# ========================================
# Sujet 1 : 97.78%
# Sujet 2 : 71.11%
# Sujet 4 : 92.22%
# Sujet 5 : 84.44%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 86.39%
# ------------------------------

# %% [markdown]
# # transfo 64 64 bathc 64 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Sujets demandés
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]
# Le sujet 3 est exclu car absent des listes ci-dessus.

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)
print(f"Nombre total d'observations chargées : {len(df)}")

# --- 2. PRÉTRAITEMENT ---

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. SÉPARATION TRAIN / TEST ---

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. ARCHITECTURE TRANSFORMER ---

class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 64, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# --- 5. ENTRAÎNEMENT ET ÉVALUATION ---

model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 (Transformer) ---
# Nombre total d'observations chargées : 72077
# /tmp/ipykernel_415/2119570442.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 4s/step - accuracy: 0.1111 - loss: 2.3191 - val_accuracy: 0.0000e+00 - val_loss: 4.2765
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step - accuracy: 0.1420 - loss: 2.3767 - val_accuracy: 0.0000e+00 - val_loss: 3.5343
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step - accuracy: 0.1543 - loss: 2.2439 - val_accuracy: 0.0000e+00 - val_loss: 4.0135
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.0988 - loss: 2.2144 - val_accuracy: 0.0000e+00 - val_loss: 4.0263
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 17s 3s/step - accuracy: 0.1389 - loss: 2.1492 - val_accuracy: 0.0000e+00 - val_loss: 3.8441
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.2284 - loss: 2.0798 - val_accuracy: 0.0000e+00 - val_loss: 4.0756
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.3488 - loss: 1.7566 - val_accuracy: 0.0000e+00 - val_loss: 5.1193
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.4444 - loss: 1.4459 - val_accuracy: 0.0000e+00 - val_loss: 6.1331
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.5401 - loss: 1.2272 - val_accuracy: 0.0000e+00 - val_loss: 5.6497
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.6512 - loss: 0.9147 - val_accuracy: 0.0000e+00 - val_loss: 6.1159
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7685 - loss: 0.6174 - val_accuracy: 0.0000e+00 - val_loss: 5.6579
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8765 - loss: 0.3857 - val_accuracy: 0.0000e+00 - val_loss: 6.2652
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8889 - loss: 0.3344 - val_accuracy: 0.0000e+00 - val_loss: 4.7709
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8549 - loss: 0.4108 - val_accuracy: 0.0000e+00 - val_loss: 5.9053
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8673 - loss: 0.3640 - val_accuracy: 0.1389 - val_loss: 5.2182
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8920 - loss: 0.3182 - val_accuracy: 0.6389 - val_loss: 2.1046
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.9259 - loss: 0.2475 - val_accuracy: 0.2222 - val_loss: 5.7117
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9660 - loss: 0.1339 - val_accuracy: 0.1944 - val_loss: 5.5610
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.9784 - loss: 0.0904 - val_accuracy: 0.3056 - val_loss: 4.8970
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9815 - loss: 0.0629 - val_accuracy: 0.4722 - val_loss: 3.6778
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.9877 - loss: 0.0488 - val_accuracy: 0.3333 - val_loss: 4.7089
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9969 - loss: 0.0309 - val_accuracy: 0.3056 - val_loss: 5.1571
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 1.0000 - loss: 0.0160 - val_accuracy: 0.4167 - val_loss: 5.0492
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0141 - val_accuracy: 0.4167 - val_loss: 4.9343
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.3889 - val_loss: 5.1156
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.3889 - val_loss: 5.2628
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.3611 - val_loss: 5.4283
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.3611 - val_loss: 5.4445
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9969 - loss: 0.0110 - val_accuracy: 0.3611 - val_loss: 5.4474
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.3889 - val_loss: 5.5424
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.3889 - val_loss: 5.5986
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.3889 - val_loss: 5.5884
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.3889 - val_loss: 5.6129
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.3889 - val_loss: 5.5776
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.3889 - val_loss: 5.6776
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.3889 - val_loss: 5.8109
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.3889 - val_loss: 5.9181
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.3889 - val_loss: 5.9789
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.3889 - val_loss: 5.9901
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.3889 - val_loss: 6.0737
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.3889 - val_loss: 6.0507
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.3889 - val_loss: 5.8735
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.3889 - val_loss: 5.8811
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.3889 - val_loss: 6.0501
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.3889 - val_loss: 5.9614
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.3889 - val_loss: 5.9075
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.3889 - val_loss: 5.9403
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.3889 - val_loss: 5.9889
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.3889 - val_loss: 6.0394
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.3889 - val_loss: 6.1026
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets         : [6, 7, 8, 9, 10]
# ========================================
# Sujet 6 : 93.33%
# Sujet 7 : 74.44%
# Sujet 8 : 85.56%
# Sujet 9 : 76.67%
# Sujet 10 : 83.33%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 82.67%
# ------------------------------

# %% [markdown]
# # transfp 64 64 64 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Sujets demandés
TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]
# Le sujet 3 est exclu car absent des listes ci-dessus.

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)
print(f"Nombre total d'observations chargées : {len(df)}")

# --- 2. PRÉTRAITEMENT ---

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. SÉPARATION TRAIN / TEST ---

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. ARCHITECTURE TRANSFORMER ---

class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 64, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# --- 5. ENTRAÎNEMENT ET ÉVALUATION ---

model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 (Transformer) ---
# Nombre total d'observations chargées : 72077
# /tmp/ipykernel_415/931329062.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 44s 4s/step - accuracy: 0.1210 - loss: 2.4118 - val_accuracy: 0.0000e+00 - val_loss: 3.3511
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 31s 4s/step - accuracy: 0.0864 - loss: 2.2299 - val_accuracy: 0.0000e+00 - val_loss: 3.2126
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - accuracy: 0.0963 - loss: 2.2132 - val_accuracy: 0.0000e+00 - val_loss: 3.8003
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.1827 - loss: 2.1488 - val_accuracy: 0.0000e+00 - val_loss: 3.8602
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.2444 - loss: 1.9659 - val_accuracy: 0.0000e+00 - val_loss: 3.6071
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.5679 - loss: 1.3276 - val_accuracy: 0.0000e+00 - val_loss: 5.3625
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8741 - loss: 0.5656 - val_accuracy: 0.0000e+00 - val_loss: 4.6942
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.9506 - loss: 0.2475 - val_accuracy: 0.0000e+00 - val_loss: 3.4963
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9654 - loss: 0.1251 - val_accuracy: 0.0889 - val_loss: 2.1767
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.9728 - loss: 0.1081 - val_accuracy: 0.1778 - val_loss: 2.6991
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9630 - loss: 0.1443 - val_accuracy: 0.2444 - val_loss: 2.4223
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9556 - loss: 0.1183 - val_accuracy: 0.0444 - val_loss: 4.4948
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.9901 - loss: 0.0472 - val_accuracy: 0.1333 - val_loss: 2.6898
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.9901 - loss: 0.0365 - val_accuracy: 0.5778 - val_loss: 1.8368
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9926 - loss: 0.0282 - val_accuracy: 0.3556 - val_loss: 2.9442
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.9975 - loss: 0.0178 - val_accuracy: 0.3333 - val_loss: 3.8372
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.3556 - val_loss: 4.0601
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 0.3556 - val_loss: 4.1136
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.3556 - val_loss: 4.1161
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.9975 - loss: 0.0077 - val_accuracy: 0.3778 - val_loss: 3.8128
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.3556 - val_loss: 3.4328
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.3778 - val_loss: 3.3088
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.3778 - val_loss: 3.4446
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.3778 - val_loss: 3.5347
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.3778 - val_loss: 3.6870
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.3778 - val_loss: 3.9011
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.3778 - val_loss: 4.0884
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.3778 - val_loss: 4.4025
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.3778 - val_loss: 4.5415
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.3778 - val_loss: 4.4588
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.3778 - val_loss: 4.3417
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.3778 - val_loss: 4.4327
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.3556 - val_loss: 4.5442
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.3556 - val_loss: 4.6005
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.3556 - val_loss: 4.5870
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.3333 - val_loss: 4.7290
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.3333 - val_loss: 4.9453
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.3333 - val_loss: 5.0310
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.3556 - val_loss: 4.6477
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.3778 - val_loss: 4.4759
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.3778 - val_loss: 4.4553
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.3778 - val_loss: 4.5492
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.3333 - val_loss: 4.8222
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.3333 - val_loss: 5.0498
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.3333 - val_loss: 5.1661
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.3333 - val_loss: 5.1590
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 8.4148e-04 - val_accuracy: 0.3333 - val_loss: 5.1371
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.3333 - val_loss: 5.0745
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.3333 - val_loss: 5.0411
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.3333 - val_loss: 4.8142
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets         : [1, 2, 4, 5]
# ========================================
# Sujet 1 : 84.44%
# Sujet 2 : 58.89%
# Sujet 4 : 83.33%
# Sujet 5 : 76.67%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 75.83%
# ------------------------------

# %% [markdown]
# # transfo 64 64 16 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Sujets demandés
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]
# Le sujet 3 est exclu car absent des listes ci-dessus.

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)
print(f"Nombre total d'observations chargées : {len(df)}")

# --- 2. PRÉTRAITEMENT ---

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. SÉPARATION TRAIN / TEST ---

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. ARCHITECTURE TRANSFORMER ---

class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 64, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# --- 5. ENTRAÎNEMENT ET ÉVALUATION ---

model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 (Transformer) ---
# Nombre total d'observations chargées : 72077
# /tmp/ipykernel_415/916984944.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 22s 656ms/step - accuracy: 0.1173 - loss: 2.3613 - val_accuracy: 0.0000e+00 - val_loss: 3.3842
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 609ms/step - accuracy: 0.1512 - loss: 2.2390 - val_accuracy: 0.0000e+00 - val_loss: 3.7131
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 573ms/step - accuracy: 0.2963 - loss: 1.8559 - val_accuracy: 0.0000e+00 - val_loss: 3.7081
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 532ms/step - accuracy: 0.5617 - loss: 1.1678 - val_accuracy: 0.0000e+00 - val_loss: 4.7100
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 578ms/step - accuracy: 0.7377 - loss: 0.6800 - val_accuracy: 0.0000e+00 - val_loss: 4.4661
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 614ms/step - accuracy: 0.8056 - loss: 0.5379 - val_accuracy: 0.0000e+00 - val_loss: 4.3649
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 602ms/step - accuracy: 0.9259 - loss: 0.2919 - val_accuracy: 0.0000e+00 - val_loss: 3.4575
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 597ms/step - accuracy: 0.9383 - loss: 0.2205 - val_accuracy: 0.0833 - val_loss: 2.2304
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 588ms/step - accuracy: 0.9599 - loss: 0.1391 - val_accuracy: 0.3889 - val_loss: 1.9782
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 555ms/step - accuracy: 0.9784 - loss: 0.0840 - val_accuracy: 0.1944 - val_loss: 4.4357
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 584ms/step - accuracy: 0.9753 - loss: 0.1045 - val_accuracy: 0.5278 - val_loss: 1.6892
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 587ms/step - accuracy: 0.9846 - loss: 0.0493 - val_accuracy: 0.5000 - val_loss: 2.4497
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 598ms/step - accuracy: 0.9877 - loss: 0.0483 - val_accuracy: 0.5278 - val_loss: 2.1047
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 597ms/step - accuracy: 0.9877 - loss: 0.0315 - val_accuracy: 0.5000 - val_loss: 2.2446
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 602ms/step - accuracy: 0.9475 - loss: 0.2277 - val_accuracy: 0.2222 - val_loss: 2.5639
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 632ms/step - accuracy: 0.9475 - loss: 0.1766 - val_accuracy: 0.3056 - val_loss: 3.2401
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 593ms/step - accuracy: 0.9722 - loss: 0.0944 - val_accuracy: 0.4444 - val_loss: 2.6735
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 600ms/step - accuracy: 0.9722 - loss: 0.0944 - val_accuracy: 0.5278 - val_loss: 1.9495
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 567ms/step - accuracy: 0.9907 - loss: 0.0622 - val_accuracy: 0.5556 - val_loss: 1.8588
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 613ms/step - accuracy: 0.9846 - loss: 0.0457 - val_accuracy: 0.6111 - val_loss: 2.0061
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 594ms/step - accuracy: 0.9660 - loss: 0.0923 - val_accuracy: 0.4167 - val_loss: 2.2795
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 611ms/step - accuracy: 0.9907 - loss: 0.0356 - val_accuracy: 0.4722 - val_loss: 2.9573
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 603ms/step - accuracy: 0.9969 - loss: 0.0589 - val_accuracy: 0.4444 - val_loss: 3.9268
# Epoch 24/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 602ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.3889 - val_loss: 3.7949
# Epoch 25/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 571ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.3889 - val_loss: 3.9226
# Epoch 26/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 553ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.3889 - val_loss: 3.9536
# Epoch 27/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 587ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.3889 - val_loss: 3.9171
# Epoch 28/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 604ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.3889 - val_loss: 4.0500
# Epoch 29/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 603ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.3889 - val_loss: 4.0361
# Epoch 30/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 589ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.3889 - val_loss: 3.9692
# Epoch 31/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 595ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.3889 - val_loss: 4.0929
# Epoch 32/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 548ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.3889 - val_loss: 4.0810
# Epoch 33/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 602ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.3889 - val_loss: 3.9900
# Epoch 34/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 605ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.3889 - val_loss: 4.4189
# Epoch 35/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 599ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.3889 - val_loss: 4.5341
# Epoch 36/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 611ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.3889 - val_loss: 4.4635
# Epoch 37/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 697ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.3889 - val_loss: 4.5022
# Epoch 38/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 16s 736ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.3889 - val_loss: 4.3744
# Epoch 39/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 604ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.3889 - val_loss: 4.3062
# Epoch 40/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 607ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.3889 - val_loss: 4.3167
# Epoch 41/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 604ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.4444 - val_loss: 4.0196
# Epoch 42/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 600ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.4444 - val_loss: 3.9978
# Epoch 43/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 601ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.4444 - val_loss: 4.0296
# Epoch 44/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 603ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.4167 - val_loss: 4.3113
# Epoch 45/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 613ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.3889 - val_loss: 4.4535
# Epoch 46/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 604ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.3889 - val_loss: 4.4421
# Epoch 47/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 559ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.4167 - val_loss: 4.3241
# Epoch 48/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 600ms/step - accuracy: 1.0000 - loss: 7.9488e-04 - val_accuracy: 0.4167 - val_loss: 4.2681
# Epoch 49/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 618ms/step - accuracy: 1.0000 - loss: 7.4865e-04 - val_accuracy: 0.4167 - val_loss: 4.2420
# Epoch 50/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 13s 621ms/step - accuracy: 1.0000 - loss: 9.9271e-04 - val_accuracy: 0.4167 - val_loss: 4.1658
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [1, 2, 4, 5]
# Test sur sujets         : [6, 7, 8, 9, 10]
# ========================================
# Sujet 6 : 88.89%
# Sujet 7 : 81.11%
# Sujet 8 : 88.89%
# Sujet 9 : 88.89%
# Sujet 10 : 92.22%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 88.00%
# ------------------------------

# %% [markdown]
# # transfo 64 64 16 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import layers, models
import tensorflow as tf

# --- PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print("Décompression terminée !")

# --- CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Sujets demandés
TRAIN_SUBJECTS =  [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]
# Le sujet 3 est exclu car absent des listes ci-dessus.

df_list = []

print(f"--- 1. Début du Chargement du Domaine {DOMAIN_ID} (Transformer) ---")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError("Aucun fichier chargé. Vérifiez le chemin /content/temp_data/DOMAIN2_CSV")

df = pd.concat(df_list, ignore_index=True)
print(f"Nombre total d'observations chargées : {len(df)}")

# --- 2. PRÉTRAITEMENT ---

def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

df100 = resample_gesture(df)

# --- 3. SÉPARATION TRAIN / TEST ---

def prepare_data_split(df_in, train_subs, test_subs):
    train_df = df_in[df_in['subject'].isin(train_subs)]
    test_df = df_in[df_in['subject'].isin(test_subs)]

    def df_to_array(df_target):
        X, y, sub_ids = [], [], []
        for (g, s, i), group in df_target.groupby(['gesture', 'subject', 'iter']):
            X.append(group[['x_std', 'y_std', 'z_std']].values)
            y.append(g)
            sub_ids.append(s)
        return np.array(X), np.array(y), np.array(sub_ids)

    X_train, y_train, _ = df_to_array(train_df)
    X_test, y_test, test_sub_ids = df_to_array(test_df)
    return X_train, y_train, X_test, y_test, test_sub_ids

X_train, y_train, X_test, y_test, test_sub_ids = prepare_data_split(df100, TRAIN_SUBJECTS, TEST_SUBJECTS)

# --- 4. ARCHITECTURE TRANSFORMER ---

class PositionalEncoding(layers.Layer):
    def __init__(self, max_len, d_model):
        super().__init__()
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates
        pe = np.zeros((max_len, d_model))
        pe[:, 0::2] = np.sin(angle_rads[:, 0::2])
        pe[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.positional_encoding = tf.constant(pe[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.positional_encoding[:, :seq_len, :]

def transformer_encoder(x, num_heads, d_model, dff, dropout):
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = layers.Dropout(dropout)(attn_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(x + attn_output)
    ffn = models.Sequential([layers.Dense(dff, activation="relu"), layers.Dense(d_model)])
    ffn_output = ffn(out1)
    ffn_output = layers.Dropout(dropout)(ffn_output)
    return layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

def create_transformer_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    d_model, num_heads, num_layers, dff, dropout = 128, 8, 2, 64, 0.2
    x = layers.Dense(d_model)(inputs)
    x = PositionalEncoding(100, d_model)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, num_heads, d_model, dff, dropout)
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# --- 5. ENTRAÎNEMENT ET ÉVALUATION ---

model = create_transformer_model((X_train.shape[1], X_train.shape[2]), 10)
print("\nEntraînement Transformer en cours...")
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1, verbose=1)

print("\n" + "="*40)
print(f"RÉSULTATS DÉTAILLÉS - TRANSFORMER")
print(f"Entraînement sur sujets : {TRAIN_SUBJECTS}")
print(f"Test sur sujets         : {TEST_SUBJECTS}")
print("="*40)

y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
subject_scores = {}

for s_id in TEST_SUBJECTS:
    mask = (test_sub_ids == s_id)
    if np.any(mask):
        acc_s = accuracy_score(y_test[mask], y_pred[mask])
        subject_scores[s_id] = acc_s
        print(f"Sujet {s_id} : {acc_s:.2%}")

print("-" * 30)
mean_acc = np.mean(list(subject_scores.values()))
print(f"MOYENNE GLOBALE TRANSFORMER : {mean_acc:.2%}")
print("-" * 30)
# Out:
# --- 1. Début du Chargement du Domaine 2 (Transformer) ---
# Nombre total d'observations chargées : 72077
# /tmp/ipykernel_415/1423141737.py:65: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Entraînement Transformer en cours...
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 27s 607ms/step - accuracy: 0.1481 - loss: 2.3041 - val_accuracy: 0.0000e+00 - val_loss: 3.2261
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 619ms/step - accuracy: 0.2296 - loss: 2.0326 - val_accuracy: 0.0000e+00 - val_loss: 3.8939
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 587ms/step - accuracy: 0.7630 - loss: 0.6659 - val_accuracy: 0.0667 - val_loss: 2.6459
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 594ms/step - accuracy: 0.9037 - loss: 0.2833 - val_accuracy: 0.0000e+00 - val_loss: 4.9390
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 585ms/step - accuracy: 0.9605 - loss: 0.1550 - val_accuracy: 0.5556 - val_loss: 1.6672
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 640ms/step - accuracy: 0.9605 - loss: 0.1409 - val_accuracy: 0.3111 - val_loss: 3.4543
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 19s 586ms/step - accuracy: 0.9630 - loss: 0.1424 - val_accuracy: 0.1333 - val_loss: 3.8880
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 589ms/step - accuracy: 0.9827 - loss: 0.0843 - val_accuracy: 0.5111 - val_loss: 2.3051
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 585ms/step - accuracy: 0.9827 - loss: 0.0795 - val_accuracy: 0.4444 - val_loss: 3.0068
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 587ms/step - accuracy: 0.9827 - loss: 0.0726 - val_accuracy: 0.5556 - val_loss: 1.6534
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 593ms/step - accuracy: 0.9827 - loss: 0.0468 - val_accuracy: 0.6667 - val_loss: 1.0445
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 595ms/step - accuracy: 0.9926 - loss: 0.0319 - val_accuracy: 0.6667 - val_loss: 1.6356
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 593ms/step - accuracy: 0.9951 - loss: 0.0247 - val_accuracy: 0.4889 - val_loss: 2.2528
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 586ms/step - accuracy: 0.9852 - loss: 0.0416 - val_accuracy: 0.4222 - val_loss: 2.8343
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 638ms/step - accuracy: 0.9704 - loss: 0.1522 - val_accuracy: 0.2889 - val_loss: 4.6452
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 598ms/step - accuracy: 0.9704 - loss: 0.1460 - val_accuracy: 0.6000 - val_loss: 1.7793
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 593ms/step - accuracy: 0.9901 - loss: 0.0487 - val_accuracy: 0.6000 - val_loss: 2.6983
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 590ms/step - accuracy: 0.9901 - loss: 0.0426 - val_accuracy: 0.3556 - val_loss: 4.3041
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 583ms/step - accuracy: 0.9975 - loss: 0.0166 - val_accuracy: 0.4000 - val_loss: 3.4277
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 597ms/step - accuracy: 0.9877 - loss: 0.0460 - val_accuracy: 0.6667 - val_loss: 2.2794
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 580ms/step - accuracy: 0.9951 - loss: 0.0170 - val_accuracy: 0.6667 - val_loss: 2.1257
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 578ms/step - accuracy: 0.9975 - loss: 0.0105 - val_accuracy: 0.5556 - val_loss: 2.8460
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 580ms/step - accuracy: 0.9975 - loss: 0.0081 - val_accuracy: 0.6000 - val_loss: 3.1316
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 574ms/step - accuracy: 0.9951 - loss: 0.0237 - val_accuracy: 0.6667 - val_loss: 1.4863
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 577ms/step - accuracy: 0.9728 - loss: 0.0611 - val_accuracy: 0.2444 - val_loss: 5.0362
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 573ms/step - accuracy: 0.9926 - loss: 0.0200 - val_accuracy: 0.4667 - val_loss: 3.4909
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 605ms/step - accuracy: 0.9827 - loss: 0.0344 - val_accuracy: 0.4444 - val_loss: 4.2224
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 579ms/step - accuracy: 0.9926 - loss: 0.0127 - val_accuracy: 0.4444 - val_loss: 4.9365
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 579ms/step - accuracy: 0.9852 - loss: 0.0479 - val_accuracy: 0.5333 - val_loss: 3.7464
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 575ms/step - accuracy: 0.9333 - loss: 0.2803 - val_accuracy: 0.5111 - val_loss: 1.9557
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 589ms/step - accuracy: 0.9481 - loss: 0.1009 - val_accuracy: 0.4889 - val_loss: 3.4366
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 575ms/step - accuracy: 0.9926 - loss: 0.0280 - val_accuracy: 0.3111 - val_loss: 5.8175
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 585ms/step - accuracy: 0.9975 - loss: 0.0235 - val_accuracy: 0.5333 - val_loss: 3.7874
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 585ms/step - accuracy: 0.9975 - loss: 0.0144 - val_accuracy: 0.6000 - val_loss: 3.5001
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 596ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.5333 - val_loss: 4.6809
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 601ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.4000 - val_loss: 5.0347
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 19s 573ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.4000 - val_loss: 5.1020
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 576ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.4222 - val_loss: 4.9101
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 580ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.4222 - val_loss: 4.8488
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 592ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.4222 - val_loss: 4.8354
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 596ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.4222 - val_loss: 4.8517
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 579ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.4000 - val_loss: 4.8843
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 594ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.4000 - val_loss: 4.8614
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 577ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.4000 - val_loss: 4.7770
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 574ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.3778 - val_loss: 4.8430
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 583ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.3778 - val_loss: 5.0299
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 575ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.3778 - val_loss: 5.0549
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 21s 598ms/step - accuracy: 1.0000 - loss: 9.3621e-04 - val_accuracy: 0.3778 - val_loss: 5.1200
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 592ms/step - accuracy: 1.0000 - loss: 7.2995e-04 - val_accuracy: 0.3778 - val_loss: 5.0210
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 586ms/step - accuracy: 1.0000 - loss: 8.2782e-04 - val_accuracy: 0.3778 - val_loss: 5.0384
#
# ========================================
# RÉSULTATS DÉTAILLÉS - TRANSFORMER
# Entraînement sur sujets : [6, 7, 8, 9, 10]
# Test sur sujets         : [1, 2, 4, 5]
# ========================================
# Sujet 1 : 87.78%
# Sujet 2 : 63.33%
# Sujet 4 : 84.44%
# Sujet 5 : 81.11%
# ------------------------------
# MOYENNE GLOBALE TRANSFORMER : 79.17%
# ------------------------------

# %% [markdown]
# # dtw knn 3 trin 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# --- 1. PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print(" Décompression terminée !")

# --- 2. CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Configuration demandée
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]
# Sujet 3 exclu par omission

df_list = []
print(f"--- 1. Chargement : Train sur {TRAIN_SUBJECTS}, Test sur {TEST_SUBJECTS} ---")

for subject in (TRAIN_SUBJECTS + TEST_SUBJECTS):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

df = pd.concat(df_list, ignore_index=True)

# --- 3. PRÉ-TRAITEMENT ---
def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling (100 points)...")
df100 = resample_gesture(df, target_len=100)

# --- 4. DTW LOGIC ---
def eucl_dist(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def dtw_dist(seq1, seq2):
    n, m = len(seq1), len(seq2)
    dtw = np.full((n+1, m+1), np.inf)
    dtw[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = eucl_dist(seq1[i-1], seq2[j-1])
            dtw[i, j] = cost + min(dtw[i-1, j], dtw[i, j-1], dtw[i-1, j-1])
    return dtw[n, m]

def knn_dtw_predict(reference_seq, train_dict, k=3):
    distances = []
    for gesture, sequences in train_dict.items():
        for seq in sequences:
            dist = dtw_dist(reference_seq, seq)
            distances.append((gesture, dist))
    distances.sort(key=lambda x: x[1])
    return Counter([g for g, _ in distances[:k]]).most_common(1)[0][0]

# --- 5. ÉVALUATION AVEC AFFICHAGE PAR SUJET ---
def run_evaluation_by_subject(df_prep, train_list, test_list, k=3):
    # Préparation du dictionnaire de train (global pour tous les tests)
    train_df = df_prep[df_prep["subject"].isin(train_list)]
    dict_train = defaultdict(list)
    for (g, s, it), group in train_df.groupby(["gesture", "subject", "iter"]):
        dict_train[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())

    all_true, all_pred = [], []

    print(f"\n--- Début des tests sur les sujets {test_list} ---")

    # Évaluation individuelle pour chaque sujet de test
    for subj_id in test_list:
        subj_df = df_prep[df_prep["subject"] == subj_id]
        y_true_subj, y_pred_subj = [], []

        # Groupement par geste/itération pour ce sujet précis
        for (g, it), group in subj_df.groupby(["gesture", "iter"]):
            seq = group[["x_std", "y_std", "z_std"]].values.tolist()
            pred = knn_dtw_predict(seq, dict_train, k=k)
            y_true_subj.append(g)
            y_pred_subj.append(pred)

        acc_subj = accuracy_score(y_true_subj, y_pred_subj)
        print(f"Résultat Sujet {subj_id} : {acc_subj:.2%}")

        all_true.extend(y_true_subj)
        all_pred.extend(y_pred_subj)

    # Résultat Final
    print("-" * 30)
    print(f" PRÉCISION GLOBALE : {accuracy_score(all_true, all_pred):.2%}")



# Lancement
run_evaluation_by_subject(df100, TRAIN_SUBJECTS, TEST_SUBJECTS, k=3)
# Out:
# --- 1. Chargement : Train sur [1, 2, 4, 5], Test sur [6, 7, 8, 9, 10] ---
# Standardisation...
# /tmp/ipykernel_11238/3012464243.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling (100 points)...
#
# --- Début des tests sur les sujets [6, 7, 8, 9, 10] ---
# Résultat Sujet 6 : 81.11%
# Résultat Sujet 7 : 94.44%
# Résultat Sujet 8 : 77.78%
# Résultat Sujet 9 : 92.22%
# Résultat Sujet 10 : 93.33%
# ------------------------------
#  PRÉCISION GLOBALE : 87.78%

# %% [markdown]
# # dtw knn 3 train 5 tets 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# --- 1. PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print(" Décompression terminée !")

# --- 2. CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Configuration demandée
TRAIN_SUBJECTS = [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]
# Sujet 3 exclu par omission

df_list = []
print(f"--- 1. Chargement : Train sur {TRAIN_SUBJECTS}, Test sur {TEST_SUBJECTS} ---")

for subject in (TRAIN_SUBJECTS + TEST_SUBJECTS):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

df = pd.concat(df_list, ignore_index=True)

# --- 3. PRÉ-TRAITEMENT ---
def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling (100points)...")
df100= resample_gesture(df, target_len=100)

# --- 4. DTW LOGIC ---
def eucl_dist(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def dtw_dist(seq1, seq2):
    n, m = len(seq1), len(seq2)
    dtw = np.full((n+1, m+1), np.inf)
    dtw[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = eucl_dist(seq1[i-1], seq2[j-1])
            dtw[i, j] = cost + min(dtw[i-1, j], dtw[i, j-1], dtw[i-1, j-1])
    return dtw[n, m]

def knn_dtw_predict(reference_seq, train_dict, k=3):
    distances = []
    for gesture, sequences in train_dict.items():
        for seq in sequences:
            dist = dtw_dist(reference_seq, seq)
            distances.append((gesture, dist))
    distances.sort(key=lambda x: x[1])
    return Counter([g for g, _ in distances[:k]]).most_common(1)[0][0]

# --- 5. ÉVALUATION AVEC AFFICHAGE PAR SUJET ---
def run_evaluation_by_subject(df_prep, train_list, test_list, k=3):
    # Préparation du dictionnaire de train (global pour tous les tests)
    train_df = df_prep[df_prep["subject"].isin(train_list)]
    dict_train = defaultdict(list)
    for (g, s, it), group in train_df.groupby(["gesture", "subject", "iter"]):
        dict_train[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())

    all_true, all_pred = [], []

    print(f"\n--- Début des tests sur les sujets {test_list} ---")

    # Évaluation individuelle pour chaque sujet de test
    for subj_id in test_list:
        subj_df = df_prep[df_prep["subject"] == subj_id]
        y_true_subj, y_pred_subj = [], []

        # Groupement par geste/itération pour ce sujet précis
        for (g, it), group in subj_df.groupby(["gesture", "iter"]):
            seq = group[["x_std", "y_std", "z_std"]].values.tolist()
            pred = knn_dtw_predict(seq, dict_train, k=k)
            y_true_subj.append(g)
            y_pred_subj.append(pred)

        acc_subj = accuracy_score(y_true_subj, y_pred_subj)
        print(f"Résultat Sujet {subj_id} : {acc_subj:.2%}")

        all_true.extend(y_true_subj)
        all_pred.extend(y_pred_subj)

    # Résultat Final
    print("-" * 30)
    print(f" PRÉCISION GLOBALE : {accuracy_score(all_true, all_pred):.2%}")



# Lancement
run_evaluation_by_subject(df100, TRAIN_SUBJECTS, TEST_SUBJECTS, k=3)
# Out:
# --- 1. Chargement : Train sur [6, 7, 8, 9, 10], Test sur [1, 2, 4, 5] ---
# Standardisation...
# /tmp/ipykernel_11238/2304354132.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling (100points)...
#
# --- Début des tests sur les sujets [1, 2, 4, 5] ---
# Résultat Sujet 1 : 98.89%
# Résultat Sujet 2 : 86.67%
# Résultat Sujet 4 : 96.67%
# Résultat Sujet 5 : 87.78%
# ------------------------------
#  PRÉCISION GLOBALE : 92.50%

# %% [markdown]
# # dtw knn 5 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# --- 1. PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print(" Décompression terminée !")

# --- 2. CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Configuration demandée
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]
# Sujet 3 exclu par omission

df_list = []
print(f"--- 1. Chargement : Train sur {TRAIN_SUBJECTS}, Test sur {TEST_SUBJECTS} ---")

for subject in (TRAIN_SUBJECTS + TEST_SUBJECTS):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

df = pd.concat(df_list, ignore_index=True)

# --- 3. PRÉ-TRAITEMENT ---
def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling (100 points)...")
df100 = resample_gesture(df, target_len=100)

# --- 4. DTW LOGIC ---
def eucl_dist(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def dtw_dist(seq1, seq2):
    n, m = len(seq1), len(seq2)
    dtw = np.full((n+1, m+1), np.inf)
    dtw[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = eucl_dist(seq1[i-1], seq2[j-1])
            dtw[i, j] = cost + min(dtw[i-1, j], dtw[i, j-1], dtw[i-1, j-1])
    return dtw[n, m]

def knn_dtw_predict(reference_seq, train_dict, k=5):
    distances = []
    for gesture, sequences in train_dict.items():
        for seq in sequences:
            dist = dtw_dist(reference_seq, seq)
            distances.append((gesture, dist))
    distances.sort(key=lambda x: x[1])
    return Counter([g for g, _ in distances[:k]]).most_common(1)[0][0]

# --- 5. ÉVALUATION AVEC AFFICHAGE PAR SUJET ---
def run_evaluation_by_subject(df_prep, train_list, test_list, k=5):
    # Préparation du dictionnaire de train (global pour tous les tests)
    train_df = df_prep[df_prep["subject"].isin(train_list)]
    dict_train = defaultdict(list)
    for (g, s, it), group in train_df.groupby(["gesture", "subject", "iter"]):
        dict_train[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())

    all_true, all_pred = [], []

    print(f"\n--- Début des tests sur les sujets {test_list} ---")

    # Évaluation individuelle pour chaque sujet de test
    for subj_id in test_list:
        subj_df = df_prep[df_prep["subject"] == subj_id]
        y_true_subj, y_pred_subj = [], []

        # Groupement par geste/itération pour ce sujet précis
        for (g, it), group in subj_df.groupby(["gesture", "iter"]):
            seq = group[["x_std", "y_std", "z_std"]].values.tolist()
            pred = knn_dtw_predict(seq, dict_train, k=k)
            y_true_subj.append(g)
            y_pred_subj.append(pred)

        acc_subj = accuracy_score(y_true_subj, y_pred_subj)
        print(f"Résultat Sujet {subj_id} : {acc_subj:.2%}")

        all_true.extend(y_true_subj)
        all_pred.extend(y_pred_subj)

    # Résultat Final
    print("-" * 30)
    print(f" PRÉCISION GLOBALE : {accuracy_score(all_true, all_pred):.2%}")



# Lancement
run_evaluation_by_subject(df100, TRAIN_SUBJECTS, TEST_SUBJECTS, k=5)
# Out:
# --- 1. Chargement : Train sur [1, 2, 4, 5], Test sur [6, 7, 8, 9, 10] ---
# Standardisation...
# /tmp/ipykernel_11238/4116295946.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling (100 points)...
#
# --- Début des tests sur les sujets [6, 7, 8, 9, 10] ---
# Résultat Sujet 6 : 77.78%
# Résultat Sujet 7 : 93.33%
# Résultat Sujet 8 : 75.56%
# Résultat Sujet 9 : 92.22%
# Résultat Sujet 10 : 91.11%
# ------------------------------
#  PRÉCISION GLOBALE : 86.00%

# %% [markdown]
# # dtw knn 5 train 5 test 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# --- 1. PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print(" Décompression terminée !")

# --- 2. CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Configuration demandée
TRAIN_SUBJECTS = [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]
# Sujet 3 exclu par omission

df_list = []
print(f"--- 1. Chargement : Train sur {TRAIN_SUBJECTS}, Test sur {TEST_SUBJECTS} ---")

for subject in (TRAIN_SUBJECTS + TEST_SUBJECTS):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

df = pd.concat(df_list, ignore_index=True)

# --- 3. PRÉ-TRAITEMENT ---
def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling (100points)...")
df100= resample_gesture(df, target_len=100)

# --- 4. DTW LOGIC ---
def eucl_dist(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def dtw_dist(seq1, seq2):
    n, m = len(seq1), len(seq2)
    dtw = np.full((n+1, m+1), np.inf)
    dtw[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = eucl_dist(seq1[i-1], seq2[j-1])
            dtw[i, j] = cost + min(dtw[i-1, j], dtw[i, j-1], dtw[i-1, j-1])
    return dtw[n, m]

def knn_dtw_predict(reference_seq, train_dict, k=5):
    distances = []
    for gesture, sequences in train_dict.items():
        for seq in sequences:
            dist = dtw_dist(reference_seq, seq)
            distances.append((gesture, dist))
    distances.sort(key=lambda x: x[1])
    return Counter([g for g, _ in distances[:k]]).most_common(1)[0][0]

# --- 5. ÉVALUATION AVEC AFFICHAGE PAR SUJET ---
def run_evaluation_by_subject(df_prep, train_list, test_list, k=5):
    # Préparation du dictionnaire de train (global pour tous les tests)
    train_df = df_prep[df_prep["subject"].isin(train_list)]
    dict_train = defaultdict(list)
    for (g, s, it), group in train_df.groupby(["gesture", "subject", "iter"]):
        dict_train[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())

    all_true, all_pred = [], []

    print(f"\n--- Début des tests sur les sujets {test_list} ---")

    # Évaluation individuelle pour chaque sujet de test
    for subj_id in test_list:
        subj_df = df_prep[df_prep["subject"] == subj_id]
        y_true_subj, y_pred_subj = [], []

        # Groupement par geste/itération pour ce sujet précis
        for (g, it), group in subj_df.groupby(["gesture", "iter"]):
            seq = group[["x_std", "y_std", "z_std"]].values.tolist()
            pred = knn_dtw_predict(seq, dict_train, k=k)
            y_true_subj.append(g)
            y_pred_subj.append(pred)

        acc_subj = accuracy_score(y_true_subj, y_pred_subj)
        print(f"Résultat Sujet {subj_id} : {acc_subj:.2%}")

        all_true.extend(y_true_subj)
        all_pred.extend(y_pred_subj)

    # Résultat Final
    print("-" * 30)
    print(f" PRÉCISION GLOBALE : {accuracy_score(all_true, all_pred):.2%}")



# Lancement
run_evaluation_by_subject(df100, TRAIN_SUBJECTS, TEST_SUBJECTS, k=5)
# Out:
# --- 1. Chargement : Train sur [6, 7, 8, 9, 10], Test sur [1, 2, 4, 5] ---
# Standardisation...
# /tmp/ipykernel_11238/1416780077.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling (100points)...
#
# --- Début des tests sur les sujets [1, 2, 4, 5] ---
# Résultat Sujet 1 : 100.00%
# Résultat Sujet 2 : 90.00%
# Résultat Sujet 4 : 96.67%
# Résultat Sujet 5 : 91.11%
# ------------------------------
#  PRÉCISION GLOBALE : 94.44%

# %% [markdown]
# # dtw knn 7 train 4 test 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# --- 1. PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print(" Décompression terminée !")

# --- 2. CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Configuration demandée
TRAIN_SUBJECTS = [1, 2, 4, 5]
TEST_SUBJECTS = [6, 7, 8, 9, 10]
# Sujet 3 exclu par omission

df_list = []
print(f"--- 1. Chargement : Train sur {TRAIN_SUBJECTS}, Test sur {TEST_SUBJECTS} ---")

for subject in (TRAIN_SUBJECTS + TEST_SUBJECTS):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

df = pd.concat(df_list, ignore_index=True)

# --- 3. PRÉ-TRAITEMENT ---
def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling (100 points)...")
df100 = resample_gesture(df, target_len=100)

# --- 4. DTW LOGIC ---
def eucl_dist(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def dtw_dist(seq1, seq2):
    n, m = len(seq1), len(seq2)
    dtw = np.full((n+1, m+1), np.inf)
    dtw[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = eucl_dist(seq1[i-1], seq2[j-1])
            dtw[i, j] = cost + min(dtw[i-1, j], dtw[i, j-1], dtw[i-1, j-1])
    return dtw[n, m]

def knn_dtw_predict(reference_seq, train_dict, k=7):
    distances = []
    for gesture, sequences in train_dict.items():
        for seq in sequences:
            dist = dtw_dist(reference_seq, seq)
            distances.append((gesture, dist))
    distances.sort(key=lambda x: x[1])
    return Counter([g for g, _ in distances[:k]]).most_common(1)[0][0]

# --- 5. ÉVALUATION AVEC AFFICHAGE PAR SUJET ---
def run_evaluation_by_subject(df_prep, train_list, test_list, k=7):
    # Préparation du dictionnaire de train (global pour tous les tests)
    train_df = df_prep[df_prep["subject"].isin(train_list)]
    dict_train = defaultdict(list)
    for (g, s, it), group in train_df.groupby(["gesture", "subject", "iter"]):
        dict_train[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())

    all_true, all_pred = [], []

    print(f"\n--- Début des tests sur les sujets {test_list} ---")

    # Évaluation individuelle pour chaque sujet de test
    for subj_id in test_list:
        subj_df = df_prep[df_prep["subject"] == subj_id]
        y_true_subj, y_pred_subj = [], []

        # Groupement par geste/itération pour ce sujet précis
        for (g, it), group in subj_df.groupby(["gesture", "iter"]):
            seq = group[["x_std", "y_std", "z_std"]].values.tolist()
            pred = knn_dtw_predict(seq, dict_train, k=k)
            y_true_subj.append(g)
            y_pred_subj.append(pred)

        acc_subj = accuracy_score(y_true_subj, y_pred_subj)
        print(f"Résultat Sujet {subj_id} : {acc_subj:.2%}")

        all_true.extend(y_true_subj)
        all_pred.extend(y_pred_subj)

    # Résultat Final
    print("-" * 30)
    print(f" PRÉCISION GLOBALE : {accuracy_score(all_true, all_pred):.2%}")



# Lancement
run_evaluation_by_subject(df100, TRAIN_SUBJECTS, TEST_SUBJECTS, k=7)
# Out:
#  Décompression terminée !
# --- 1. Chargement : Train sur [1, 2, 4, 5], Test sur [6, 7, 8, 9, 10] ---
# Standardisation...
# /tmp/ipykernel_9053/1071875599.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling (100 points)...
#
# --- Début des tests sur les sujets [6, 7, 8, 9, 10] ---
# Résultat Sujet 6 : 73.33%
# Résultat Sujet 7 : 94.44%
# Résultat Sujet 8 : 72.22%
# Résultat Sujet 9 : 87.78%
# Résultat Sujet 10 : 91.11%
# ------------------------------
#  PRÉCISION GLOBALE : 83.78%

# %% [markdown]
# # knn 7 train 5 tets 4

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# --- 1. PRÉPARATION DES FICHIERS SUR COLAB ---
if not os.path.exists("/content/temp_data/DOMAIN2_CSV"):
    # !unzip -q /content/DOMAIN2_CSV.zip -d /content/temp_data
    print(" Décompression terminée !")

# --- 2. CONFIGURATION ---
DOMAIN_FOLDER = "/content/temp_data/DOMAIN2_CSV"
DOMAIN_ID = 2

# Configuration demandée
TRAIN_SUBJECTS = [6, 7, 8, 9, 10]
TEST_SUBJECTS = [1, 2, 4, 5]
# Sujet 3 exclu par omission

df_list = []
print(f"--- 1. Chargement : Train sur {TRAIN_SUBJECTS}, Test sur {TEST_SUBJECTS} ---")

for subject in (TRAIN_SUBJECTS + TEST_SUBJECTS):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])
                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)
                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

df = pd.concat(df_list, ignore_index=True)

# --- 3. PRÉ-TRAITEMENT ---
def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling (100points)...")
df100= resample_gesture(df, target_len=100)

# --- 4. DTW LOGIC ---
def eucl_dist(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def dtw_dist(seq1, seq2):
    n, m = len(seq1), len(seq2)
    dtw = np.full((n+1, m+1), np.inf)
    dtw[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = eucl_dist(seq1[i-1], seq2[j-1])
            dtw[i, j] = cost + min(dtw[i-1, j], dtw[i, j-1], dtw[i-1, j-1])
    return dtw[n, m]

def knn_dtw_predict(reference_seq, train_dict, k=7):
    distances = []
    for gesture, sequences in train_dict.items():
        for seq in sequences:
            dist = dtw_dist(reference_seq, seq)
            distances.append((gesture, dist))
    distances.sort(key=lambda x: x[1])
    return Counter([g for g, _ in distances[:k]]).most_common(1)[0][0]

# --- 5. ÉVALUATION AVEC AFFICHAGE PAR SUJET ---
def run_evaluation_by_subject(df_prep, train_list, test_list, k=7):
    # Préparation du dictionnaire de train (global pour tous les tests)
    train_df = df_prep[df_prep["subject"].isin(train_list)]
    dict_train = defaultdict(list)
    for (g, s, it), group in train_df.groupby(["gesture", "subject", "iter"]):
        dict_train[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())

    all_true, all_pred = [], []

    print(f"\n--- Début des tests sur les sujets {test_list} ---")

    # Évaluation individuelle pour chaque sujet de test
    for subj_id in test_list:
        subj_df = df_prep[df_prep["subject"] == subj_id]
        y_true_subj, y_pred_subj = [], []

        # Groupement par geste/itération pour ce sujet précis
        for (g, it), group in subj_df.groupby(["gesture", "iter"]):
            seq = group[["x_std", "y_std", "z_std"]].values.tolist()
            pred = knn_dtw_predict(seq, dict_train, k=k)
            y_true_subj.append(g)
            y_pred_subj.append(pred)

        acc_subj = accuracy_score(y_true_subj, y_pred_subj)
        print(f"Résultat Sujet {subj_id} : {acc_subj:.2%}")

        all_true.extend(y_true_subj)
        all_pred.extend(y_pred_subj)

    # Résultat Final
    print("-" * 30)
    print(f" PRÉCISION GLOBALE : {accuracy_score(all_true, all_pred):.2%}")



# Lancement
run_evaluation_by_subject(df100, TRAIN_SUBJECTS, TEST_SUBJECTS, k=7)
# Out:
# --- 1. Chargement : Train sur [6, 7, 8, 9, 10], Test sur [1, 2, 4, 5] ---
# Standardisation...
# /tmp/ipykernel_9053/3735933094.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling (100points)...
#
# --- Début des tests sur les sujets [1, 2, 4, 5] ---
# Résultat Sujet 1 : 100.00%
# Résultat Sujet 2 : 93.33%
# Résultat Sujet 4 : 96.67%
# Résultat Sujet 5 : 86.67%
# ------------------------------
#  PRÉCISION GLOBALE : 94.17%

# %% [markdown]
# # dtw tets final knn 5

# %%
import pandas as pd
import numpy as np
import os
from collections import Counter, defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import interp1d
import seaborn as sns



DOMAIN_FOLDER =r"\\student.fucam.ac.be\users$\isadiki\Downloads\Domain2base\DOMAIN2_CSVcorrigé"

df_list = []

print("--- Début du Chargement ---")
for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')

            try:

                file = pd.read_csv(filename, skiprows=5, header=None)

                if file.empty or file.shape[0] < 2:
                    continue


                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])


                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)


                file_df['gesture'] = int(number)
                file_df['subject'] = int(subject)
                file_df['iter'] = int(iteration)

                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(" Aucun fichier chargé. Vérifiez le chemin : " + DOMAIN_FOLDER)

df = pd.concat(df_list, ignore_index=True)
for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)





subdf = df.loc[(df['gesture'] == 0) & (df['subject'] == 10) & (df['iter'] == 1)]

if not subdf.empty:
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(subdf['x'], subdf['y'], subdf['z'], c='red', s=20)
    ax.set_title("Visualisation 3D du geste (Sujet 10, Geste 0, Iter 1)")
    ax.set_xlabel('X'); ax.set_ylabel('Y'); ax.set_zlabel('Z')
    plt.show()




durations = df.groupby(['gesture', 'iter'])['t'].agg(lambda x: x.max() - x.min()).reset_index(name='duration')
mean_durations = durations.groupby('gesture')['duration'].mean()
print("\n--- Durée moyenne des gestes (s) ---")
print(mean_durations)


mean_coords_user = df.groupby(['subject', 'gesture'])[['x', 'y', 'z']].mean().reset_index()
mean_coords_global = df.groupby('gesture')[['x', 'y', 'z']].mean().reset_index().rename(
    columns={'x':'x_global', 'y':'y_global', 'z':'z_global'})

merged = pd.merge(mean_coords_user, mean_coords_global, on='gesture')
merged['dist_to_global'] = np.sqrt((merged['x']-merged['x_global'])**2 +
                                   (merged['y']-merged['y_global'])**2 +
                                   (merged['z']-merged['z_global'])**2)

pivot = merged.pivot(index='subject', columns='gesture', values='dist_to_global')
plt.figure(figsize=(10, 6))
sns.heatmap(pivot, annot=True, fmt=".3f", cmap='Blues')
plt.title("Écart entre la moyenne de l'utilisateur et la moyenne globale")
plt.show()



def standardize_gesture(df_group):
    df_res = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_res[axis].std()
        df_res[f'{axis}_std'] = (df_res[axis] - df_res[axis].mean()) / std if std != 0 else 0
    return df_res

print("Standardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col], kind='linear')(target_idx)
        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len, 'subject': [subject] * target_len, 'iter': [iteration] * target_len,
            'x_std': interp('x_std'), 'y_std': interp('y_std'), 'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling...")
df100 = resample_gesture(df)



def eucl_dist(p1, p2):
    return np.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2 + (p1[2] - p2[2])**2)

def dtw_dist(seq1, seq2):
    n, m = len(seq1), len(seq2)
    dtw = np.full((n+1, m+1), np.inf)
    dtw[0, 0] = 0
    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = eucl_dist(seq1[i-1], seq2[j-1])
            dtw[i, j] = cost + min(dtw[i-1, j], dtw[i, j-1], dtw[i-1, j-1])
    return dtw[n, m]

def knn_dtw_predict(reference_seq, train_dict, k=3):
    distances = []
    for gesture, sequences in train_dict.items():
        for seq in sequences:
            dist = dtw_dist(reference_seq, seq)
            distances.append((gesture, dist))
    distances.sort(key=lambda x: x[1])
    k_nearest = distances[:k]
    votes = Counter([g for g, _ in k_nearest])
    return votes.most_common(1)[0][0]



def dict_creation_userout(df, subj_out):
    test_df = df[df["subject"] == subj_out]
    train_df = df[df["subject"] != subj_out]

    dict_train = defaultdict(list)
    dict_test = defaultdict(list)

    for (g, s, it), group in train_df.groupby(["gesture", "subject", "iter"]):
        dict_train[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())
    for (g, s, it), group in test_df.groupby(["gesture", "subject", "iter"]):
        dict_test[g].append(group[["x_std", "y_std", "z_std"]].values.tolist())
    return dict_train, dict_test

def testmodel(DictCreationFunc, df, loop_range=10, k=5):
    total_true, total_pred = [], []
    for i in range(1, loop_range + 1):
        print(f"\n--- Test Split OUT : {i} ---")
        coord_train, coord_test = DictCreationFunc(df, i)
        y_true, y_pred = [], []
        for gesture, sequences in coord_test.items():
            for seq in sequences:
                pred = knn_dtw_predict(seq, coord_train, k=k)
                y_true.append(gesture)
                y_pred.append(pred)

        acc = accuracy_score(y_true, y_pred)
        total_true.extend(y_true); total_pred.extend(y_pred)
        print(f"Précision split {i} : {acc:.2%}")

    print(f"\nPrécision GLOBALE : {accuracy_score(total_true, total_pred):.2%}")
    cm = confusion_matrix(total_true, total_pred)
    ConfusionMatrixDisplay(cm).plot(cmap="Blues")
    plt.title("Matrice de Confusion Finale")
    plt.show()


testmodel(dict_creation_userout, df100, loop_range=10, k=5)
# Out:
# --- Début du Chargement ---
# --- Durée moyenne des gestes (s) ---
# gesture
# 0    3980.0
# 1    3567.2
# 2    2570.5
# 3    4037.7
# 4    3087.1
# 5    5395.7
# 6    4499.0
# 7    4250.9
# 8    2463.7
# 9    3477.0
# Name: duration, dtype: float64
# Standardisation...
# C:\Users\Isadiki\AppData\Local\Temp\ipykernel_14072\894795356.py:104: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling...
#
# --- Test Split OUT : 1 ---
# Précision split 1 : 100.00%
#
# --- Test Split OUT : 2 ---
# Précision split 2 : 98.00%
#
# --- Test Split OUT : 3 ---
# Précision split 3 : 95.00%
#
# --- Test Split OUT : 4 ---
# Précision split 4 : 100.00%
#
# --- Test Split OUT : 5 ---
# Précision split 5 : 97.00%
#
# --- Test Split OUT : 6 ---
# Précision split 6 : 94.00%
#
# --- Test Split OUT : 7 ---
# Précision split 7 : 97.00%
#
# --- Test Split OUT : 8 ---
# Précision split 8 : 94.00%
#
# --- Test Split OUT : 9 ---
# Précision split 9 : 99.00%
#
# --- Test Split OUT : 10 ---
# Précision split 10 : 97.00%
#
# Précision GLOBALE : 97.10%

# %% [markdown]
# # lstm final 256 32 32

# %%
import pandas as pd
import numpy as np
import os
import shutil
import glob
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- 1. CONFIGURATION COLAB (MODIFIÉ) ---
# Assure-toi d'avoir uploadé DOMAIN2_CSVcorrig.zip dans Colab
zip_path = "/content/DOMAIN2_CSVcorrig.zip"
extract_path = "/content/temp_data"

if os.path.exists(zip_path):
    if os.path.exists(extract_path): shutil.rmtree(extract_path)
    os.makedirs(extract_path, exist_ok=True)
    # Décompression silencieuse
    print(f"📦 Extraction de {zip_path}...")
    # !unzip -o -q "{zip_path}" -d "{extract_path}"
else:
    raise FileNotFoundError(f"❌ Fichier {zip_path} introuvable. Upload-le dans Colab.")

# Détection automatique du dossier (pour éviter les erreurs de chemin Windows)
all_dirs = [d for d in glob.glob(os.path.join(extract_path, "**/"), recursive=True)
            if "__MACOSX" not in d and d != extract_path]
DOMAIN_FOLDER = max(all_dirs, key=len) if all_dirs else extract_path
DOMAIN_ID = 2

# --- 2. CHARGEMENT DES DONNÉES (TON CODE) ---
df_list = []
print(f"--- Début du Chargement du Domaine {DOMAIN_ID} ---")
print(f"Dossier source détecté : {DOMAIN_FOLDER}")

for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                # Lecture en sautant l'entête
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                # Nettoyage spécifique à ton format
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(" Aucun fichier n'a été chargé. Vérifiez le contenu du ZIP.")

df = pd.concat(df_list, ignore_index=True)
for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)




# --- 4. PRE-TRAITEMENT (TON CODE) ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

print("\nStandardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'),
            'y_std': interp('y_std'),
            'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling à longueur 100...")
df100 = resample_gesture(df)

# --- 5. MODÈLE & ÉVALUATION (TON CODE) ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, dropout=0.2, input_shape=input_shape),
        layers.LSTM(256, dropout=0.3),
        layers.Dense(32, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

def test_lstm_user_independent(df_data, epochs=50, batch_size=32):
    total_true, total_pred = [], []
    subjects = sorted(df_data['subject'].unique())

    for subj_out in subjects:
        print(f"\n--- Test subject OUT : {subj_out} ---")
        train_df = df_data[df_data['subject'] != subj_out]
        test_df = df_data[df_data['subject'] == subj_out]

        def df_to_array(df_target):
            X, y = [], []
            for (g, s, it), group in df_target.groupby(['gesture', 'subject', 'iter']):
                X.append(group[['x_std', 'y_std', 'z_std']].values)
                y.append(g)
            return np.array(X), np.array(y)

        X_train, y_train = df_to_array(train_df)
        X_test, y_test = df_to_array(test_df)

        model = create_lstm_model(input_shape=(100, 3), num_classes=10)
        model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)

        y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
        print(f"Exactitude subject {subj_out} : {accuracy_score(y_test, y_pred):.2%}")

        total_true.extend(y_test)
        total_pred.extend(y_pred)

    print(f"\n🎯 Exactitude globale LSTM : {accuracy_score(total_true, total_pred):.2%}")
    cm = confusion_matrix(total_true, total_pred)
    ConfusionMatrixDisplay(cm).plot(cmap="Blues")
    plt.show()

# Lancement final
test_lstm_user_independent(df100)
# Out:
# 📦 Extraction de /content/DOMAIN2_CSVcorrig.zip...
# --- Début du Chargement du Domaine 2 ---
# Dossier source détecté : /content/temp_data/DOMAIN2_CSVcorrig/
#
# Standardisation...
# /tmp/ipykernel_3199/2262805267.py:80: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling à longueur 100...
#
# --- Test subject OUT : 1 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3199/2262805267.py in <cell line: 0>()
#     148
#     149 # Lancement final
# --> 150 test_lstm_user_independent(df100)
#
# /tmp/ipykernel_3199/2262805267.py in test_lstm_user_independent(df_data, epochs, batch_size)
#     134
#     135         model = create_lstm_model(input_shape=(100, 3), num_classes=10)
# --> 136         model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)
#     137
#     138         y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397                 for begin_step, end_step, iterator in epoch_iterator:
#     398                     callbacks.on_train_batch_begin(begin_step)
# --> 399                     logs = self.train_function(iterator)
#     400                     callbacks.on_train_batch_end(end_step, logs)
#     401                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     239                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240             ):
# --> 241                 opt_outputs = multi_step_on_iterator(iterator)
#     242                 if not opt_outputs.has_value():
#     243                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
import os
import shutil
import glob
from collections import defaultdict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from tensorflow.keras import models, layers

# --- 1. CONFIGURATION COLAB (MODIFIÉ) ---
# Assure-toi d'avoir uploadé DOMAIN2_CSVcorrig.zip dans Colab
zip_path = "/content/DOMAIN2_CSVcorrig.zip"
extract_path = "/content/temp_data"

if os.path.exists(zip_path):
    if os.path.exists(extract_path): shutil.rmtree(extract_path)
    os.makedirs(extract_path, exist_ok=True)
    # Décompression silencieuse
    #print(f"📦 Extraction de {zip_path}...")
    # !unzip -o -q "{zip_path}" -d "{extract_path}"
else:
    raise FileNotFoundError(f" Fichier {zip_path} introuvable. Upload-le dans Colab.")

# Détection automatique du dossier (pour éviter les erreurs de chemin Windows)
all_dirs = [d for d in glob.glob(os.path.join(extract_path, "**/"), recursive=True)
            if "__MACOSX" not in d and d != extract_path]
DOMAIN_FOLDER = max(all_dirs, key=len) if all_dirs else extract_path
DOMAIN_ID = 2

# --- 2. CHARGEMENT DES DONNÉES (TON CODE) ---
df_list = []
print(f"--- Début du Chargement du Domaine {DOMAIN_ID} ---")


for subject in range(1, 11):
    for number in range(0, 10):
        for iteration in range(1, 11):
            filename = os.path.join(DOMAIN_FOLDER, f'Subject{subject}-{number}-{iteration}.csv')
            try:
                # Lecture en sautant l'entête
                file = pd.read_csv(filename, skiprows=5, header=None)
                if file.empty or file.shape[0] < 2: continue

                # Nettoyage spécifique à ton format
                data = file[0].str.strip('"').str.split(',', expand=True)
                file_df = pd.DataFrame(data.iloc[:, :4].values, columns=['x', 'y', 'z', 't'])

                for col in ['x', 'y', 'z', 't']:
                    file_df[col] = pd.to_numeric(file_df[col], errors='coerce')
                file_df.dropna(subset=['x', 'y', 'z', 't'], inplace=True)

                file_df['gesture'] = number
                file_df['subject'] = subject
                file_df['iter'] = iteration
                df_list.append(file_df)
            except:
                continue

if not df_list:
    raise ValueError(" Aucun fichier n'a été chargé. Vérifiez le contenu du ZIP.")

df = pd.concat(df_list, ignore_index=True)
for col in ['gesture', 'subject', 'iter']:
    df[col] = df[col].astype(int)


# --- 3. ANALYSE EXPLORATOIRE (TON CODE) ---
print("\n--- 2. Analyse Exploratoire ---")
grouped = df.groupby(['gesture', 'iter'])
sequence_lengths = grouped.size().reset_index(name='length')
mean_lengths = sequence_lengths.groupby('gesture')['length'].mean().reset_index()
mean_lengths.columns = ['Chiffre', 'Frames moyennes']

plt.figure(figsize=(8, 5))
plt.bar(mean_lengths["Chiffre"], mean_lengths["Frames moyennes"])
plt.title("Nombre moyen de coordonnées par chiffre")
plt.xlabel("Chiffre"); plt.ylabel("Nombre"); plt.show()

# --- 4. PRE-TRAITEMENT (TON CODE) ---
def standardize_gesture(df_group):
    df_copy = df_group.copy()
    for axis in ['x', 'y', 'z']:
        std = df_copy[axis].std()
        df_copy[f'{axis}_std'] = (df_copy[axis] - df_copy[axis].mean()) / std if std > 0 else 0.0
    return df_copy

print("\nStandardisation...")
df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)

def resample_gesture(df_in, target_len=100):
    resampled_data = []
    for (gesture, subject, iteration), group in df_in.groupby(['gesture', 'subject', 'iter']):
        n = len(group)
        if n < 2: continue
        original_idx = np.arange(n)
        target_idx = np.linspace(0, n - 1, target_len)
        interp = lambda col: interp1d(original_idx, group[col].values, kind='linear', fill_value="extrapolate")(target_idx)

        resampled_data.append(pd.DataFrame({
            'gesture': [gesture] * target_len,
            'subject': [subject] * target_len,
            'iter': [iteration] * target_len,
            'x_std': interp('x_std'),
            'y_std': interp('y_std'),
            'z_std': interp('z_std')
        }))
    return pd.concat(resampled_data, ignore_index=True)

print("Resampling à longueur 100...")
df100 = resample_gesture(df)

# --- 5. MODÈLE & ÉVALUATION (TON CODE) ---
def create_lstm_model(input_shape, num_classes):
    model = models.Sequential([
        layers.LSTM(256, return_sequences=True, dropout=0.2, input_shape=input_shape),
        layers.LSTM(256, dropout=0.3),
        layers.Dense(32, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

def test_lstm_user_independent(df_data, epochs=50, batch_size=32):
    total_true, total_pred = [], []
    subjects = sorted(df_data['subject'].unique())

    for subj_out in subjects:
        print(f"\n--- Test subject OUT : {subj_out} ---")
        train_df = df_data[df_data['subject'] != subj_out]
        test_df = df_data[df_data['subject'] == subj_out]

        def df_to_array(df_target):
            X, y = [], []
            for (g, s, it), group in df_target.groupby(['gesture', 'subject', 'iter']):
                X.append(group[['x_std', 'y_std', 'z_std']].values)
                y.append(g)
            return np.array(X), np.array(y)

        X_train, y_train = df_to_array(train_df)
        X_test, y_test = df_to_array(test_df)

        model = create_lstm_model(input_shape=(100, 3), num_classes=10)
        model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)

        y_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)
        print(f"Exactitude subject {subj_out} : {accuracy_score(y_test, y_pred):.2%}")

        total_true.extend(y_test)
        total_pred.extend(y_pred)

    print(f"\n Exactitude globale LSTM : {accuracy_score(total_true, total_pred):.2%}")
    cm = confusion_matrix(total_true, total_pred)
    ConfusionMatrixDisplay(cm).plot(cmap="Blues")
    plt.show()

# Lancement final
test_lstm_user_independent(df100)
# Out:
# --- Début du Chargement du Domaine 2 ---
#
# --- 2. Analyse Exploratoire ---
# Standardisation...
# /tmp/ipykernel_3199/87024163.py:90: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby(['subject', 'gesture', 'iter'], group_keys=False).apply(standardize_gesture)
# Resampling à longueur 100...
#
# --- Test subject OUT : 1 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 1 : 96.00%
#
# --- Test subject OUT : 2 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 2 : 92.00%
#
# --- Test subject OUT : 3 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7af7aff0d580> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7af7aff0d580> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exactitude subject 3 : 93.00%
#
# --- Test subject OUT : 4 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 4 : 98.00%
#
# --- Test subject OUT : 5 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 5 : 95.00%
#
# --- Test subject OUT : 6 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 6 : 99.00%
#
# --- Test subject OUT : 7 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 7 : 93.00%
#
# --- Test subject OUT : 8 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 8 : 100.00%
#
# --- Test subject OUT : 9 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 9 : 98.00%
#
# --- Test subject OUT : 10 ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Exactitude subject 10 : 89.00%
#
#  Exactitude globale LSTM : 95.30%
